# %% [markdown]
# # Modul 2_1 Aufgabe

# %%
import pandas as pd
import requests

# %%
#import json

# url = "https://www.bibsonomy.org/json/search/database?items=1000&duplicates=merged"
# result = requests.get(url) # result ist ein requests.models.Response Objekt
# data = result.json() # das Response-Objekt bietet diese nützliche Methode an
# df_bib_pd = pd.DataFrame(data["items"])

#data1 = json.load(open("data/database.json"))
#data2 = json.load(open("data/archive.json"))
#df_search1 = pd.DataFrame(data1["items"])
#df_search2 = pd.DataFrame(data2["items"])
#df = pd.concat([df_search1, df_search2])"""

# data = data.loc[data.type == "Publication"]

# %%
url_base = "https://www.bibsonomy.org/json/search/"
url_attr = "?items=1000"

# %%
def df_from_query(query):
    url = url_base + query.replace(" ", "%20") + url_attr  
    result = requests.get(url)
    json_data = result.json()
    dataframe = pd.DataFrame(json_data["items"])
    dataframe["query"] = query
    return dataframe

# %%
dataframes = []
queries = ["database", "text", "library", "archive"]

for q in queries:
    df = df_from_query(q)
    dataframes.append(df)
    print(f"{len(df)} Ergebnisse für query {q} gefunden.")
# Out:
# 2000 Ergebnisse für query database gefunden.
# 2000 Ergebnisse für query text gefunden.
# 2000 Ergebnisse für query library gefunden.
# 2000 Ergebnisse für query archive gefunden.

# %%
data = pd.concat(dataframes, ignore_index=True)

# %%
data
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/cc45493bf442b78d...
# 1        Bookmark  https://www.bibsonomy.org/url/61474ed79d5c3f63...
# 2        Bookmark  https://www.bibsonomy.org/url/3cd373dd8ed9c534...
# 3        Bookmark  https://www.bibsonomy.org/url/cc45493bf442b78d...
# 4        Bookmark  https://www.bibsonomy.org/url/2f5f76391c720a9b...
# ...           ...                                                ...
# 7995  Publication  https://www.bibsonomy.org/bibtex/2040f345d94cd...
# 7996  Publication  https://www.bibsonomy.org/bibtex/28217f4fe9f6a...
# 7997  Publication  https://www.bibsonomy.org/bibtex/29994ea45725f...
# 7998  Publication  https://www.bibsonomy.org/bibtex/2ee55445bc456...
# 7999  Publication  https://www.bibsonomy.org/bibtex/2dc534ef1b015...
#
#                                                    tags  \
# 0     [web2.0, database, desktop, aggregator, daily,...
# 1     [tool, database, 3403, Error, Fix,, recovery,,...
# 2           [Article(s), Design, Database, Information]
# 3     [web2.0, 2007, database, socialsoftware, tools...
# 4                                           [databases]
# ...                                                 ...
# 7995                                             [dblp]
# 7996                                             [dblp]
# 7997                                             [dblp]
# 7998                                             [dblp]
# 7999                                             [dblp]
#
#                              intraHash  \
# 0     cc45493bf442b78d923b0b1b9342676b
# 1     61474ed79d5c3f63c1d0b6dcd8c653f5
# 2     3cd373dd8ed9c53483d39eaa928686f6
# 3     cc45493bf442b78d923b0b1b9342676b
# 4     2f5f76391c720a9b688f60ec6f900f1d
# ...                                ...
# 7995  040f345d94cd5d5e6c4e6a2ca7d2f43e
# 7996  8217f4fe9f6a3929c0d365d35447be84
# 7997  9994ea45725f4b521a1ca2da5f6b1bae
# 7998  ee55445bc456b80407d888fe2948f6a1
# 7999  dc534ef1b01530bf66755fb1a8eaa51a
#
#                                                   label       user  \
# 0                                   Office 2.0 Database  springnet
# 1                           SQL Database 3403 Error Fix  traktools
# 2                                     Database Sharding      panic
# 3                                   Office 2.0 Database       akpe
# 4                      Encyclopedia of Database Systems   ludaesch
# ...                                                 ...        ...
# 7995  Faculty self-archiving behavior: Factors affec...       dblp
# 7996  Sensitivity and Access: Unlocking the Colonial...       dblp
# 7997  Online hot topic detection from web news archi...       dblp
# 7998  Serge Modular Archive Instrument (SMAI): Bridg...       dblp
# 7999  The peer-to-peer trace archive: design and com...       dblp
#
#                                             description                 date  \
# 0                                   Office 2.0 Database  2006-04-19 19:49:42
# 1     SysTools Software releases an effective SQL da...  2009-09-15 19:13:52
# 2     The term "sharding" was coined by Google engin...  2011-10-01 02:24:14
# 3     Overview of roughly 250 Web 2.0 applications, ...  2007-03-14 20:26:50
# 4                      Encyclopedia of Database Systems  2007-02-08 11:20:08
# ...                                                 ...                  ...
# 7995                                                     2020-06-24 00:00:00
# 7996                                                     2024-08-08 00:00:00
# 7997                                                     2021-09-19 00:00:00
# 7998                                                     2024-09-16 00:00:00
# 7999                                                     2024-05-07 00:00:00
#
#                changeDate  count  ... attachments categories url_pdf data  \
# 0     2008-06-29 17:52:49     13  ...         NaN        NaN     NaN  NaN
# 1     2009-09-15 19:13:52      1  ...         NaN        NaN     NaN  NaN
# 2     2011-10-01 02:27:38      1  ...         NaN        NaN     NaN  NaN
# 3     2011-03-14 16:42:58     13  ...         NaN        NaN     NaN  NaN
# 4     2007-09-26 06:23:20      1  ...         NaN        NaN     NaN  NaN
# ...                   ...    ...  ...         ...        ...     ...  ...
# 7995  2024-04-10 00:42:34      1  ...         NaN        NaN     NaN  NaN
# 7996  2024-08-12 07:04:36      1  ...         NaN        NaN     NaN  NaN
# 7997  2024-04-10 19:24:49      1  ...         NaN        NaN     NaN  NaN
# 7998  2024-09-23 07:12:24      1  ...         NaN        NaN     NaN  NaN
# 7999  2024-05-13 10:00:25      1  ...         NaN        NaN     NaN  NaN
#
#      online titleaddon refnum in-text-citation w-type w-projects
# 0       NaN        NaN    NaN              NaN    NaN        NaN
# 1       NaN        NaN    NaN              NaN    NaN        NaN
# 2       NaN        NaN    NaN              NaN    NaN        NaN
# 3       NaN        NaN    NaN              NaN    NaN        NaN
# 4       NaN        NaN    NaN              NaN    NaN        NaN
# ...     ...        ...    ...              ...    ...        ...
# 7995    NaN        NaN    NaN              NaN    NaN        NaN
# 7996    NaN        NaN    NaN              NaN    NaN        NaN
# 7997    NaN        NaN    NaN              NaN    NaN        NaN
# 7998    NaN        NaN    NaN              NaN    NaN        NaN
# 7999    NaN        NaN    NaN              NaN    NaN        NaN
#
# [8000 rows x 200 columns]

# %%
data.columns
# Out:
# Index(['type', 'id', 'tags', 'intraHash', 'label', 'user', 'description',
#        'date', 'changeDate', 'count',
#        ...
#        'attachments', 'categories', 'url_pdf', 'data', 'online', 'titleaddon',
#        'refnum', 'in-text-citation', 'w-type', 'w-projects'],
#       dtype='object', length=200)

# %%
df_filtered = data[['label', 'id', 'type', 'url', 'year', 'author', 'doi', 'query']]

# %%
df_filtered = df_filtered.loc[data.type == "Publication"]

# %%
df_filtered
# Out:
#                                                   label  \
# 1000  EcoliNet: a database of cofunctional gene netw...
# 1001  The drug-minded protein interaction database (...
# 1002  PhosphoGRID: a database of experimentally veri...
# 1003  GoSynthetic database tool to analyse natural a...
# 1004                    Database for Mobile Application
# ...                                                 ...
# 7995  Faculty self-archiving behavior: Factors affec...
# 7996  Sensitivity and Access: Unlocking the Colonial...
# 7997  Online hot topic detection from web news archi...
# 7998  Serge Modular Archive Instrument (SMAI): Bridg...
# 7999  The peer-to-peer trace archive: design and com...
#
#                                                      id         type  \
# 1000  https://www.bibsonomy.org/bibtex/2750b8770eec8...  Publication
# 1001  https://www.bibsonomy.org/bibtex/2d93ac9b6cfa6...  Publication
# 1002  https://www.bibsonomy.org/bibtex/233d3effaf95a...  Publication
# 1003  https://www.bibsonomy.org/bibtex/2ca6461cce248...  Publication
# 1004  https://www.bibsonomy.org/bibtex/2eb1605409b13...  Publication
# ...                                                 ...          ...
# 7995  https://www.bibsonomy.org/bibtex/2040f345d94cd...  Publication
# 7996  https://www.bibsonomy.org/bibtex/28217f4fe9f6a...  Publication
# 7997  https://www.bibsonomy.org/bibtex/29994ea45725f...  Publication
# 7998  https://www.bibsonomy.org/bibtex/2ee55445bc456...  Publication
# 7999  https://www.bibsonomy.org/bibtex/2dc534ef1b015...  Publication
#
#                                                     url  year  \
# 1000          http://dx.doi.org/10.1093/database/bav001  2015
# 1001          http://dx.doi.org/10.1093/database/baw041  2016
# 1002          http://dx.doi.org/10.1093/database/bap026  2010
# 1003          http://dx.doi.org/10.1093/database/bat043  2013
# 1004  http://www.ijtsrd.com/computer-science/databas...  2018
# ...                                                 ...   ...
# 7995  http://dblp.uni-trier.de/db/conf/asist/asist20...  2007
# 7996  http://dblp.uni-trier.de/db/journals/dhq/dhq18...  2024
# 7997  http://dblp.uni-trier.de/db/conf/fskd/fskd2014...  2014
# 7998  http://dblp.uni-trier.de/db/conf/nime/nime2023...  2023
# 7999  http://dblp.uni-trier.de/db/conf/conext/sw2010...  2010
#
#                                                  author  \
# 1000  [Hanhae Kim, Jung Eun E. Shim, Junha Shin, Ins...
# 1001  [Meik Kunz, Chunguang Liang, Santosh Nilla, Al...
# 1002  [Chris Stark, Ting-Cheng C. Su, Ashton Breitkr...
# 1003                 [C. Liang, B. Kruger, T. Dandekar]
# 1004                   [Jasra Nisar Owais Noor Trumboo]
# ...                                                 ...
# 7995                                       [Jihyun Kim]
# 7996  [Jonathan Dentler, Lise Jaillant, Daniel Folia...
# 7997     [RuiGuo Yu, Mankun Zhao, Peng Chang, MuWen He]
# 7998                          [Ted Moore, Jean Brazeau]
# 7999  [Boxun Zhang, Alexandru Iosup, Johan Pouwelse,...
#
#                           doi     query
# 1000  10.1093/database/bav001  database
# 1001  10.1093/database/baw041  database
# 1002  10.1093/database/bap026  database
# 1003  10.1093/database/bat043  database
# 1004                      NaN  database
# ...                       ...       ...
# 7995                      NaN   archive
# 7996                      NaN   archive
# 7997                      NaN   archive
# 7998                      NaN   archive
# 7999                      NaN   archive
#
# [4000 rows x 8 columns]

# %%
df_filtered["year"].unique()
# Out:
# array(['2015', '2016', '2010', '2013', '2018', '2005', '2019', '2009',
#        '1984', '2011', '2014', '2007', '1990', '2006', '1988', '1986',
#        '2017', '2000', '2023', '2004', '1998', '2003', '2008', '2012',
#        '2001', '2024', '2021', '2022', '1987', '1999', '2020', '1993',
#        '1996', '2002', '1976', '1995', '1980', '1983', '1991', '1994',
#        '1997', '1992', '1978', '1985', '1981', '1977', '1989', '1979',
#        '{1998}', '1982', '1972', '2006-2012', '19980301', 'o.J.', 'test',
#        '1970', '2002 ', ' 2010 ', 'Test-Year', '1931', '1887',
#        'August 2007', '1900', '1974', '20-13', 'November 2015', '1946',
#        '1973', '2010 ', ' 2000 ', '1975', 'u.å.', '2001ff', '1953',
#        '5555', '1938--1957', '1960', '2004/9', '1961', '2001?', '1971',
#        '1962', '1957', '1956', '1952', '2009, updated July 2010', '1876',
#        '1964', 'Accessed: 20-01-2005', '99', 'November 26th, 2006',
#        '1869', 'n.a.', 'n.d.', '1955', '2025', '1898', '1901'],
#       dtype=object)

# %%
df_filtered["year_correct"] = df_filtered.apply(lambda row: row.year.isdigit(), axis=1)
df_filtered = df_filtered.loc[df_filtered.year_correct == True]

# %%
df_filtered["year"].unique()
# Out:
# array(['2015', '2016', '2010', '2013', '2018', '2005', '2019', '2009',
#        '1984', '2011', '2014', '2007', '1990', '2006', '1988', '1986',
#        '2017', '2000', '2023', '2004', '1998', '2003', '2008', '2012',
#        '2001', '2024', '2021', '2022', '1987', '1999', '2020', '1993',
#        '1996', '2002', '1976', '1995', '1980', '1983', '1991', '1994',
#        '1997', '1992', '1978', '1985', '1981', '1977', '1989', '1979',
#        '1982', '1972', '19980301', '1970', '1931', '1887', '1900', '1974',
#        '1946', '1973', '1975', '1953', '5555', '1960', '1961', '1971',
#        '1962', '1957', '1956', '1952', '1876', '1964', '99', '1869',
#        '1955', '2025', '1898', '1901'], dtype=object)

# %%
#delete_row = df_filtered.loc[df_filtered['year'] == '5555'].index
#df_filtered.drop(delete_row, inplace=True, axis="index")
# Out:
# /var/folders/88/9blsh45918g8y3n5vl6vztxr0000gq/T/ipykernel_1605/51856490.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered.drop(delete_row, inplace=True, axis="index")

# %%
df_filtered["year"].unique()
# Out:
# array(['2015', '2016', '2010', '2013', '2018', '2005', '2019', '2009',
#        '1984', '2011', '2014', '2007', '1990', '2006', '1988', '1986',
#        '2017', '2000', '2023', '2004', '1998', '2003', '2008', '2012',
#        '2001', '2024', '2021', '2022', '1987', '1999', '2020', '1993',
#        '1996', '2002', '1976', '1995', '1980', '1983', '1991', '1994',
#        '1997', '1992', '1978', '1985', '1981', '1977', '1989', '1979',
#        '1982', '1972', '1970', '1931', '1887', '1900', '1974', '1946',
#        '1973', '1975', '1953', '1960', '1961', '1971', '1962', '1957',
#        '1956', '1952', '1876', '1964', '99', '1869', '1955', '2025',
#        '1898', '1901'], dtype=object)

# %%
df_filtered = df_filtered.loc[df_filtered["author"].isnull() == False]
df_filtered = df_filtered.drop_duplicates(subset = "label", keep ="first")
df_filtered = df_filtered.rename(columns={"label": "title", "author": "authors"})

# %%
df_filtered.groupby("year").count().title
# Out:
# year
# 1869      1
# 1876      1
# 1898      1
# 1900      3
# 1901      1
#        ...
# 2022    123
# 2023    109
# 2024    127
# 2025      1
# 99        1
# Name: title, Length: 72, dtype: int64

# %%
df_filtered = df_filtered.drop("year_correct", axis=1)

# %%
df_filtered["editor"] = "Jannik Ott"

# %%
df_filtered
# Out:
#                                                   title  \
# 1000  EcoliNet: a database of cofunctional gene netw...
# 1001  The drug-minded protein interaction database (...
# 1002  PhosphoGRID: a database of experimentally veri...
# 1003  GoSynthetic database tool to analyse natural a...
# 1004                    Database for Mobile Application
# ...                                                 ...
# 7995  Faculty self-archiving behavior: Factors affec...
# 7996  Sensitivity and Access: Unlocking the Colonial...
# 7997  Online hot topic detection from web news archi...
# 7998  Serge Modular Archive Instrument (SMAI): Bridg...
# 7999  The peer-to-peer trace archive: design and com...
#
#                                                      id         type  \
# 1000  https://www.bibsonomy.org/bibtex/2750b8770eec8...  Publication
# 1001  https://www.bibsonomy.org/bibtex/2d93ac9b6cfa6...  Publication
# 1002  https://www.bibsonomy.org/bibtex/233d3effaf95a...  Publication
# 1003  https://www.bibsonomy.org/bibtex/2ca6461cce248...  Publication
# 1004  https://www.bibsonomy.org/bibtex/2eb1605409b13...  Publication
# ...                                                 ...          ...
# 7995  https://www.bibsonomy.org/bibtex/2040f345d94cd...  Publication
# 7996  https://www.bibsonomy.org/bibtex/28217f4fe9f6a...  Publication
# 7997  https://www.bibsonomy.org/bibtex/29994ea45725f...  Publication
# 7998  https://www.bibsonomy.org/bibtex/2ee55445bc456...  Publication
# 7999  https://www.bibsonomy.org/bibtex/2dc534ef1b015...  Publication
#
#                                                     url  year  \
# 1000          http://dx.doi.org/10.1093/database/bav001  2015
# 1001          http://dx.doi.org/10.1093/database/baw041  2016
# 1002          http://dx.doi.org/10.1093/database/bap026  2010
# 1003          http://dx.doi.org/10.1093/database/bat043  2013
# 1004  http://www.ijtsrd.com/computer-science/databas...  2018
# ...                                                 ...   ...
# 7995  http://dblp.uni-trier.de/db/conf/asist/asist20...  2007
# 7996  http://dblp.uni-trier.de/db/journals/dhq/dhq18...  2024
# 7997  http://dblp.uni-trier.de/db/conf/fskd/fskd2014...  2014
# 7998  http://dblp.uni-trier.de/db/conf/nime/nime2023...  2023
# 7999  http://dblp.uni-trier.de/db/conf/conext/sw2010...  2010
#
#                                                 authors  \
# 1000  [Hanhae Kim, Jung Eun E. Shim, Junha Shin, Ins...
# 1001  [Meik Kunz, Chunguang Liang, Santosh Nilla, Al...
# 1002  [Chris Stark, Ting-Cheng C. Su, Ashton Breitkr...
# 1003                 [C. Liang, B. Kruger, T. Dandekar]
# 1004                   [Jasra Nisar Owais Noor Trumboo]
# ...                                                 ...
# 7995                                       [Jihyun Kim]
# 7996  [Jonathan Dentler, Lise Jaillant, Daniel Folia...
# 7997     [RuiGuo Yu, Mankun Zhao, Peng Chang, MuWen He]
# 7998                          [Ted Moore, Jean Brazeau]
# 7999  [Boxun Zhang, Alexandru Iosup, Johan Pouwelse,...
#
#                           doi     query      editor
# 1000  10.1093/database/bav001  database  Jannik Ott
# 1001  10.1093/database/baw041  database  Jannik Ott
# 1002  10.1093/database/bap026  database  Jannik Ott
# 1003  10.1093/database/bat043  database  Jannik Ott
# 1004                      NaN  database  Jannik Ott
# ...                       ...       ...         ...
# 7995                      NaN   archive  Jannik Ott
# 7996                      NaN   archive  Jannik Ott
# 7997                      NaN   archive  Jannik Ott
# 7998                      NaN   archive  Jannik Ott
# 7999                      NaN   archive  Jannik Ott
#
# [3520 rows x 9 columns]

# %%
df_filtered.to_json("data/output.json", orient="records")

# %%
# check, if it looks correct
with open("data/output.json", "r") as f:
    j_load = json.load(f)
    print(json.dumps(j_load, indent=2))
# Out:
# [
#   {
#     "title": "EcoliNet: a database of cofunctional gene network for Escherichia coli.",
#     "id": "https://www.bibsonomy.org/bibtex/2750b8770eec83ca7d18107df3d520113/karthikraman",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1093/database/bav001",
#     "year": "2015",
#     "authors": [
#       "Hanhae Kim",
#       "Jung Eun E. Shim",
#       "Junha Shin",
#       "Insuk Lee"
#     ],
#     "doi": "10.1093/database/bav001",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "The drug-minded protein interaction database (DrumPID) for efficient target analysis and drug development.",
#     "id": "https://www.bibsonomy.org/bibtex/2d93ac9b6cfa60505ee7b3d7ffefca15f/karthikraman",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1093/database/baw041",
#     "year": "2016",
#     "authors": [
#       "Meik Kunz",
#       "Chunguang Liang",
#       "Santosh Nilla",
#       "Alexander Cecil",
#       "Thomas Dandekar"
#     ],
#     "doi": "10.1093/database/baw041",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "PhosphoGRID: a database of experimentally verified in vivo protein phosphorylation sites from the budding yeast Saccharomyces cerevisiae.",
#     "id": "https://www.bibsonomy.org/bibtex/233d3effaf95a6d714a6fb06099bdf647/karthikraman",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1093/database/bap026",
#     "year": "2010",
#     "authors": [
#       "Chris Stark",
#       "Ting-Cheng C. Su",
#       "Ashton Breitkreutz",
#       "Pedro Lourenco",
#       "Matthew Dahabieh",
#       "Bobby-Joe J. Breitkreutz",
#       "Mike Tyers",
#       "Ivan Sadowski"
#     ],
#     "doi": "10.1093/database/bap026",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "GoSynthetic database tool to analyse natural and engineered molecular processes",
#     "id": "https://www.bibsonomy.org/bibtex/2ca6461cce248858567237c85cca8f378/evp66rk",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1093/database/bat043",
#     "year": "2013",
#     "authors": [
#       "C. Liang",
#       "B. Kruger",
#       "T. Dandekar"
#     ],
#     "doi": "10.1093/database/bat043",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Database for Mobile Application",
#     "id": "https://www.bibsonomy.org/bibtex/2eb1605409b134cc14adb1c45bc1bd3b0/ijtsrd",
#     "type": "Publication",
#     "url": "http://www.ijtsrd.com/computer-science/database/11215/database-for-mobile-application/jasra-nisar",
#     "year": "2018",
#     "authors": [
#       "Jasra Nisar Owais Noor Trumboo"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "An international otology database",
#     "id": "https://www.bibsonomy.org/bibtex/25f85238089c4a2ec183b243bf83fa523/stevenarild",
#     "type": "Publication",
#     "url": "http://www.ncbi.nlm.nih.gov.ep.fjernadgang.kb.dk/pubmed/?term=yung+gjuric+haeusler",
#     "year": "2005",
#     "authors": [
#       "M Yung",
#       "M Gjuric",
#       "R Haeusler",
#       "P H Van de Heyning",
#       "C Martin",
#       "I R Swan",
#       "R A Tange",
#       "P T Huy",
#       " European Otology Database Project Group"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Enable Auditing in Oracle database",
#     "id": "https://www.bibsonomy.org/bibtex/27757584ce817952545d28d956896ba6a/ijtsrd",
#     "type": "Publication",
#     "url": "https://www.ijtsrd.com/computer-science/database/29881/enable-auditing-in-oracle-database/amrish-srivastava",
#     "year": "2019",
#     "authors": [
#       "Amrish Srivastava"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Database and database application security",
#     "id": "https://www.bibsonomy.org/bibtex/2b8151c596a8d3eb7e7233f1a47d53b08/malte.wunsch",
#     "type": "Publication",
#     "url": "http://portal.acm.org/citation.cfm?id=1562877.1562909",
#     "year": "2009",
#     "authors": [
#       "Huwida E. Said",
#       "Mario A. Guimaraes",
#       "Zakaria Maamar",
#       "Leon Jololian"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Vertical partitioning algorithms for database design",
#     "id": "https://www.bibsonomy.org/bibtex/281eb5e7b67cc969365c65a67721cb495/joergh",
#     "type": "Publication",
#     "url": "http://portal.acm.org/citation.cfm?id=1994.2209",
#     "year": "1984",
#     "authors": [
#       "Shamkant Navathe",
#       "Stefano Ceri",
#       "Gio Wiederhold",
#       "Jinglie Dou"
#     ],
#     "doi": "http://doi.acm.org/10.1145/1994.2209",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "The Reactome BioMart.",
#     "id": "https://www.bibsonomy.org/bibtex/206ba5aaa99967712038c684d1864c421/karthikraman",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1093/database/bar031",
#     "year": "2011",
#     "authors": [
#       "Robin A. Haw",
#       "David Croft",
#       "Christina K. Yung",
#       "Nelson Ndegwa",
#       "Peter D'Eustachio",
#       "Henning Hermjakob",
#       "Lincoln D. Stein"
#     ],
#     "doi": "10.1093/database/bar031",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "WholeCellSimDB: a hybrid relational/HDF database for whole-cell model predictions.",
#     "id": "https://www.bibsonomy.org/bibtex/235a7f0439923ab61281f80bb4fbe77c9/karthikraman",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1093/database/bau095",
#     "year": "2014",
#     "authors": [
#       "Jonathan R. Karr",
#       "Nolan C. Phillips",
#       "Markus W. Covert"
#     ],
#     "doi": "10.1093/database/bau095",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Oracle Database Backup Testing",
#     "id": "https://www.bibsonomy.org/bibtex/23300b9d02e6150493d24278d652fd980/ijtsrd",
#     "type": "Publication",
#     "url": "http://www.ijtsrd.com/computer-science/database/11572/oracle-database-backup-testing/vijay-kumar-tiwari",
#     "year": "2018",
#     "authors": [
#       "Vijay Kumar Tiwari"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Implications of certain assumptions in database performance evauation",
#     "id": "https://www.bibsonomy.org/bibtex/2a8e950024e05fb6206578bb5a3c4d44a/jhammerb",
#     "type": "Publication",
#     "url": "http://portal.acm.org/citation.cfm?doid=329.318578",
#     "year": "1984",
#     "authors": [
#       "S. Christodoulakis"
#     ],
#     "doi": "http://doi.acm.org/10.1145/329.318578",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "A standardized database management of middle ear surgery in Korea",
#     "id": "https://www.bibsonomy.org/bibtex/24d001da0c68be5efe71702f9ecc2e4f2/stevenarild",
#     "type": "Publication",
#     "url": "http://www.ncbi.nlm.nih.gov.ep.fjernadgang.kb.dk/pubmed/?term=kim+hj+a+standardized+database+management",
#     "year": "2007",
#     "authors": [
#       "H J Kim"
#     ],
#     "doi": "10.1080/03655230701624871",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "SwissRegulon, a database of genome-wide annotations of regulatory sites: recent updates",
#     "id": "https://www.bibsonomy.org/bibtex/2e15360b1fc6345c1913a65b3112680fd/karthikraman",
#     "type": "Publication",
#     "url": "https://www.ncbi.nlm.nih.gov/pubmed/?term=SwissRegulon%2C+a+database+of+genome-wide+annotations+of+regulatory+sites%3A+recent+updates",
#     "year": "2013",
#     "authors": [
#       "M Pachkov",
#       "P J Balwierz",
#       "P Arnold",
#       "E Ozonov",
#       "E van Nimwegen"
#     ],
#     "doi": "10.1093/nar/gks1145",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "ConsensusPathDB--a database for integrating human functional interaction networks",
#     "id": "https://www.bibsonomy.org/bibtex/22b7406cd1753f56e5a06ae8b48b24cdf/wnpxrz",
#     "type": "Publication",
#     "url": "http://www.ncbi.nlm.nih.gov/pubmed/18940869",
#     "year": "2009",
#     "authors": [
#       "A Kamburov",
#       "C Wierling",
#       "H Lehrach",
#       "R Herwig"
#     ],
#     "doi": "10.1093/nar/gkn698",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "PID: the Pathway Interaction Database",
#     "id": "https://www.bibsonomy.org/bibtex/250055d426be1ad08439d9523ae3c83d1/wnpxrz",
#     "type": "Publication",
#     "url": "http://www.ncbi.nlm.nih.gov/pubmed/18832364",
#     "year": "2009",
#     "authors": [
#       "C F Schaefer",
#       "K Anthony",
#       "S Krupa",
#       "J Buchoff",
#       "M Day",
#       "T Hannay",
#       "K H Buetow"
#     ],
#     "doi": "10.1093/nar/gkn653",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Parallel database systems: the future of database processing or a passing fad?",
#     "id": "https://www.bibsonomy.org/bibtex/28af31bbdb0bde12ef6965492973f4831/jhammerb",
#     "type": "Publication",
#     "url": "http://portal.acm.org/citation.cfm?id=122058.122071",
#     "year": "1990",
#     "authors": [
#       "David J. DeWitt",
#       "Jim Gray"
#     ],
#     "doi": "http://doi.acm.org/10.1145/122058.122071",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "The HUGO Gene Nomenclature Database, 2006 updates",
#     "id": "https://www.bibsonomy.org/bibtex/29b3aa72d312bf8a3e038ca92b6612fcd/sbsad",
#     "type": "Publication",
#     "url": "http://www.ncbi.nlm.nih.gov/pubmed/16381876",
#     "year": "2006",
#     "authors": [
#       "T A Eyre",
#       "F Ducluzeau",
#       "T P Sneddon",
#       "S Povey",
#       "E A Bruford",
#       "M J Lush"
#     ],
#     "doi": "10.1093/nar/gkj147",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Traditional Databases vs NOSQL",
#     "id": "https://www.bibsonomy.org/bibtex/2a25665734dddc3bd249a981cd424fc74/ijtsrd",
#     "type": "Publication",
#     "url": "http://www.ijtsrd.com/computer-science/database/12961/traditional-databases-vs-nosql/owais-noor-trumboo",
#     "year": "2018",
#     "authors": [
#       "Owais Noor Trumboo Jasra Nisar"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Federated database systems for managing distributed, heterogeneous, and autonomous databases",
#     "id": "https://www.bibsonomy.org/bibtex/2d8ab08ff39573bd64e7dc080adb2230b/buehner",
#     "type": "Publication",
#     "url": "http://delivery.acm.org/10.1145/100000/96604/p183-sheth.pdf?key1=96604&key2=8693487821&coll=GUIDE&dl=ACM&CFID=107002774&CFTOKEN=13258373",
#     "year": "1990",
#     "authors": [
#       "Amit P. Sheth",
#       "James A. Larson"
#     ],
#     "doi": "10.1145/96602.96604",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Migration from relational database like MySQL to nosql database like Cassandra is necessary and how to migrate it using spark",
#     "id": "https://www.bibsonomy.org/bibtex/2c47aa8b0c0695dbf04c04e34bb3a9101/ijtsrd",
#     "type": "Publication",
#     "url": "http://www.ijtsrd.com/engineering/computer-engineering/57/migration-from-relational-database-like-mysql-to-nosql-database-like-cassandra-is-necessary-and-how-to-migrate-it-using-spark/dr-kishor-atkotiya",
#     "year": "2016",
#     "authors": [
#       "Dr. Kishor Atkotiya | Parag Shukla"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Database Security Model using Access Control Mechanism in Student Data Management",
#     "id": "https://www.bibsonomy.org/bibtex/2f21be0dc285cb90890e1d9ce3146a63a/ijtsrd",
#     "type": "Publication",
#     "url": "https://www.ijtsrd.com/computer-science/database/22820/database-security-model-using-access-control-mechanism-in-student-data-management/aye-mon-win",
#     "year": "2019",
#     "authors": [
#       "Aye Mon Win | Khin Lay Myint"
#     ],
#     "doi": "https://doi.org/10.31142/ijtsrd22820",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Survival of an Intrusion Tolerance Database System",
#     "id": "https://www.bibsonomy.org/bibtex/24f8b60cb12c7f1d1b31465d7e7b2f44b/ijtsrd",
#     "type": "Publication",
#     "url": "https://www.ijtsrd.com/computer-science/computer-security/26748/survival-of-an-intrusion-tolerance-database-system/su-thawda-win",
#     "year": "2019",
#     "authors": [
#       "Su Thawda Win"
#     ],
#     "doi": "https://doi.org/10.31142/ijtsrd26748",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "BioNumbers--the database of key numbers in molecular and cell biology",
#     "id": "https://www.bibsonomy.org/bibtex/2c35febbc664422e27257b6f2f27b40f4/karthikraman",
#     "type": "Publication",
#     "url": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2808940/",
#     "year": "2010",
#     "authors": [
#       "R Milo",
#       "P Jorgensen",
#       "U Moran",
#       "G Weber",
#       "M Springer"
#     ],
#     "doi": "10.1093/nar/gkp889",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Janaushadhi Database Management System",
#     "id": "https://www.bibsonomy.org/bibtex/20900193932683227409336a3befeac54/ijtsrd",
#     "type": "Publication",
#     "url": "https://www.ijtsrd.com/computer-science/database/26403/janaushadhi-database-management-system/naimisha-u",
#     "year": "2019",
#     "authors": [
#       "Naimisha U | Ashritha A"
#     ],
#     "doi": "https://doi.org/10.31142/ijtsrd26403",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "GAMMA\\\u2014a high performance dataflow database machine",
#     "id": "https://www.bibsonomy.org/bibtex/2a295018d8ecc0212aca487ae1b0c753e/jhammerb",
#     "type": "Publication",
#     "url": "http://portal.acm.org/citation.cfm?id=48751.48773",
#     "year": "1988",
#     "authors": [
#       "David J. DeWitt",
#       "Goetz Graefe",
#       "Krishna B. Kumar",
#       "Robert H. Gerber",
#       "Michael L. Heytens",
#       "M. Muralikrishna"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Performance Driven Database Design for Scalable Web Applications",
#     "id": "https://www.bibsonomy.org/bibtex/2c753bff717eb9632d39e3679f7c269ef/mbruschi",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1007/978-3-642-03973-7_5",
#     "year": "2009",
#     "authors": [
#       "Jozsef Patvarczki",
#       "Murali Mani",
#       "Neil Heffernan"
#     ],
#     "doi": "10.1007/978-3-642-03973-7_5",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "A comparative analysis of methodologies for database schema integration",
#     "id": "https://www.bibsonomy.org/bibtex/22636802d129dbf10d3dc35bdfdc6efb6/gravity",
#     "type": "Publication",
#     "url": "http://portal.acm.org/citation.cfm?doid=27633.27634",
#     "year": "1986",
#     "authors": [
#       "C. Batini",
#       "M. Lenzerini",
#       "S. B. Navathe"
#     ],
#     "doi": "http://doi.acm.org/10.1145/27633.27634",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "A Comparison between Relational Databases and NoSQL Databases",
#     "id": "https://www.bibsonomy.org/bibtex/292e537486422445d574ddbbef9a49300/ijtsrd",
#     "type": "Publication",
#     "url": "http://www.ijtsrd.com/computer-science/database/11214/a-comparison-between-relational-databases-and-nosql-databases/behjat-u-nisa",
#     "year": "2018",
#     "authors": [
#       "Behjat U Nisa"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "XML and relational database management systems: the inside story",
#     "id": "https://www.bibsonomy.org/bibtex/26d3b73cfb1b666af1155c893cd37f5d5/malte.wunsch",
#     "type": "Publication",
#     "url": "http://portal.acm.org/citation.cfm?id=1066157.1066298",
#     "year": "2005",
#     "authors": [
#       "Michael Rys",
#       "Don Chamberlin",
#       "Daniela Florescu"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "The Claremont report on database research",
#     "id": "https://www.bibsonomy.org/bibtex/2c23ca6a7338e9687327054b7d62596bf/sb3000",
#     "type": "Publication",
#     "url": "http://doi.acm.org/10.1145/1516046.1516062",
#     "year": "2009",
#     "authors": [
#       "Rakesh Agrawal",
#       "Anastasia Ailamaki",
#       "Philip A. Bernstein",
#       "Eric A. Brewer",
#       "Michael J. Carey",
#       "Surajit Chaudhuri",
#       "Anhai Doan",
#       "Daniela Florescu",
#       "Michael J. Franklin",
#       "Hector Garcia-Molina",
#       "Johannes Gehrke",
#       "Le Gruenwald",
#       "Laura M. Haas",
#       "Alon Y. Halevy",
#       "Joseph M. Hellerstein",
#       "Yannis E. Ioannidis",
#       "Hank F. Korth",
#       "Donald Kossmann",
#       "Samuel Madden",
#       "Roger Magoulas",
#       "Beng Chin Ooi",
#       "Tim O'Reilly",
#       "Raghu Ramakrishnan",
#       "Sunita Sarawagi",
#       "Michael Stonebraker",
#       "Alexander S. Szalay",
#       "Gerhard Weikum"
#     ],
#     "doi": "10.1145/1516046.1516062",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Argonaute--a database for gene regulation by mammalian microRNAs.",
#     "id": "https://www.bibsonomy.org/bibtex/2ebee7ffeb63027567b55bf06c3d56e87/bbrors",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1093/nar/gkj093",
#     "year": "2006",
#     "authors": [
#       "Priyanka Shahi",
#       "Serguei Loukianiouk",
#       "Andreas Bohne-Lang",
#       "Marc Kenzelmann",
#       "Stefan K\u00fcffer",
#       "Sabine Maertens",
#       "Roland Eils",
#       "Herrmann-Josef Gr\u00f6ne",
#       "Norbert Gretz",
#       "Benedikt Brors"
#     ],
#     "doi": "10.1093/nar/gkj093",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Meta-Modeling to design the Structured Database Schema",
#     "id": "https://www.bibsonomy.org/bibtex/21ff8657202cd17730f4dfb25f867073d/dm.kovalev",
#     "type": "Publication",
#     "url": "",
#     "year": "2006",
#     "authors": [
#       "Elvira Locuratolo"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "SMPDB: The Small Molecule Pathway Database.",
#     "id": "https://www.bibsonomy.org/bibtex/28679729b73db4e8c758f177ed6c1b7bb/karthikraman",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1093/nar/gkp1002",
#     "year": "2010",
#     "authors": [
#       "Alex Frolkis",
#       "Craig Knox",
#       "Emilia Lim",
#       "Timothy Jewison",
#       "Vivian Law",
#       "David D. Hau",
#       "Phillip Liu",
#       "Bijaya Gautam",
#       "Son Ly",
#       "An Chi C. Guo",
#       "Jianguo Xia",
#       "Yongjie Liang",
#       "Savita Shrivastava",
#       "David S. Wishart"
#     ],
#     "doi": "10.1093/nar/gkp1002",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "RAIN: RNA-protein Association and Interaction Networks.",
#     "id": "https://www.bibsonomy.org/bibtex/2d13ac84ab45538ea9d0463e006d70ffa/karthikraman",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1093/database/baw167",
#     "year": "2017",
#     "authors": [
#       "Alexander Junge",
#       "Jan C. Refsgaard",
#       "Christian Garde",
#       "Xiaoyong Pan",
#       "Alberto Santos",
#       "Ferhat Alkan",
#       "Christian Anthon",
#       "Christian von Mering",
#       "Christopher T. Workman",
#       "Lars Juhl J. Jensen",
#       "Jan Gorodkin"
#     ],
#     "doi": "10.1093/database/baw167",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "LIGAND: chemical database of enzyme reactions",
#     "id": "https://www.bibsonomy.org/bibtex/263a5437227eab1cc867c5cf5e310779e/artheibault",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/nar/nar28.html#GotoNK00",
#     "year": "2000",
#     "authors": [
#       "Susumu Goto",
#       "Takaaki Nishioka",
#       "Minoru Kanehisa"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "ChEBI - Chemical Entities of Biological Interest",
#     "id": "https://www.bibsonomy.org/bibtex/232c444add4e2b89c8e61b6406211eb0f/fairybasslet",
#     "type": "Publication",
#     "url": "http://www.oxfordjournals.org/nar/database/summary/646",
#     "year": "2006",
#     "authors": [
#       "P. de Matos",
#       "M. Ennis",
#       "M. Zbinden",
#       "A. McNaught",
#       "R. Alc\u00e1ntara",
#       "M. Darsow",
#       "M. Guedj",
#       "M. Ashburner",
#       "K. Degtyarenko"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "On replacing standard system error messages for relational database constraints with context aware natural language ones",
#     "id": "https://www.bibsonomy.org/bibtex/28295d89e9077528ec2e8075a7e3450c0/gjetajournal",
#     "type": "Publication",
#     "url": "https://gjeta.com/content/replacing-standard-system-error-messages-relational-database-constraints-context-aware",
#     "year": "2023",
#     "authors": [
#       "Diana Christina Mancas"
#     ],
#     "doi": "10.30574/gjeta.2023.14.3.0062",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "PolyQ Database - an integrated database on polyglutamine diseases.",
#     "id": "https://www.bibsonomy.org/bibtex/2fa048127b5236c08aad055f921f0f172/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2023.html#EstevamMN23",
#     "year": "2023",
#     "authors": [
#       "Bernardo Estevam",
#       "Carlos A. Matos",
#       "Cl\u00e9vio N\u00f3brega"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "MEMOSys 2.0: an update of the bioinformatics database for genome-scale models and genomic data.",
#     "id": "https://www.bibsonomy.org/bibtex/23798a8113a8f076a1b188ca98eb5a9d5/karthikraman",
#     "type": "Publication",
#     "url": "http://view.ncbi.nlm.nih.gov/pubmed/24532766",
#     "year": "2014",
#     "authors": [
#       "Stephan Pabinger",
#       "Rene Snajder",
#       "Timo Hardiman",
#       "Michaela Willi",
#       "Andreas Dander",
#       "Zlatko Trajanoski"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "An introduction to database systems",
#     "id": "https://www.bibsonomy.org/bibtex/27f49dd238fa7ce88cbd91004b080ef64/vivion",
#     "type": "Publication",
#     "url": "http://www.amazon.com/Introduction-Database-Systems-8th/dp/0321197844",
#     "year": "2004",
#     "authors": [
#       "C. J Date"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "DBGET/LinkDB: an integrated database retrieval system",
#     "id": "https://www.bibsonomy.org/bibtex/2a7c165d1f79c89f55ff28d2cb9d0019c/artheibault",
#     "type": "Publication",
#     "url": "http://psb.stanford.edu/psb-online/proceedings/psb98/abstracts/p683.html",
#     "year": "1998",
#     "authors": [
#       "W. Fujibuchi",
#       "S. Goto",
#       "H. Migimatsu",
#       "I. Uchiyama",
#       "A. Ogiwara",
#       "Y. Akiyama",
#       "M. Kanehisa"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Introduction to Database Systems, An (8th Edition)",
#     "id": "https://www.bibsonomy.org/bibtex/265848417b2c10b9e8241cce148763e63/mksivana",
#     "type": "Publication",
#     "url": "http://www.amazon.com/Introduction-Database-Systems-C-J-Date/dp/0321197844%3FSubscriptionId%3D192BW6DQ43CK9FN0ZGG2%26tag%3Dws%26linkCode%3Dxm2%26camp%3D2025%26creative%3D165953%26creativeASIN%3D0321197844",
#     "year": "2003",
#     "authors": [
#       "C.J. Date"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Beginning Database Design Solutions (Wrox Programmer to Programmer)",
#     "id": "https://www.bibsonomy.org/bibtex/2b1532af1f47c7afdb576b95a0a9c5517/mksivana",
#     "type": "Publication",
#     "url": "http://www.amazon.com/Beginning-Database-Design-Solutions-Programmer/dp/0470385499%3FSubscriptionId%3D192BW6DQ43CK9FN0ZGG2%26tag%3Dws%26linkCode%3Dxm2%26camp%3D2025%26creative%3D165953%26creativeASIN%3D0470385499",
#     "year": "2008",
#     "authors": [
#       "Rod Stephens"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "SABIO-RK--database for biochemical reaction kinetics.",
#     "id": "https://www.bibsonomy.org/bibtex/2c054e549e878e3d9404cbecdbeaad576/karthikraman",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1093/nar/gkr1046",
#     "year": "2012",
#     "authors": [
#       "Ulrike Wittig",
#       "Renate Kania",
#       "Martin Golebiewski",
#       "Maja Rey",
#       "Lei Shi",
#       "Lenneke Jong",
#       "Enkhjargal Algaa",
#       "Andreas Weidemann",
#       "Heidrun Sauer-Danzwith",
#       "Saqib Mir",
#       "Olga Krebs",
#       "Meik Bittkowski",
#       "Elina Wetsch",
#       "Isabel Rojas",
#       "Wolfgang M\u00fcller"
#     ],
#     "doi": "10.1093/nar/gkr1046",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Heterogeneous database integration in biomedicine.",
#     "id": "https://www.bibsonomy.org/bibtex/2710d023013e81830ace8a7920b7a8ac1/neilernst",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1006/jbin.2001.1024",
#     "year": "2001",
#     "authors": [
#       "W. Sujansky"
#     ],
#     "doi": "10.1006/jbin.2001.1024",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Human Protein Reference Database--2009 update.",
#     "id": "https://www.bibsonomy.org/bibtex/260921811a03b42c976a31094c5877e08/karthikraman",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1093/nar/gkn892",
#     "year": "2009",
#     "authors": [
#       "T. S. K. Prasad",
#       "Renu Goel",
#       "Kumaran Kandasamy",
#       "Shivakumar Keerthikumar",
#       "Sameer Kumar",
#       "Suresh Mathivanan",
#       "Deepthi Telikicherla",
#       "Rajesh Raju",
#       "Beema Shafreen",
#       "Abhilash Venugopal",
#       "Lavanya Balakrishnan",
#       "Arivusudar Marimuthu",
#       "Sutopa Banerjee",
#       "Devi S. Somanathan",
#       "Aimy Sebastian",
#       "Sandhya Rani",
#       "Somak Ray",
#       "C. J. Harrys Kishore",
#       "Sashi Kanth",
#       "Mukhtar Ahmed",
#       "Manoj K. Kashyap",
#       "Riaz Mohmood",
#       "Y. L. Ramachandra",
#       "V. Krishna",
#       "Abdul A. Rahiman",
#       "Sujatha Mohan",
#       "Prathibha Ranganathan",
#       "Subhashri Ramabadran",
#       "Raghothama Chaerkady",
#       "Akhilesh Pandey"
#     ],
#     "doi": "10.1093/nar/gkn892",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Coronavirus Immunotherapeutic Consortium Database.",
#     "id": "https://www.bibsonomy.org/bibtex/2414a4dabcdd032b866640600b45ffde4/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2023.html#MahitaHGSLHDLKPBMOAOVGMKHKAGBTGBG23",
#     "year": "2023",
#     "authors": [
#       "Jarjapu Mahita",
#       "Brendan Ha",
#       "Anais Gambiez",
#       "Sharon L. Schendel",
#       "Haoyang Li",
#       "Kathryn M. Hastie",
#       "S. Moses Dennison",
#       "Kan Li",
#       "Natalia Kuzmina",
#       "Sivakumar Periasamy",
#       "Alexander Bukreyev",
#       "Jennifer E. Munt",
#       "Mary Osei-Twum",
#       "Caroline Atyeo",
#       "James A. Overton",
#       "Randi Vita",
#       "Hector Guzman-Orozco",
#       "Marcus Mendes",
#       "Mari Kojima",
#       "Peter J. Halfmann",
#       "Yoshihiro Kawaoka",
#       "Galit Alter",
#       "Luc Gagnon",
#       "Ralph S. Baric",
#       "Georgia D. Tomaras",
#       "Tim Germann",
#       "Daniel Bedinger",
#       "Jason A. Greenbaum",
#       "Erica Ollmann Saphire",
#       "Bjoern Peters"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Properties of geothermal fluids in Switzerland: A new interactive database",
#     "id": "https://www.bibsonomy.org/bibtex/27ef9235f5377a8f379f36449b52798ee/thorade",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1016/j.geothermics.2008.07.001",
#     "year": "2008",
#     "authors": [
#       "Romain Sonney",
#       "Fran\u00e7ois-D. Vuataz"
#     ],
#     "doi": "10.1016/j.geothermics.2008.07.001",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Autoinhibited Protein Database: a curated database of autoinhibitory domains and their autoinhibition mechanisms.",
#     "id": "https://www.bibsonomy.org/bibtex/244e9d39cefe1ca2efc46b43bf4bf0515/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#ChoLKSHLPTKVBPLGKN24",
#     "year": "2024",
#     "authors": [
#       "Daeahn Cho",
#       "Hyang-Mi Lee",
#       "Ji Ah Kim",
#       "Jae Gwang Song",
#       "Su hee Hwang",
#       "Bomi Lee",
#       "Jinsil Park",
#       "Kha Mong Tran",
#       "Jiwon Kim",
#       "Phuong Ngoc Lam Vo",
#       "Jooeun Bae",
#       "Teerapat Pimt",
#       "Kangseok Lee",
#       "J\u00f6rg Gsponer",
#       "Hyung Wook Kim",
#       "Dokyun Na"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Integrating compression and execution in column-oriented database systems",
#     "id": "https://www.bibsonomy.org/bibtex/299c75c63dbe821e399a559d5859e5790/jhammerb",
#     "type": "Publication",
#     "url": "http://portal.acm.org/citation.cfm?id=1142473.1142548",
#     "year": "2006",
#     "authors": [
#       "Daniel Abadi",
#       "Samuel Madden",
#       "Miguel Ferreira"
#     ],
#     "doi": "http://doi.acm.org/10.1145/1142473.1142548",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Update of TTD: Therapeutic Target Database.",
#     "id": "https://www.bibsonomy.org/bibtex/25b096e8ed6040b5c5136e9177854aff3/karthikraman",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1093/nar/gkp1014",
#     "year": "2010",
#     "authors": [
#       "Feng Zhu",
#       "BuCong Han",
#       "Pankaj Kumar",
#       "XiangHui Liu",
#       "XiaoHua Ma",
#       "Xiaona Wei",
#       "Lu Huang",
#       "YangFan Guo",
#       "LianYi Han",
#       "ChanJuan Zheng",
#       "YuZong Chen"
#     ],
#     "doi": "10.1093/nar/gkp1014",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "A Analysis of Different Type of Advance database System For Data Mining Based on Basic Factor",
#     "id": "https://www.bibsonomy.org/bibtex/28cf327f27489aae5ae55bb5625868945/ijritcc",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.17762/ijritcc2321-8169.150206",
#     "year": "2015",
#     "authors": [
#       "Kamlesh Kumar Pandey",
#       "Rajat Kumar Yadu",
#       "Anshu Dwivedi",
#       "Pradeep Kumar Shukla"
#     ],
#     "doi": "10.17762/ijritcc2321-8169.150206",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Strategic Database Security Management and Cybercrime Reduction among Youths in Information Technology Companies in Nigeria",
#     "id": "https://www.bibsonomy.org/bibtex/27bb034bc5ccc279720df2d0a1f53bcba/ijtsrd",
#     "type": "Publication",
#     "url": "https://www.ijtsrd.com/management/strategic-management/47643/strategic-database-security-management-and-cybercrime-reduction-among-youths-in-information-technology-companies-in-nigeria/agbeche-aaron",
#     "year": "2021",
#     "authors": [
#       "Agbeche Aaron | Elechi Bobby Chime | Okechukwu Prince Jumbo"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "VFDB: a reference database for bacterial virulence factors.",
#     "id": "https://www.bibsonomy.org/bibtex/2a823bcdc4890fc93dfff20ec10d5810b/karthikraman",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1093/nar/gki008",
#     "year": "2005",
#     "authors": [
#       "Lihong Chen",
#       "Jian Yang",
#       "Jun Yu",
#       "Zhijian Yao",
#       "Lilian Sun",
#       "Yan Shen",
#       "Qi Jin"
#     ],
#     "doi": "10.1093/nar/gki008",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Human immunodeficiency virus type 1, human protein interaction database at NCBI",
#     "id": "https://www.bibsonomy.org/bibtex/225f0ed2bbba34e4efc60c35caff70351/wnpxrz",
#     "type": "Publication",
#     "url": "http://nar.oxfordjournals.org/cgi/content/abstract/37/suppl_1/D417",
#     "year": "2009",
#     "authors": [
#       "William Fu",
#       "Brigitte E. Sanders-Beer",
#       "Kenneth S. Katz",
#       "Donna R. Maglott",
#       "Kim D. Pruitt",
#       "Roger G. Ptak"
#     ],
#     "doi": "10.1093/nar/gkn708",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "A prospective multicentre otology database",
#     "id": "https://www.bibsonomy.org/bibtex/25f551a2372225fbca2bae05c30bb2e20/stevenarild",
#     "type": "Publication",
#     "url": "http://www.ncbi.nlm.nih.gov.ep.fjernadgang.kb.dk/pubmed/17245068",
#     "year": "2007",
#     "authors": [
#       "M Yung",
#       "P v Heyning"
#     ],
#     "doi": "10.1159/000098856",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Autophagy3D: a comprehensive autophagy structure database.",
#     "id": "https://www.bibsonomy.org/bibtex/2e555ce98e627ba663ccf8ced1e24ee23/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#NehaCFGAT24",
#     "year": "2024",
#     "authors": [
#       " Neha",
#       "Jesu Castin",
#       "Saman Fatihi",
#       "Deepanshi Gahlot",
#       "Akanksha Arun",
#       "Lipi Thukral"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "HOFE: an interactive forensic entomological database.",
#     "id": "https://www.bibsonomy.org/bibtex/214b0484f7ece5d86b1ef302a79eaf2a4/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#LiuQLJMLHCM24",
#     "year": "2024",
#     "authors": [
#       "Mandie Liu",
#       "Yihong Qu",
#       "Yifei Luo",
#       "Binta J. J. Jallow",
#       "Yuting Ma",
#       "Afito Luciano",
#       "Jingjing Huang",
#       "Jifeng Cai",
#       "Fanming Meng"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "SEPDB: a database of secreted proteins.",
#     "id": "https://www.bibsonomy.org/bibtex/29775f21b89228d7b629530b347af0ef8/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#WangRGLBZZCZ24",
#     "year": "2024",
#     "authors": [
#       "Ruiqing Wang",
#       "Chao Ren",
#       "Tian Gao",
#       "Hao Li",
#       "Xiaochen Bo",
#       "Dahai Zhu",
#       "Dan Zhang",
#       "Hebing Chen",
#       "Yong Zhang"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "GMMID: genetically modified mice information database.",
#     "id": "https://www.bibsonomy.org/bibtex/22f200183a4d3e5f59ccc836adfa8ac49/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#XuFCXXCZWZCZDJLCZLGHLYJ24",
#     "year": "2024",
#     "authors": [
#       "Menglin Xu",
#       "Minghui Fang",
#       "Qiyang Chen",
#       "Wenjun Xiao",
#       "Zhixuan Xu",
#       "Bao Cai",
#       "Zhenyang Zhao",
#       "Tao Wang",
#       "Zhu Zhu",
#       "Yingshan Chen",
#       "Yue Zhu",
#       "Mingzhou Dai",
#       "Tiancheng Jiang",
#       "Xinyi Li",
#       "Siuwing Chun",
#       "Runhua Zhou",
#       "Yafei Li",
#       "Yueyue Gou",
#       "Jingjing He",
#       "Lin Luo",
#       "Linlin You",
#       "Xuan Jiang"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "TRY \u2013 a global database of plant traits",
#     "id": "https://www.bibsonomy.org/bibtex/26ca2603105742c082347f1136dc8133f/schmidt2",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1111/j.1365-2486.2011.02451.x",
#     "year": "2011",
#     "authors": [
#       "J. KATTGE",
#       "S. D\u00cdAZ",
#       "S. LAVOREL",
#       "I. C. PRENTICE",
#       "P. LEADLEY",
#       "G. B\u00d6NISCH",
#       "E. GARNIER",
#       "M. WESTOBY",
#       "P. B. REICH",
#       "I. J. WRIGHT",
#       "J. H. C. CORNELISSEN",
#       "C. VIOLLE",
#       "S. P. HARRISON",
#       "P. M. Van BODEGOM",
#       "M. REICHSTEIN",
#       "B. J. ENQUIST",
#       "N. A. SOUDZILOVSKAIA",
#       "D. D. ACKERLY",
#       "M. ANAND",
#       "O. ATKIN",
#       "M. BAHN",
#       "T. R. BAKER",
#       "D. BALDOCCHI",
#       "R. BEKKER",
#       "C. C. BLANCO",
#       "B. BLONDER",
#       "W. J. BOND",
#       "R. BRADSTOCK",
#       "D. E. BUNKER",
#       "F. CASANOVES",
#       "J. CAVENDER-BARES",
#       "J. Q. CHAMBERS",
#       "F. S. CHAPIN III",
#       "J. CHAVE",
#       "D. COOMES",
#       "W. K. CORNWELL",
#       "J. M. CRAINE",
#       "B. H. DOBRIN",
#       "L. DUARTE",
#       "W. DURKA",
#       "J. ELSER",
#       "G. ESSER",
#       "M. ESTIARTE",
#       "W. F. FAGAN",
#       "J. FANG",
#       "F. FERN\u00c1NDEZ-M\u00c9NDEZ",
#       "A. FIDELIS",
#       "B. FINEGAN",
#       "O. FLORES",
#       "H. FORD",
#       "D. FRANK",
#       "G. T. FRESCHET",
#       "N. M. FYLLAS",
#       "R. V. GALLAGHER",
#       "W. A. GREEN",
#       "A. G. GUTIERREZ",
#       "T. HICKLER",
#       "S. I. HIGGINS",
#       "J. G. HODGSON",
#       "A. JALILI",
#       "S. JANSEN",
#       "C. A. JOLY",
#       "A. J. KERKHOFF",
#       "D. KIRKUP",
#       "K. KITAJIMA",
#       "M. KLEYER",
#       "S. KLOTZ",
#       "J. M. H. KNOPS",
#       "K. KRAMER",
#       "I. K\u00dcHN",
#       "H. KUROKAWA",
#       "D. LAUGHLIN",
#       "T. D. LEE",
#       "M. LEISHMAN",
#       "F. LENS",
#       "T. LENZ",
#       "S. L. LEWIS",
#       "J. LLOYD",
#       "J. LLUSI\u00c0",
#       "F. LOUAULT",
#       "S. MA",
#       "M. D. MAHECHA",
#       "P. MANNING",
#       "T. MASSAD",
#       "B. E. MEDLYN",
#       "J. MESSIER",
#       "A. T. MOLES",
#       "S. C. M\u00dcLLER",
#       "K. NADROWSKI",
#       "S. NAEEM",
#       "\u00dc. NIINEMETS",
#       "S. N\u00d6LLERT",
#       "A. N\u00dcSKE",
#       "R. OGAYA",
#       "J. OLEKSYN",
#       "V. G. ONIPCHENKO",
#       "Y. ONODA",
#       "J. ORDO\u00d1EZ",
#       "G. OVERBECK",
#       "W. A. OZINGA",
#       "S. PATI\u00d1O",
#       "S. PAULA",
#       "J. G. PAUSAS",
#       "J. PE\u00d1UELAS",
#       "O. L. PHILLIPS",
#       "V. PILLAR",
#       "H. POORTER",
#       "L. POORTER",
#       "P. POSCHLOD",
#       "A. PRINZING",
#       "R. PROULX",
#       "A. RAMMIG",
#       "S. REINSCH",
#       "B. REU",
#       "L. SACK",
#       "B. SALGADO-NEGRET",
#       "J. SARDANS",
#       "S. SHIODERA",
#       "B. SHIPLEY",
#       "A. SIEFERT",
#       "E. SOSINSKI",
#       "J.-F. SOUSSANA",
#       "E. SWAINE",
#       "N. SWENSON",
#       "K. THOMPSON",
#       "P. THORNTON",
#       "M. WALDRAM",
#       "E. WEIHER",
#       "M. WHITE",
#       "S. WHITE",
#       "S. J. WRIGHT",
#       "B. YGUEL",
#       "S. ZAEHLE",
#       "A. E. ZANNE",
#       "C. WIRTH"
#     ],
#     "doi": "10.1111/j.1365-2486.2011.02451.x",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "GabiPD: the GABI primary database--a plant integrative 'omics' database",
#     "id": "https://www.bibsonomy.org/bibtex/228d1d6bf10bf9535cf975fa605d7fd04/schmidt2",
#     "type": "Publication",
#     "url": "https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2686513/?report=abstract",
#     "year": "2009",
#     "authors": [
#       "D M Ria\u00f1o-Pach\u00f3n",
#       "A Nagel",
#       "J Neigenfind",
#       "R Wagner",
#       "R Basekow",
#       "E Weber",
#       "B Mueller-Roeber",
#       "S Diehl",
#       "B Kersten"
#     ],
#     "doi": "10.1093/nar/gkn611",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "An introduction to multilevel secure relational database management systems",
#     "id": "https://www.bibsonomy.org/bibtex/251d33c392d126d4380d8366f09151b49/malte.wunsch",
#     "type": "Publication",
#     "url": "http://portal.acm.org/citation.cfm?id=1034932",
#     "year": "2004",
#     "authors": [
#       "Walid Rjaibi"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "The European ribosomal RNA database",
#     "id": "https://www.bibsonomy.org/bibtex/212c5e8b4f2b0d1b934308106aab0d832/lutzm",
#     "type": "Publication",
#     "url": "http://www.ncbi.nlm.nih.gov/pubmed/14681368?dopt=Abstract",
#     "year": "2004",
#     "authors": [
#       "J Wuyts",
#       "G Perri\u00e8re",
#       "Y Van De Peer"
#     ],
#     "doi": "10.1093/nar/gkh065",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "athisomiRDB: A comprehensive database of Arabidopsis isomiRs.",
#     "id": "https://www.bibsonomy.org/bibtex/2a3fe70219a05115fa5a2a967fb1b01d7/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#VivekASK24",
#     "year": "2024",
#     "authors": [
#       "A. T. Vivek",
#       "Ajay Arya",
#       "Supriya P. Swain",
#       "Shailesh Kumar"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "PSINDB: the postsynaptic protein-protein interaction database.",
#     "id": "https://www.bibsonomy.org/bibtex/23a7cfafb2923ceae382162beaba4bc73/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2022.html#KalmanDMGD22",
#     "year": "2022",
#     "authors": [
#       "Zsofia E. Kalman",
#       "D\u00e1niel Dudola",
#       "B\u00e1lint M\u00e9sz\u00e1ros",
#       "Zolt\u00e1n G\u00e1sp\u00e1ri",
#       "Laszlo Dobson"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "The molecular biology database collection: 2004 update",
#     "id": "https://www.bibsonomy.org/bibtex/264b95239e9a6bcc0b07b8af1b0c57f5c/tkirsten",
#     "type": "Publication",
#     "url": "http://www.pubmedcentral.nih.gov/articlerender.fcgi?artid=308877",
#     "year": "2004",
#     "authors": [
#       "Michael Y. Galperin"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "A STUDY ON GRAPH STORAGE DATABASE OF\r\nNOSQL",
#     "id": "https://www.bibsonomy.org/bibtex/219faea2600afe2348579ce647d3ae85f/leninsha",
#     "type": "Publication",
#     "url": "https://aircconline.com/ijscai/V5N1/5116ijscai04.pdf",
#     "year": "2016",
#     "authors": [
#       "Smita Agrawal",
#       "Atul Patel"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "The molecular biology database collection: 2005 update",
#     "id": "https://www.bibsonomy.org/bibtex/2f677c5dceeb0b2e48fc2c0a75e4b6d65/tkirsten",
#     "type": "Publication",
#     "url": "",
#     "year": "2005",
#     "authors": [
#       "Michael Y. Galperin"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Reactome: a database of reactions, pathways and biological processes.",
#     "id": "https://www.bibsonomy.org/bibtex/2238dfabac8607fd4e1b57b5ff80465f7/karthikraman",
#     "type": "Publication",
#     "url": "http://dx.doi.org/10.1093/nar/gkq1018",
#     "year": "2011",
#     "authors": [
#       "David Croft",
#       "Gavin O'Kelly",
#       "Guanming Wu",
#       "Robin Haw",
#       "Marc Gillespie",
#       "Lisa Matthews",
#       "Michael Caudy",
#       "Phani Garapati",
#       "Gopal Gopinath",
#       "Bijay Jassal",
#       "Steven Jupe",
#       "Irina Kalatskaya",
#       "Shahana Mahajan",
#       "Bruce May",
#       "Nelson Ndegwa",
#       "Esther Schmidt",
#       "Veronica Shamovsky",
#       "Christina Yung",
#       "Ewan Birney",
#       "Henning Hermjakob",
#       "Peter D'Eustachio",
#       "Lincoln Stein"
#     ],
#     "doi": "10.1093/nar/gkq1018",
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "PurificationDB: database of purification conditions for proteins.",
#     "id": "https://www.bibsonomy.org/bibtex/2621cb4d56f3a0c246aa4e6bfc9f14aeb/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2023.html#GarlandRPCL23",
#     "year": "2023",
#     "authors": [
#       "Olivia Garland",
#       "Mariia Radaeva",
#       "Mohit Pandey",
#       "Artem Cherkasov",
#       "Nada Lallous"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "MyxoPortal: a database of myxobacterial genomic features.",
#     "id": "https://www.bibsonomy.org/bibtex/22eeee121b1fdaa6fadb179a9521534d0/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#SwethaARSWRJLA24",
#     "year": "2024",
#     "authors": [
#       "Rayapadi G. Swetha",
#       "Benita S. Arakal",
#       "Santhosh Rajendran",
#       "Kanagaraj Sekar",
#       "David E. Whitworth",
#       "Sudha Ramaiah",
#       "Philip E. James",
#       "Paul G. Livingstone",
#       "Anand Anbarasu"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "DIRMC: a database of immunotherapy-related molecular characteristics.",
#     "id": "https://www.bibsonomy.org/bibtex/26f12d7f73012511856a2ab6f33d8322f/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#LiuZHLWJLHW24",
#     "year": "2024",
#     "authors": [
#       "Yue Liu",
#       "Yuhuan Zhou",
#       "Xiumei Hu",
#       "Wuri Le-Ge",
#       "Haoyan Wang",
#       "Tao Jiang",
#       "Junyi Li",
#       "Yang Hu",
#       "Yadong Wang"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "KinMod database: a tool for investigating metabolic regulation.",
#     "id": "https://www.bibsonomy.org/bibtex/24306251361d0500631db77752f4de260/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2022.html#HaddadiBM22",
#     "year": "2022",
#     "authors": [
#       "Kiandokht Haddadi",
#       "Rana Ahmed Barghout",
#       "Radhakrishnan Mahadevan"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "DAPredict: a database for drug action phenotype prediction.",
#     "id": "https://www.bibsonomy.org/bibtex/23731124189288d562ad788cd989334e7/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#MengCZXHXYZC24",
#     "year": "2024",
#     "authors": [
#       "Qingkang Meng",
#       "Yiyang Cai",
#       "Kun Zhou",
#       "Fei Xu",
#       "Diwei Huo",
#       "Hongbo Xie",
#       "Meini Yu",
#       "Denan Zhang",
#       "Xiujie Chen"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "MODB: a comprehensive mitochondrial genome database for Mollusca.",
#     "id": "https://www.bibsonomy.org/bibtex/2d933fadcbbfe6e3f80ab0c2848232bdb/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2021.html#QuXCWWLXGWLSLWL21",
#     "year": "2021",
#     "authors": [
#       "Jiangyong Qu",
#       "Yanran Xu",
#       "Yutong Cui",
#       "Sen Wu",
#       "Lijun Wang",
#       "Xiumei Liu",
#       "Zhikai Xing",
#       "Xiaoyu Guo",
#       "Shanshan Wang",
#       "Ruoran Li",
#       "Xiaoyue Sun",
#       "Xiang Li",
#       "Xiyue Wang",
#       "Tao Liu",
#       "Xumin Wang"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Encyclopedia of database systems",
#     "id": "https://www.bibsonomy.org/bibtex/2bcb7a734a91759aee90015798b3a8f77/dbenz",
#     "type": "Publication",
#     "url": "http://www.worldcat.org/search?qt=worldcat_org_all&q=9780387496160",
#     "year": "2009",
#     "authors": [
#       "M. Tame \u00d6zsu",
#       "Lin Liu"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "AagingBase: a comprehensive database of anti-aging peptides.",
#     "id": "https://www.bibsonomy.org/bibtex/2df89f1d1f6f13d8ee5933b715e5f0e9b/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#RKKSKSPKARTK24",
#     "year": "2024",
#     "authors": [
#       "Kunjulakshmi R",
#       "Ambuj Kumar",
#       "Keerthana Vinod Kumar",
#       "Avik Sengupta",
#       "Kavita Kundal",
#       "Simran Sharma",
#       "Ankita Pawar",
#       "Pithani Sai Krishna",
#       "Mohammad Alfatah",
#       "Sandipan Ray",
#       "Bhavana Tiwari",
#       "Rahul Kumar"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Multi-omics molecular biomarkers and database of osteoarthritis.",
#     "id": "https://www.bibsonomy.org/bibtex/265b03ed21379e58a54f5436131223279/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/biodb/biodb2022.html#LiYCXDXTF22",
#     "year": "2022",
#     "authors": [
#       "Jianhua Li",
#       "Xiaotian Yang",
#       "Qinjie Chu",
#       "Lingjuan Xie",
#       "Yuwen Ding",
#       "Xiaoxu Xu",
#       "Michael P. Timko",
#       "Longjiang Fan"
#     ],
#     "doi": null,
#     "query": "database",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Assembling a global database of malaria parasite prevalence for the Malaria Atlas Project.",
#     "id": "https://www.bibsonomy.org/bibtex/21898409e4f69eac943a59322e8002286/uvesco",
# ...
#   },
#   {
#     "title": "mediaWalker: a video archive explorer based on time-series semantic structure.",
#     "id": "https://www.bibsonomy.org/bibtex/22c48e9351b1bb4c0d2e6951d6da18195/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/mm/mm2007.html#IdeKTSM07",
#     "year": "2007",
#     "authors": [
#       "Ichiro Ide",
#       "Tomoyoshi Kinoshita",
#       "Tomokazu Takahashi",
#       "Shin'ichi Satoh",
#       "Hiroshi Murase"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Establishment and Management of a Digital Archive for Taiwanese Folk Arts.",
#     "id": "https://www.bibsonomy.org/bibtex/20765ac6a3ed5d17feb04546c240107bf/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/csse/csse2008-6.html#Yung-ChengJHM08",
#     "year": "2008",
#     "authors": [
#       "Hsieh Yung-Cheng",
#       "Chien Ju-Chun",
#       "Cheng Hui-Wen",
#       "Wu Mei-Ying"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "A text-retrieval system used in humanistic archive applications (abstract only).",
#     "id": "https://www.bibsonomy.org/bibtex/2390b02f23f3d61106b73a274032580d9/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/chi/chi1981-1.html#HoflandA81",
#     "year": "1981",
#     "authors": [
#       "Knut Hofland",
#       "Sigbjorn Arhus"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "External archive hybrid genetic algorithm for unequal area facility layout problem.",
#     "id": "https://www.bibsonomy.org/bibtex/21bd9c8d3099e30a31baed30080272329/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/gecco/gecco2022c.html#Shen0Z22",
#     "year": "2022",
#     "authors": [
#       "Ailing Shen",
#       "Juan Lin",
#       "Yiwen Zhong"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "An Archive Enhanced Hybrid Genetic Algorithm for Shortest Path Routing Problem.",
#     "id": "https://www.bibsonomy.org/bibtex/2c2c620881257805f331dff1d60ece54f/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/iccct/iccct2015.html#SunandaA15",
#     "year": "2015",
#     "authors": [
#       " Sunanda",
#       "Sakshi Arora"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Elimination of clicks from archive speech signals using sparse autoregressive modeling.",
#     "id": "https://www.bibsonomy.org/bibtex/25f8e56fcd58d7d32691a525a4dc83a67/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/eusipco/eusipco2012.html#NiedzwieckiC12",
#     "year": "2012",
#     "authors": [
#       "Maciej Niedzwiecki",
#       "Marcin Ciolek"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Reconstruction of degraded images using genetic algoritm for archive film restoration.",
#     "id": "https://www.bibsonomy.org/bibtex/20d9348d1609e7b9e53df9c2d97aff8fa/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/icip/icip2009.html#KimKK09",
#     "year": "2009",
#     "authors": [
#       "Byunggeun Kim",
#       "Kyung tai Kim",
#       "Eun Yi Kim"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Integration Experiences and Performance Studies of A COTS Parallel Archive System.",
#     "id": "https://www.bibsonomy.org/bibtex/25d3f12c5e0f60ca501c0a45cd52e9a85/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/cluster/cluster2010.html#ChenGSTTSB10",
#     "year": "2010",
#     "authors": [
#       "Hsing bung Chen",
#       "Gary Grider",
#       "Cody Scott",
#       "Milton Turley",
#       "Aaron Torres",
#       "Kathy Sanchez",
#       "John Bremer"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Internet Archive of Electronic Music IAEM - internet Audio Rendering System iARS.",
#     "id": "https://www.bibsonomy.org/bibtex/270a5cfbabcbbbeea1702256109bd7b4d/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/cmmr/cmmr2004.html#FrauenbergerR04",
#     "year": "2004",
#     "authors": [
#       "Christopher Frauenberger",
#       "Winfried Ritsch"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Remembrance of Contemporary Events: On Setting Up The Sunflower Movement Archive.",
#     "id": "https://www.bibsonomy.org/bibtex/2a05637c94c64563f8d1b46a1bede223c/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/dihu/dh2017.html#ChuangL17",
#     "year": "2017",
#     "authors": [
#       "Tyng-Ruey Chuang",
#       "Chao-Lin Liu"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Discriminative Concept Learning Network: Sample Source Code and Supplement (Project Archive).",
#     "id": "https://www.bibsonomy.org/bibtex/25aadd43394223e38a3630fceea400d63/dblp",
#     "type": "Publication",
#     "url": "",
#     "year": "2022",
#     "authors": [
#       "Qiao Wang",
#       "Sylvia Young",
#       "Aaron Harwood",
#       "Cheng Soon Ong"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "AMGA: an archive-based micro genetic algorithm for multi-objective optimization.",
#     "id": "https://www.bibsonomy.org/bibtex/2b27aec7370b2d430636d2a55f8e888af/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/gecco/gecco2008.html#TiwariKFD08",
#     "year": "2008",
#     "authors": [
#       "Santosh Tiwari",
#       "Patrick Koch",
#       "Georges M. Fadel",
#       "Kalyanmoy Deb"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "New Framework of Multi-Objective Evolutionary Algorithms with Unbounded External Archive.",
#     "id": "https://www.bibsonomy.org/bibtex/23a5920eb59042971e352056b67e65017/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/gecco/gecco2024c.html#IshibuchiPS24",
#     "year": "2024",
#     "authors": [
#       "Hisao Ishibuchi",
#       "Lie Meng Pang",
#       "Ke Shang"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "A New Multi-objective Evolutionary Optimisation Algorithm: The Two-Archive Algorithm.",
#     "id": "https://www.bibsonomy.org/bibtex/24146fdd3590a624eabd6e977f191c94c/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/cis/cis2006.html#PraditwongY06",
#     "year": "2006",
#     "authors": [
#       "Kata Praditwong",
#       "Xin Yao"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Text Extraction from Smartphone Screenshots to Archive in situ Media Behavior.",
#     "id": "https://www.bibsonomy.org/bibtex/29182c02dd721263de8aac9400271f482/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/kcap/kcap2017.html#ChiattiYBCGRRG17",
#     "year": "2017",
#     "authors": [
#       "Agnese Chiatti",
#       "Xiao Yang",
#       "Miriam Brinberg",
#       "Mu Jung Cho",
#       "Anupriya Gagneja",
#       "Nilam Ram",
#       "Byron Reeves",
#       "C. Lee Giles"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Vocal Access to a Newspaper Archive: Design Issues and Preliminary Investigations.",
#     "id": "https://www.bibsonomy.org/bibtex/21e0af437f3897407996d952ff1d93f6f/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/dl/dl99.html#Crestani99",
#     "year": "1999",
#     "authors": [
#       "Fabio Crestani"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "DANA (Digital Archive Network for Anthropology): a model for digital archiving.",
#     "id": "https://www.bibsonomy.org/bibtex/25ff71757761a4b7a12528a615ad4f299/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/sac/sac2002.html#ClarkSBLFLPJ02",
#     "year": "2002",
#     "authors": [
#       "Jeffrey T. Clark",
#       "Brian M. Slator",
#       "Aaron Bergstrom",
#       "Francis Larson",
#       "Richard Frovarp",
#       "James E. Landrum",
#       "William Perrizo",
#       "William Jockheck"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "AIR-IA: an analogous image removal approach using the intelligent archive.",
#     "id": "https://www.bibsonomy.org/bibtex/217e640a5e9c67a1c37466e96b3a264d5/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/ijauc/ijauc3.html#MalhotraB20",
#     "year": "2020",
#     "authors": [
#       "Jyoti Malhotra",
#       "Jagdish W. Bakal"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Searching semantically similar questions from a large community-based question archive.",
#     "id": "https://www.bibsonomy.org/bibtex/2b0a4646f0c1c4bcfadcc68c41678a494/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/nlpke/nlpke2009.html#LiuLY09",
#     "year": "2009",
#     "authors": [
#       "Mingrong Liu",
#       "Yicen Liu",
#       "Qing Yang"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "`The confessions of an unrepentant model builder': Rummaging in\r\n\tGoodwin's Archive",
#     "id": "https://www.bibsonomy.org/bibtex/296e4f2e29eeef66919fa00b4082e34b1/smicha",
#     "type": "Publication",
#     "url": "http://www.sciencedirect.com/science/article/B6VFN-4M1DFVC-1/1/5bd0ee1820c111d12acb87a3d673a73b",
#     "year": "2006",
#     "authors": [
#       "Massimo Di Matteo",
#       "Francesco Filippi",
#       "Serena Sordi"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Sp\u00e4tquart\u00e4re Sedimente im Am\u00f6neburger Becken: Archive der Umweltgeschichte einer mittelhessischen Altsiedellandschaft",
#     "id": "https://www.bibsonomy.org/bibtex/26ba2f164443badc1e9215dc75d8e397f/genealogie",
#     "type": "Publication",
#     "url": "",
#     "year": "1995",
#     "authors": [
#       "Holger Rittweger"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Comprehensive contextual visualization of a news archive for aiding story planning.",
#     "id": "https://www.bibsonomy.org/bibtex/22690889f826fb3984b079f3e131149eb/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/ecir/text2story2022.html#SamiRS22",
#     "year": "2022",
#     "authors": [
#       "Ishrat Rahman Sami",
#       "Tony Russell-Rose",
#       "Larisa N. Soldatova"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "An Architecture of a Distributed Archive for Re-useable Learning Objects.",
#     "id": "https://www.bibsonomy.org/bibtex/2df79206373797d6ab6a019386db7f8a1/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/icadl/icadl2003.html#TanFCS03",
#     "year": "2003",
#     "authors": [
#       "Daniel Tan",
#       "Mohamed Ismail Fazilah",
#       "Tony Chan",
#       "Ravi Sharma"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Extending Basic Dublin Core Elements for an Open Research Data Archive.",
#     "id": "https://www.bibsonomy.org/bibtex/2d74f4abd77bed2c042fc5ee217e02c13/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/dc/dc2012.html#Wira-AlamDZ12",
#     "year": "2012",
#     "authors": [
#       "Andias Wira-Alam",
#       "Dimitar Dimitrov",
#       "Wolfgang Zenk-M\u00f6ltgen"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Spacio-Temporal Analysis Using the Web Archive System Based on Ajax.",
#     "id": "https://www.bibsonomy.org/bibtex/25926f6dbad9ba26ef5e7201927c9076c/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/icadl/icadl2008.html#YoshiokaMMT08",
#     "year": "2008",
#     "authors": [
#       "Suguru Yoshioka",
#       "Masumi Morii",
#       "Shintaro Matsushima",
#       "Seiichi Tani"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "The bavarian archive for speech signals: resources for the speech community.",
#     "id": "https://www.bibsonomy.org/bibtex/270b1a0c5a24719712329ae00ab7cd88a/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/interspeech/eurospeech1997.html#SchielDT97",
#     "year": "1997",
#     "authors": [
#       "Florian Schiel",
#       "Christoph Draxler",
#       "Hans G. Tillmann"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Concept and Initial Learning Log Analysis for Lecture Archive Summarization Platform.",
#     "id": "https://www.bibsonomy.org/bibtex/22314a058113250dd53a12569303c4714/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/tencon/tencon2023.html#HasegawaLGO23",
#     "year": "2023",
#     "authors": [
#       "Shinobu Hasegawa",
#       "Xiaoting Liu",
#       "Wen Gu",
#       "Koichi Ota"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "How People Watch Videos? Viewer Behavior Analysis for Video Archive Summarization.",
#     "id": "https://www.bibsonomy.org/bibtex/2d736d643f9610a7577848e1fe4ce6fbd/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/narsum/narsum2023.html#000123",
#     "year": "2023",
#     "authors": [
#       "Shin'ichi Satoh"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Faculty self-archiving behavior: Factors affecting the decision to self-archive.",
#     "id": "https://www.bibsonomy.org/bibtex/2040f345d94cd5d5e6c4e6a2ca7d2f43e/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/asist/asist2007.html#Kim07a",
#     "year": "2007",
#     "authors": [
#       "Jihyun Kim"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Sensitivity and Access: Unlocking the Colonial Visual Archive with Machine Learning.",
#     "id": "https://www.bibsonomy.org/bibtex/28217f4fe9f6a3929c0d365d35447be84/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/journals/dhq/dhq18.html#DentlerJFS24",
#     "year": "2024",
#     "authors": [
#       "Jonathan Dentler",
#       "Lise Jaillant",
#       "Daniel Foliard",
#       "Julien Schuh"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Online hot topic detection from web news archive in short terms.",
#     "id": "https://www.bibsonomy.org/bibtex/29994ea45725f4b521a1ca2da5f6b1bae/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/fskd/fskd2014.html#YuZCH14",
#     "year": "2014",
#     "authors": [
#       "RuiGuo Yu",
#       "Mankun Zhao",
#       "Peng Chang",
#       "MuWen He"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "Serge Modular Archive Instrument (SMAI): Bridging Skeuomorphic & Machine Learning Enabled Interfaces.",
#     "id": "https://www.bibsonomy.org/bibtex/2ee55445bc456b80407d888fe2948f6a1/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/nime/nime2023.html#MooreB23",
#     "year": "2023",
#     "authors": [
#       "Ted Moore",
#       "Jean Brazeau"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   },
#   {
#     "title": "The peer-to-peer trace archive: design and comparative trace analysis.",
#     "id": "https://www.bibsonomy.org/bibtex/2dc534ef1b01530bf66755fb1a8eaa51a/dblp",
#     "type": "Publication",
#     "url": "http://dblp.uni-trier.de/db/conf/conext/sw2010.html#ZhangIPE10",
#     "year": "2010",
#     "authors": [
#       "Boxun Zhang",
#       "Alexandru Iosup",
#       "Johan Pouwelse",
#       "Dick H. J. Epema"
#     ],
#     "doi": null,
#     "query": "archive",
#     "editor": "Jannik Ott"
#   }
# ]
