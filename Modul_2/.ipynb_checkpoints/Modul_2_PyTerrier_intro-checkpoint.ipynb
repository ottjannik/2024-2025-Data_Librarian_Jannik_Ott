# %%
import pyterrier as pt
import requests
import pandas as pd
import pickle
import nltk
import numpy as np

# %%
query = 'artificial intelligence'
url = f"https://www.bibsonomy.org/json/search/{query}?items=1000"

# %%
res = requests.get(url)

# %%
data = res.json()

# %%
df_ai = pd.DataFrame(data["items"])
df_ai = df_ai[df_ai["type"] == "Publication"]

# %%
df_ai_filtered = df_ai.dropna(axis=1, thresh=len(df_ai)*0.5)

# %%
df_ai_filtered.columns
# Out:
# Index(['type', 'id', 'tags', 'intraHash', 'label', 'user', 'description',
#        'date', 'changeDate', 'count', 'url', 'interHash', 'pub-type', 'year',
#        'author', 'authors', 'volume', 'pages', 'bibtexKey', 'publisher'],
#       dtype='object')

# %%
useful_columns = ['id', 'tags', 'label', 'description', 'date', 'changeDate', 'url', 'pub-type', 'year', 'author', 'authors', 'publisher']
df_ai_filtered = df_ai_filtered[useful_columns]

# %%
# initialise pyterrier
if not pt.started():
    pt.init()
# Out:
# /var/folders/88/9blsh45918g8y3n5vl6vztxr0000gq/T/ipykernel_11842/1219906578.py:2: DeprecationWarning: Call to deprecated function (or staticmethod) started. (use pt.java.started() instead) -- Deprecated since version 0.11.0.
#   if not pt.started():
# The operation couldn’t be completed. Unable to locate a Java Runtime.
# Please visit http://www.java.com for information on installing Java.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 # initialise pyterrier
#       2 if not pt.started():
# ----> 3     pt.init()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyterrier/java/_utils.py:64, in before_init.<locals>._wrapper(*args, **kwargs)
#      62 if started():
#      63     raise RuntimeError(f'You can only call {fn} before either you start using java or call pt.java.init()')
# ---> 64 return fn(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyterrier/java/_utils.py:239, in legacy_init(version, mem, packages, jvm_opts, redirect_io, logging, home_dir, boot_packages, tqdm, no_download, helper_version)
#     236     pt.java.mavenresolver.offline()
#     237     deprecated_calls.append('pt.java.mavenresolver.offline()')
# --> 239 pt.java.init()
#     240 deprecated_calls.append('pt.java.init() # optional, forces java initialisation')
#     242 # Import other java packages
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyterrier/java/_utils.py:103, in init()
#     102 def init() -> None:
# --> 103     _init()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyterrier/utils.py:94, in once.<locals>._once.<locals>._wrapper(*args, **kwargs)
#      92     raise ValueError(f"{fn.__name__} has already been run")
#      93 # how to handle errors?
# ---> 94 res = fn(*args, **kwargs)
#      95 called = True
#      96 return res
#
# File /opt/anaconda3/lib/python3.12/site-packages/pyterrier/java/_utils.py:135, in _init(trigger)
#     132 for _, initializer in initializers:
#     133     initializer.pre_init(jnius_config)
# --> 135 import jnius # noqa: PT100
#     136 _started = True
#     138 # run post-initialization setup
#
# File /opt/anaconda3/lib/python3.12/site-packages/jnius/__init__.py:45
#      43 else:
#      44     from .jnius import *  # noqa
# ---> 45     from .reflect import *  # noqa
#      47 # XXX monkey patch methods that cannot be in cython.
#      48 # Cython doesn't allow to set new attribute on methods it compiled
#      50 HASHCODE_MAX = 2 ** 31 - 1
#
# File /opt/anaconda3/lib/python3.12/site-packages/jnius/reflect.py:19
#      14 __all__ = ('autoclass', 'ensureclass', 'protocol_map')
#      16 log = logging.getLogger('kivy').getChild(__name__)
# ---> 19 class Class(JavaClass, metaclass=MetaJavaClass):
#      20     __javaclass__ = 'java/lang/Class'
#      22     desiredAssertionStatus = JavaMethod('()Z')
#
# File jnius/jnius_export_class.pxi:117, in jnius.MetaJavaClass.__new__()
#
# File jnius/jnius_export_class.pxi:177, in jnius.MetaJavaClass.resolve_class()
#
# File jnius/jnius_env.pxi:11, in jnius.get_jnienv()
#
# File jnius/jnius_jvm_dlopen.pxi:95, in jnius.get_platform_jnienv()
#
# File jnius/jnius_jvm_dlopen.pxi:54, in jnius.create_jnienv()
#
# File /opt/anaconda3/lib/python3.12/site-packages/jnius/env.py:56, in get_java_setup(platform)
#      54     JAVA_HOME = get_osx_framework()
#      55     if not is_set(JAVA_HOME):
# ---> 56         raise Exception('You must install Java for Mac OSX')
#      58 # go hunting for Javac and Java programs, in that order
#      59 if not is_set(JAVA_HOME):
#
# Exception: You must install Java for Mac OSX
