# %%
import pandas as pd
import requests

# %%
url = "https://www.bibsonomy.org/json/search/database?items=1000&duplicates=merged"
result = requests.get(url) # result ist ein requests.models.Response Objekt
data = result.json() # das Response-Objekt bietet diese nützliche Methode an
df_bibsonomy = pd.DataFrame(data["items"])

# %%
data.keys()
# Out:
# dict_keys(['types', 'properties', 'items'])

# %%
df_bibsonomy
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/cc45493bf442b78d...
# 1        Bookmark  https://www.bibsonomy.org/url/61474ed79d5c3f63...
# 2        Bookmark  https://www.bibsonomy.org/url/3cd373dd8ed9c534...
# 3        Bookmark  https://www.bibsonomy.org/url/cc45493bf442b78d...
# 4        Bookmark  https://www.bibsonomy.org/url/2f5f76391c720a9b...
# ...           ...                                                ...
# 1995  Publication  https://www.bibsonomy.org/bibtex/28615de192f73...
# 1996  Publication  https://www.bibsonomy.org/bibtex/2198dde1c2e52...
# 1997  Publication  https://www.bibsonomy.org/bibtex/2742e5a92ee02...
# 1998  Publication  https://www.bibsonomy.org/bibtex/232fd390a2ecc...
# 1999  Publication  https://www.bibsonomy.org/bibtex/2ceaa520aaa77...
#
#                                                    tags  \
# 0     [web2.0, database, desktop, aggregator, daily,...
# 1     [tool, database, 3403, Error, Fix,, recovery,,...
# 2           [Article(s), Design, Database, Information]
# 3     [web2.0, 2007, database, socialsoftware, tools...
# 4                                           [databases]
# ...                                                 ...
# 1995                                             [dblp]
# 1996                                         [imported]
# 1997                                             [dblp]
# 1998  [genome-scale, database, pathway-database, rec...
# 1999                                             [dblp]
#
#                              intraHash  \
# 0     cc45493bf442b78d923b0b1b9342676b
# 1     61474ed79d5c3f63c1d0b6dcd8c653f5
# 2     3cd373dd8ed9c53483d39eaa928686f6
# 3     cc45493bf442b78d923b0b1b9342676b
# 4     2f5f76391c720a9b688f60ec6f900f1d
# ...                                ...
# 1995  8615de192f7368fa76c114a9090a06b8
# 1996  198dde1c2e523df8d1a296224deed38d
# 1997  742e5a92ee025df51471a0185b086025
# 1998  32fd390a2ecc435ba738291f74e4e333
# 1999  ceaa520aaa779a8b2ac948318ce0d884
#
#                                                   label          user  \
# 0                                   Office 2.0 Database     springnet
# 1                           SQL Database 3403 Error Fix     traktools
# 2                                     Database Sharding         panic
# 3                                   Office 2.0 Database          akpe
# 4                      Encyclopedia of Database Systems      ludaesch
# ...                                                 ...           ...
# 1995        An Operating System for a Database Machine.          dblp
# 1996  A database of thermodynamic properties of the ...      eladnoor
# 1997      Towards an Integrated Database-Prolog System.          dblp
# 1998  MetRxn: a knowledgebase of metabolites and rea...  karthikraman
# 1999    Hybrid Concurrency Control in Database Systems.          dblp
#
#                                             description                 date  \
# 0                                   Office 2.0 Database  2006-04-19 19:49:42
# 1     SysTools Software releases an effective SQL da...  2009-09-15 19:13:52
# 2     The term "sharding" was coined by Google engin...  2011-10-01 02:24:14
# 3     Overview of roughly 250 Web 2.0 applications, ...  2007-03-14 20:26:50
# 4                      Encyclopedia of Database Systems  2007-02-08 11:20:08
# ...                                                 ...                  ...
# 1995                                                     2020-03-10 00:00:00
# 1996                                                     2017-09-19 09:22:19
# 1997                                                     2019-07-29 00:00:00
# 1998                                                     2018-12-02 16:09:07
# 1999                                                     2019-08-07 00:00:00
#
#                changeDate  count  ... subject-category  \
# 0     2008-06-29 17:52:49     14  ...              NaN
# 1     2009-09-15 19:13:52      1  ...              NaN
# 2     2011-10-01 02:27:38      1  ...              NaN
# 3     2011-03-14 16:42:58     14  ...              NaN
# 4     2007-09-26 06:23:20      1  ...              NaN
# ...                   ...    ...  ...              ...
# 1995  2020-03-11 11:39:24      1  ...              NaN
# 1996  2017-09-19 09:22:19      1  ...              NaN
# 1997  2019-07-30 11:52:38      1  ...              NaN
# 1998  2018-12-02 16:09:07      2  ...              NaN
# 1999  2019-08-08 11:39:30      1  ...              NaN
#
#      number-of-cited-references journal-iso unique-id times-cited  \
# 0                           NaN         NaN       NaN         NaN
# 1                           NaN         NaN       NaN         NaN
# 2                           NaN         NaN       NaN         NaN
# 3                           NaN         NaN       NaN         NaN
# 4                           NaN         NaN       NaN         NaN
# ...                         ...         ...       ...         ...
# 1995                        NaN         NaN       NaN         NaN
# 1996                        NaN         NaN       NaN         NaN
# 1997                        NaN         NaN       NaN         NaN
# 1998                        NaN         NaN       NaN         NaN
# 1999                        NaN         NaN       NaN         NaN
#
#      doc-delivery-number   m3   ty bdsk-url-2 library
# 0                    NaN  NaN  NaN        NaN     NaN
# 1                    NaN  NaN  NaN        NaN     NaN
# 2                    NaN  NaN  NaN        NaN     NaN
# 3                    NaN  NaN  NaN        NaN     NaN
# 4                    NaN  NaN  NaN        NaN     NaN
# ...                  ...  ...  ...        ...     ...
# 1995                 NaN  NaN  NaN        NaN     NaN
# 1996                 NaN  NaN  NaN        NaN     NaN
# 1997                 NaN  NaN  NaN        NaN     NaN
# 1998                 NaN  NaN  NaN        NaN     NaN
# 1999                 NaN  NaN  NaN        NaN     NaN
#
# [2000 rows x 132 columns]
