# %%
import pyterrier as pt
import requests
import pandas as pd
import pickle
import nltk
import numpy as np
import json

# %%
# eigene Daten laden


# load bibsonomy data, filter type = publication
url = "https://www.bibsonomy.org/json/search/database?items=1000"
result = requests.get(url)
data = result.json()
df = pd.DataFrame(data["items"])
df = df[df["type"] == "Publication"]

# %%
#drop columns where at least 50% of the rows have missing values
df_filtered = df.dropna(axis=1, thresh=len(df)*0.5)

# %%
df_filtered.columns
# Out:
# Index(['type', 'id', 'tags', 'intraHash', 'label', 'user', 'description',
#        'date', 'changeDate', 'count', 'url', 'interHash', 'pub-type',
#        'journal', 'year', 'author', 'authors', 'volume', 'bibtexKey', 'pages'],
#       dtype='object')

# %%
useful_columns = ['id', 'tags', 'label', 'description', 'date', 'changeDate', 'url', 'pub-type', 'year', 'author', 'authors']
df_filtered = df_filtered[useful_columns]

# %%
df_filtered
# Out:
#                                                      id  \
# 1000  https://www.bibsonomy.org/bibtex/2750b8770eec8...
# 1001  https://www.bibsonomy.org/bibtex/2d93ac9b6cfa6...
# 1002  https://www.bibsonomy.org/bibtex/233d3effaf95a...
# 1003  https://www.bibsonomy.org/bibtex/2ca6461cce248...
# 1004  https://www.bibsonomy.org/bibtex/2eb1605409b13...
# ...                                                 ...
# 1995  https://www.bibsonomy.org/bibtex/2cf5fc7f15560...
# 1996  https://www.bibsonomy.org/bibtex/2659463d56cc3...
# 1997  https://www.bibsonomy.org/bibtex/2354fd159aea9...
# 1998  https://www.bibsonomy.org/bibtex/278388b15fe96...
# 1999  https://www.bibsonomy.org/bibtex/295246b77271b...
#
#                                                    tags  \
# 1000                   [ecoli, gene-networks, database]
# 1001  [database, drug-protein-interactions, protein-...
# 1002     [database, phosphorylation, signalling, yeast]
# 1003                                             [test]
# 1004       [JSON, XML, Database, documents, NOSQL, SQL]
# ...                                                 ...
# 1995                                             [dblp]
# 1996                                             [dblp]
# 1997                                             [dblp]
# 1998                                             [dblp]
# 1999                                         [imported]
#
#                                                   label description  \
# 1000  EcoliNet: a database of cofunctional gene netw...
# 1001  The drug-minded protein interaction database (...
# 1002  PhosphoGRID: a database of experimentally veri...
# 1003  GoSynthetic database tool to analyse natural a...
# 1004                    Database for Mobile Application
# ...                                                 ...         ...
# 1995  miRwayDB: a database for experimentally valida...
# 1996  Applying graph database technology for analyzi...
# 1997  Database Management and Computer-Assisted VLSI...
# 1998  Physical Integrity in a Large Segmented Database.
# 1999              The Integrated Geneome Database (IGD)
#
#                      date           changeDate  \
# 1000  2018-12-02 16:09:07  2018-12-02 16:09:07
# 1001  2018-12-02 16:09:07  2018-12-02 16:09:07
# 1002  2018-12-02 16:09:07  2018-12-02 16:09:07
# 1003  2013-12-11 13:22:35  2013-12-11 13:22:35
# 1004  2018-09-04 08:57:56  2018-10-02 11:01:26
# ...                   ...                  ...
# 1995  2022-10-02 00:00:00  2024-04-08 19:25:43
# 1996  2021-07-25 00:00:00  2024-04-08 19:25:28
# 1997  2020-03-10 00:00:00  2020-03-11 11:40:03
# 1998  2018-11-06 00:00:00  2018-11-07 11:49:44
# 1999  2007-10-23 13:35:30  2007-10-23 13:35:41
#
#                                                     url       pub-type  year  \
# 1000          http://dx.doi.org/10.1093/database/bav001        article  2015
# 1001          http://dx.doi.org/10.1093/database/baw041        article  2016
# 1002          http://dx.doi.org/10.1093/database/bap026        article  2010
# 1003          http://dx.doi.org/10.1093/database/bat043        article  2013
# 1004  http://www.ijtsrd.com/computer-science/databas...        article  2018
# ...                                                 ...            ...   ...
# 1995  http://dblp.uni-trier.de/db/journals/biodb/bio...        article  2018
# 1996  http://dblp.uni-trier.de/db/journals/biodb/bio...        article  2020
# 1997  http://dblp.uni-trier.de/db/journals/debu/debu...        article  1984
# 1998  http://dblp.uni-trier.de/db/journals/tods/tods...        article  1977
# 1999                                                     inproceedings  1994
#
#                                                  author  \
# 1000  [Hanhae Kim, Jung Eun E. Shim, Junha Shin, Ins...
# 1001  [Meik Kunz, Chunguang Liang, Santosh Nilla, Al...
# 1002  [Chris Stark, Ting-Cheng C. Su, Ashton Breitkr...
# 1003                 [C. Liang, B. Kruger, T. Dandekar]
# 1004                   [Jasra Nisar Owais Noor Trumboo]
# ...                                                 ...
# 1995  [Sankha Subhra Das, Pritam Saha, Nishant Chakr...
# 1996                  [Claire M. Simpson, Florian Gnad]
# 1997                                    [Randy H. Katz]
# 1998                                 [Raymond A. Lorie]
# 1999                                      [Otto Ritter]
#
#                                                 authors
# 1000  [{'first': 'Hanhae', 'last': 'Kim'}, {'first':...
# 1001  [{'first': 'Meik', 'last': 'Kunz'}, {'first': ...
# 1002  [{'first': 'Chris', 'last': 'Stark'}, {'first'...
# 1003  [{'first': 'C.', 'last': 'Liang'}, {'first': '...
# 1004  [{'first': 'Jasra Nisar Owais Noor', 'last': '...
# ...                                                 ...
# 1995  [{'first': 'Sankha Subhra', 'last': 'Das'}, {'...
# 1996  [{'first': 'Claire M.', 'last': 'Simpson'}, {'...
# 1997            [{'first': 'Randy H.', 'last': 'Katz'}]
# 1998         [{'first': 'Raymond A.', 'last': 'Lorie'}]
# 1999              [{'first': 'Otto', 'last': 'Ritter'}]
#
# [1000 rows x 11 columns]

# %%
#pyterrier exspects a docno field
df_filtered['docno'] = df_filtered['id']
df_filtered['text'] = df_filtered['label']

# %%
index_folder = "./df_index"

indexer = pt.DFIndexer(index_folder, overwrite=True)
index_ref = indexer.index(df_filtered['text'], df_filtered['docno'])

print(f"path to our index: {index_ref.toString()}")
# Out:
# /var/folders/88/9blsh45918g8y3n5vl6vztxr0000gq/T/ipykernel_2460/146072258.py:3: DeprecationWarning: Call to deprecated class DFIndexer. (use pt.terrier.IterDictIndexer().index(dataframe.to_dict(orient='records')) instead) -- Deprecated since version 0.11.0.
#   indexer = pt.DFIndexer(index_folder, overwrite=True)
# Java started (triggered by TerrierIndexer.__init__) and loaded: pyterrier.java, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]
# path to our index: ./df_index/data.properties

# %%
index = pt.IndexFactory.of(index_ref)

# %%
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 1000
# Number of terms: 1982
# Number of postings: 6668
# Number of fields: 0
# Number of tokens: 6827
# Field names: []
# Positions:   false

# %%
for kv in index.getLexicon():
    print(f"{kv.getKey()} -> {kv.getValue().toString()}")
# Out:
# 0 -> term165 Nt=10 TF=10 maxTF=1 @{0 0 0}
# 050 -> term1146 Nt=1 TF=1 maxTF=1 @{0 13 2}
# 1 -> term219 Nt=8 TF=9 maxTF=2 @{0 15 4}
# 10g -> term1042 Nt=1 TF=1 maxTF=1 @{0 27 7}
# 153 -> term586 Nt=1 TF=1 maxTF=1 @{0 30 1}
# 16th -> term1601 Nt=1 TF=1 maxTF=1 @{0 32 1}
# 18 -> term484 Nt=1 TF=1 maxTF=1 @{0 34 5}
# 19 -> term626 Nt=4 TF=5 maxTF=2 @{0 36 5}
# 1992 -> term1816 Nt=1 TF=2 maxTF=2 @{0 43 2}
# 1997 -> term1185 Nt=1 TF=1 maxTF=1 @{0 45 7}
# 1998 -> term1673 Nt=1 TF=1 maxTF=1 @{0 48 1}
# 1st -> term1676 Nt=1 TF=1 maxTF=1 @{0 50 5}
# 2 -> term164 Nt=14 TF=14 maxTF=1 @{0 53 1}
# 2000 -> term1080 Nt=3 TF=3 maxTF=1 @{0 72 7}
# 2001 -> term1228 Nt=1 TF=1 maxTF=1 @{0 79 1}
# 2002 -> term1497 Nt=1 TF=1 maxTF=1 @{0 81 5}
# 2003 -> term1642 Nt=1 TF=1 maxTF=1 @{0 84 1}
# 2004 -> term252 Nt=1 TF=1 maxTF=1 @{0 86 5}
# 2005 -> term256 Nt=1 TF=1 maxTF=1 @{0 88 3}
# 2006 -> term87 Nt=3 TF=3 maxTF=1 @{0 90 1}
# 2009 -> term181 Nt=2 TF=2 maxTF=1 @{0 95 1}
# 2011 -> term681 Nt=1 TF=1 maxTF=1 @{0 98 5}
# 2015 -> term1188 Nt=3 TF=3 maxTF=1 @{0 100 5}
# 2016 -> term1857 Nt=1 TF=1 maxTF=1 @{0 105 5}
# 2018 -> term820 Nt=1 TF=1 maxTF=1 @{0 108 1}
# 21st -> term1774 Nt=1 TF=1 maxTF=1 @{0 110 3}
# 231 -> term1672 Nt=1 TF=1 maxTF=1 @{0 112 7}
# 24 -> term1670 Nt=1 TF=1 maxTF=1 @{0 115 3}
# 25th -> term1187 Nt=2 TF=2 maxTF=1 @{0 117 7}
# 26 -> term1813 Nt=1 TF=1 maxTF=1 @{0 120 5}
# 28 -> term1812 Nt=1 TF=1 maxTF=1 @{0 123 1}
# 2d -> term1809 Nt=1 TF=1 maxTF=1 @{0 125 5}
# 2nd -> term1110 Nt=1 TF=1 maxTF=1 @{0 128 1}
# 3 -> term1151 Nt=4 TF=4 maxTF=1 @{0 130 3}
# 3cdb -> term1836 Nt=1 TF=1 maxTF=1 @{0 137 7}
# 3d -> term1182 Nt=2 TF=2 maxTF=1 @{0 140 3}
# 4 -> term1421 Nt=4 TF=4 maxTF=1 @{0 144 7}
# 4th -> term1633 Nt=1 TF=1 maxTF=1 @{0 152 5}
# 5 -> term1158 Nt=2 TF=2 maxTF=1 @{0 155 1}
# 5th -> term603 Nt=2 TF=2 maxTF=1 @{0 159 1}
# 6 -> term1652 Nt=1 TF=1 maxTF=1 @{0 162 7}
# 7 -> term1651 Nt=1 TF=1 maxTF=1 @{0 165 3}
# 8th -> term170 Nt=1 TF=1 maxTF=1 @{0 167 7}
# aagingbas -> term276 Nt=1 TF=1 maxTF=1 @{0 169 3}
# abampdb -> term291 Nt=1 TF=1 maxTF=1 @{0 171 1}
# abbrevi -> term1166 Nt=1 TF=1 maxTF=1 @{0 172 7}
# abiot -> term1338 Nt=1 TF=1 maxTF=1 @{0 175 1}
# abstract -> term1134 Nt=8 TF=8 maxTF=1 @{0 177 5}
# academ -> term736 Nt=1 TF=1 maxTF=1 @{0 189 5}
# acceler -> term429 Nt=2 TF=2 maxTF=1 @{0 191 5}
# access -> term104 Nt=12 TF=12 maxTF=1 @{0 194 7}
# accid -> term905 Nt=1 TF=1 maxTF=1 @{0 214 3}
# account -> term1392 Nt=1 TF=1 maxTF=1 @{0 216 5}
# accuraci -> term1958 Nt=1 TF=1 maxTF=1 @{0 219 1}
# acetobas -> term1921 Nt=1 TF=1 maxTF=1 @{0 221 5}
# acid -> term617 Nt=4 TF=4 maxTF=1 @{0 224 1}
# acinetobact -> term295 Nt=2 TF=2 maxTF=1 @{0 232 1}
# acinetobas -> term326 Nt=1 TF=1 maxTF=1 @{0 234 7}
# acoust -> term331 Nt=1 TF=1 maxTF=1 @{0 236 5}
# across -> term1579 Nt=2 TF=2 maxTF=1 @{0 238 3}
# action -> term270 Nt=1 TF=1 maxTF=1 @{0 241 3}
# activ -> term545 Nt=10 TF=11 maxTF=2 @{0 243 1}
# acubert -> term1526 Nt=1 TF=1 maxTF=1 @{0 258 2}
# acupunctur -> term1528 Nt=1 TF=1 maxTF=1 @{0 260 6}
# ad -> term1584 Nt=1 TF=2 maxTF=2 @{0 263 2}
# adam -> term1167 Nt=1 TF=1 maxTF=1 @{0 265 7}
# adapt -> term772 Nt=2 TF=2 maxTF=1 @{0 268 1}
# address -> term928 Nt=1 TF=1 maxTF=1 @{0 272 3}
# aditi -> term1720 Nt=1 TF=1 maxTF=1 @{0 274 5}
# administr -> term850 Nt=4 TF=4 maxTF=1 @{0 277 1}
# adopt -> term373 Nt=1 TF=1 maxTF=1 @{0 285 1}
# advanc -> term206 Nt=11 TF=11 maxTF=1 @{0 286 7}
# advers -> term1524 Nt=1 TF=1 maxTF=1 @{0 303 3}
# aerial -> term1616 Nt=1 TF=1 maxTF=1 @{0 305 7}
# aerob -> term1972 Nt=1 TF=1 maxTF=1 @{0 308 3}
# affect -> term1770 Nt=1 TF=1 maxTF=1 @{0 310 7}
# affymetrix -> term859 Nt=1 TF=1 maxTF=1 @{0 313 3}
# african -> term1319 Nt=1 TF=1 maxTF=1 @{0 315 5}
# aftm -> term507 Nt=1 TF=1 maxTF=1 @{0 318 1}
# ag -> term277 Nt=5 TF=6 maxTF=2 @{0 320 1}
# agbas -> term1911 Nt=1 TF=1 maxTF=1 @{0 328 4}
# agbiodata -> term1022 Nt=1 TF=1 maxTF=1 @{0 331 0}
# agd -> term1069 Nt=1 TF=1 maxTF=1 @{0 333 2}
# ageid -> term1235 Nt=1 TF=1 maxTF=1 @{0 335 4}
# agenc -> term1521 Nt=1 TF=1 maxTF=1 @{0 338 0}
# agent -> term1850 Nt=1 TF=1 maxTF=1 @{0 340 4}
# aggreg -> term1363 Nt=4 TF=4 maxTF=1 @{0 343 0}
# agodb -> term321 Nt=1 TF=1 maxTF=1 @{0 350 4}
# agricultur -> term418 Nt=3 TF=3 maxTF=1 @{0 352 2}
# agrosi -> term1263 Nt=1 TF=1 maxTF=1 @{0 358 0}
# ahp -> term461 Nt=1 TF=1 maxTF=1 @{0 360 4}
# aid -> term1589 Nt=1 TF=1 maxTF=1 @{0 362 4}
# aimedgraph -> term1422 Nt=1 TF=1 maxTF=1 @{0 365 0}
# al -> term707 Nt=1 TF=1 maxTF=1 @{0 367 4}
# alamo -> term1752 Nt=1 TF=1 maxTF=1 @{0 369 4}
# alert -> term625 Nt=1 TF=1 maxTF=1 @{0 372 0}
# algal -> term1734 Nt=1 TF=1 maxTF=1 @{0 374 0}
# algebra -> term1713 Nt=1 TF=1 maxTF=1 @{0 376 4}
# algorithm -> term41 Nt=7 TF=7 maxTF=1 @{0 379 0}
# align -> term370 Nt=2 TF=2 maxTF=1 @{0 390 0}
# allow -> term981 Nt=1 TF=1 maxTF=1 @{0 394 0}
# alon -> term1316 Nt=1 TF=1 maxTF=1 @{0 396 2}
# alpha -> term732 Nt=1 TF=1 maxTF=1 @{0 398 6}
# alphafold -> term509 Nt=1 TF=1 maxTF=1 @{0 400 6}
# alphamissens -> term1434 Nt=1 TF=1 maxTF=1 @{0 402 6}
# altern -> term1012 Nt=3 TF=3 maxTF=1 @{0 405 2}
# alzheim -> term1583 Nt=1 TF=1 maxTF=1 @{0 411 6}
# ambigu -> term1594 Nt=1 TF=1 maxTF=1 @{0 414 2}
# amino -> term1334 Nt=1 TF=1 maxTF=1 @{0 416 6}
# aminobutyr -> term1487 Nt=1 TF=1 maxTF=1 @{0 419 2}
# analys -> term32 Nt=5 TF=5 maxTF=1 @{0 421 6}
# analysi -> term13 Nt=51 TF=51 maxTF=1 @{0 428 2}
# analyt -> term1062 Nt=1 TF=1 maxTF=1 @{0 476 0}
# analyz -> term1336 Nt=2 TF=2 maxTF=1 @{0 478 2}
# anambra -> term934 Nt=1 TF=1 maxTF=1 @{0 483 0}
# anaphora -> term1943 Nt=1 TF=1 maxTF=1 @{0 485 2}
# ancestri -> term1611 Nt=1 TF=1 maxTF=1 @{0 487 6}
# ancient -> term1574 Nt=1 TF=1 maxTF=1 @{0 490 2}
# anemia -> term1587 Nt=1 TF=1 maxTF=1 @{0 492 6}
# anerbc -> term1590 Nt=1 TF=1 maxTF=1 @{0 495 2}
# aneurysm -> term1070 Nt=1 TF=1 maxTF=1 @{0 497 6}
# anim -> term760 Nt=3 TF=3 maxTF=1 @{0 500 0}
# annot -> term69 Nt=25 TF=25 maxTF=1 @{0 506 2}
# annual -> term1600 Nt=1 TF=1 maxTF=1 @{0 534 0}
# answer -> term1219 Nt=2 TF=3 maxTF=2 @{0 536 4}
# anti -> term278 Nt=1 TF=1 maxTF=1 @{0 541 3}
# antibiot -> term1333 Nt=1 TF=1 maxTF=1 @{0 543 1}
# anticanc -> term611 Nt=1 TF=1 maxTF=1 @{0 545 5}
# antimicrobi -> term292 Nt=4 TF=4 maxTF=1 @{0 547 5}
# anwendungen -> term1869 Nt=2 TF=2 maxTF=1 @{0 555 7}
# aortic -> term1310 Nt=1 TF=1 maxTF=1 @{0 558 5}
# apach -> term1055 Nt=1 TF=1 maxTF=1 @{0 561 1}
# apadb -> term1834 Nt=1 TF=1 maxTF=1 @{0 563 3}
# apd -> term1969 Nt=1 TF=1 maxTF=1 @{0 565 7}
# api -> term1496 Nt=2 TF=3 maxTF=2 @{0 568 3}
# app -> term1822 Nt=1 TF=1 maxTF=1 @{0 573 0}
# appli -> term1636 Nt=2 TF=2 maxTF=1 @{0 575 4}
# applic -> term33 Nt=23 TF=23 maxTF=1 @{0 580 2}
# apprais -> term1481 Nt=1 TF=1 maxTF=1 @{0 609 6}
# approach -> term660 Nt=24 TF=24 maxTF=1 @{0 612 2}
# april -> term1818 Nt=1 TF=1 maxTF=1 @{0 641 6}
# aptam -> term386 Nt=1 TF=1 maxTF=1 @{0 644 2}
# aqueou -> term460 Nt=1 TF=1 maxTF=1 @{0 646 0}
# arabidopsi -> term246 Nt=2 TF=2 maxTF=1 @{0 648 0}
# archi -> term1677 Nt=1 TF=1 maxTF=1 @{0 651 4}
# architectur -> term1105 Nt=8 TF=8 maxTF=1 @{0 654 0}
# archiv -> term781 Nt=5 TF=5 maxTF=1 @{0 666 4}
# arduino -> term740 Nt=1 TF=1 maxTF=1 @{0 676 2}
# area -> term1266 Nt=1 TF=1 maxTF=1 @{0 678 2}
# argania -> term713 Nt=1 TF=1 maxTF=1 @{0 680 6}
# argonaut -> term130 Nt=2 TF=2 maxTF=1 @{0 682 6}
# aromadeg -> term1975 Nt=1 TF=1 maxTF=1 @{0 685 6}
# aromat -> term1973 Nt=1 TF=1 maxTF=1 @{0 688 2}
# arrai -> term1506 Nt=2 TF=2 maxTF=1 @{0 690 6}
# arrayexpress -> term1707 Nt=1 TF=1 maxTF=1 @{0 695 2}
# articl -> term1545 Nt=3 TF=3 maxTF=1 @{0 697 6}
# artifici -> term1613 Nt=1 TF=1 maxTF=1 @{0 703 2}
# ascertain -> term443 Nt=1 TF=1 maxTF=1 @{0 705 6}
# asian -> term1695 Nt=1 TF=1 maxTF=1 @{0 707 6}
# aspect -> term1635 Nt=1 TF=1 maxTF=1 @{0 710 2}
# assai -> term1910 Nt=1 TF=1 maxTF=1 @{0 712 6}
# assembl -> term283 Nt=1 TF=1 maxTF=1 @{0 715 2}
# assess -> term1240 Nt=2 TF=2 maxTF=1 @{0 717 0}
# assist -> term1977 Nt=1 TF=1 maxTF=1 @{0 721 4}
# associ -> term139 Nt=19 TF=19 maxTF=1 @{0 724 0}
# asssrdb -> term715 Nt=1 TF=1 maxTF=1 @{0 748 0}
# assumpt -> term58 Nt=1 TF=1 maxTF=1 @{0 750 0}
# astrocyt -> term1722 Nt=1 TF=1 maxTF=1 @{0 751 0}
# atc -> term1411 Nt=1 TF=1 maxTF=1 @{0 753 4}
# athena -> term1106 Nt=1 TF=1 maxTF=1 @{0 756 0}
# atherosclerot -> term1558 Nt=1 TF=1 maxTF=1 @{0 758 2}
# athisomirdb -> term247 Nt=1 TF=1 maxTF=1 @{0 760 6}
# athribonc -> term473 Nt=1 TF=1 maxTF=1 @{0 762 4}
# atla -> term287 Nt=4 TF=4 maxTF=1 @{0 764 4}
# atomist -> term886 Nt=1 TF=1 maxTF=1 @{0 772 6}
# attack -> term888 Nt=1 TF=1 maxTF=1 @{0 775 0}
# attend -> term743 Nt=1 TF=1 maxTF=1 @{0 777 2}
# audit -> term38 Nt=3 TF=3 maxTF=1 @{0 779 2}
# augment -> term1446 Nt=2 TF=2 maxTF=1 @{0 783 6}
# australian -> term765 Nt=2 TF=2 maxTF=1 @{0 788 0}
# austrian -> term1255 Nt=1 TF=1 maxTF=1 @{0 792 4}
# author -> term1025 Nt=1 TF=1 maxTF=1 @{0 795 0}
# auto -> term628 Nt=1 TF=1 maxTF=1 @{0 797 2}
# autoimmun -> term1605 Nt=1 TF=1 maxTF=1 @{0 799 2}
# autoinhibit -> term198 Nt=1 TF=2 maxTF=2 @{0 801 6}
# autoinhibitori -> term195 Nt=1 TF=1 maxTF=1 @{0 803 3}
# autom -> term520 Nt=7 TF=7 maxTF=1 @{0 804 7}
# automat -> term316 Nt=13 TF=13 maxTF=1 @{0 816 3}
# autonom -> term90 Nt=4 TF=4 maxTF=1 @{0 836 3}
# autophagi -> term225 Nt=1 TF=1 maxTF=1 @{0 841 7}
# autophagy3d -> term224 Nt=1 TF=1 maxTF=1 @{0 843 3}
# avail -> term870 Nt=1 TF=1 maxTF=1 @{0 844 7}
# avoid -> term722 Nt=1 TF=1 maxTF=1 @{0 847 1}
# awar -> term156 Nt=2 TF=2 maxTF=1 @{0 849 1}
# bacillu -> term912 Nt=2 TF=2 maxTF=1 @{0 853 1}
# bacillusregnet -> term1760 Nt=1 TF=1 maxTF=1 @{0 857 7}
# backend -> term1038 Nt=1 TF=1 maxTF=1 @{0 860 3}
# backup -> term55 Nt=1 TF=1 maxTF=1 @{0 862 5}
# bacteri -> term215 Nt=4 TF=4 maxTF=1 @{0 863 5}
# bacteria -> term620 Nt=2 TF=2 maxTF=1 @{0 871 5}
# barcod -> term488 Nt=1 TF=1 maxTF=1 @{0 875 7}
# barlei -> term1468 Nt=1 TF=1 maxTF=1 @{0 877 7}
# barleyvardb -> term1467 Nt=1 TF=1 maxTF=1 @{0 880 3}
# base -> term202 Nt=60 TF=61 maxTF=2 @{0 882 7}
# basic -> term203 Nt=1 TF=1 maxTF=1 @{0 939 4}
# basket -> term1286 Nt=1 TF=1 maxTF=1 @{0 941 0}
# baumannii -> term293 Nt=1 TF=1 maxTF=1 @{0 943 4}
# bavaria -> term1919 Nt=1 TF=1 maxTF=1 @{0 945 2}
# bc8 -> term1384 Nt=1 TF=1 maxTF=1 @{0 947 6}
# bcedb -> term432 Nt=1 TF=1 maxTF=1 @{0 950 2}
# bcl -> term1893 Nt=1 TF=1 maxTF=1 @{0 952 0}
# bcl2db -> term1891 Nt=1 TF=1 maxTF=1 @{0 954 4}
# be -> term1690 Nt=1 TF=1 maxTF=1 @{0 957 0}
# begin -> term172 Nt=1 TF=1 maxTF=1 @{0 959 4}
# benchmark -> term972 Nt=4 TF=4 maxTF=1 @{0 961 0}
# benzothiazol -> term359 Nt=1 TF=1 maxTF=1 @{0 968 6}
# bert -> term1406 Nt=3 TF=3 maxTF=1 @{0 970 4}
# best -> term442 Nt=3 TF=3 maxTF=1 @{0 975 6}
# bh3 -> term1890 Nt=1 TF=1 maxTF=1 @{0 982 2}
# bhaderwah -> term1852 Nt=1 TF=1 maxTF=1 @{0 984 6}
# bia -> term1967 Nt=1 TF=1 maxTF=1 @{0 987 2}
# bias -> term1376 Nt=1 TF=1 maxTF=1 @{0 989 6}
# bibliograph -> term459 Nt=3 TF=3 maxTF=1 @{0 992 2}
# bibliographi -> term1177 Nt=4 TF=4 maxTF=1 @{0 998 4}
# bibliometr -> term307 Nt=10 TF=10 maxTF=1 @{0 1004 2}
# bidirect -> term1575 Nt=1 TF=1 maxTF=1 @{0 1016 6}
# big -> term744 Nt=8 TF=8 maxTF=1 @{0 1019 2}
# bill -> term831 Nt=1 TF=1 maxTF=1 @{0 1031 0}
# bim -> term1539 Nt=1 TF=1 maxTF=1 @{0 1033 2}
# bind -> term354 Nt=7 TF=7 maxTF=1 @{0 1035 6}
# bioactiv -> term1477 Nt=1 TF=1 maxTF=1 @{0 1047 0}
# biobank -> term1439 Nt=1 TF=1 maxTF=1 @{0 1049 4}
# biochem -> term176 Nt=5 TF=5 maxTF=1 @{0 1052 0}
# biochem4j -> term1743 Nt=1 TF=1 maxTF=1 @{0 1061 2}
# biocr -> term1372 Nt=5 TF=5 maxTF=1 @{0 1063 6}
# biocur -> term1602 Nt=3 TF=3 maxTF=1 @{0 1071 4}
# biocyc -> term699 Nt=1 TF=1 maxTF=1 @{0 1076 4}
# biodataom -> term317 Nt=2 TF=2 maxTF=1 @{0 1078 4}
# biodegrad -> term400 Nt=1 TF=1 maxTF=1 @{0 1082 4}
# biodivers -> term971 Nt=2 TF=2 maxTF=1 @{0 1084 2}
# biogerontologist -> term1475 Nt=1 TF=1 maxTF=1 @{0 1088 4}
# biogrid -> term1631 Nt=1 TF=1 maxTF=1 @{0 1091 0}
# bioinformat -> term162 Nt=6 TF=6 maxTF=1 @{0 1093 4}
# biolog -> term147 Nt=6 TF=6 maxTF=1 @{0 1103 4}
# biologi -> term110 Nt=13 TF=13 maxTF=1 @{0 1113 6}
# biomark -> term281 Nt=5 TF=5 maxTF=1 @{0 1131 0}
# biomart -> term46 Nt=1 TF=1 maxTF=1 @{0 1138 2}
# biomed -> term1289 Nt=15 TF=15 maxTF=1 @{0 1139 2}
# biomedicin -> term180 Nt=1 TF=1 maxTF=1 @{0 1153 2}
# biometr -> term741 Nt=1 TF=1 maxTF=1 @{0 1154 6}
# biomodel -> term768 Nt=1 TF=1 maxTF=1 @{0 1156 6}
# biomolecular -> term579 Nt=2 TF=2 maxTF=1 @{0 1158 6}
# bionumb -> term109 Nt=1 TF=1 maxTF=1 @{0 1163 2}
# bior -> term1457 Nt=2 TF=2 maxTF=1 @{0 1164 4}
# bioreact -> term774 Nt=1 TF=1 maxTF=1 @{0 1168 6}
# biosecur -> term762 Nt=1 TF=1 maxTF=1 @{0 1170 6}
# biosystem -> term1858 Nt=1 TF=1 maxTF=1 @{0 1172 6}
# biotechnolog -> term659 Nt=3 TF=3 maxTF=1 @{0 1175 2}
# biotransform -> term719 Nt=1 TF=1 maxTF=1 @{0 1179 6}
# biowarehous -> term961 Nt=1 TF=1 maxTF=1 @{0 1181 6}
# birth -> term1206 Nt=1 TF=1 maxTF=1 @{0 1184 0}
# bkm -> term290 Nt=1 TF=1 maxTF=1 @{0 1186 2}
# blab2cancerkd -> term619 Nt=1 TF=1 maxTF=1 @{0 1188 0}
# block -> term1934 Nt=1 TF=1 maxTF=1 @{0 1190 0}
# blockchain -> term1793 Nt=1 TF=1 maxTF=1 @{0 1192 4}
# blood -> term686 Nt=2 TF=2 maxTF=1 @{0 1195 0}
# bmtedb -> term1926 Nt=1 TF=1 maxTF=1 @{0 1199 2}
# botryosphaerial -> term1394 Nt=1 TF=2 maxTF=2 @{0 1201 6}
# bottleneck -> term1625 Nt=1 TF=1 maxTF=1 @{0 1204 3}
# boundari -> term1684 Nt=1 TF=1 maxTF=1 @{0 1206 7}
# bowel -> term1568 Nt=1 TF=1 maxTF=1 @{0 1209 3}
# box -> term1130 Nt=3 TF=3 maxTF=1 @{0 1211 7}
# brain -> term1724 Nt=1 TF=1 maxTF=1 @{0 1217 7}
# breach -> term1955 Nt=1 TF=1 maxTF=1 @{0 1220 3}
# breed -> term738 Nt=3 TF=4 maxTF=2 @{0 1222 7}
# brenda -> term1191 Nt=3 TF=3 maxTF=1 @{0 1229 2}
# bridg -> term786 Nt=1 TF=1 maxTF=1 @{0 1234 2}
# brief -> term976 Nt=1 TF=1 maxTF=1 @{0 1236 2}
# broadcast -> term1210 Nt=1 TF=1 maxTF=1 @{0 1238 4}
# brows -> term1426 Nt=1 TF=1 maxTF=1 @{0 1240 6}
# browser -> term1360 Nt=2 TF=2 maxTF=1 @{0 1243 2}
# bu -> term1265 Nt=1 TF=1 maxTF=1 @{0 1247 2}
# bud -> term21 Nt=1 TF=1 maxTF=1 @{0 1249 6}
# build -> term1278 Nt=9 TF=9 maxTF=1 @{0 1250 2}
# cad -> term1073 Nt=2 TF=2 maxTF=1 @{0 1263 0}
# cadastr -> term901 Nt=1 TF=1 maxTF=1 @{0 1267 4}
# cafeteriasa -> term1578 Nt=1 TF=1 maxTF=1 @{0 1269 6}
# california -> term1957 Nt=1 TF=1 maxTF=1 @{0 1272 2}
# cam -> term1626 Nt=1 TF=1 maxTF=1 @{0 1274 6}
# cambridg -> term1500 Nt=1 TF=1 maxTF=1 @{0 1277 2}
# camera -> term666 Nt=1 TF=1 maxTF=1 @{0 1279 6}
# cancer -> term324 Nt=22 TF=23 maxTF=2 @{0 1281 6}
# candid -> term449 Nt=1 TF=1 maxTF=1 @{0 1308 1}
# captur -> term811 Nt=5 TF=5 maxTF=1 @{0 1310 1}
# carbohydr -> term964 Nt=2 TF=3 maxTF=2 @{0 1319 5}
# carbon -> term1345 Nt=1 TF=1 maxTF=1 @{0 1324 2}
# card -> term900 Nt=2 TF=2 maxTF=1 @{0 1326 6}
# cardiac -> term1309 Nt=1 TF=1 maxTF=1 @{0 1331 4}
# cardio -> term565 Nt=1 TF=1 maxTF=1 @{0 1334 0}
# cardiolog -> term564 Nt=1 TF=1 maxTF=1 @{0 1336 0}
# carnot -> term924 Nt=1 TF=1 maxTF=1 @{0 1338 0}
# carp -> term1346 Nt=1 TF=1 maxTF=1 @{0 1340 2}
# carstream -> term1275 Nt=1 TF=1 maxTF=1 @{0 1342 6}
# case -> term454 Nt=5 TF=5 maxTF=1 @{0 1345 2}
# cassandra -> term95 Nt=1 TF=1 maxTF=1 @{0 1354 4}
# catalog -> term525 Nt=1 TF=1 maxTF=1 @{0 1355 6}
# catalogu -> term1225 Nt=1 TF=1 maxTF=1 @{0 1357 6}
# categor -> term1283 Nt=1 TF=1 maxTF=1 @{0 1360 2}
# categori -> term693 Nt=1 TF=1 maxTF=1 @{0 1362 6}
# caucasian -> term1861 Nt=5 TF=5 maxTF=1 @{0 1364 6}
# caucasu -> term1864 Nt=5 TF=6 maxTF=2 @{0 1371 0}
# caus -> term706 Nt=1 TF=1 maxTF=1 @{0 1377 3}
# causal -> term1657 Nt=1 TF=1 maxTF=1 @{0 1379 3}
# cazym -> term305 Nt=1 TF=1 maxTF=1 @{0 1381 7}
# cbd -> term1485 Nt=1 TF=1 maxTF=1 @{0 1383 5}
# cbgda -> term1389 Nt=1 TF=1 maxTF=1 @{0 1386 1}
# cbpddb -> term360 Nt=1 TF=1 maxTF=1 @{0 1388 5}
# ccidb -> term435 Nt=1 TF=1 maxTF=1 @{0 1390 3}
# ceg -> term1801 Nt=1 TF=1 maxTF=1 @{0 1392 1}
# cell -> term53 Nt=14 TF=18 maxTF=3 @{0 1394 5}
# cellular -> term448 Nt=3 TF=3 maxTF=1 @{0 1411 3}
# cenhanc -> term482 Nt=1 TF=1 maxTF=1 @{0 1416 3}
# center -> term657 Nt=4 TF=4 maxTF=1 @{0 1418 3}
# central -> term452 Nt=5 TF=5 maxTF=1 @{0 1424 7}
# centric -> term810 Nt=2 TF=2 maxTF=1 @{0 1433 7}
# centuri -> term1775 Nt=1 TF=1 maxTF=1 @{0 1437 3}
# cerebrovascular -> term1556 Nt=1 TF=1 maxTF=1 @{0 1439 7}
# cerevisia -> term18 Nt=2 TF=2 maxTF=1 @{0 1442 3}
# cervic -> term1131 Nt=1 TF=1 maxTF=1 @{0 1445 1}
# cg -> term1181 Nt=1 TF=1 maxTF=1 @{0 1447 3}
# chain -> term1321 Nt=1 TF=1 maxTF=1 @{0 1449 5}
# challeng -> term1418 Nt=5 TF=5 maxTF=1 @{0 1452 1}
# chang -> term990 Nt=3 TF=3 maxTF=1 @{0 1460 5}
# chaperonin -> term1747 Nt=1 TF=1 maxTF=1 @{0 1467 1}
# character -> term1162 Nt=1 TF=1 maxTF=1 @{0 1469 5}
# characterist -> term263 Nt=1 TF=1 maxTF=1 @{0 1471 7}
# chebi -> term146 Nt=4 TF=4 maxTF=1 @{0 1473 5}
# chembioport -> term1560 Nt=1 TF=1 maxTF=1 @{0 1480 3}
# chemic -> term145 Nt=11 TF=11 maxTF=1 @{0 1482 7}
# chemistri -> term1243 Nt=2 TF=2 maxTF=1 @{0 1499 3}
# chemoresist -> term496 Nt=1 TF=1 maxTF=1 @{0 1502 5}
# china -> term466 Nt=1 TF=1 maxTF=1 @{0 1504 5}
# chinchilla -> term1905 Nt=1 TF=1 maxTF=1 @{0 1506 5}
# chm13 -> term1431 Nt=1 TF=1 maxTF=1 @{0 1509 1}
# choic -> term969 Nt=1 TF=1 maxTF=1 @{0 1511 5}
# chromosom -> term1377 Nt=2 TF=2 maxTF=1 @{0 1513 7}
# ciliamin -> term312 Nt=1 TF=1 maxTF=1 @{0 1518 5}
# ciliopathi -> term311 Nt=1 TF=2 maxTF=2 @{0 1520 3}
# cipic -> term1484 Nt=1 TF=1 maxTF=1 @{0 1522 2}
# circfunbas -> term1495 Nt=1 TF=1 maxTF=1 @{0 1524 6}
# circr2canc -> term1932 Nt=1 TF=1 maxTF=1 @{0 1527 2}
# circrna -> term1832 Nt=2 TF=2 maxTF=1 @{0 1529 6}
# circul -> term1079 Nt=1 TF=1 maxTF=1 @{0 1534 0}
# circular -> term1494 Nt=1 TF=1 maxTF=1 @{0 1536 2}
# citat -> term1015 Nt=4 TF=4 maxTF=1 @{0 1538 6}
# citizen -> term803 Nt=3 TF=3 maxTF=1 @{0 1545 2}
# claremont -> term128 Nt=3 TF=3 maxTF=1 @{0 1549 2}
# class -> term697 Nt=4 TF=4 maxTF=1 @{0 1553 4}
# classif -> term640 Nt=9 TF=9 maxTF=1 @{0 1561 4}
# classifi -> term1113 Nt=3 TF=3 maxTF=1 @{0 1573 0}
# cleans -> term1700 Nt=1 TF=1 maxTF=1 @{0 1578 4}
# clearanc -> term1293 Nt=1 TF=1 maxTF=1 @{0 1581 0}
# clearer -> term1559 Nt=1 TF=1 maxTF=1 @{0 1583 4}
# cleveland -> term921 Nt=1 TF=1 maxTF=1 @{0 1586 0}
# climat -> term1341 Nt=1 TF=1 maxTF=1 @{0 1588 2}
# clinic -> term585 Nt=6 TF=6 maxTF=1 @{0 1590 6}
# cloud -> term856 Nt=5 TF=5 maxTF=1 @{0 1601 2}
# cluster -> term367 Nt=5 TF=5 maxTF=1 @{0 1610 6}
# cm54 -> term1962 Nt=1 TF=1 maxTF=1 @{0 1618 6}
# cmbd -> term322 Nt=1 TF=1 maxTF=1 @{0 1621 2}
# cmregnet -> term844 Nt=1 TF=1 maxTF=1 @{0 1623 0}
# cmsaf -> term1968 Nt=1 TF=1 maxTF=1 @{0 1625 2}
# cnvintegr -> term557 Nt=1 TF=1 maxTF=1 @{0 1627 6}
# cod -> term1172 Nt=1 TF=1 maxTF=1 @{0 1629 6}
# code -> term472 Nt=5 TF=5 maxTF=1 @{0 1632 0}
# coel -> term783 Nt=2 TF=2 maxTF=1 @{0 1640 6}
# coexpress -> term827 Nt=1 TF=1 maxTF=1 @{0 1645 2}
# cofunct -> term6 Nt=1 TF=1 maxTF=1 @{0 1647 4}
# cognit -> term1771 Nt=1 TF=1 maxTF=1 @{0 1647 6}
# coi -> term487 Nt=2 TF=2 maxTF=1 @{0 1650 2}
# coin -> term589 Nt=1 TF=1 maxTF=1 @{0 1653 4}
# coli -> term1 Nt=1 TF=1 maxTF=1 @{0 1655 4}
# collabor -> term852 Nt=5 TF=5 maxTF=1 @{0 1655 6}
# collect -> term251 Nt=15 TF=15 maxTF=1 @{0 1664 4}
# collectnet -> term1604 Nt=1 TF=1 maxTF=1 @{0 1685 4}
# colon -> term1930 Nt=1 TF=1 maxTF=1 @{0 1688 0}
# colorect -> term1486 Nt=1 TF=1 maxTF=1 @{0 1690 4}
# column -> term193 Nt=4 TF=4 maxTF=1 @{0 1693 0}
# com -> term395 Nt=1 TF=1 maxTF=1 @{0 1700 0}
# commerc -> term839 Nt=1 TF=1 maxTF=1 @{0 1701 6}
# commerci -> term737 Nt=2 TF=2 maxTF=1 @{0 1704 0}
# committe -> term787 Nt=1 TF=1 maxTF=1 @{0 1708 2}
# common -> term341 Nt=4 TF=4 maxTF=1 @{0 1710 2}
# commun -> term329 Nt=12 TF=12 maxTF=1 @{0 1718 0}
# compani -> term211 Nt=1 TF=1 maxTF=1 @{0 1737 6}
# compar -> term121 Nt=10 TF=10 maxTF=1 @{0 1739 2}
# comparison -> term123 Nt=7 TF=7 maxTF=1 @{0 1754 4}
# compart -> term652 Nt=1 TF=1 maxTF=1 @{0 1766 0}
# compcon -> term1634 Nt=1 TF=1 maxTF=1 @{0 1768 0}
# compendia -> term861 Nt=1 TF=1 maxTF=1 @{0 1770 4}
# compet -> term933 Nt=1 TF=1 maxTF=1 @{0 1772 6}
# competit -> term1585 Nt=1 TF=1 maxTF=1 @{0 1775 0}
# compil -> term997 Nt=3 TF=3 maxTF=1 @{0 1777 4}
# complet -> term1366 Nt=1 TF=1 maxTF=1 @{0 1784 0}
# complex -> term752 Nt=7 TF=7 maxTF=1 @{0 1786 4}
# complic -> term1330 Nt=1 TF=1 maxTF=1 @{0 1797 2}
# compon -> term1084 Nt=3 TF=3 maxTF=1 @{0 1799 6}
# compound -> term358 Nt=1 TF=1 maxTF=1 @{0 1805 6}
# comprehens -> term223 Nt=30 TF=30 maxTF=1 @{0 1807 4}
# compress -> term191 Nt=2 TF=2 maxTF=1 @{0 1836 4}
# comput -> term647 Nt=10 TF=10 maxTF=1 @{0 1839 4}
# concept -> term923 Nt=7 TF=7 maxTF=1 @{0 1857 2}
# conceptu -> term498 Nt=4 TF=4 maxTF=1 @{0 1868 4}
# concurr -> term1281 Nt=5 TF=5 maxTF=1 @{0 1876 6}
# condens -> term1764 Nt=1 TF=1 maxTF=1 @{0 1885 4}
# condit -> term258 Nt=4 TF=4 maxTF=1 @{0 1888 0}
# confer -> term788 Nt=2 TF=2 maxTF=1 @{0 1895 0}
# confid -> term1448 Nt=1 TF=1 maxTF=1 @{0 1899 2}
# conflict -> term1761 Nt=1 TF=1 maxTF=1 @{0 1901 6}
# conform -> term709 Nt=2 TF=2 maxTF=1 @{0 1904 2}
# connect -> term966 Nt=1 TF=1 maxTF=1 @{0 1908 6}
# consciou -> term805 Nt=1 TF=1 maxTF=1 @{0 1911 0}
# consensuspathdb -> term76 Nt=1 TF=1 maxTF=1 @{0 1913 0}
# consequ -> term1260 Nt=1 TF=1 maxTF=1 @{0 1914 2}
# conserv -> term915 Nt=3 TF=3 maxTF=1 @{0 1916 6}
# consist -> term874 Nt=6 TF=6 maxTF=1 @{0 1923 2}
# consolid -> term402 Nt=4 TF=4 maxTF=1 @{0 1934 2}
# consortium -> term183 Nt=3 TF=3 maxTF=1 @{0 1942 0}
# constraint -> term151 Nt=3 TF=3 maxTF=1 @{0 1947 4}
# constrict -> term1308 Nt=1 TF=1 maxTF=1 @{0 1953 4}
# construct -> term714 Nt=3 TF=3 maxTF=1 @{0 1956 0}
# consum -> term1519 Nt=1 TF=1 maxTF=1 @{0 1961 6}
# consumpt -> term515 Nt=1 TF=1 maxTF=1 @{0 1964 2}
# contain -> term917 Nt=2 TF=2 maxTF=1 @{0 1966 2}
# content -> term747 Nt=5 TF=5 maxTF=1 @{0 1970 6}
# context -> term154 Nt=4 TF=4 maxTF=1 @{0 1980 2}
# continu -> term393 Nt=3 TF=3 maxTF=1 @{0 1987 0}
# contrast -> term1271 Nt=1 TF=1 maxTF=1 @{0 1993 2}
# control -> term100 Nt=10 TF=10 maxTF=1 @{0 1995 6}
# convert -> term1937 Nt=1 TF=1 maxTF=1 @{0 2011 4}
# cooper -> term1196 Nt=2 TF=2 maxTF=1 @{0 2014 0}
# coordin -> term720 Nt=4 TF=4 maxTF=1 @{0 2018 4}
# copac -> term1671 Nt=2 TF=2 maxTF=1 @{0 2026 4}
# copi -> term560 Nt=1 TF=1 maxTF=1 @{0 2030 6}
# copyright -> term878 Nt=1 TF=1 maxTF=1 @{0 2032 6}
# corecg -> term1931 Nt=1 TF=1 maxTF=1 @{0 2035 0}
# coronaviru -> term185 Nt=1 TF=1 maxTF=1 @{0 2037 4}
# corpora -> term1419 Nt=1 TF=1 maxTF=1 @{0 2039 0}
# corpu -> term1402 Nt=4 TF=4 maxTF=1 @{0 2041 4}
# correct -> term1160 Nt=2 TF=2 maxTF=1 @{0 2047 4}
# correl -> term627 Nt=1 TF=1 maxTF=1 @{0 2052 2}
# corynebacteri -> term846 Nt=1 TF=1 maxTF=1 @{0 2054 2}
# cosfish -> term486 Nt=1 TF=1 maxTF=1 @{0 2056 4}
# cosmic -> term1224 Nt=1 TF=1 maxTF=1 @{0 2058 4}
# cost -> term1878 Nt=2 TF=2 maxTF=1 @{0 2061 0}
# coumarin -> term363 Nt=1 TF=1 maxTF=1 @{0 2065 0}
# count -> term1014 Nt=1 TF=1 maxTF=1 @{0 2066 6}
# cours -> term801 Nt=2 TF=2 maxTF=1 @{0 2069 0}
# cov -> term433 Nt=4 TF=4 maxTF=1 @{0 2073 2}
# cover -> term1653 Nt=1 TF=1 maxTF=1 @{0 2080 2}
# coverag -> term910 Nt=4 TF=4 maxTF=1 @{0 2082 6}
# covid -> term629 Nt=5 TF=5 maxTF=1 @{0 2090 2}
# covidoutcom -> term1515 Nt=1 TF=1 maxTF=1 @{0 2098 0}
# coxpresdb -> term828 Nt=1 TF=1 maxTF=1 @{0 2100 4}
# cpmkg -> term1355 Nt=1 TF=1 maxTF=1 @{0 2102 6}
# cpndb -> term1748 Nt=1 TF=1 maxTF=1 @{0 2105 2}
# cpu -> term1242 Nt=1 TF=1 maxTF=1 @{0 2107 6}
# crack -> term926 Nt=1 TF=1 maxTF=1 @{0 2110 2}
# creat -> term851 Nt=3 TF=4 maxTF=2 @{0 2112 4}
# creation -> term729 Nt=3 TF=3 maxTF=1 @{0 2117 1}
# credo -> term1668 Nt=1 TF=1 maxTF=1 @{0 2123 3}
# crf -> term1537 Nt=1 TF=1 maxTF=1 @{0 2125 7}
# crispr -> term1390 Nt=1 TF=1 maxTF=1 @{0 2128 3}
# critic -> term1173 Nt=3 TF=3 maxTF=1 @{0 2130 7}
# criu -> term410 Nt=1 TF=1 maxTF=1 @{0 2136 5}
# crop -> term1538 Nt=2 TF=2 maxTF=1 @{0 2138 3}
# cross -> term417 Nt=3 TF=3 maxTF=1 @{0 2142 7}
# crowd -> term1682 Nt=1 TF=1 maxTF=1 @{0 2148 5}
# cu -> term703 Nt=1 TF=1 maxTF=1 @{0 2151 1}
# cultiv -> term301 Nt=1 TF=1 maxTF=1 @{0 2153 1}
# cultivar -> term1888 Nt=1 TF=1 maxTF=1 @{0 2154 7}
# cultur -> term1779 Nt=1 TF=1 maxTF=1 @{0 2157 3}
# cupca -> term1531 Nt=1 TF=1 maxTF=1 @{0 2159 7}
# cuproptosi -> term1532 Nt=1 TF=1 maxTF=1 @{0 2162 3}
# curat -> term197 Nt=28 TF=28 maxTF=1 @{0 2164 7}
# curcumin -> term1019 Nt=1 TF=1 maxTF=1 @{0 2194 7}
# cure -> term445 Nt=1 TF=1 maxTF=1 @{0 2197 1}
# current -> term1143 Nt=2 TF=2 maxTF=1 @{0 2199 1}
# cybercrim -> term207 Nt=1 TF=1 maxTF=1 @{0 2203 5}
# cyp -> term350 Nt=1 TF=1 maxTF=1 @{0 2205 1}
# cytochrom -> term352 Nt=1 TF=1 maxTF=1 @{0 2206 7}
# cytoscap -> term1697 Nt=1 TF=1 maxTF=1 @{0 2208 5}
# cytosin -> term685 Nt=2 TF=2 maxTF=1 @{0 2211 1}
# cytosql -> term1698 Nt=1 TF=1 maxTF=1 @{0 2215 5}
# d2r -> term1237 Nt=3 TF=3 maxTF=1 @{0 2218 1}
# damag -> term1749 Nt=1 TF=1 maxTF=1 @{0 2221 7}
# dapredict -> term271 Nt=1 TF=1 maxTF=1 @{0 2224 3}
# dat -> term1649 Nt=1 TF=1 maxTF=1 @{0 2226 1}
# data -> term101 Nt=72 TF=75 maxTF=2 @{0 2228 5}
# databank -> term1170 Nt=1 TF=1 maxTF=1 @{0 2295 2}
# databas -> term5 Nt=847 TF=897 maxTF=2 @{0 2297 4}
# dataflow -> term114 Nt=1 TF=1 maxTF=1 @{0 2530 4}
# dataloga -> term1859 Nt=1 TF=1 maxTF=1 @{0 2531 6}
# datapump -> term992 Nt=1 TF=1 maxTF=1 @{0 2534 2}
# dataset -> term318 Nt=11 TF=12 maxTF=2 @{0 2536 4}
# dataspac -> term1133 Nt=3 TF=3 maxTF=1 @{0 2551 7}
# date -> term1393 Nt=1 TF=1 maxTF=1 @{0 2556 3}
# db -> term462 Nt=6 TF=6 maxTF=1 @{0 2558 7}
# db2 -> term1247 Nt=1 TF=1 maxTF=1 @{0 2569 7}
# dbate -> term1208 Nt=1 TF=1 maxTF=1 @{0 2572 3}
# dbc -> term1679 Nt=1 TF=1 maxTF=1 @{0 2574 5}
# dbget -> term168 Nt=1 TF=1 maxTF=1 @{0 2577 1}
# dbm -> term1805 Nt=1 TF=1 maxTF=1 @{0 2578 5}
# dbptb -> term1205 Nt=1 TF=1 maxTF=1 @{0 2581 1}
# dbtb -> term916 Nt=1 TF=1 maxTF=1 @{0 2583 3}
# ddrprot -> term1750 Nt=1 TF=1 maxTF=1 @{0 2585 5}
# de -> term778 Nt=3 TF=3 maxTF=1 @{0 2588 1}
# death -> term638 Nt=1 TF=1 maxTF=1 @{0 2593 1}
# decad -> term789 Nt=1 TF=1 maxTF=1 @{0 2595 1}
# decentralis -> term1046 Nt=1 TF=1 maxTF=1 @{0 2597 1}
# deciph -> term1632 Nt=1 TF=1 maxTF=1 @{0 2599 3}
# decis -> term1284 Nt=2 TF=2 maxTF=1 @{0 2601 7}
# declar -> term1947 Nt=1 TF=1 maxTF=1 @{0 2606 3}
# decod -> term1081 Nt=1 TF=1 maxTF=1 @{0 2608 7}
# decomposit -> term1211 Nt=1 TF=1 maxTF=1 @{0 2611 1}
# decoupl -> term1638 Nt=1 TF=1 maxTF=1 @{0 2613 3}
# dedic -> term1781 Nt=1 TF=1 maxTF=1 @{0 2615 7}
# deduct -> term1358 Nt=6 TF=6 maxTF=1 @{0 2618 3}
# deep -> term1533 Nt=1 TF=1 maxTF=1 @{0 2627 5}
# definit -> term1768 Nt=1 TF=1 maxTF=1 @{0 2630 1}
# degrad -> term1456 Nt=3 TF=3 maxTF=1 @{0 2632 5}
# deja -> term1711 Nt=1 TF=1 maxTF=1 @{0 2639 1}
# denot -> term691 Nt=1 TF=1 maxTF=1 @{0 2641 5}
# depend -> term1641 Nt=2 TF=2 maxTF=1 @{0 2643 5}
# depress -> term1400 Nt=1 TF=1 maxTF=1 @{0 2648 1}
# deriv -> term361 Nt=5 TF=5 maxTF=1 @{0 2650 5}
# derivatis -> term1238 Nt=1 TF=1 maxTF=1 @{0 2659 7}
# descript -> term1121 Nt=3 TF=3 maxTF=1 @{0 2662 3}
# design -> term42 Nt=39 TF=40 maxTF=2 @{0 2667 7}
# detect -> term1174 Nt=12 TF=12 maxTF=1 @{0 2712 2}
# develop -> term7 Nt=14 TF=14 maxTF=1 @{0 2725 2}
# dfg -> term986 Nt=1 TF=1 maxTF=1 @{0 2743 2}
# dfvf -> term1204 Nt=1 TF=1 maxTF=1 @{0 2745 4}
# diagnosi -> term1169 Nt=3 TF=3 maxTF=1 @{0 2747 6}
# diagnost -> term1542 Nt=1 TF=1 maxTF=1 @{0 2753 0}
# dictionari -> term1078 Nt=4 TF=4 maxTF=1 @{0 2755 4}
# differ -> term1258 Nt=2 TF=2 maxTF=1 @{0 2762 6}
# digit -> term965 Nt=2 TF=2 maxTF=1 @{0 2767 4}
# dii -> term1702 Nt=1 TF=1 maxTF=1 @{0 2772 0}
# dilemma -> term1051 Nt=1 TF=1 maxTF=1 @{0 2774 4}
# dimension -> term945 Nt=1 TF=1 maxTF=1 @{0 2776 6}
# dip -> term819 Nt=2 TF=2 maxTF=1 @{0 2779 0}
# diploid -> term1696 Nt=1 TF=1 maxTF=1 @{0 2783 4}
# direct -> term1510 Nt=2 TF=2 maxTF=1 @{0 2786 0}
# dirmc -> term264 Nt=1 TF=1 maxTF=1 @{0 2790 0}
# disast -> term1650 Nt=1 TF=1 maxTF=1 @{0 2791 6}
# disclosur -> term1956 Nt=1 TF=1 maxTF=1 @{0 2794 2}
# discov -> term405 Nt=5 TF=5 maxTF=1 @{0 2796 6}
# discoveri -> term425 Nt=13 TF=13 maxTF=1 @{0 2805 4}
# diseas -> term158 Nt=24 TF=25 maxTF=2 @{0 2825 2}
# disjunct -> term1639 Nt=1 TF=1 maxTF=1 @{0 2853 3}
# dismutas -> term702 Nt=1 TF=1 maxTF=1 @{0 2855 7}
# disord -> term1399 Nt=3 TF=3 maxTF=1 @{0 2857 7}
# dispar -> term1442 Nt=2 TF=2 maxTF=1 @{0 2862 7}
# dispel -> term441 Nt=1 TF=1 maxTF=1 @{0 2866 7}
# displai -> term1623 Nt=1 TF=1 maxTF=1 @{0 2868 7}
# disprot -> term1541 Nt=1 TF=1 maxTF=1 @{0 2871 3}
# dissemin -> term1950 Nt=1 TF=1 maxTF=1 @{0 2873 7}
# distanc -> term1798 Nt=1 TF=1 maxTF=1 @{0 2876 3}
# distribut -> term91 Nt=25 TF=25 maxTF=1 @{0 2878 7}
# disturb -> term340 Nt=1 TF=1 maxTF=1 @{0 2907 5}
# divers -> term704 Nt=3 TF=3 maxTF=1 @{0 2909 3}
# dml -> term1546 Nt=1 TF=1 maxTF=1 @{0 2915 1}
# dna -> term588 Nt=5 TF=5 maxTF=1 @{0 2917 5}
# dock -> term833 Nt=1 TF=1 maxTF=1 @{0 2926 5}
# document -> term478 Nt=8 TF=8 maxTF=1 @{0 2928 7}
# doda -> term1853 Nt=1 TF=1 maxTF=1 @{0 2941 7}
# domain -> term196 Nt=6 TF=7 maxTF=2 @{0 2944 3}
# dooml -> term1180 Nt=1 TF=1 maxTF=1 @{0 2955 0}
# drgkb -> term1551 Nt=1 TF=1 maxTF=1 @{0 2957 2}
# driven -> term117 Nt=12 TF=12 maxTF=1 @{0 2959 6}
# driver -> term1840 Nt=1 TF=2 maxTF=2 @{0 2979 4}
# drone -> term1614 Nt=1 TF=1 maxTF=1 @{0 2982 1}
# drosophila -> term1549 Nt=2 TF=2 maxTF=1 @{0 2984 5}
# drought -> term1300 Nt=1 TF=2 maxTF=2 @{0 2989 1}
# drug -> term8 Nt=17 TF=18 maxTF=2 @{0 2991 6}
# drugprot -> term1373 Nt=1 TF=1 maxTF=1 @{0 3015 5}
# drugrepobank -> term428 Nt=1 TF=1 maxTF=1 @{0 3018 1}
# drumpid -> term9 Nt=1 TF=1 maxTF=1 @{0 3019 7}
# dssat -> term1261 Nt=1 TF=2 maxTF=2 @{0 3020 3}
# dtd -> term1954 Nt=1 TF=1 maxTF=1 @{0 3023 0}
# duo -> term1030 Nt=1 TF=1 maxTF=1 @{0 3025 4}
# duplic -> term1159 Nt=4 TF=4 maxTF=1 @{0 3027 6}
# dutch -> term1413 Nt=1 TF=1 maxTF=1 @{0 3035 2}
# dyadic -> term1501 Nt=1 TF=1 maxTF=1 @{0 3037 6}
# dynam -> term689 Nt=11 TF=12 maxTF=2 @{0 3040 2}
# dynameom -> term690 Nt=1 TF=1 maxTF=1 @{0 3051 5}
# e3 -> term1454 Nt=1 TF=1 maxTF=1 @{0 3053 5}
# ear -> term62 Nt=1 TF=1 maxTF=1 @{0 3056 1}
# earthquak -> term1708 Nt=1 TF=1 maxTF=1 @{0 3057 1}
# easier -> term1557 Nt=1 TF=1 maxTF=1 @{0 3059 5}
# east -> term1815 Nt=1 TF=1 maxTF=1 @{0 3062 1}
# eastern -> term1961 Nt=1 TF=1 maxTF=1 @{0 3064 5}
# eccdna -> term1554 Nt=1 TF=1 maxTF=1 @{0 3067 1}
# echinobas -> term1443 Nt=1 TF=1 maxTF=1 @{0 3069 5}
# echinoderm -> term1340 Nt=1 TF=1 maxTF=1 @{0 3072 1}
# ecolinet -> term0 Nt=1 TF=1 maxTF=1 @{0 3074 5}
# ecolog -> term725 Nt=3 TF=5 maxTF=2 @{0 3074 7}
# ecologist -> term1086 Nt=1 TF=1 maxTF=1 @{0 3079 7}
# econom -> term1002 Nt=1 TF=1 maxTF=1 @{0 3082 1}
# ecosystem -> term987 Nt=1 TF=1 maxTF=1 @{0 3084 3}
# edbt -> term1498 Nt=1 TF=1 maxTF=1 @{0 3086 5}
# edit -> term171 Nt=8 TF=8 maxTF=1 @{0 3089 1}
# editor -> term1276 Nt=1 TF=1 maxTF=1 @{0 3103 7}
# editosom -> term1789 Nt=1 TF=2 maxTF=2 @{0 3106 3}
# educ -> term1010 Nt=1 TF=1 maxTF=1 @{0 3109 0}
# eee -> term1248 Nt=1 TF=1 maxTF=1 @{0 3111 2}
# effect -> term883 Nt=6 TF=6 maxTF=1 @{0 3113 6}
# effici -> term14 Nt=5 TF=5 maxTF=1 @{0 3124 4}
# egg -> term1287 Nt=1 TF=1 maxTF=1 @{0 3132 0}
# einkorn -> term577 Nt=1 TF=1 maxTF=1 @{0 3134 4}
# elast -> term1661 Nt=1 TF=1 maxTF=1 @{0 3136 4}
# electromagnet -> term1786 Nt=1 TF=1 maxTF=1 @{0 3139 0}
# electron -> term517 Nt=15 TF=15 maxTF=1 @{0 3141 4}
# element -> term598 Nt=2 TF=2 maxTF=1 @{0 3160 0}
# eleven -> term829 Nt=1 TF=1 maxTF=1 @{0 3164 4}
# eliah -> term1453 Nt=1 TF=1 maxTF=1 @{0 3166 6}
# ellipsi -> term1942 Nt=1 TF=1 maxTF=1 @{0 3169 2}
# elucid -> term1535 Nt=1 TF=1 maxTF=1 @{0 3171 6}
# em -> term1648 Nt=1 TF=1 maxTF=1 @{0 3174 2}
# emancip -> term796 Nt=1 TF=1 maxTF=1 @{0 3176 6}
# embed -> term1005 Nt=2 TF=2 maxTF=1 @{0 3178 6}
# emot -> term1502 Nt=1 TF=1 maxTF=1 @{0 3183 2}
# emphas -> term1230 Nt=1 TF=1 maxTF=1 @{0 3185 6}
# empir -> term799 Nt=2 TF=2 maxTF=1 @{0 3188 2}
# enabl -> term39 Nt=3 TF=3 maxTF=1 @{0 3192 6}
# encapsul -> term1472 Nt=1 TF=1 maxTF=1 @{0 3198 0}
# encd -> term539 Nt=1 TF=1 maxTF=1 @{0 3200 4}
# encod -> term1082 Nt=2 TF=2 maxTF=1 @{0 3202 4}
# encrypt -> term855 Nt=6 TF=6 maxTF=1 @{0 3207 0}
# encyclopedia -> term275 Nt=8 TF=8 maxTF=1 @{0 3217 6}
# end -> term1085 Nt=4 TF=5 maxTF=2 @{0 3231 0}
# endang -> term710 Nt=1 TF=1 maxTF=1 @{0 3238 3}
# endocrin -> term538 Nt=1 TF=1 maxTF=1 @{0 3240 3}
# engin -> term26 Nt=11 TF=11 maxTF=1 @{0 3242 3}
# english -> term767 Nt=3 TF=3 maxTF=1 @{0 3258 3}
# enhanc -> term422 Nt=9 TF=9 maxTF=1 @{0 3263 7}
# ensembl -> term1444 Nt=1 TF=1 maxTF=1 @{0 3278 7}
# enterpris -> term1068 Nt=1 TF=1 maxTF=1 @{0 3281 3}
# enthusiast -> term1060 Nt=1 TF=1 maxTF=1 @{0 3283 5}
# entiti -> term148 Nt=10 TF=11 maxTF=2 @{0 3285 7}
# entomolog -> term228 Nt=1 TF=1 maxTF=1 @{0 3299 2}
# entrez -> term1028 Nt=1 TF=1 maxTF=1 @{0 3300 6}
# environ -> term497 Nt=10 TF=10 maxTF=1 @{0 3303 0}
# environment -> term1142 Nt=1 TF=1 maxTF=1 @{0 3319 4}
# enzym -> term142 Nt=9 TF=10 maxTF=2 @{0 3321 6}
# eon -> term1108 Nt=1 TF=1 maxTF=1 @{0 3337 1}
# epidem -> term621 Nt=1 TF=1 maxTF=1 @{0 3339 3}
# epidemiolog -> term1168 Nt=1 TF=1 maxTF=1 @{0 3341 3}
# epigenet -> term1217 Nt=1 TF=1 maxTF=1 @{0 3343 5}
# episurf -> term1335 Nt=1 TF=1 maxTF=1 @{0 3346 1}
# epitop -> term431 Nt=2 TF=2 maxTF=1 @{0 3348 5}
# eqtl -> term591 Nt=1 TF=1 maxTF=1 @{0 3352 5}
# eric -> term1013 Nt=1 TF=1 maxTF=1 @{0 3354 5}
# error -> term150 Nt=2 TF=2 maxTF=1 @{0 3356 7}
# escherichia -> term2 Nt=1 TF=1 maxTF=1 @{0 3360 5}
# esomir -> term491 Nt=1 TF=1 maxTF=1 @{0 3360 7}
# esophag -> term490 Nt=1 TF=1 maxTF=1 @{0 3362 7}
# essenti -> term807 Nt=2 TF=2 maxTF=1 @{0 3364 7}
# establish -> term1746 Nt=1 TF=1 maxTF=1 @{0 3369 3}
# estim -> term1513 Nt=1 TF=1 maxTF=1 @{0 3371 7}
# ethnic -> term558 Nt=2 TF=2 maxTF=1 @{0 3374 3}
# eukaryom -> term385 Nt=1 TF=1 maxTF=1 @{0 3378 7}
# eukaryot -> term384 Nt=2 TF=2 maxTF=1 @{0 3380 5}
# europ -> term906 Nt=2 TF=2 maxTF=1 @{0 3384 3}
# european -> term244 Nt=3 TF=3 maxTF=1 @{0 3389 1}
# eurowordnet -> term1691 Nt=1 TF=1 maxTF=1 @{0 3395 1}
# evalu -> term723 Nt=14 TF=14 maxTF=1 @{0 3397 5}
# evauat -> term60 Nt=1 TF=1 maxTF=1 @{0 3417 7}
# event -> term503 Nt=4 TF=4 maxTF=1 @{0 3418 7}
# evid -> term653 Nt=2 TF=2 maxTF=1 @{0 3426 1}
# evolut -> term1027 Nt=4 TF=4 maxTF=1 @{0 3429 7}
# evolutionari -> term812 Nt=5 TF=5 maxTF=1 @{0 3437 1}
# evolutionori -> term451 Nt=1 TF=1 maxTF=1 @{0 3443 3}
# exchang -> term1194 Nt=1 TF=1 maxTF=1 @{0 3445 3}
# excit -> term1189 Nt=2 TF=2 maxTF=1 @{0 3447 5}
# exclus -> term1640 Nt=2 TF=2 maxTF=1 @{0 3450 3}
# execut -> term194 Nt=2 TF=2 maxTF=1 @{0 3454 7}
# exist -> term1190 Nt=2 TF=2 maxTF=1 @{0 3458 7}
# expans -> term1683 Nt=1 TF=1 maxTF=1 @{0 3461 5}
# experi -> term982 Nt=4 TF=4 maxTF=1 @{0 3464 1}
# experiment -> term22 Nt=8 TF=8 maxTF=1 @{0 3471 3}
# expert -> term994 Nt=6 TF=6 maxTF=1 @{0 3483 3}
# explor -> term746 Nt=7 TF=7 maxTF=1 @{0 3494 1}
# express -> term594 Nt=11 TF=11 maxTF=1 @{0 3505 3}
# extend -> term721 Nt=5 TF=5 maxTF=1 @{0 3523 3}
# extens -> term315 Nt=7 TF=7 maxTF=1 @{0 3532 3}
# extent -> term1721 Nt=1 TF=1 maxTF=1 @{0 3543 1}
# extract -> term676 Nt=19 TF=19 maxTF=1 @{0 3545 5}
# f1 -> term1157 Nt=1 TF=1 maxTF=1 @{0 3566 7}
# fabric -> term1979 Nt=1 TF=1 maxTF=1 @{0 3569 1}
# face -> term663 Nt=1 TF=1 maxTF=1 @{0 3571 5}
# facil -> term552 Nt=1 TF=1 maxTF=1 @{0 3573 5}
# facilit -> term601 Nt=5 TF=5 maxTF=1 @{0 3575 5}
# factor -> term204 Nt=7 TF=7 maxTF=1 @{0 3584 1}
# fad -> term84 Nt=1 TF=1 maxTF=1 @{0 3595 7}
# failur -> term1153 Nt=1 TF=1 maxTF=1 @{0 3597 1}
# famili -> term1229 Nt=6 TF=6 maxTF=1 @{0 3599 3}
# far -> term1819 Nt=1 TF=1 maxTF=1 @{0 3610 1}
# fast -> term897 Nt=3 TF=3 maxTF=1 @{0 3612 5}
# fatplant -> term1291 Nt=1 TF=1 maxTF=1 @{0 3618 1}
# faunist -> term1862 Nt=5 TF=5 maxTF=1 @{0 3620 5}
# feasibl -> term973 Nt=1 TF=1 maxTF=1 @{0 3626 7}
# featur -> term260 Nt=3 TF=3 maxTF=1 @{0 3629 1}
# feda -> term632 Nt=1 TF=1 maxTF=1 @{0 3634 1}
# feder -> term92 Nt=7 TF=7 maxTF=1 @{0 3636 1}
# fgcd -> term366 Nt=1 TF=1 maxTF=1 @{0 3647 1}
# field -> term1026 Nt=1 TF=1 maxTF=1 @{0 3648 7}
# filariasi -> term615 Nt=1 TF=1 maxTF=1 @{0 3651 1}
# fill -> term1570 Nt=1 TF=1 maxTF=1 @{0 3653 1}
# filoviru -> term1753 Nt=1 TF=1 maxTF=1 @{0 3655 5}
# find -> term1144 Nt=2 TF=2 maxTF=1 @{0 3658 1}
# finder -> term956 Nt=1 TF=1 maxTF=1 @{0 3662 3}
# fine -> term891 Nt=1 TF=1 maxTF=1 @{0 3664 5}
# fingerprint -> term739 Nt=2 TF=2 maxTF=1 @{0 3666 7}
# fingertip -> term1820 Nt=1 TF=1 maxTF=1 @{0 3670 7}
# finit -> term1870 Nt=1 TF=1 maxTF=1 @{0 3673 3}
# fire -> term949 Nt=1 TF=2 maxTF=2 @{0 3675 7}
# first -> term556 Nt=2 TF=2 maxTF=1 @{0 3678 2}
# fish -> term485 Nt=3 TF=3 maxTF=1 @{0 3682 6}
# fishtedb -> term599 Nt=1 TF=1 maxTF=1 @{0 3688 4}
# flexibl -> term808 Nt=4 TF=4 maxTF=1 @{0 3690 4}
# flickr -> term884 Nt=1 TF=1 maxTF=1 @{0 3697 6}
# flow -> term1267 Nt=1 TF=1 maxTF=1 @{0 3700 0}
# fluid -> term189 Nt=1 TF=1 maxTF=1 @{0 3702 4}
# flyvar -> term1738 Nt=1 TF=1 maxTF=1 @{0 3704 0}
# focus -> term616 Nt=1 TF=1 maxTF=1 @{0 3706 4}
# fold -> term866 Nt=1 TF=1 maxTF=1 @{0 3708 4}
# food -> term633 Nt=4 TF=5 maxTF=2 @{0 3710 6}
# fopgdb -> term415 Nt=1 TF=1 maxTF=1 @{0 3718 3}
# for1246 -> term985 Nt=1 TF=1 maxTF=1 @{0 3720 1}
# forens -> term227 Nt=4 TF=4 maxTF=1 @{0 3722 3}
# formal -> term823 Nt=2 TF=2 maxTF=1 @{0 3730 3}
# fraction -> term1297 Nt=1 TF=1 maxTF=1 @{0 3734 3}
# framenet -> term1277 Nt=1 TF=1 maxTF=1 @{0 3736 7}
# framework -> term696 Nt=9 TF=9 maxTF=1 @{0 3739 3}
# fre -> term1380 Nt=1 TF=1 maxTF=1 @{0 3754 1}
# free -> term769 Nt=3 TF=3 maxTF=1 @{0 3756 5}
# freebas -> term853 Nt=2 TF=2 maxTF=1 @{0 3761 1}
# fresh -> term1102 Nt=1 TF=1 maxTF=1 @{0 3764 3}
# friend -> term838 Nt=1 TF=1 maxTF=1 @{0 3766 5}
# friendli -> term408 Nt=2 TF=2 maxTF=1 @{0 3768 7}
# frontier -> term436 Nt=1 TF=1 maxTF=1 @{0 3772 1}
# fsrd -> term1120 Nt=1 TF=1 maxTF=1 @{0 3774 1}
# function -> term77 Nt=18 TF=18 maxTF=1 @{0 3776 3}
# fundament -> term602 Nt=8 TF=8 maxTF=1 @{0 3801 5}
# fungal -> term364 Nt=4 TF=4 maxTF=1 @{0 3812 3}
# fungi -> term391 Nt=2 TF=2 maxTF=1 @{0 3818 7}
# fungiofpakistan -> term394 Nt=1 TF=1 maxTF=1 @{0 3822 7}
# fungu -> term1385 Nt=1 TF=1 maxTF=1 @{0 3824 5}
# fusarium -> term414 Nt=1 TF=1 maxTF=1 @{0 3827 1}
# fuse -> term651 Nt=1 TF=1 maxTF=1 @{0 3828 7}
# futur -> term83 Nt=3 TF=3 maxTF=1 @{0 3830 7}
# gabi -> term240 Nt=1 TF=1 maxTF=1 @{0 3836 1}
# gabipd -> term242 Nt=1 TF=1 maxTF=1 @{0 3837 7}
# game -> term1851 Nt=1 TF=1 maxTF=1 @{0 3839 5}
# gamif -> term800 Nt=1 TF=1 maxTF=1 @{0 3842 1}
# gamma -> term116 Nt=2 TF=2 maxTF=1 @{0 3844 1}
# gap -> term1571 Nt=1 TF=1 maxTF=1 @{0 3847 3}
# gatewai -> term1322 Nt=1 TF=1 maxTF=1 @{0 3849 7}
# gather -> term636 Nt=1 TF=1 maxTF=1 @{0 3852 3}
# gatmd -> term1489 Nt=1 TF=1 maxTF=1 @{0 3854 3}
# gemini -> term1617 Nt=1 TF=1 maxTF=1 @{0 3856 7}
# gemo -> term1610 Nt=1 TF=1 maxTF=1 @{0 3859 3}
# genbank -> term1580 Nt=1 TF=1 maxTF=1 @{0 3861 7}
# gene -> term3 Nt=43 TF=44 maxTF=2 @{0 3864 3}
# genefriend -> term824 Nt=1 TF=1 maxTF=1 @{0 3909 6}
# geneom -> term1980 Nt=1 TF=1 maxTF=1 @{0 3912 0}
# genepattern -> term338 Nt=1 TF=1 maxTF=1 @{0 3914 4}
# gener -> term868 Nt=15 TF=15 maxTF=1 @{0 3916 2}
# genet -> term231 Nt=8 TF=8 maxTF=1 @{0 3938 0}
# geniepool -> term1437 Nt=1 TF=1 maxTF=1 @{0 3951 4}
# genom -> term67 Nt=48 TF=51 maxTF=2 @{0 3954 0}
# genotyp -> term1825 Nt=1 TF=1 maxTF=1 @{0 4006 1}
# geo -> term862 Nt=3 TF=3 maxTF=1 @{0 4008 5}
# geograph -> term1666 Nt=1 TF=1 maxTF=1 @{0 4014 3}
# geospati -> term1773 Nt=1 TF=1 maxTF=1 @{0 4016 7}
# geotherm -> term188 Nt=1 TF=1 maxTF=1 @{0 4019 3}
# german -> term1257 Nt=1 TF=1 maxTF=1 @{0 4020 7}
# germlin -> term575 Nt=1 TF=1 maxTF=1 @{0 4023 3}
# gfdp -> term1492 Nt=1 TF=1 maxTF=1 @{0 4025 3}
# gigascop -> term1915 Nt=1 TF=1 maxTF=1 @{0 4027 7}
# glcnacom -> term528 Nt=1 TF=1 maxTF=1 @{0 4030 3}
# glida -> term1945 Nt=1 TF=1 maxTF=1 @{0 4032 3}
# glioblastoma -> term1088 Nt=1 TF=1 maxTF=1 @{0 4034 7}
# global -> term238 Nt=10 TF=10 maxTF=1 @{0 4037 1}
# globin -> term377 Nt=1 TF=1 maxTF=1 @{0 4052 1}
# glycan -> term1603 Nt=1 TF=1 maxTF=1 @{0 4053 7}
# glycim -> term1808 Nt=1 TF=1 maxTF=1 @{0 4056 3}
# glycosci -> term963 Nt=1 TF=1 maxTF=1 @{0 4058 7}
# gmmid -> term234 Nt=1 TF=1 maxTF=1 @{0 4061 1}
# gnomad -> term1432 Nt=1 TF=1 maxTF=1 @{0 4062 5}
# goal -> term730 Nt=1 TF=1 maxTF=1 @{0 4065 1}
# gossym -> term1807 Nt=1 TF=1 maxTF=1 @{0 4067 1}
# gosynthet -> term27 Nt=2 TF=2 maxTF=1 @{0 4069 5}
# govern -> term1048 Nt=1 TF=1 maxTF=1 @{0 4072 7}
# gpcr -> term1944 Nt=1 TF=1 maxTF=1 @{0 4075 1}
# gpt -> term1618 Nt=1 TF=1 maxTF=1 @{0 4077 5}
# gpu -> term649 Nt=1 TF=1 maxTF=1 @{0 4080 1}
# grain -> term892 Nt=2 TF=2 maxTF=1 @{0 4082 1}
# granular -> term1474 Nt=1 TF=1 maxTF=1 @{0 4086 5}
# graph -> term255 Nt=20 TF=21 maxTF=2 @{0 4089 1}
# graphic -> term1029 Nt=2 TF=2 maxTF=1 @{0 4116 0}
# group -> term1552 Nt=1 TF=1 maxTF=1 @{0 4120 4}
# growth -> term309 Nt=6 TF=6 maxTF=1 @{0 4123 0}
# gsm -> term1139 Nt=1 TF=1 maxTF=1 @{0 4130 2}
# gsmdb -> term419 Nt=1 TF=1 maxTF=1 @{0 4132 4}
# guid -> term1550 Nt=1 TF=1 maxTF=1 @{0 4134 2}
# gut -> term492 Nt=1 TF=1 maxTF=1 @{0 4136 6}
# gwidd -> term834 Nt=1 TF=1 maxTF=1 @{0 4138 6}
# h3abionet -> term1606 Nt=1 TF=1 maxTF=1 @{0 4141 0}
# hackathon -> term1608 Nt=1 TF=1 maxTF=1 @{0 4143 4}
# hadoop -> term1071 Nt=2 TF=2 maxTF=1 @{0 4146 0}
# halophil -> term1064 Nt=1 TF=1 maxTF=1 @{0 4150 2}
# hana -> term1164 Nt=1 TF=1 maxTF=1 @{0 4152 4}
# hand -> term1175 Nt=7 TF=7 maxTF=1 @{0 4154 6}
# handbook -> term1675 Nt=1 TF=1 maxTF=1 @{0 4160 0}
# handl -> term1780 Nt=1 TF=1 maxTF=1 @{0 4162 4}
# hardwar -> term1715 Nt=1 TF=1 maxTF=1 @{0 4165 0}
# hazard -> term911 Nt=1 TF=1 maxTF=1 @{0 4167 4}
# hbase -> term1111 Nt=1 TF=1 maxTF=1 @{0 4169 6}
# hdf -> term52 Nt=1 TF=1 maxTF=1 @{0 4172 0}
# hdm05 -> term1009 Nt=1 TF=1 maxTF=1 @{0 4173 0}
# head -> term1536 Nt=1 TF=1 maxTF=1 @{0 4175 2}
# health -> term1440 Nt=2 TF=2 maxTF=1 @{0 4177 6}
# healthcar -> term1525 Nt=1 TF=1 maxTF=1 @{0 4181 6}
# healthi -> term1423 Nt=1 TF=1 maxTF=1 @{0 4184 2}
# hear -> term1145 Nt=1 TF=1 maxTF=1 @{0 4186 6}
# heart -> term920 Nt=1 TF=1 maxTF=1 @{0 4189 0}
# hedd -> term1218 Nt=1 TF=1 maxTF=1 @{0 4191 2}
# held -> term1595 Nt=1 TF=1 maxTF=1 @{0 4193 6}
# hep1 -> term1566 Nt=1 TF=1 maxTF=1 @{0 4196 2}
# hereditari -> term644 Nt=1 TF=1 maxTF=1 @{0 4198 6}
# heterogen -> term93 Nt=12 TF=12 maxTF=1 @{0 4200 6}
# hidden -> term1784 Nt=1 TF=1 maxTF=1 @{0 4218 2}
# hierarch -> term970 Nt=2 TF=2 maxTF=1 @{0 4220 6}
# high -> term115 Nt=8 TF=8 maxTF=1 @{0 4225 4}
# highli -> term1712 Nt=1 TF=1 maxTF=1 @{0 4239 0}
# hisgatla -> term1464 Nt=1 TF=1 maxTF=1 @{0 4241 4}
# histor -> term387 Nt=4 TF=4 maxTF=1 @{0 4244 0}
# histori -> term785 Nt=2 TF=2 maxTF=1 @{0 4252 0}
# hiv -> term1126 Nt=2 TF=2 maxTF=1 @{0 4255 6}
# hive -> term1054 Nt=1 TF=1 maxTF=1 @{0 4258 4}
# hivoligodb -> term1128 Nt=1 TF=1 maxTF=1 @{0 4260 6}
# hla -> term1874 Nt=1 TF=1 maxTF=1 @{0 4263 0}
# hofe -> term226 Nt=1 TF=1 maxTF=1 @{0 4265 4}
# horizont -> term1197 Nt=1 TF=1 maxTF=1 @{0 4267 0}
# host -> term469 Nt=4 TF=4 maxTF=1 @{0 4269 2}
# hourli -> term1959 Nt=1 TF=1 maxTF=1 @{0 4277 2}
# hpidb -> term1755 Nt=1 TF=1 maxTF=1 @{0 4279 6}
# hpvmd -> term464 Nt=1 TF=1 maxTF=1 @{0 4282 2}
# hrtf -> term1483 Nt=1 TF=1 maxTF=1 @{0 4284 2}
# http -> term389 Nt=4 TF=4 maxTF=1 @{0 4286 6}
# hugo -> term85 Nt=2 TF=2 maxTF=1 @{0 4293 4}
# human -> term75 Nt=31 TF=32 maxTF=2 @{0 4296 6}
# humor -> term463 Nt=1 TF=1 maxTF=1 @{0 4331 5}
# hybrid -> term54 Nt=2 TF=2 maxTF=1 @{0 4333 5}
# hyper -> term1227 Nt=1 TF=1 maxTF=1 @{0 4336 7}
# hyperlink -> term1663 Nt=1 TF=1 maxTF=1 @{0 4339 3}
# hypermedia -> term1044 Nt=1 TF=1 maxTF=1 @{0 4341 7}
# hypertext -> term1154 Nt=1 TF=1 maxTF=1 @{0 4344 1}
# hypoxia -> term1462 Nt=1 TF=1 maxTF=1 @{0 4346 3}
# hypoxiadb -> term1461 Nt=1 TF=1 maxTF=1 @{0 4348 7}
# ibdirp -> term1569 Nt=1 TF=1 maxTF=1 @{0 4351 3}
# ibm -> term1245 Nt=1 TF=1 maxTF=1 @{0 4353 7}
# icazygfadb -> term306 Nt=1 TF=1 maxTF=1 @{0 4356 3}
# id -> term522 Nt=1 TF=1 maxTF=1 @{0 4358 1}
# ideal -> term1304 Nt=1 TF=1 maxTF=1 @{0 4360 1}
# identif -> term383 Nt=9 TF=9 maxTF=1 @{0 4362 5}
# identifi -> term559 Nt=3 TF=3 maxTF=1 @{0 4377 1}
# iemocap -> term1503 Nt=1 TF=1 maxTF=1 @{0 4382 1}
# ifo -> term1004 Nt=1 TF=1 maxTF=1 @{0 4384 5}
# igd -> term1981 Nt=1 TF=1 maxTF=1 @{0 4386 7}
# iii -> term755 Nt=2 TF=2 maxTF=1 @{0 4389 3}
# illustr -> term1960 Nt=1 TF=1 maxTF=1 @{0 4393 5}
# imag -> term727 Nt=14 TF=14 maxTF=1 @{0 4396 1}
# imagenet -> term1920 Nt=1 TF=1 maxTF=1 @{0 4414 1}
# imap -> term1161 Nt=1 TF=1 maxTF=1 @{0 4416 5}
# imgt -> term1873 Nt=1 TF=1 maxTF=1 @{0 4418 7}
# immrna -> term298 Nt=1 TF=1 maxTF=1 @{0 4421 3}
# immumethi -> term682 Nt=1 TF=1 maxTF=1 @{0 4423 1}
# immun -> term299 Nt=2 TF=2 maxTF=1 @{0 4425 1}
# immunedata -> term1314 Nt=1 TF=1 maxTF=1 @{0 4428 5}
# immunodefici -> term217 Nt=1 TF=1 maxTF=1 @{0 4431 1}
# immunolog -> term1315 Nt=3 TF=3 maxTF=1 @{0 4432 5}
# immunosuppress -> term1463 Nt=1 TF=1 maxTF=1 @{0 4437 3}
# immunotherapeut -> term184 Nt=1 TF=1 maxTF=1 @{0 4439 7}
# immunotherapi -> term265 Nt=1 TF=1 maxTF=1 @{0 4441 3}
# impact -> term1215 Nt=1 TF=1 maxTF=1 @{0 4443 1}
# implement -> term335 Nt=10 TF=10 maxTF=1 @{0 4445 5}
# implic -> term59 Nt=2 TF=2 maxTF=1 @{0 4461 5}
# import -> term996 Nt=1 TF=1 maxTF=1 @{0 4465 1}
# improv -> term641 Nt=9 TF=9 maxTF=1 @{0 4467 3}
# includ -> term351 Nt=1 TF=1 maxTF=1 @{0 4481 7}
# inclus -> term983 Nt=1 TF=1 maxTF=1 @{0 4483 5}
# incomplet -> term1879 Nt=1 TF=1 maxTF=1 @{0 4485 7}
# inconsist -> term1220 Nt=1 TF=1 maxTF=1 @{0 4488 3}
# increas -> term1202 Nt=1 TF=1 maxTF=1 @{0 4490 7}
# incub -> term1295 Nt=1 TF=1 maxTF=1 @{0 4493 1}
# independ -> term1949 Nt=1 TF=1 maxTF=1 @{0 4495 5}
# index -> term895 Nt=4 TF=4 maxTF=1 @{0 4498 1}
# indian -> term1895 Nt=1 TF=1 maxTF=1 @{0 4505 3}
# indic -> term1529 Nt=1 TF=1 maxTF=1 @{0 4507 7}
# individu -> term584 Nt=1 TF=1 maxTF=1 @{0 4510 3}
# industri -> term907 Nt=2 TF=2 maxTF=1 @{0 4512 3}
# infer -> term842 Nt=6 TF=6 maxTF=1 @{0 4516 5}
# inferenti -> term1871 Nt=1 TF=1 maxTF=1 @{0 4527 7}
# infinitedb -> term1647 Nt=1 TF=1 maxTF=1 @{0 4530 3}
# inflammatori -> term1567 Nt=1 TF=1 maxTF=1 @{0 4532 7}
# influenza -> term1312 Nt=1 TF=1 maxTF=1 @{0 4535 3}
# inform -> term609 Nt=1 TF=1 maxTF=1 @{0 4537 7}
# informat -> term816 Nt=1 TF=1 maxTF=1 @{0 4539 7}
# infrastructur -> term1767 Nt=1 TF=1 maxTF=1 @{0 4541 7}
# inhibit -> term1561 Nt=1 TF=1 maxTF=1 @{0 4544 3}
# inhibitor -> term380 Nt=1 TF=1 maxTF=1 @{0 4546 7}
# initi -> term1065 Nt=1 TF=1 maxTF=1 @{0 4548 5}
# insect -> term304 Nt=4 TF=4 maxTF=1 @{0 4550 7}
# insexbas -> term1375 Nt=1 TF=1 maxTF=1 @{0 4558 3}
# insid -> term125 Nt=4 TF=4 maxTF=1 @{0 4560 7}
# insight -> term1596 Nt=1 TF=1 maxTF=1 @{0 4565 7}
# instanc -> term795 Nt=2 TF=2 maxTF=1 @{0 4568 3}
# institut -> term864 Nt=2 TF=2 maxTF=1 @{0 4572 5}
# integr -> term74 Nt=51 TF=51 maxTF=1 @{0 4576 3}
# intellig -> term661 Nt=5 TF=5 maxTF=1 @{0 4629 3}
# intens -> term1803 Nt=1 TF=1 maxTF=1 @{0 4638 3}
# intension -> term1471 Nt=1 TF=1 maxTF=1 @{0 4640 7}
# intenz -> term523 Nt=1 TF=1 maxTF=1 @{0 4643 3}
# inter -> term1887 Nt=1 TF=1 maxTF=1 @{0 4645 3}
# interact -> term12 Nt=38 TF=39 maxTF=2 @{0 4647 7}
# interactom -> term1367 Nt=2 TF=2 maxTF=1 @{0 4688 4}
# interest -> term149 Nt=2 TF=2 maxTF=1 @{0 4693 0}
# interf -> term1925 Nt=1 TF=1 maxTF=1 @{0 4697 0}
# interfac -> term775 Nt=8 TF=8 maxTF=1 @{0 4699 4}
# intergen -> term914 Nt=1 TF=1 maxTF=1 @{0 4711 4}
# interlingu -> term1881 Nt=1 TF=1 maxTF=1 @{0 4713 6}
# intermedi -> term1407 Nt=1 TF=1 maxTF=1 @{0 4716 2}
# intern -> term36 Nt=6 TF=6 maxTF=1 @{0 4718 6}
# internet -> term936 Nt=4 TF=4 maxTF=1 @{0 4728 2}
# interoper -> term1744 Nt=1 TF=1 maxTF=1 @{0 4736 0}
# interspeci -> term847 Nt=1 TF=1 maxTF=1 @{0 4738 4}
# interstiti -> term1480 Nt=1 TF=1 maxTF=1 @{0 4740 6}
# intervent -> term1234 Nt=1 TF=1 maxTF=1 @{0 4743 2}
# intradisciplinari -> term1259 Nt=1 TF=1 maxTF=1 @{0 4745 6}
# intrins -> term356 Nt=2 TF=2 maxTF=1 @{0 4748 2}
# introduc -> term1057 Nt=2 TF=2 maxTF=1 @{0 4752 4}
# introduct -> term166 Nt=8 TF=8 maxTF=1 @{0 4757 0}
# intrus -> term106 Nt=1 TF=1 maxTF=1 @{0 4769 2}
# invertebr -> term1388 Nt=1 TF=1 maxTF=1 @{0 4770 4}
# invertebratefungi -> term1386 Nt=1 TF=1 maxTF=1 @{0 4773 0}
# investig -> term268 Nt=3 TF=3 maxTF=1 @{0 4775 4}
# involv -> term909 Nt=2 TF=2 maxTF=1 @{0 4781 0}
# ipehd -> term1001 Nt=1 TF=1 maxTF=1 @{0 4785 6}
# irndb -> term1754 Nt=1 TF=1 maxTF=1 @{0 4788 0}
# irradi -> term1963 Nt=1 TF=1 maxTF=1 @{0 4790 4}
# isomir -> term248 Nt=1 TF=1 maxTF=1 @{0 4793 0}
# isotopo -> term555 Nt=1 TF=1 maxTF=1 @{0 4794 6}
# isotopom -> term553 Nt=1 TF=1 maxTF=1 @{0 4796 6}
# issu -> term313 Nt=7 TF=7 maxTF=1 @{0 4798 6}
# istransbas -> term381 Nt=1 TF=1 maxTF=1 @{0 4810 4}
# itali -> term1598 Nt=1 TF=1 maxTF=1 @{0 4812 2}
# its2 -> term756 Nt=6 TF=6 maxTF=1 @{0 4814 6}
# iv -> term1630 Nt=1 TF=1 maxTF=1 @{0 4824 4}
# jammu -> term1855 Nt=1 TF=1 maxTF=1 @{0 4827 0}
# janaushadhi -> term112 Nt=1 TF=1 maxTF=1 @{0 4829 4}
# japan -> term1817 Nt=1 TF=1 maxTF=1 @{0 4830 6}
# jaspar -> term821 Nt=1 TF=1 maxTF=1 @{0 4833 2}
# java -> term1680 Nt=1 TF=1 maxTF=1 @{0 4835 4}
# jddb -> term1740 Nt=1 TF=1 maxTF=1 @{0 4838 0}
# join -> term1052 Nt=2 TF=2 maxTF=1 @{0 4840 4}
# joint -> term1410 Nt=1 TF=1 maxTF=1 @{0 4845 0}
# journal -> term1737 Nt=2 TF=3 maxTF=2 @{0 4847 4}
# jti -> term1409 Nt=1 TF=1 maxTF=1 @{0 4852 1}
# kashmir -> term1854 Nt=1 TF=1 maxTF=1 @{0 4854 5}
# kawasaki -> term1745 Nt=1 TF=1 maxTF=1 @{0 4857 1}
# kbm -> term1804 Nt=1 TF=1 maxTF=1 @{0 4859 5}
# ...
# simplif -> term1396 Nt=1 TF=1 maxTF=1 @{0 8270 1}
# simplifi -> term1209 Nt=2 TF=2 maxTF=1 @{0 8272 5}
# simul -> term1806 Nt=3 TF=3 maxTF=1 @{0 8277 1}
# simultan -> term1123 Nt=1 TF=1 maxTF=1 @{0 8282 1}
# singl -> term593 Nt=3 TF=3 maxTF=1 @{0 8284 3}
# singleq -> term590 Nt=1 TF=1 maxTF=1 @{0 8289 7}
# sirna -> term1778 Nt=1 TF=1 maxTF=1 @{0 8291 7}
# site -> term17 Nt=5 TF=5 maxTF=1 @{0 8294 3}
# sk -> term1562 Nt=1 TF=1 maxTF=1 @{0 8301 3}
# skeel -> term716 Nt=1 TF=1 maxTF=1 @{0 8303 7}
# skeleton -> term1811 Nt=1 TF=1 maxTF=1 @{0 8305 7}
# small -> term137 Nt=2 TF=2 maxTF=1 @{0 8308 3}
# smart -> term526 Nt=1 TF=1 maxTF=1 @{0 8312 3}
# smartwoodid -> term1591 Nt=1 TF=1 maxTF=1 @{0 8314 3}
# smcvdb -> term447 Nt=1 TF=1 maxTF=1 @{0 8316 7}
# smile -> term1940 Nt=1 TF=1 maxTF=1 @{0 8318 7}
# smoki -> term1178 Nt=2 TF=2 maxTF=1 @{0 8321 3}
# smpdb -> term136 Nt=1 TF=1 maxTF=1 @{0 8324 5}
# sochaindb -> term1792 Nt=1 TF=1 maxTF=1 @{0 8326 1}
# social -> term1794 Nt=1 TF=1 maxTF=1 @{0 8328 5}
# societi -> term1913 Nt=1 TF=1 maxTF=1 @{0 8331 1}
# sociocultur -> term1692 Nt=1 TF=1 maxTF=1 @{0 8333 5}
# sodcod -> term705 Nt=1 TF=1 maxTF=1 @{0 8336 1}
# soil -> term951 Nt=2 TF=2 maxTF=1 @{0 8338 1}
# solar -> term1966 Nt=1 TF=1 maxTF=1 @{0 8342 7}
# solut -> term174 Nt=7 TF=7 maxTF=1 @{0 8345 3}
# solv -> term439 Nt=1 TF=1 maxTF=1 @{0 8357 7}
# somat -> term573 Nt=2 TF=2 maxTF=1 @{0 8359 7}
# sorghum -> term1729 Nt=1 TF=1 maxTF=1 @{0 8364 1}
# sorghumfdb -> term1730 Nt=1 TF=1 maxTF=1 @{0 8366 5}
# south -> term1965 Nt=1 TF=1 maxTF=1 @{0 8369 1}
# spacer -> term1627 Nt=1 TF=1 maxTF=1 @{0 8371 5}
# spadahc -> term645 Nt=1 TF=1 maxTF=1 @{0 8374 1}
# spanish -> term642 Nt=2 TF=2 maxTF=1 @{0 8376 1}
# spark -> term99 Nt=1 TF=1 maxTF=1 @{0 8380 3}
# sparql -> term1063 Nt=1 TF=1 maxTF=1 @{0 8381 5}
# spatial -> term930 Nt=4 TF=4 maxTF=1 @{0 8383 7}
# speci -> term825 Nt=4 TF=4 maxTF=1 @{0 8391 7}
# special -> term314 Nt=1 TF=1 maxTF=1 @{0 8399 5}
# specif -> term294 Nt=9 TF=9 maxTF=1 @{0 8401 3}
# spectral -> term733 Nt=1 TF=1 maxTF=1 @{0 8415 1}
# spectrometr -> term1239 Nt=1 TF=1 maxTF=1 @{0 8417 1}
# speech -> term1254 Nt=2 TF=2 maxTF=1 @{0 8419 5}
# speechdat -> term1256 Nt=1 TF=1 maxTF=1 @{0 8424 3}
# spider -> term1863 Nt=5 TF=11 maxTF=3 @{0 8426 7}
# spinosa -> term712 Nt=1 TF=1 maxTF=1 @{0 8433 7}
# sql -> term802 Nt=7 TF=7 maxTF=1 @{0 8435 7}
# ssaha -> term896 Nt=1 TF=1 maxTF=1 @{0 8446 3}
# ssr -> term424 Nt=2 TF=3 maxTF=2 @{0 8448 5}
# stabil -> term865 Nt=1 TF=1 maxTF=1 @{0 8452 2}
# staff -> term728 Nt=1 TF=1 maxTF=1 @{0 8454 4}
# stand -> term1318 Nt=1 TF=1 maxTF=1 @{0 8456 4}
# standard -> term61 Nt=6 TF=6 maxTF=1 @{0 8459 0}
# stanford -> term337 Nt=2 TF=2 maxTF=1 @{0 8469 2}
# stape -> term343 Nt=2 TF=2 maxTF=1 @{0 8473 2}
# stapedotomi -> term1149 Nt=1 TF=1 maxTF=1 @{0 8477 0}
# start -> term1826 Nt=1 TF=1 maxTF=1 @{0 8479 2}
# state -> term937 Nt=1 TF=1 maxTF=1 @{0 8481 6}
# statist -> term630 Nt=10 TF=10 maxTF=1 @{0 8484 0}
# statu -> term1184 Nt=2 TF=2 maxTF=1 @{0 8499 0}
# stem -> term1270 Nt=3 TF=3 maxTF=1 @{0 8503 0}
# step -> term1408 Nt=1 TF=1 maxTF=1 @{0 8508 0}
# stopkb -> term1353 Nt=1 TF=1 maxTF=1 @{0 8510 4}
# storag -> term253 Nt=3 TF=3 maxTF=1 @{0 8513 0}
# store -> term480 Nt=7 TF=7 maxTF=1 @{0 8518 0}
# stori -> term126 Nt=1 TF=1 maxTF=1 @{0 8530 4}
# strain -> term327 Nt=1 TF=1 maxTF=1 @{0 8531 6}
# strapep -> term1476 Nt=1 TF=1 maxTF=1 @{0 8533 4}
# strateg -> term208 Nt=1 TF=1 maxTF=1 @{0 8536 0}
# strategi -> term1011 Nt=2 TF=2 maxTF=1 @{0 8537 4}
# stream -> term1916 Nt=1 TF=1 maxTF=1 @{0 8542 2}
# stress -> term1119 Nt=2 TF=2 maxTF=1 @{0 8544 6}
# string -> term679 Nt=2 TF=2 maxTF=1 @{0 8549 0}
# structur -> term135 Nt=26 TF=26 maxTF=1 @{0 8553 2}
# student -> term103 Nt=2 TF=2 maxTF=1 @{0 8584 6}
# studi -> term254 Nt=17 TF=17 maxTF=1 @{0 8588 0}
# style -> term1772 Nt=1 TF=1 maxTF=1 @{0 8612 6}
# subcellular -> term655 Nt=2 TF=2 maxTF=1 @{0 8615 2}
# subject -> term372 Nt=1 TF=1 maxTF=1 @{0 8619 4}
# submiss -> term1034 Nt=2 TF=2 maxTF=1 @{0 8621 2}
# subschem -> term1036 Nt=1 TF=1 maxTF=1 @{0 8625 6}
# subset -> term1470 Nt=1 TF=1 maxTF=1 @{0 8628 0}
# substrat -> term378 Nt=1 TF=1 maxTF=1 @{0 8630 4}
# subtili -> term913 Nt=1 TF=1 maxTF=1 @{0 8632 2}
# sulq -> term1849 Nt=1 TF=1 maxTF=1 @{0 8634 4}
# summar -> term1137 Nt=1 TF=1 maxTF=1 @{0 8637 0}
# supercyp -> term348 Nt=1 TF=1 maxTF=1 @{0 8639 2}
# supermarket -> term832 Nt=1 TF=1 maxTF=1 @{0 8641 0}
# superoxid -> term700 Nt=1 TF=1 maxTF=1 @{0 8643 2}
# supervis -> term1115 Nt=2 TF=2 maxTF=1 @{0 8645 2}
# supervisor -> term938 Nt=1 TF=1 maxTF=1 @{0 8649 4}
# supplement -> term1705 Nt=1 TF=1 maxTF=1 @{0 8651 6}
# support -> term541 Nt=14 TF=14 maxTF=1 @{0 8654 2}
# suppress -> term1351 Nt=1 TF=1 maxTF=1 @{0 8675 6}
# surfac -> term568 Nt=2 TF=2 maxTF=1 @{0 8678 2}
# surgeri -> term63 Nt=3 TF=3 maxTF=1 @{0 8682 6}
# surgic -> term1148 Nt=1 TF=1 maxTF=1 @{0 8687 4}
# survei -> term687 Nt=4 TF=4 maxTF=1 @{0 8689 6}
# surveil -> term664 Nt=1 TF=1 maxTF=1 @{0 8697 2}
# surviv -> term107 Nt=1 TF=1 maxTF=1 @{0 8699 2}
# sustain -> term420 Nt=1 TF=1 maxTF=1 @{0 8700 4}
# swarm -> term330 Nt=1 TF=1 maxTF=1 @{0 8702 2}
# swiss -> term1706 Nt=1 TF=1 maxTF=1 @{0 8704 0}
# swissregulon -> term70 Nt=1 TF=1 maxTF=1 @{0 8706 4}
# switzerland -> term187 Nt=1 TF=1 maxTF=1 @{0 8707 4}
# symbiodiniacea -> term1735 Nt=1 TF=1 maxTF=1 @{0 8709 0}
# symbol -> term1016 Nt=1 TF=1 maxTF=1 @{0 8711 4}
# symptemist -> term1381 Nt=1 TF=1 maxTF=1 @{0 8713 6}
# symptom -> term1405 Nt=2 TF=2 maxTF=1 @{0 8716 2}
# synchron -> term1101 Nt=2 TF=2 maxTF=1 @{0 8719 6}
# syndrom -> term534 Nt=1 TF=2 maxTF=2 @{0 8724 2}
# synlethdb -> term613 Nt=1 TF=1 maxTF=1 @{0 8726 3}
# syntact -> term1577 Nt=1 TF=1 maxTF=1 @{0 8728 3}
# syntenyview -> term1438 Nt=1 TF=1 maxTF=1 @{0 8730 7}
# synthesi -> term991 Nt=2 TF=2 maxTF=1 @{0 8733 3}
# synthet -> term614 Nt=3 TF=3 maxTF=1 @{0 8738 1}
# synthetas -> term1922 Nt=1 TF=1 maxTF=1 @{0 8742 7}
# system -> term81 Nt=147 TF=150 maxTF=2 @{0 8745 3}
# t2t -> term1433 Nt=1 TF=1 maxTF=1 @{0 8849 4}
# tag -> term1907 Nt=1 TF=1 maxTF=1 @{0 8852 0}
# tailor -> term1116 Nt=1 TF=1 maxTF=1 @{0 8854 4}
# tamper -> term1727 Nt=1 TF=1 maxTF=1 @{0 8856 6}
# tandem -> term1797 Nt=1 TF=1 maxTF=1 @{0 8859 2}
# tangui -> term1938 Nt=1 TF=1 maxTF=1 @{0 8861 6}
# target -> term15 Nt=5 TF=6 maxTF=2 @{0 8864 2}
# task -> term1371 Nt=3 TF=3 maxTF=1 @{0 8872 1}
# tast -> term342 Nt=1 TF=1 maxTF=1 @{0 8877 3}
# taxa -> term1391 Nt=1 TF=1 maxTF=1 @{0 8879 1}
# taxon -> term1629 Nt=1 TF=1 maxTF=1 @{0 8881 5}
# taxonomi -> term1872 Nt=1 TF=1 maxTF=1 @{0 8884 1}
# tb -> term792 Nt=1 TF=1 maxTF=1 @{0 8886 5}
# tbro -> term776 Nt=2 TF=2 maxTF=1 @{0 8888 5}
# tcga -> term1087 Nt=1 TF=1 maxTF=1 @{0 8892 1}
# tde -> term1249 Nt=1 TF=1 maxTF=1 @{0 8894 3}
# te -> term600 Nt=2 TF=3 maxTF=2 @{0 8896 7}
# tea -> term1936 Nt=1 TF=1 maxTF=1 @{0 8901 2}
# teach -> term944 Nt=4 TF=4 maxTF=1 @{0 8903 6}
# teamid -> term1935 Nt=1 TF=1 maxTF=1 @{0 8911 2}
# techniken -> term1867 Nt=2 TF=2 maxTF=1 @{0 8913 6}
# techniqu -> term849 Nt=4 TF=4 maxTF=1 @{0 8916 4}
# technolog -> term209 Nt=6 TF=6 maxTF=1 @{0 8924 6}
# telephon -> term1253 Nt=1 TF=1 maxTF=1 @{0 8935 2}
# teleshop -> term1847 Nt=1 TF=1 maxTF=1 @{0 8937 6}
# tempor -> term995 Nt=8 TF=8 maxTF=1 @{0 8940 2}
# ten -> term1043 Nt=1 TF=1 maxTF=1 @{0 8953 2}
# tenant -> term1662 Nt=1 TF=1 maxTF=1 @{0 8955 4}
# term -> term1150 Nt=4 TF=4 maxTF=1 @{0 8958 0}
# terrestri -> term763 Nt=1 TF=1 maxTF=1 @{0 8966 0}
# terror -> term1056 Nt=1 TF=1 maxTF=1 @{0 8968 0}
# tertiari -> term935 Nt=1 TF=1 maxTF=1 @{0 8970 2}
# test -> term56 Nt=3 TF=3 maxTF=1 @{0 8972 4}
# tetrahymena -> term1032 Nt=1 TF=1 maxTF=1 @{0 8977 2}
# text -> term780 Nt=11 TF=11 maxTF=1 @{0 8979 4}
# text2term -> term1415 Nt=1 TF=1 maxTF=1 @{0 8995 2}
# textual -> term1428 Nt=1 TF=1 maxTF=1 @{0 8997 6}
# thalassemia -> term375 Nt=1 TF=1 maxTF=1 @{0 9000 2}
# theileria -> term1756 Nt=1 TF=1 maxTF=1 @{0 9002 0}
# theori -> term931 Nt=5 TF=5 maxTF=1 @{0 9004 4}
# therapeut -> term200 Nt=1 TF=1 maxTF=1 @{0 9013 2}
# therapi -> term1349 Nt=2 TF=2 maxTF=1 @{0 9014 6}
# thermodynam -> term357 Nt=1 TF=1 maxTF=1 @{0 9018 2}
# throughput -> term470 Nt=3 TF=3 maxTF=1 @{0 9020 0}
# time -> term980 Nt=8 TF=8 maxTF=1 @{0 9026 2}
# tissu -> term345 Nt=9 TF=9 maxTF=1 @{0 9038 6}
# toler -> term105 Nt=1 TF=1 maxTF=1 @{0 9053 4}
# tool -> term28 Nt=26 TF=26 maxTF=1 @{0 9054 6}
# toolkit -> term960 Nt=3 TF=3 maxTF=1 @{0 9087 2}
# topex -> term1420 Nt=1 TF=1 maxTF=1 @{0 9093 4}
# topic -> term1417 Nt=3 TF=3 maxTF=1 @{0 9096 0}
# tourism -> term1769 Nt=1 TF=1 maxTF=1 @{0 9102 2}
# toxic -> term446 Nt=1 TF=1 maxTF=1 @{0 9104 6}
# tparvadb -> term1758 Nt=1 TF=1 maxTF=1 @{0 9106 6}
# traceabl -> term1285 Nt=1 TF=1 maxTF=1 @{0 9109 2}
# track -> term1382 Nt=5 TF=5 maxTF=1 @{0 9111 6}
# tradeoff -> term1066 Nt=1 TF=1 maxTF=1 @{0 9118 6}
# tradit -> term88 Nt=1 TF=1 maxTF=1 @{0 9121 0}
# train -> term1117 Nt=3 TF=3 maxTF=1 @{0 9122 2}
# trait -> term237 Nt=4 TF=4 maxTF=1 @{0 9127 4}
# trajectori -> term885 Nt=1 TF=1 maxTF=1 @{0 9134 2}
# transact -> term1096 Nt=8 TF=8 maxTF=1 @{0 9136 4}
# transcrib -> term1628 Nt=1 TF=1 maxTF=1 @{0 9148 4}
# transcript -> term678 Nt=10 TF=10 maxTF=1 @{0 9151 0}
# transcriptom -> term777 Nt=7 TF=7 maxTF=1 @{0 9166 4}
# transduct -> term1251 Nt=1 TF=1 maxTF=1 @{0 9177 6}
# transform -> term717 Nt=5 TF=5 maxTF=1 @{0 9180 2}
# translat -> term1083 Nt=5 TF=5 maxTF=1 @{0 9188 2}
# transmembran -> term511 Nt=1 TF=1 maxTF=1 @{0 9196 4}
# transpar -> term1250 Nt=3 TF=3 maxTF=1 @{0 9198 4}
# transport -> term379 Nt=2 TF=2 maxTF=1 @{0 9204 4}
# transpos -> term597 Nt=2 TF=2 maxTF=1 @{0 9208 6}
# transvers -> term1311 Nt=1 TF=1 maxTF=1 @{0 9213 2}
# tredd -> term1796 Nt=1 TF=1 maxTF=1 @{0 9215 6}
# tree -> term1576 Nt=1 TF=1 maxTF=1 @{0 9218 2}
# trembl -> term1704 Nt=1 TF=1 maxTF=1 @{0 9220 6}
# trend -> term977 Nt=2 TF=2 maxTF=1 @{0 9223 2}
# trial -> term581 Nt=2 TF=2 maxTF=1 @{0 9227 2}
# trigger -> term1097 Nt=1 TF=1 maxTF=1 @{0 9230 0}
# trust -> term1656 Nt=1 TF=1 maxTF=1 @{0 9232 2}
# trustdb -> term1368 Nt=1 TF=1 maxTF=1 @{0 9234 6}
# trustworthi -> term1324 Nt=1 TF=1 maxTF=1 @{0 9237 2}
# try -> term236 Nt=2 TF=2 maxTF=1 @{0 9239 6}
# ttd -> term199 Nt=1 TF=1 maxTF=1 @{0 9243 4}
# tuberculosi -> term793 Nt=1 TF=1 maxTF=1 @{0 9245 0}
# tumor -> term300 Nt=1 TF=1 maxTF=1 @{0 9247 0}
# tune -> term894 Nt=2 TF=2 maxTF=1 @{0 9248 6}
# tutor -> term942 Nt=2 TF=2 maxTF=1 @{0 9253 2}
# tutori -> term1125 Nt=1 TF=1 maxTF=1 @{0 9256 4}
# tweet -> term1586 Nt=1 TF=1 maxTF=1 @{0 9258 6}
# twice -> term1877 Nt=2 TF=2 maxTF=1 @{0 9261 2}
# type -> term205 Nt=4 TF=4 maxTF=1 @{0 9264 4}
# typolog -> term1829 Nt=1 TF=1 maxTF=1 @{0 9270 6}
# tyranni -> term794 Nt=1 TF=1 maxTF=1 @{0 9273 2}
# ubiqu -> term804 Nt=1 TF=1 maxTF=1 @{0 9275 2}
# uci -> term1114 Nt=1 TF=1 maxTF=1 @{0 9277 2}
# ucsc -> term1359 Nt=1 TF=1 maxTF=1 @{0 9279 4}
# udb -> term1246 Nt=1 TF=1 maxTF=1 @{0 9282 0}
# uk -> term1441 Nt=1 TF=1 maxTF=1 @{0 9284 4}
# uml -> term695 Nt=1 TF=1 maxTF=1 @{0 9287 0}
# unbound -> term1296 Nt=1 TF=1 maxTF=1 @{0 9289 0}
# uncov -> term1306 Nt=2 TF=2 maxTF=1 @{0 9291 4}
# und -> term1868 Nt=2 TF=2 maxTF=1 @{0 9295 0}
# understand -> term1364 Nt=2 TF=2 maxTF=1 @{0 9297 6}
# uni -> term1701 Nt=1 TF=1 maxTF=1 @{0 9302 2}
# unif -> term656 Nt=1 TF=1 maxTF=1 @{0 9304 6}
# unifi -> term1303 Nt=1 TF=1 maxTF=1 @{0 9306 6}
# uniform -> term1037 Nt=1 TF=1 maxTF=1 @{0 9309 2}
# uniformli -> term319 Nt=3 TF=3 maxTF=1 @{0 9311 4}
# unit -> term984 Nt=1 TF=1 maxTF=1 @{0 9317 0}
# univers -> term537 Nt=4 TF=4 maxTF=1 @{0 9319 2}
# updat -> term68 Nt=33 TF=33 maxTF=1 @{0 9327 2}
# upstream -> term918 Nt=1 TF=1 maxTF=1 @{0 9365 2}
# ur -> term1717 Nt=1 TF=1 maxTF=1 @{0 9367 4}
# us -> term97 Nt=42 TF=42 maxTF=1 @{0 9370 0}
# usag -> term1214 Nt=2 TF=2 maxTF=1 @{0 9414 2}
# user -> term409 Nt=8 TF=8 maxTF=1 @{0 9418 4}
# util -> term505 Nt=4 TF=4 maxTF=1 @{0 9432 0}
# v2 -> term544 Nt=1 TF=1 maxTF=1 @{0 9440 0}
# v3 -> term1262 Nt=1 TF=1 maxTF=1 @{0 9442 0}
# v4 -> term1435 Nt=1 TF=1 maxTF=1 @{0 9444 4}
# v9 -> term1203 Nt=1 TF=1 maxTF=1 @{0 9447 0}
# va -> term1104 Nt=1 TF=1 maxTF=1 @{0 9449 2}
# vaccin -> term1759 Nt=1 TF=1 maxTF=1 @{0 9451 4}
# vadr -> term1313 Nt=1 TF=1 maxTF=1 @{0 9454 0}
# valid -> term818 Nt=6 TF=6 maxTF=1 @{0 9456 4}
# valu -> term1089 Nt=2 TF=2 maxTF=1 @{0 9467 4}
# variabl -> term1889 Nt=1 TF=1 maxTF=1 @{0 9471 6}
# variant -> term376 Nt=5 TF=6 maxTF=2 @{0 9474 2}
# variat -> term561 Nt=5 TF=5 maxTF=1 @{0 9483 3}
# vdn -> term1742 Nt=1 TF=1 maxTF=1 @{0 9491 3}
# vehicl -> term1274 Nt=1 TF=1 maxTF=1 @{0 9493 7}
# verb -> term1791 Nt=1 TF=1 maxTF=1 @{0 9496 3}
# verif -> term437 Nt=3 TF=3 maxTF=1 @{0 9498 7}
# verifi -> term16 Nt=1 TF=1 maxTF=1 @{0 9505 3}
# version -> term688 Nt=9 TF=9 maxTF=1 @{0 9505 7}
# vertic -> term44 Nt=1 TF=1 maxTF=1 @{0 9518 7}
# vfdb -> term216 Nt=1 TF=1 maxTF=1 @{0 9519 7}
# video -> term1933 Nt=1 TF=1 maxTF=1 @{0 9521 3}
# view -> term692 Nt=7 TF=7 maxTF=1 @{0 9523 7}
# vii -> term1370 Nt=3 TF=3 maxTF=1 @{0 9534 1}
# viii -> term1458 Nt=2 TF=2 maxTF=1 @{0 9539 5}
# viral -> term502 Nt=2 TF=2 maxTF=1 @{0 9543 7}
# virtual -> term1644 Nt=1 TF=1 maxTF=1 @{0 9548 1}
# viru -> term218 Nt=2 TF=2 maxTF=1 @{0 9550 5}
# virul -> term214 Nt=2 TF=2 maxTF=1 @{0 9554 5}
# virusurf -> term501 Nt=1 TF=1 maxTF=1 @{0 9558 3}
# visual -> term334 Nt=6 TF=6 maxTF=1 @{0 9560 3}
# visualis -> term1059 Nt=2 TF=2 maxTF=1 @{0 9571 3}
# vitripenni -> term1731 Nt=1 TF=1 maxTF=1 @{0 9575 7}
# vitro -> term1294 Nt=1 TF=1 maxTF=1 @{0 9578 3}
# vivo -> term19 Nt=1 TF=1 maxTF=1 @{0 9580 7}
# vlsi -> term1978 Nt=1 TF=1 maxTF=1 @{0 9581 3}
# vol -> term1674 Nt=1 TF=1 maxTF=1 @{0 9583 7}
# vu -> term1710 Nt=1 TF=1 maxTF=1 @{0 9586 3}
# walk -> term1783 Nt=1 TF=1 maxTF=1 @{0 9588 7}
# warehous -> term950 Nt=3 TF=3 maxTF=1 @{0 9591 3}
# wash -> term958 Nt=1 TF=1 maxTF=1 @{0 9595 5}
# wasp -> term1379 Nt=1 TF=1 maxTF=1 @{0 9597 7}
# waspatla -> term1733 Nt=1 TF=1 maxTF=1 @{0 9600 3}
# watermark -> term877 Nt=1 TF=1 maxTF=1 @{0 9602 7}
# weak -> term1517 Nt=1 TF=1 maxTF=1 @{0 9605 1}
# weaver -> term646 Nt=1 TF=1 maxTF=1 @{0 9607 5}
# web -> term118 Nt=27 TF=28 maxTF=2 @{0 9609 5}
# websit -> term1223 Nt=1 TF=1 maxTF=1 @{0 9641 6}
# well -> term1800 Nt=1 TF=1 maxTF=1 @{0 9644 2}
# wheat -> term576 Nt=2 TF=2 maxTF=1 @{0 9646 6}
# white -> term1508 Nt=1 TF=1 maxTF=1 @{0 9651 0}
# whole -> term49 Nt=2 TF=2 maxTF=1 @{0 9653 4}
# wholecellsimdb -> term47 Nt=1 TF=1 maxTF=1 @{0 9657 0}
# wide -> term72 Nt=4 TF=4 maxTF=1 @{0 9658 0}
# wiki -> term1031 Nt=2 TF=2 maxTF=1 @{0 9664 6}
# wikidata -> term512 Nt=3 TF=3 maxTF=1 @{0 9668 2}
# wikigenom -> term513 Nt=1 TF=1 maxTF=1 @{0 9673 0}
# wildlif -> term1615 Nt=1 TF=1 maxTF=1 @{0 9675 0}
# window -> term1687 Nt=1 TF=1 maxTF=1 @{0 9677 4}
# wine -> term1232 Nt=1 TF=1 maxTF=1 @{0 9680 0}
# winesi -> term1231 Nt=1 TF=1 maxTF=1 @{0 9682 4}
# wireless -> term742 Nt=2 TF=2 maxTF=1 @{0 9685 0}
# wise -> term569 Nt=1 TF=1 maxTF=1 @{0 9689 0}
# women -> term1427 Nt=1 TF=1 maxTF=1 @{0 9691 0}
# wood -> term1592 Nt=1 TF=1 maxTF=1 @{0 9693 4}
# word -> term1830 Nt=1 TF=1 maxTF=1 @{0 9696 0}
# wordnet -> term516 Nt=15 TF=16 maxTF=2 @{0 9698 4}
# work -> term1195 Nt=3 TF=3 maxTF=1 @{0 9718 1}
# workflow -> term1912 Nt=1 TF=1 maxTF=1 @{0 9724 3}
# workload -> term1163 Nt=2 TF=2 maxTF=1 @{0 9726 7}
# workshop -> term1599 Nt=3 TF=3 maxTF=1 @{0 9731 1}
# world -> term1093 Nt=2 TF=2 maxTF=1 @{0 9736 3}
# worldwid -> term962 Nt=2 TF=2 maxTF=1 @{0 9740 5}
# wrox -> term173 Nt=1 TF=1 maxTF=1 @{0 9745 1}
# www -> term392 Nt=1 TF=1 maxTF=1 @{0 9746 5}
# xenobiot -> term718 Nt=1 TF=1 maxTF=1 @{0 9748 3}
# xenograft -> term1451 Nt=1 TF=1 maxTF=1 @{0 9750 3}
# xephir -> term1452 Nt=1 TF=1 maxTF=1 @{0 9752 7}
# xml -> term124 Nt=13 TF=13 maxTF=1 @{0 9755 3}
# xsb -> term1665 Nt=1 TF=1 maxTF=1 @{0 9773 3}
# year -> term1192 Nt=2 TF=2 maxTF=1 @{0 9775 7}
# yeast -> term20 Nt=2 TF=2 maxTF=1 @{0 9778 5}
# yeastgenom -> term1821 Nt=1 TF=1 maxTF=1 @{0 9781 5}
# yeastract -> term835 Nt=1 TF=1 maxTF=1 @{0 9784 1}
# yeastss -> term1827 Nt=1 TF=1 maxTF=1 @{0 9786 3}
# yh -> term1694 Nt=1 TF=1 maxTF=1 @{0 9788 7}
# youth -> term210 Nt=1 TF=1 maxTF=1 @{0 9791 3}
# zebrafish -> term1450 Nt=2 TF=2 maxTF=1 @{0 9792 7}
# zflnc -> term1799 Nt=1 TF=1 maxTF=1 @{0 9797 3}
# zinc -> term1465 Nt=1 TF=1 maxTF=1 @{0 9799 7}
# zincbind -> term1466 Nt=1 TF=1 maxTF=1 @{0 9802 3}
# zn -> term708 Nt=1 TF=1 maxTF=1 @{0 9804 7}
# zubud -> term1279 Nt=2 TF=2 maxTF=1 @{0 9806 7}

# %%
term_freq_dict = {}

for kv in index.getLexicon():
    term_freq_dict[kv.getKey()] = kv.getValue().frequency

# %%
term_freq_dict_sorted = sorted(term_freq_dict.items(), key=lambda x: x[1], reverse=True)

# %%
top_k = 30
term_freq_dict_sorted[:top_k]
# Out:
# [('databas', 897),
#  ('system', 150),
#  ('data', 75),
#  ('base', 61),
#  ('manag', 59),
#  ('relat', 57),
#  ('analysi', 51),
#  ('genom', 51),
#  ('integr', 51),
#  ('protein', 47),
#  ('gene', 44),
#  ('us', 42),
#  ('design', 40),
#  ('interact', 39),
#  ('model', 37),
#  ('knowledg', 36),
#  ('queri', 35),
#  ('resourc', 34),
#  ('updat', 33),
#  ('human', 32),
#  ('orient', 31),
#  ('comprehens', 30),
#  ('network', 29),
#  ('research', 29),
#  ('curat', 28),
#  ('web', 28),
#  ('object', 27),
#  ('structur', 26),
#  ('tool', 26),
#  ('annot', 25)]

# %%
search_engine = pt.BatchRetrieve(index, wmodel="Tf")
# Out:
# /var/folders/88/9blsh45918g8y3n5vl6vztxr0000gq/T/ipykernel_2460/951663741.py:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   search_engine = pt.BatchRetrieve(index, wmodel="Tf")

# %%
search_engine.search("system")
# Out:
#     qid  docid                                              docno  rank  \
# 0     1    845  https://www.bibsonomy.org/bibtex/27cebe02af1e4...     0
# 1     1    861  https://www.bibsonomy.org/bibtex/2e8737a4cce47...     1
# 2     1    863  https://www.bibsonomy.org/bibtex/2072b030962e3...     2
# 3     1     17  https://www.bibsonomy.org/bibtex/28af31bbdb0bd...     3
# 4     1     20  https://www.bibsonomy.org/bibtex/2d8ab08ff3957...     4
# ..   ..    ...                                                ...   ...
# 142   1    974  https://www.bibsonomy.org/bibtex/22c283923428b...   142
# 143   1    978  https://www.bibsonomy.org/bibtex/2c131a54ea01f...   143
# 144   1    981  https://www.bibsonomy.org/bibtex/23329ecb8e4df...   144
# 145   1    982  https://www.bibsonomy.org/bibtex/23fe63077cacd...   145
# 146   1    983  https://www.bibsonomy.org/bibtex/20fded9de6835...   146
#
#      score   query
# 0      2.0  system
# 1      2.0  system
# 2      2.0  system
# 3      1.0  system
# 4      1.0  system
# ..     ...     ...
# 142    1.0  system
# 143    1.0  system
# 144    1.0  system
# 145    1.0  system
# 146    1.0  system
#
# [147 rows x 6 columns]

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
stem = stemmer.stem("learning")
stem
# Out:
# 'learn'

# %%
lexicon = index.getLexicon()
lexicon[stem].getDocumentFrequency()
# Out:
# 8

# %%
index.getCollectionStatistics().numberOfDocuments
# Out:
# 1000

# %%
def get_idf_for_term(term, index):
  lex = index.getLexicon()
  stemmed_term = stemmer.stem(term)

  if not stemmed_term in lex:
    return 
    
  lex_entry = lex[stemmed_term]

  df_term = lex_entry.getDocumentFrequency()
  N = index.getCollectionStatistics().numberOfDocuments
  
  #inverse document frequency
  idf = N/df_term

  #apply logarithm(base 10) to idf
  log_idf = np.emath.logn(10, idf)

  return log_idf

# %%
get_idf_for_term("learning", index)
# Out:
# 2.0969100130080562

# %%
#define your own tf_idf method here:

def calc_tf_idf(query, docno, index):
    #remember that tfidf is the product of two components
    #hint: the tf model search result contains tf frequencies
    return 0

# %%
search_engine_tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")
# Out:
# /var/folders/88/9blsh45918g8y3n5vl6vztxr0000gq/T/ipykernel_2460/2880449899.py:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   search_engine_tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")

# %%
search_engine_tfidf.search("intelligent education")
# Out:
#   qid  docid                                              docno  rank  \
# 0   1    362  https://www.bibsonomy.org/bibtex/2c84df7e01ddd...     0
# 1   1    586  https://www.bibsonomy.org/bibtex/2a9aeedc023b8...     1
# 2   1    319  https://www.bibsonomy.org/bibtex/2e01c06213221...     2
# 3   1    330  https://www.bibsonomy.org/bibtex/2e01c06213221...     3
# 4   1    191  https://www.bibsonomy.org/bibtex/24174ad281bc2...     4
# 5   1    705  https://www.bibsonomy.org/bibtex/2dada3848a74e...     5
#
#       score                  query
# 0  5.720135  intelligent education
# 1  4.130482  intelligent education
# 2  3.899228  intelligent education
# 3  3.899228  intelligent education
# 4  3.692495  intelligent education
# 5  3.506580  intelligent education
