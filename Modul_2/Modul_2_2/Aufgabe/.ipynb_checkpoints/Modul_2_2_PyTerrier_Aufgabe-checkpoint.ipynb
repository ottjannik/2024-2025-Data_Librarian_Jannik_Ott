# %%
import pyterrier as pt
import requests
import pandas as pd
import pickle
import nltk
import numpy as np
import json

# %%
url_base = "https://www.bibsonomy.org/json/search/"
url_attr = "?items=1000"

def df_from_query(query):
    url = url_base + query.replace(" ", "%20") + url_attr  
    result = requests.get(url)
    json_data = result.json()
    dataframe = pd.DataFrame(json_data["items"])
    dataframe["query"] = query
    return dataframe

dataframes = []
queries = ["database", "text", "library", "archive"]

for q in queries:
    df = df_from_query(q)
    dataframes.append(df)
    print(f"{len(df)} Ergebnisse für query {q} gefunden.")

data = pd.concat(dataframes, ignore_index=True)
# Out:
# 2000 Ergebnisse für query database gefunden.
# 2000 Ergebnisse für query text gefunden.
# 2000 Ergebnisse für query library gefunden.
# 2000 Ergebnisse für query archive gefunden.

# %%
data
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/cc45493bf442b78d...
# 1        Bookmark  https://www.bibsonomy.org/url/61474ed79d5c3f63...
# 2        Bookmark  https://www.bibsonomy.org/url/3cd373dd8ed9c534...
# 3        Bookmark  https://www.bibsonomy.org/url/cc45493bf442b78d...
# 4        Bookmark  https://www.bibsonomy.org/url/2f5f76391c720a9b...
# ...           ...                                                ...
# 7995  Publication  https://www.bibsonomy.org/bibtex/2040f345d94cd...
# 7996  Publication  https://www.bibsonomy.org/bibtex/28217f4fe9f6a...
# 7997  Publication  https://www.bibsonomy.org/bibtex/29994ea45725f...
# 7998  Publication  https://www.bibsonomy.org/bibtex/2ee55445bc456...
# 7999  Publication  https://www.bibsonomy.org/bibtex/2dc534ef1b015...
#
#                                                    tags  \
# 0     [web2.0, database, desktop, aggregator, daily,...
# 1     [tool, database, 3403, Error, Fix,, recovery,,...
# 2           [Article(s), Design, Database, Information]
# 3     [web2.0, 2007, database, socialsoftware, tools...
# 4                                           [databases]
# ...                                                 ...
# 7995                                             [dblp]
# 7996                                             [dblp]
# 7997                                             [dblp]
# 7998                                             [dblp]
# 7999                                             [dblp]
#
#                              intraHash  \
# 0     cc45493bf442b78d923b0b1b9342676b
# 1     61474ed79d5c3f63c1d0b6dcd8c653f5
# 2     3cd373dd8ed9c53483d39eaa928686f6
# 3     cc45493bf442b78d923b0b1b9342676b
# 4     2f5f76391c720a9b688f60ec6f900f1d
# ...                                ...
# 7995  040f345d94cd5d5e6c4e6a2ca7d2f43e
# 7996  8217f4fe9f6a3929c0d365d35447be84
# 7997  9994ea45725f4b521a1ca2da5f6b1bae
# 7998  ee55445bc456b80407d888fe2948f6a1
# 7999  dc534ef1b01530bf66755fb1a8eaa51a
#
#                                                   label       user  \
# 0                                   Office 2.0 Database  springnet
# 1                           SQL Database 3403 Error Fix  traktools
# 2                                     Database Sharding      panic
# 3                                   Office 2.0 Database       akpe
# 4                      Encyclopedia of Database Systems   ludaesch
# ...                                                 ...        ...
# 7995  Faculty self-archiving behavior: Factors affec...       dblp
# 7996  Sensitivity and Access: Unlocking the Colonial...       dblp
# 7997  Online hot topic detection from web news archi...       dblp
# 7998  Serge Modular Archive Instrument (SMAI): Bridg...       dblp
# 7999  The peer-to-peer trace archive: design and com...       dblp
#
#                                             description                 date  \
# 0                                   Office 2.0 Database  2006-04-19 19:49:42
# 1     SysTools Software releases an effective SQL da...  2009-09-15 19:13:52
# 2     The term "sharding" was coined by Google engin...  2011-10-01 02:24:14
# 3     Overview of roughly 250 Web 2.0 applications, ...  2007-03-14 20:26:50
# 4                      Encyclopedia of Database Systems  2007-02-08 11:20:08
# ...                                                 ...                  ...
# 7995                                                     2020-06-24 00:00:00
# 7996                                                     2024-08-08 00:00:00
# 7997                                                     2021-09-19 00:00:00
# 7998                                                     2024-09-16 00:00:00
# 7999                                                     2024-05-07 00:00:00
#
#                changeDate  count  ... attachments categories url_pdf data  \
# 0     2008-06-29 17:52:49     13  ...         NaN        NaN     NaN  NaN
# 1     2009-09-15 19:13:52      1  ...         NaN        NaN     NaN  NaN
# 2     2011-10-01 02:27:38      1  ...         NaN        NaN     NaN  NaN
# 3     2011-03-14 16:42:58     13  ...         NaN        NaN     NaN  NaN
# 4     2007-09-26 06:23:20      1  ...         NaN        NaN     NaN  NaN
# ...                   ...    ...  ...         ...        ...     ...  ...
# 7995  2024-04-10 00:42:34      1  ...         NaN        NaN     NaN  NaN
# 7996  2024-08-12 07:04:36      1  ...         NaN        NaN     NaN  NaN
# 7997  2024-04-10 19:24:49      1  ...         NaN        NaN     NaN  NaN
# 7998  2024-09-23 07:12:24      1  ...         NaN        NaN     NaN  NaN
# 7999  2024-05-13 10:00:25      1  ...         NaN        NaN     NaN  NaN
#
#      online titleaddon refnum in-text-citation w-type w-projects
# 0       NaN        NaN    NaN              NaN    NaN        NaN
# 1       NaN        NaN    NaN              NaN    NaN        NaN
# 2       NaN        NaN    NaN              NaN    NaN        NaN
# 3       NaN        NaN    NaN              NaN    NaN        NaN
# 4       NaN        NaN    NaN              NaN    NaN        NaN
# ...     ...        ...    ...              ...    ...        ...
# 7995    NaN        NaN    NaN              NaN    NaN        NaN
# 7996    NaN        NaN    NaN              NaN    NaN        NaN
# 7997    NaN        NaN    NaN              NaN    NaN        NaN
# 7998    NaN        NaN    NaN              NaN    NaN        NaN
# 7999    NaN        NaN    NaN              NaN    NaN        NaN
#
# [8000 rows x 200 columns]

# %%
#drop columns where at least 50% of the rows have missing values
df_filtered = data.dropna(axis=1, thresh=len(df)*0.5)

# %%
df_filtered.columns
# Out:
# Index(['type', 'id', 'tags', 'intraHash', 'label', 'user', 'description',
#        'date', 'changeDate', 'count', 'url', 'interHash', 'pub-type',
#        'journal', 'year', 'author', 'authors', 'volume', 'abstract',
#        'bibtexKey', 'pages', 'publisher', 'number', 'booktitle', 'ee',
#        'query'],
#       dtype='object')

# %%
useful_columns = ['id', 'tags', 'label', 'description', 'date', 'changeDate', 'url', 'pub-type', 'year', 'author', 'authors']
df_filtered = df_filtered[useful_columns]

# %%
df_filtered
# Out:
#                                                      id  \
# 0     https://www.bibsonomy.org/url/cc45493bf442b78d...
# 1     https://www.bibsonomy.org/url/61474ed79d5c3f63...
# 2     https://www.bibsonomy.org/url/3cd373dd8ed9c534...
# 3     https://www.bibsonomy.org/url/cc45493bf442b78d...
# 4     https://www.bibsonomy.org/url/2f5f76391c720a9b...
# ...                                                 ...
# 7995  https://www.bibsonomy.org/bibtex/2040f345d94cd...
# 7996  https://www.bibsonomy.org/bibtex/28217f4fe9f6a...
# 7997  https://www.bibsonomy.org/bibtex/29994ea45725f...
# 7998  https://www.bibsonomy.org/bibtex/2ee55445bc456...
# 7999  https://www.bibsonomy.org/bibtex/2dc534ef1b015...
#
#                                                    tags  \
# 0     [web2.0, database, desktop, aggregator, daily,...
# 1     [tool, database, 3403, Error, Fix,, recovery,,...
# 2           [Article(s), Design, Database, Information]
# 3     [web2.0, 2007, database, socialsoftware, tools...
# 4                                           [databases]
# ...                                                 ...
# 7995                                             [dblp]
# 7996                                             [dblp]
# 7997                                             [dblp]
# 7998                                             [dblp]
# 7999                                             [dblp]
#
#                                                   label  \
# 0                                   Office 2.0 Database
# 1                           SQL Database 3403 Error Fix
# 2                                     Database Sharding
# 3                                   Office 2.0 Database
# 4                      Encyclopedia of Database Systems
# ...                                                 ...
# 7995  Faculty self-archiving behavior: Factors affec...
# 7996  Sensitivity and Access: Unlocking the Colonial...
# 7997  Online hot topic detection from web news archi...
# 7998  Serge Modular Archive Instrument (SMAI): Bridg...
# 7999  The peer-to-peer trace archive: design and com...
#
#                                             description                 date  \
# 0                                   Office 2.0 Database  2006-04-19 19:49:42
# 1     SysTools Software releases an effective SQL da...  2009-09-15 19:13:52
# 2     The term "sharding" was coined by Google engin...  2011-10-01 02:24:14
# 3     Overview of roughly 250 Web 2.0 applications, ...  2007-03-14 20:26:50
# 4                      Encyclopedia of Database Systems  2007-02-08 11:20:08
# ...                                                 ...                  ...
# 7995                                                     2020-06-24 00:00:00
# 7996                                                     2024-08-08 00:00:00
# 7997                                                     2021-09-19 00:00:00
# 7998                                                     2024-09-16 00:00:00
# 7999                                                     2024-05-07 00:00:00
#
#                changeDate                                                url  \
# 0     2008-06-29 17:52:49             http://itredux.com/office-20/database/
# 1     2009-09-15 19:13:52  http://www.sqlrecoverytool.com/sql-database-34...
# 2     2011-10-01 02:27:38      http://www.codefutures.com/database-sharding/
# 3     2011-03-14 16:42:58             http://itredux.com/office-20/database/
# 4     2007-09-26 06:23:20     http://refworks.springer.com/database-systems/
# ...                   ...                                                ...
# 7995  2024-04-10 00:42:34  http://dblp.uni-trier.de/db/conf/asist/asist20...
# 7996  2024-08-12 07:04:36  http://dblp.uni-trier.de/db/journals/dhq/dhq18...
# 7997  2024-04-10 19:24:49  http://dblp.uni-trier.de/db/conf/fskd/fskd2014...
# 7998  2024-09-23 07:12:24  http://dblp.uni-trier.de/db/conf/nime/nime2023...
# 7999  2024-05-13 10:00:25  http://dblp.uni-trier.de/db/conf/conext/sw2010...
#
#            pub-type  year                                             author  \
# 0               NaN   NaN                                                NaN
# 1               NaN   NaN                                                NaN
# 2               NaN   NaN                                                NaN
# 3               NaN   NaN                                                NaN
# 4               NaN   NaN                                                NaN
# ...             ...   ...                                                ...
# 7995  inproceedings  2007                                       [Jihyun Kim]
# 7996        article  2024  [Jonathan Dentler, Lise Jaillant, Daniel Folia...
# 7997  inproceedings  2014     [RuiGuo Yu, Mankun Zhao, Peng Chang, MuWen He]
# 7998  inproceedings  2023                          [Ted Moore, Jean Brazeau]
# 7999  inproceedings  2010  [Boxun Zhang, Alexandru Iosup, Johan Pouwelse,...
#
#                                                 authors
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7995               [{'first': 'Jihyun', 'last': 'Kim'}]
# 7996  [{'first': 'Jonathan', 'last': 'Dentler'}, {'f...
# 7997  [{'first': 'RuiGuo', 'last': 'Yu'}, {'first': ...
# 7998  [{'first': 'Ted', 'last': 'Moore'}, {'first': ...
# 7999  [{'first': 'Boxun', 'last': 'Zhang'}, {'first'...
#
# [8000 rows x 11 columns]

# %%
#pyterrier exspects a docno field
df_filtered['docno'] = df_filtered['id']
df_filtered['text'] = df_filtered['label']

# %%
index_folder = "./df_index"

indexer = pt.DFIndexer(index_folder, overwrite=True)
index_ref = indexer.index(df_filtered['text'], df_filtered['docno'])

print(f"path to our index: {index_ref.toString()}")
# Out:
# /var/folders/88/9blsh45918g8y3n5vl6vztxr0000gq/T/ipykernel_3547/146072258.py:3: DeprecationWarning: Call to deprecated class DFIndexer. (use pt.terrier.IterDictIndexer().index(dataframe.to_dict(orient='records')) instead) -- Deprecated since version 0.11.0.
#   indexer = pt.DFIndexer(index_folder, overwrite=True)
# Java started (triggered by TerrierIndexer.__init__) and loaded: pyterrier.java, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]
# 09:14:34.413 [main] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (https://www.bibsonomy.org/url/45d7bb8eace077fe1f46f404529960f4/iblis) - further warnings are suppressed
# 09:14:35.454 [main] WARN org.terrier.structures.indexing.Indexer -- Indexed 4 empty documents
# path to our index: ./df_index/data.properties

# %%
index = pt.IndexFactory.of(index_ref)

# %%
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 8000
# Number of terms: 8481
# Number of postings: 46839
# Number of fields: 0
# Number of tokens: 48611
# Field names: []
# Positions:   false

# %%
for kv in index.getLexicon():
    print(f"{kv.getKey()} -> {kv.getValue().toString()}")
# Out:
# 0 -> term1 Nt=94 TF=103 maxTF=3 @{0 0 0}
# 000 -> term4818 Nt=5 TF=5 maxTF=1 @{0 132 1}
# 0002 -> term4089 Nt=4 TF=4 maxTF=1 @{0 145 3}
# 01 -> term5346 Nt=3 TF=3 maxTF=1 @{0 150 1}
# 017 -> term5389 Nt=1 TF=1 maxTF=1 @{0 158 3}
# 02 -> term3559 Nt=4 TF=4 maxTF=1 @{0 161 5}
# 03 -> term3626 Nt=3 TF=3 maxTF=1 @{0 169 7}
# 0301 -> term3463 Nt=1 TF=1 maxTF=1 @{0 177 1}
# 04 -> term3599 Nt=3 TF=3 maxTF=1 @{0 180 1}
# 05 -> term1331 Nt=3 TF=3 maxTF=1 @{0 187 5}
# 050 -> term2507 Nt=1 TF=1 maxTF=1 @{0 195 3}
# 06 -> term4354 Nt=3 TF=3 maxTF=1 @{0 198 1}
# 062 -> term7186 Nt=1 TF=1 maxTF=1 @{0 206 7}
# 07 -> term3868 Nt=3 TF=3 maxTF=1 @{0 210 1}
# 08 -> term3969 Nt=3 TF=4 maxTF=2 @{0 217 5}
# 09 -> term5266 Nt=1 TF=1 maxTF=1 @{0 224 0}
# 1 -> term767 Nt=48 TF=58 maxTF=4 @{0 227 2}
# 10 -> term1029 Nt=24 TF=25 maxTF=2 @{0 310 2}
# 100 -> term3368 Nt=8 TF=8 maxTF=1 @{0 355 1}
# 101 -> term3875 Nt=1 TF=1 maxTF=1 @{0 374 5}
# 1039 -> term5958 Nt=1 TF=1 maxTF=1 @{0 377 5}
# 10g -> term96 Nt=7 TF=7 maxTF=1 @{0 380 7}
# 11 -> term1275 Nt=11 TF=11 maxTF=1 @{0 393 3}
# 113 -> term5603 Nt=1 TF=1 maxTF=1 @{0 418 7}
# 115th -> term4565 Nt=1 TF=1 maxTF=1 @{0 422 1}
# 116 -> term5369 Nt=1 TF=1 maxTF=1 @{0 425 1}
# 12 -> term468 Nt=6 TF=6 maxTF=1 @{0 428 3}
# 120 -> term7135 Nt=1 TF=1 maxTF=1 @{0 443 1}
# 13 -> term3557 Nt=5 TF=6 maxTF=2 @{0 446 3}
# 14 -> term1698 Nt=7 TF=7 maxTF=1 @{0 458 4}
# 140 -> term6192 Nt=1 TF=1 maxTF=1 @{0 475 0}
# 1450 -> term371 Nt=2 TF=2 maxTF=1 @{0 478 2}
# 15 -> term1126 Nt=7 TF=7 maxTF=1 @{0 482 6}
# 150 -> term4460 Nt=1 TF=1 maxTF=1 @{0 497 2}
# 153 -> term2136 Nt=1 TF=1 maxTF=1 @{0 500 2}
# 16 -> term1598 Nt=6 TF=7 maxTF=2 @{0 503 0}
# 160 -> term4044 Nt=1 TF=1 maxTF=1 @{0 516 3}
# 1644 -> term808 Nt=1 TF=1 maxTF=1 @{0 519 3}
# 16th -> term2877 Nt=1 TF=1 maxTF=1 @{0 521 5}
# 17 -> term4353 Nt=3 TF=3 maxTF=1 @{0 524 3}
# 1740 -> term985 Nt=1 TF=1 maxTF=1 @{0 532 5}
# 1785 -> term7080 Nt=2 TF=2 maxTF=1 @{0 534 7}
# 17th -> term1425 Nt=1 TF=1 maxTF=1 @{0 540 1}
# 18 -> term1449 Nt=4 TF=4 maxTF=1 @{0 542 5}
# 180 -> term6991 Nt=1 TF=1 maxTF=1 @{0 550 7}
# 1800 -> term1230 Nt=1 TF=1 maxTF=1 @{0 554 1}
# 1802 -> term7352 Nt=1 TF=1 maxTF=1 @{0 556 5}
# 1837 -> term1708 Nt=1 TF=1 maxTF=1 @{0 559 7}
# 1850 -> term987 Nt=1 TF=1 maxTF=1 @{0 562 3}
# 1869 -> term7876 Nt=1 TF=1 maxTF=1 @{0 564 5}
# 1874 -> term6210 Nt=1 TF=1 maxTF=1 @{0 567 7}
# 1878 -> term8413 Nt=1 TF=1 maxTF=1 @{0 571 1}
# 1893 -> term7132 Nt=1 TF=1 maxTF=1 @{0 574 3}
# 1894 -> term7184 Nt=1 TF=1 maxTF=1 @{0 577 5}
# 1895 -> term6986 Nt=2 TF=2 maxTF=1 @{0 580 7}
# 1896 -> term6975 Nt=1 TF=1 maxTF=1 @{0 584 5}
# 1897 -> term6985 Nt=2 TF=2 maxTF=1 @{0 587 7}
# 1899 -> term6969 Nt=1 TF=1 maxTF=1 @{0 591 3}
# 19 -> term2164 Nt=8 TF=9 maxTF=2 @{0 594 5}
# 1900 -> term6984 Nt=2 TF=2 maxTF=1 @{0 612 4}
# 1901 -> term1707 Nt=1 TF=1 maxTF=1 @{0 616 6}
# 1902 -> term6971 Nt=1 TF=1 maxTF=1 @{0 619 2}
# 1904 -> term6974 Nt=1 TF=1 maxTF=1 @{0 622 4}
# 1907 -> term6973 Nt=1 TF=1 maxTF=1 @{0 625 6}
# 1909 -> term6972 Nt=1 TF=1 maxTF=1 @{0 629 0}
# 191 -> term1522 Nt=1 TF=1 maxTF=1 @{0 632 2}
# 1912 -> term807 Nt=2 TF=2 maxTF=1 @{0 634 6}
# 1922 -> term6211 Nt=1 TF=1 maxTF=1 @{0 640 2}
# 1923 -> term7372 Nt=1 TF=1 maxTF=1 @{0 643 4}
# 1939 -> term8358 Nt=1 TF=1 maxTF=1 @{0 646 6}
# 194 -> term1276 Nt=1 TF=1 maxTF=1 @{0 650 0}
# 1941 -> term8410 Nt=1 TF=1 maxTF=1 @{0 652 4}
# 1945 -> term370 Nt=3 TF=3 maxTF=1 @{0 655 6}
# 1950 -> term6156 Nt=1 TF=1 maxTF=1 @{0 663 4}
# 1956 -> term7166 Nt=1 TF=1 maxTF=1 @{0 666 6}
# 1957 -> term5955 Nt=1 TF=1 maxTF=1 @{0 670 0}
# 1959 -> term6263 Nt=2 TF=2 maxTF=1 @{0 673 2}
# 1960 -> term8401 Nt=1 TF=1 maxTF=1 @{0 678 4}
# 1960er -> term8094 Nt=1 TF=1 maxTF=1 @{0 681 6}
# 1965 -> term6863 Nt=1 TF=1 maxTF=1 @{0 685 0}
# 1967 -> term6670 Nt=1 TF=1 maxTF=1 @{0 688 2}
# 1970 -> term6147 Nt=2 TF=2 maxTF=1 @{0 691 4}
# 1974 -> term1630 Nt=1 TF=1 maxTF=1 @{0 697 0}
# 1976 -> term6188 Nt=1 TF=1 maxTF=1 @{0 699 4}
# 1980er -> term8097 Nt=1 TF=1 maxTF=1 @{0 702 6}
# 1981 -> term1553 Nt=1 TF=1 maxTF=1 @{0 706 0}
# 1983 -> term1050 Nt=2 TF=2 maxTF=1 @{0 708 4}
# 1984 -> term6265 Nt=1 TF=1 maxTF=1 @{0 712 6}
# 1985 -> term7081 Nt=2 TF=2 maxTF=1 @{0 716 0}
# 1986 -> term7848 Nt=2 TF=2 maxTF=1 @{0 721 2}
# 1990 -> term6148 Nt=1 TF=1 maxTF=1 @{0 727 0}
# 1992 -> term3056 Nt=1 TF=2 maxTF=2 @{0 730 2}
# 1994 -> term4670 Nt=1 TF=1 maxTF=1 @{0 733 1}
# 1996 -> term7329 Nt=2 TF=2 maxTF=1 @{0 736 1}
# 1997 -> term109 Nt=2 TF=2 maxTF=1 @{0 740 5}
# 1998 -> term2937 Nt=1 TF=1 maxTF=1 @{0 744 7}
# 1999 -> term6305 Nt=1 TF=1 maxTF=1 @{0 747 5}
# 1d -> term6518 Nt=1 TF=1 maxTF=1 @{0 750 7}
# 1st -> term2940 Nt=2 TF=2 maxTF=1 @{0 754 1}
# 2 -> term0 Nt=104 TF=113 maxTF=2 @{0 759 7}
# 20 -> term50 Nt=9 TF=9 maxTF=1 @{0 907 4}
# 200 -> term3409 Nt=1 TF=1 maxTF=1 @{0 927 4}
# 2000 -> term675 Nt=10 TF=10 maxTF=1 @{0 930 4}
# 2001 -> term1450 Nt=3 TF=4 maxTF=2 @{0 954 4}
# 2002 -> term2796 Nt=1 TF=1 maxTF=1 @{0 962 7}
# 2003 -> term2915 Nt=3 TF=3 maxTF=1 @{0 965 5}
# 2004 -> term1908 Nt=3 TF=3 maxTF=1 @{0 974 1}
# 2005 -> term276 Nt=8 TF=8 maxTF=1 @{0 981 7}
# 2006 -> term1332 Nt=8 TF=8 maxTF=1 @{0 1000 7}
# 2007 -> term3290 Nt=7 TF=7 maxTF=1 @{0 1018 7}
# 2008 -> term1110 Nt=9 TF=9 maxTF=1 @{0 1033 7}
# 2009 -> term1861 Nt=10 TF=10 maxTF=1 @{0 1052 7}
# 2010 -> term3602 Nt=6 TF=6 maxTF=1 @{0 1075 7}
# 2011 -> term2206 Nt=10 TF=10 maxTF=1 @{0 1089 7}
# 2012 -> term3993 Nt=7 TF=7 maxTF=1 @{0 1112 5}
# 2013 -> term1266 Nt=6 TF=6 maxTF=1 @{0 1129 5}
# 2014 -> term6352 Nt=2 TF=2 maxTF=1 @{0 1145 3}
# 2015 -> term2539 Nt=12 TF=12 maxTF=1 @{0 1150 5}
# 2016 -> term3088 Nt=11 TF=11 maxTF=1 @{0 1174 7}
# 2017 -> term1244 Nt=11 TF=13 maxTF=2 @{0 1197 3}
# 2018 -> term1127 Nt=10 TF=10 maxTF=1 @{0 1223 1}
# 2019 -> term3558 Nt=13 TF=14 maxTF=2 @{0 1245 3}
# 2020 -> term3601 Nt=3 TF=3 maxTF=1 @{0 1268 6}
# 2021 -> term1308 Nt=7 TF=7 maxTF=1 @{0 1277 6}
# 2022 -> term484 Nt=5 TF=5 maxTF=1 @{0 1295 0}
# 2025 -> term3600 Nt=1 TF=1 maxTF=1 @{0 1306 4}
# 2030 -> term6225 Nt=9 TF=9 maxTF=1 @{0 1309 4}
# 21 -> term4117 Nt=4 TF=4 maxTF=1 @{0 1322 4}
# 21c -> term175 Nt=1 TF=1 maxTF=1 @{0 1332 2}
# 21st -> term3023 Nt=10 TF=10 maxTF=1 @{0 1333 6}
# 22 -> term1549 Nt=6 TF=6 maxTF=1 @{0 1355 2}
# 2200 -> term7394 Nt=1 TF=1 maxTF=1 @{0 1370 2}
# 23 -> term4024 Nt=3 TF=3 maxTF=1 @{0 1373 4}
# 231 -> term2936 Nt=1 TF=1 maxTF=1 @{0 1382 0}
# 2324 -> term3327 Nt=1 TF=1 maxTF=1 @{0 1384 6}
# 24 -> term1548 Nt=6 TF=6 maxTF=1 @{0 1387 6}
# 240 -> term3913 Nt=1 TF=1 maxTF=1 @{0 1402 6}
# 249 -> term1004 Nt=1 TF=1 maxTF=1 @{0 1405 6}
# 25 -> term3922 Nt=3 TF=3 maxTF=1 @{0 1408 0}
# 256 -> term4924 Nt=1 TF=1 maxTF=1 @{0 1416 6}
# 25th -> term2538 Nt=2 TF=2 maxTF=1 @{0 1419 6}
# 26 -> term3054 Nt=1 TF=1 maxTF=1 @{0 1422 6}
# 26th -> term7579 Nt=1 TF=1 maxTF=1 @{0 1425 4}
# 2756 -> term3743 Nt=1 TF=1 maxTF=1 @{0 1428 6}
# 27th -> term5379 Nt=1 TF=1 maxTF=1 @{0 1431 6}
# 28 -> term3053 Nt=5 TF=5 maxTF=1 @{0 1435 0}
# 29 -> term6258 Nt=1 TF=1 maxTF=1 @{0 1447 2}
# 2bibliometr -> term6054 Nt=1 TF=1 maxTF=1 @{0 1450 4}
# 2d -> term3050 Nt=3 TF=3 maxTF=1 @{0 1453 6}
# 2nd -> term2479 Nt=2 TF=2 maxTF=1 @{0 1462 0}
# 3 -> term285 Nt=28 TF=29 maxTF=2 @{0 1467 6}
# 30 -> term6913 Nt=2 TF=2 maxTF=1 @{0 1518 3}
# 3013 -> term1601 Nt=1 TF=1 maxTF=1 @{0 1524 3}
# 3150 -> term665 Nt=1 TF=1 maxTF=1 @{0 1526 7}
# 3159 -> term1602 Nt=1 TF=1 maxTF=1 @{0 1529 1}
# 31c3 -> term3827 Nt=1 TF=1 maxTF=1 @{0 1531 5}
# 33 -> term6866 Nt=1 TF=1 maxTF=1 @{0 1534 5}
# 3403 -> term5 Nt=1 TF=1 maxTF=1 @{0 1537 7}
# 35mm -> term7598 Nt=1 TF=1 maxTF=1 @{0 1538 3}
# 36 -> term1108 Nt=1 TF=1 maxTF=1 @{0 1541 5}
# 37 -> term3263 Nt=1 TF=1 maxTF=1 @{0 1544 1}
# 3cdb -> term3071 Nt=1 TF=1 maxTF=1 @{0 1546 7}
# 3d -> term2535 Nt=20 TF=20 maxTF=1 @{0 1549 5}
# 3dmol -> term5519 Nt=1 TF=1 maxTF=1 @{0 1589 1}
# 3m -> term5178 Nt=1 TF=1 maxTF=1 @{0 1592 3}
# 3rd -> term297 Nt=2 TF=2 maxTF=1 @{0 1595 3}
# 4 -> term1067 Nt=19 TF=19 maxTF=1 @{0 1600 3}
# 40 -> term4240 Nt=3 TF=3 maxTF=1 @{0 1639 1}
# 41 -> term5822 Nt=1 TF=1 maxTF=1 @{0 1647 7}
# 42 -> term304 Nt=1 TF=1 maxTF=1 @{0 1651 1}
# 43 -> term3305 Nt=2 TF=2 maxTF=1 @{0 1652 7}
# 445 -> term1325 Nt=1 TF=1 maxTF=1 @{0 1658 1}
# 451 -> term38 Nt=2 TF=2 maxTF=1 @{0 1660 5}
# 456 -> term7435 Nt=1 TF=1 maxTF=1 @{0 1663 1}
# 4586 -> term4564 Nt=1 TF=1 maxTF=1 @{0 1666 3}
# 478 -> term6868 Nt=1 TF=1 maxTF=1 @{0 1669 3}
# 484 -> term6867 Nt=1 TF=1 maxTF=1 @{0 1672 5}
# 4store -> term1352 Nt=2 TF=2 maxTF=1 @{0 1675 7}
# 4th -> term2906 Nt=2 TF=2 maxTF=1 @{0 1679 1}
# 5 -> term471 Nt=18 TF=18 maxTF=1 @{0 1684 3}
# 50 -> term3287 Nt=6 TF=6 maxTF=1 @{0 1719 5}
# 500 -> term5365 Nt=2 TF=2 maxTF=1 @{0 1733 7}
# 5806 -> term19 Nt=1 TF=1 maxTF=1 @{0 1739 5}
# 594 -> term5536 Nt=1 TF=1 maxTF=1 @{0 1740 5}
# 5th -> term2148 Nt=3 TF=3 maxTF=1 @{0 1743 7}
# 6 -> term278 Nt=7 TF=7 maxTF=1 @{0 1751 1}
# 64 -> term176 Nt=1 TF=1 maxTF=1 @{0 1768 7}
# 645 -> term1326 Nt=1 TF=1 maxTF=1 @{0 1770 3}
# 6581 -> term7209 Nt=1 TF=1 maxTF=1 @{0 1772 7}
# 69 -> term3215 Nt=2 TF=2 maxTF=1 @{0 1776 1}
# 6beta2 -> term879 Nt=1 TF=1 maxTF=1 @{0 1780 5}
# 7 -> term110 Nt=14 TF=14 maxTF=1 @{0 1782 7}
# 70 -> term5699 Nt=1 TF=1 maxTF=1 @{0 1810 5}
# 70th -> term5701 Nt=1 TF=1 maxTF=1 @{0 1813 7}
# 71 -> term6672 Nt=1 TF=1 maxTF=1 @{0 1817 1}
# 721 -> term1128 Nt=1 TF=1 maxTF=1 @{0 1820 3}
# 74 -> term1283 Nt=1 TF=1 maxTF=1 @{0 1822 7}
# 760 -> term1193 Nt=1 TF=1 maxTF=1 @{0 1825 3}
# 76th -> term6553 Nt=1 TF=1 maxTF=1 @{0 1827 7}
# 7th -> term1453 Nt=1 TF=1 maxTF=1 @{0 1831 1}
# 8 -> term470 Nt=13 TF=13 maxTF=1 @{0 1833 5}
# 80 -> term3222 Nt=2 TF=2 maxTF=1 @{0 1862 5}
# 8080 -> term7470 Nt=1 TF=1 maxTF=1 @{0 1867 1}
# 82nd -> term6281 Nt=1 TF=1 maxTF=1 @{0 1870 3}
# 830 -> term279 Nt=1 TF=1 maxTF=1 @{0 1873 5}
# 8580 -> term7212 Nt=1 TF=1 maxTF=1 @{0 1875 3}
# 891 -> term5533 Nt=1 TF=1 maxTF=1 @{0 1878 5}
# 8th -> term1852 Nt=2 TF=2 maxTF=1 @{0 1881 7}
# 9 -> term1183 Nt=9 TF=9 maxTF=1 @{0 1887 7}
# 920 -> term3433 Nt=2 TF=2 maxTF=1 @{0 1907 7}
# 939 -> term5534 Nt=1 TF=1 maxTF=1 @{0 1912 3}
# 96 -> term7413 Nt=1 TF=1 maxTF=1 @{0 1915 5}
# 966 -> term1189 Nt=1 TF=1 maxTF=1 @{0 1918 7}
# a3 -> term4803 Nt=1 TF=1 maxTF=1 @{0 1921 3}
# a4 -> term6908 Nt=1 TF=1 maxTF=1 @{0 1924 3}
# aa2 -> term6404 Nt=1 TF=1 maxTF=1 @{0 1927 5}
# aaai -> term7807 Nt=1 TF=1 maxTF=1 @{0 1930 7}
# aac -> term4113 Nt=1 TF=1 maxTF=1 @{0 1934 1}
# aadhaar -> term1059 Nt=3 TF=3 maxTF=1 @{0 1937 1}
# aagingbas -> term1924 Nt=1 TF=1 maxTF=1 @{0 1943 7}
# aapl -> term5392 Nt=1 TF=1 maxTF=1 @{0 1946 5}
# aaron -> term5552 Nt=2 TF=2 maxTF=1 @{0 1949 7}
# aatss -> term4642 Nt=1 TF=1 maxTF=1 @{0 1954 3}
# aaup -> term7182 Nt=1 TF=1 maxTF=1 @{0 1957 3}
# ab -> term1208 Nt=3 TF=3 maxTF=1 @{0 1960 5}
# ab52 -> term6406 Nt=1 TF=1 maxTF=1 @{0 1966 3}
# abampdb -> term1935 Nt=1 TF=1 maxTF=1 @{0 1969 5}
# abandon -> term5213 Nt=1 TF=1 maxTF=1 @{0 1972 3}
# abandonwar -> term719 Nt=1 TF=2 maxTF=2 @{0 1975 3}
# abbrevi -> term2521 Nt=1 TF=1 maxTF=1 @{0 1977 6}
# abcdef -> term8165 Nt=1 TF=1 maxTF=1 @{0 1980 4}
# abella -> term8210 Nt=1 TF=1 maxTF=1 @{0 1983 6}
# abiot -> term2618 Nt=1 TF=1 maxTF=1 @{0 1987 0}
# abou -> term7324 Nt=1 TF=1 maxTF=1 @{0 1989 6}
# absatzsetz -> term3456 Nt=1 TF=1 maxTF=1 @{0 1993 0}
# abschi -> term4989 Nt=1 TF=1 maxTF=1 @{0 1996 0}
# abschluss -> term7971 Nt=1 TF=1 maxTF=1 @{0 1999 0}
# absolut -> term7206 Nt=1 TF=1 maxTF=1 @{0 2002 2}
# absorpt -> term7750 Nt=1 TF=1 maxTF=1 @{0 2005 4}
# abstract -> term150 Nt=27 TF=27 maxTF=1 @{0 2008 6}
# abu -> term5990 Nt=1 TF=1 maxTF=1 @{0 2058 6}
# ac -> term5238 Nt=4 TF=4 maxTF=1 @{0 2062 0}
# academ -> term493 Nt=72 TF=74 maxTF=3 @{0 2072 4}
# academi -> term1273 Nt=5 TF=5 maxTF=1 @{0 2164 4}
# academician -> term7914 Nt=1 TF=1 maxTF=1 @{0 2175 4}
# acadtag -> term4521 Nt=1 TF=1 maxTF=1 @{0 2178 6}
# acc -> term6690 Nt=7 TF=7 maxTF=1 @{0 2181 6}
# acceler -> term2039 Nt=5 TF=5 maxTF=1 @{0 2193 2}
# accent -> term8400 Nt=1 TF=1 maxTF=1 @{0 2205 0}
# accept -> term3734 Nt=1 TF=1 maxTF=1 @{0 2208 2}
# access -> term215 Nt=105 TF=106 maxTF=2 @{0 2211 2}
# accessdeni -> term473 Nt=1 TF=1 maxTF=1 @{0 2357 7}
# accid -> term1274 Nt=2 TF=2 maxTF=1 @{0 2359 7}
# accident -> term5325 Nt=2 TF=2 maxTF=1 @{0 2364 7}
# accord -> term6501 Nt=2 TF=2 maxTF=1 @{0 2370 5}
# account -> term2706 Nt=2 TF=2 maxTF=1 @{0 2376 1}
# accueil -> term6940 Nt=6 TF=6 maxTF=1 @{0 2381 7}
# accur -> term5120 Nt=2 TF=2 maxTF=1 @{0 2393 1}
# accuraci -> term3178 Nt=3 TF=3 maxTF=1 @{0 2398 3}
# acetobas -> term3152 Nt=1 TF=1 maxTF=1 @{0 2406 5}
# achiev -> term6392 Nt=3 TF=3 maxTF=1 @{0 2409 3}
# acid -> term236 Nt=7 TF=7 maxTF=1 @{0 2417 5}
# acinetobact -> term1938 Nt=2 TF=2 maxTF=1 @{0 2433 3}
# acinetobas -> term1962 Nt=1 TF=1 maxTF=1 @{0 2437 1}
# acl -> term7397 Nt=1 TF=1 maxTF=1 @{0 2439 7}
# acm -> term1035 Nt=5 TF=5 maxTF=1 @{0 2443 1}
# acoust -> term1965 Nt=4 TF=6 maxTF=2 @{0 2452 5}
# acousticpow -> term7314 Nt=2 TF=2 maxTF=1 @{0 2461 5}
# acquir -> term4905 Nt=5 TF=5 maxTF=1 @{0 2465 1}
# acquisit -> term4068 Nt=9 TF=9 maxTF=1 @{0 2472 3}
# acronym -> term1224 Nt=2 TF=3 maxTF=2 @{0 2492 1}
# across -> term437 Nt=7 TF=7 maxTF=1 @{0 2498 0}
# act -> term931 Nt=9 TF=9 maxTF=1 @{0 2511 2}
# acta -> term4208 Nt=3 TF=3 maxTF=1 @{0 2531 0}
# action -> term653 Nt=17 TF=18 maxTF=2 @{0 2538 4}
# actionscript -> term5226 Nt=1 TF=1 maxTF=1 @{0 2570 3}
# activ -> term1079 Nt=27 TF=28 maxTF=2 @{0 2573 3}
# activecouch -> term5304 Nt=1 TF=1 maxTF=1 @{0 2622 2}
# activemigr -> term1680 Nt=1 TF=1 maxTF=1 @{0 2625 4}
# activerecord -> term5305 Nt=1 TF=1 maxTF=1 @{0 2628 0}
# activeresourc -> term5306 Nt=1 TF=1 maxTF=1 @{0 2631 2}
# activest -> term4326 Nt=1 TF=1 maxTF=1 @{0 2634 4}
# actual -> term5639 Nt=1 TF=1 maxTF=1 @{0 2637 4}
# acubert -> term2825 Nt=1 TF=1 maxTF=1 @{0 2640 6}
# acupunctur -> term2827 Nt=1 TF=1 maxTF=1 @{0 2643 4}
# acut -> term5820 Nt=1 TF=1 maxTF=1 @{0 2646 2}
# ad -> term1721 Nt=11 TF=12 maxTF=2 @{0 2649 4}
# ada -> term7344 Nt=2 TF=2 maxTF=1 @{0 2673 1}
# adam -> term2522 Nt=2 TF=2 maxTF=1 @{0 2679 1}
# adapt -> term2271 Nt=21 TF=21 maxTF=1 @{0 2685 1}
# adarch -> term7290 Nt=1 TF=1 maxTF=1 @{0 2725 7}
# adat -> term494 Nt=2 TF=2 maxTF=1 @{0 2729 1}
# add -> term974 Nt=10 TF=10 maxTF=1 @{0 2733 3}
# addgen -> term616 Nt=1 TF=1 maxTF=1 @{0 2752 1}
# addit -> term3698 Nt=2 TF=2 maxTF=1 @{0 2754 3}
# addon -> term685 Nt=1 TF=1 maxTF=1 @{0 2760 1}
# address -> term900 Nt=9 TF=9 maxTF=1 @{0 2762 3}
# addresse -> term5003 Nt=1 TF=1 maxTF=1 @{0 2783 5}
# adhyayana -> term4771 Nt=1 TF=1 maxTF=1 @{0 2786 5}
# aditi -> term2977 Nt=1 TF=1 maxTF=1 @{0 2789 5}
# adjust -> term4330 Nt=1 TF=1 maxTF=1 @{0 2792 3}
# admin -> term1412 Nt=1 TF=1 maxTF=1 @{0 2795 3}
# administr -> term2322 Nt=7 TF=7 maxTF=1 @{0 2797 7}
# ado -> term185 Nt=3 TF=3 maxTF=1 @{0 2815 1}
# adob -> term3253 Nt=5 TF=5 maxTF=1 @{0 2822 1}
# adodb -> term1458 Nt=2 TF=2 maxTF=1 @{0 2833 5}
# adolesc -> term4635 Nt=1 TF=1 maxTF=1 @{0 2837 3}
# adopt -> term1998 Nt=4 TF=4 maxTF=1 @{0 2840 3}
# adsens -> term4189 Nt=1 TF=1 maxTF=1 @{0 2851 3}
# adult -> term5607 Nt=1 TF=1 maxTF=1 @{0 2854 3}
# advanc -> term492 Nt=28 TF=29 maxTF=2 @{0 2857 5}
# advantag -> term5589 Nt=2 TF=2 maxTF=1 @{0 2909 2}
# adventur -> term590 Nt=10 TF=11 maxTF=2 @{0 2915 0}
# adverlicio -> term7511 Nt=1 TF=1 maxTF=1 @{0 2935 1}
# advers -> term2835 Nt=1 TF=1 maxTF=1 @{0 2938 3}
# adversari -> term4620 Nt=5 TF=5 maxTF=1 @{0 2941 1}
# advertis -> term1344 Nt=8 TF=10 maxTF=2 @{0 2950 7}
# advic -> term6123 Nt=1 TF=1 maxTF=1 @{0 2970 1}
# advisori -> term6097 Nt=3 TF=3 maxTF=1 @{0 2973 3}
# advocaci -> term5663 Nt=2 TF=2 maxTF=1 @{0 2981 1}
# adwar -> term711 Nt=1 TF=1 maxTF=1 @{0 2986 7}
# adzic -> term200 Nt=1 TF=1 maxTF=1 @{0 2989 1}
# aeneid -> term4063 Nt=1 TF=1 maxTF=1 @{0 2990 7}
# aeria -> term7100 Nt=1 TF=1 maxTF=1 @{0 2993 7}
# aerial -> term2889 Nt=1 TF=1 maxTF=1 @{0 2997 1}
# aerob -> term1391 Nt=2 TF=2 maxTF=1 @{0 2999 7}
# aesthet -> term6399 Nt=1 TF=1 maxTF=1 @{0 3005 1}
# affair -> term3473 Nt=1 TF=1 maxTF=1 @{0 3008 3}
# affect -> term3018 Nt=4 TF=4 maxTF=1 @{0 3011 3}
# affili -> term6642 Nt=1 TF=1 maxTF=1 @{0 3022 5}
# afford -> term4075 Nt=2 TF=2 maxTF=1 @{0 3025 7}
# affymetrix -> term2327 Nt=1 TF=1 maxTF=1 @{0 3031 7}
# afghan -> term8067 Nt=1 TF=1 maxTF=1 @{0 3034 5}
# africa -> term6429 Nt=3 TF=3 maxTF=1 @{0 3037 7}
# africabib -> term1633 Nt=1 TF=1 maxTF=1 @{0 3045 3}
# african -> term2644 Nt=4 TF=4 maxTF=1 @{0 3047 7}
# africana -> term1632 Nt=1 TF=1 maxTF=1 @{0 3058 5}
# aftm -> term2084 Nt=1 TF=1 maxTF=1 @{0 3061 1}
# ag -> term327 Nt=14 TF=15 maxTF=2 @{0 3063 7}
# agata -> term6548 Nt=1 TF=1 maxTF=1 @{0 3093 6}
# agbas -> term3136 Nt=1 TF=1 maxTF=1 @{0 3097 0}
# agbay -> term6829 Nt=1 TF=1 maxTF=1 @{0 3099 6}
# agbiodata -> term2426 Nt=1 TF=1 maxTF=1 @{0 3103 0}
# agd -> term2457 Nt=1 TF=1 maxTF=1 @{0 3105 6}
# ageid -> term2573 Nt=1 TF=1 maxTF=1 @{0 3108 4}
# agenc -> term1409 Nt=3 TF=3 maxTF=1 @{0 3111 2}
# agend -> term6763 Nt=1 TF=1 maxTF=1 @{0 3117 6}
# agenda -> term4981 Nt=5 TF=5 maxTF=1 @{0 3121 0}
# agendi -> term6882 Nt=1 TF=1 maxTF=1 @{0 3131 6}
# agent -> term3082 Nt=6 TF=6 maxTF=1 @{0 3135 0}
# ager -> term6485 Nt=1 TF=1 maxTF=1 @{0 3150 4}
# aggreg -> term2681 Nt=17 TF=17 maxTF=1 @{0 3153 6}
# agid -> term914 Nt=1 TF=1 maxTF=1 @{0 3181 4}
# agil -> term1133 Nt=3 TF=3 maxTF=1 @{0 3183 6}
# agiledata -> term1423 Nt=1 TF=1 maxTF=1 @{0 3189 6}
# agimatec -> term1714 Nt=1 TF=1 maxTF=1 @{0 3192 2}
# agnost -> term5610 Nt=2 TF=2 maxTF=1 @{0 3194 6}
# agodb -> term1959 Nt=1 TF=1 maxTF=1 @{0 3199 6}
# agonist -> term6082 Nt=1 TF=1 maxTF=1 @{0 3202 4}
# agre -> term5830 Nt=1 TF=1 maxTF=1 @{0 3205 6}
# agreement -> term6313 Nt=1 TF=1 maxTF=1 @{0 3209 0}
# agricultur -> term2030 Nt=6 TF=6 maxTF=1 @{0 3212 2}
# agronomi -> term7046 Nt=1 TF=1 maxTF=1 @{0 3227 0}
# agronomiqu -> term7500 Nt=1 TF=1 maxTF=1 @{0 3230 2}
# agrosi -> term2595 Nt=1 TF=1 maxTF=1 @{0 3233 4}
# agsl -> term6976 Nt=1 TF=1 maxTF=1 @{0 3236 2}
# ahead -> term4397 Nt=2 TF=2 maxTF=1 @{0 3239 4}
# ahmadelsagh -> term5201 Nt=1 TF=1 maxTF=1 @{0 3245 2}
# ahp -> term2056 Nt=2 TF=2 maxTF=1 @{0 3248 2}
# ai -> term3873 Nt=17 TF=17 maxTF=1 @{0 3254 2}
# aib -> term5250 Nt=1 TF=1 maxTF=1 @{0 3281 6}
# aid -> term2867 Nt=5 TF=5 maxTF=1 @{0 3285 0}
# aim -> term584 Nt=2 TF=2 maxTF=1 @{0 3298 2}
# aimedgraph -> term2730 Nt=1 TF=1 maxTF=1 @{0 3303 4}
# aipac -> term3995 Nt=1 TF=1 maxTF=1 @{0 3306 2}
# air -> term5212 Nt=3 TF=3 maxTF=1 @{0 3309 2}
# airborn -> term8334 Nt=1 TF=1 maxTF=1 @{0 3317 2}
# aircraft -> term1734 Nt=2 TF=3 maxTF=2 @{0 3320 4}
# airlin -> term1735 Nt=1 TF=1 maxTF=1 @{0 3326 3}
# airplan -> term1733 Nt=1 TF=1 maxTF=1 @{0 3328 7}
# airtabl -> term1692 Nt=1 TF=1 maxTF=1 @{0 3331 3}
# aisel -> term5720 Nt=1 TF=1 maxTF=1 @{0 3333 7}
# ajax -> term3888 Nt=3 TF=3 maxTF=1 @{0 3337 1}
# akwukwo -> term6816 Nt=1 TF=1 maxTF=1 @{0 3346 1}
# al -> term2227 Nt=6 TF=8 maxTF=2 @{0 3349 3}
# al1 -> term7465 Nt=1 TF=1 maxTF=1 @{0 3364 1}
# ala -> term5375 Nt=10 TF=10 maxTF=1 @{0 3367 3}
# alabama -> term7154 Nt=1 TF=1 maxTF=1 @{0 3389 1}
# alamo -> term3006 Nt=1 TF=1 maxTF=1 @{0 3392 3}
# alberta -> term3745 Nt=1 TF=1 maxTF=1 @{0 3395 1}
# alberto -> term3265 Nt=1 TF=1 maxTF=1 @{0 3398 1}
# albrighton -> term5281 Nt=1 TF=2 maxTF=2 @{0 3400 7}
# album -> term703 Nt=2 TF=2 maxTF=1 @{0 3404 2}
# alch -> term1186 Nt=1 TF=1 maxTF=1 @{0 3409 0}
# alec -> term3825 Nt=1 TF=1 maxTF=1 @{0 3411 4}
# alert -> term642 Nt=5 TF=5 maxTF=1 @{0 3414 4}
# alexand -> term5757 Nt=1 TF=1 maxTF=1 @{0 3426 4}
# alexandria -> term5805 Nt=5 TF=5 maxTF=1 @{0 3429 6}
# alexandrian -> term6682 Nt=1 TF=1 maxTF=1 @{0 3441 6}
# alexandrina -> term7830 Nt=1 TF=1 maxTF=1 @{0 3445 0}
# alexandrinu -> term8278 Nt=1 TF=1 maxTF=1 @{0 3448 2}
# alfresco -> term534 Nt=1 TF=1 maxTF=1 @{0 3451 4}
# alfrescowiki -> term535 Nt=1 TF=1 maxTF=1 @{0 3453 4}
# algal -> term2989 Nt=1 TF=1 maxTF=1 @{0 3455 4}
# algebra -> term2971 Nt=2 TF=2 maxTF=1 @{0 3458 2}
# algorithm -> term1557 Nt=87 TF=88 maxTF=2 @{0 3464 0}
# algorithmen -> term4583 Nt=3 TF=3 maxTF=1 @{0 3572 3}
# algoritm -> term8459 Nt=1 TF=1 maxTF=1 @{0 3579 3}
# alias -> term3794 Nt=1 TF=1 maxTF=1 @{0 3582 5}
# alic -> term6297 Nt=1 TF=1 maxTF=1 @{0 3585 5}
# align -> term1996 Nt=16 TF=16 maxTF=1 @{0 3588 7}
# alisonbabeu -> term3700 Nt=1 TF=1 maxTF=1 @{0 3620 1}
# all -> term6760 Nt=1 TF=1 maxTF=1 @{0 3623 1}
# alla -> term6711 Nt=2 TF=2 maxTF=1 @{0 3626 3}
# allama -> term6650 Nt=1 TF=1 maxTF=1 @{0 3632 3}
# allan -> term5697 Nt=2 TF=2 maxTF=1 @{0 3635 5}
# allegro -> term5512 Nt=1 TF=1 maxTF=1 @{0 3640 3}
# allgemein -> term8322 Nt=2 TF=2 maxTF=1 @{0 3643 5}
# allianc -> term5296 Nt=2 TF=2 maxTF=1 @{0 3648 3}
# alloc -> term6740 Nt=1 TF=1 maxTF=1 @{0 3654 5}
# allow -> term2398 Nt=2 TF=2 maxTF=1 @{0 3657 7}
# alltheweb -> term7898 Nt=1 TF=1 maxTF=1 @{0 3663 5}
# allum -> term7476 Nt=1 TF=1 maxTF=1 @{0 3666 7}
# alon -> term2641 Nt=2 TF=2 maxTF=1 @{0 3670 1}
# aloud -> term3633 Nt=1 TF=1 maxTF=1 @{0 3676 1}
# alpenl -> term7526 Nt=1 TF=1 maxTF=1 @{0 3679 1}
# alpha -> term2249 Nt=3 TF=3 maxTF=1 @{0 3682 3}
# alphab -> term8274 Nt=1 TF=1 maxTF=1 @{0 3691 1}
# alphabet -> term3931 Nt=1 TF=1 maxTF=1 @{0 3694 3}
# alphafold -> term2085 Nt=1 TF=1 maxTF=1 @{0 3697 3}
# alphamissens -> term2739 Nt=1 TF=1 maxTF=1 @{0 3700 1}
# alsbjer -> term5236 Nt=1 TF=1 maxTF=1 @{0 3702 7}
# alt -> term3348 Nt=2 TF=2 maxTF=1 @{0 3706 1}
# altavista -> term3385 Nt=2 TF=2 maxTF=1 @{0 3711 5}
# altdeutsch -> term4214 Nt=1 TF=1 maxTF=1 @{0 3716 3}
# alten -> term8395 Nt=1 TF=1 maxTF=1 @{0 3719 3}
# alter -> term820 Nt=1 TF=1 maxTF=1 @{0 3722 5}
# alterc -> term4046 Nt=1 TF=1 maxTF=1 @{0 3724 7}
# altern -> term2419 Nt=12 TF=12 maxTF=1 @{0 3727 7}
# altmann -> term4976 Nt=1 TF=1 maxTF=1 @{0 3754 3}
# altmetr -> term5144 Nt=1 TF=1 maxTF=1 @{0 3757 3}
# alto -> term1048 Nt=2 TF=2 maxTF=1 @{0 3760 3}
# altregistratur -> term7981 Nt=1 TF=1 maxTF=1 @{0 3765 7}
# altsiedellandschaft -> term8476 Nt=1 TF=1 maxTF=1 @{0 3769 1}
# alvinalexand -> term1166 Nt=1 TF=1 maxTF=1 @{0 3772 3}
# alzheim -> term2862 Nt=1 TF=1 maxTF=1 @{0 3774 7}
# alzip -> term7584 Nt=1 TF=1 maxTF=1 @{0 3777 5}
# am -> term3970 Nt=3 TF=3 maxTF=1 @{0 3780 7}
# amalgam -> term4796 Nt=1 TF=1 maxTF=1 @{0 3789 5}
# amass -> term8083 Nt=2 TF=2 maxTF=1 @{0 3792 5}
# amaz -> term5981 Nt=2 TF=2 maxTF=1 @{0 3797 3}
# amazon -> term1371 Nt=8 TF=9 maxTF=2 @{0 3802 5}
# amazonia -> term5681 Nt=1 TF=1 maxTF=1 @{0 3819 4}
# ambigu -> term2871 Nt=1 TF=1 maxTF=1 @{0 3822 6}
# amd -> term1669 Nt=3 TF=3 maxTF=1 @{0 3825 4}
# amen -> term5198 Nt=1 TF=1 maxTF=1 @{0 3831 2}
# america -> term1304 Nt=6 TF=7 maxTF=2 @{0 3834 2}
# american -> term1336 Nt=23 TF=23 maxTF=1 @{0 3849 5}
# amg -> term6697 Nt=1 TF=1 maxTF=1 @{0 3893 7}
# amga -> term8464 Nt=1 TF=1 maxTF=1 @{0 3897 1}
# amgcl -> term6695 Nt=1 TF=1 maxTF=1 @{0 3900 3}
# amh -> term8093 Nt=1 TF=1 maxTF=1 @{0 3903 5}
# amherst -> term5542 Nt=1 TF=1 maxTF=1 @{0 3906 7}
# amicu -> term5494 Nt=1 TF=1 maxTF=1 @{0 3910 1}
# amiga -> term422 Nt=2 TF=2 maxTF=1 @{0 3913 3}
# amino -> term2615 Nt=1 TF=1 maxTF=1 @{0 3918 5}
# aminobutyr -> term2784 Nt=1 TF=1 maxTF=1 @{0 3921 3}
# ampersand -> term1492 Nt=1 TF=1 maxTF=1 @{0 3924 1}
# amr -> term4808 Nt=1 TF=1 maxTF=1 @{0 3926 5}
# amsterdam -> term6244 Nt=1 TF=1 maxTF=1 @{0 3929 5}
# anaconda -> term6921 Nt=1 TF=1 maxTF=1 @{0 3932 7}
# anag -> term49 Nt=1 TF=1 maxTF=1 @{0 3936 1}
# analog -> term6844 Nt=2 TF=2 maxTF=1 @{0 3937 3}
# analys -> term1789 Nt=8 TF=8 maxTF=1 @{0 3943 5}
# analysi -> term91 Nt=198 TF=202 maxTF=2 @{0 3959 7}
# analysieren -> term5084 Nt=1 TF=1 maxTF=1 @{0 4186 5}
# analyst -> term4598 Nt=1 TF=1 maxTF=1 @{0 4189 5}
# analyt -> term358 Nt=29 TF=29 maxTF=1 @{0 4192 5}
# analyz -> term1235 Nt=18 TF=18 maxTF=1 @{0 4248 7}
# anambra -> term2371 Nt=1 TF=1 maxTF=1 @{0 4285 3}
# anaphora -> term3165 Nt=1 TF=1 maxTF=1 @{0 4288 1}
# anatomi -> term4741 Nt=1 TF=1 maxTF=1 @{0 4290 7}
# ancestri -> term2886 Nt=1 TF=1 maxTF=1 @{0 4293 7}
# anchor -> term4654 Nt=10 TF=10 maxTF=1 @{0 4296 5}
# ancient -> term834 Nt=6 TF=8 maxTF=2 @{0 4311 1}
# anderen -> term7668 Nt=1 TF=1 maxTF=1 @{0 4324 5}
# andexperiment -> term6536 Nt=1 TF=1 maxTF=1 @{0 4327 7}
# andrea -> term5334 Nt=1 TF=1 maxTF=1 @{0 4331 1}
# andrei -> term7913 Nt=1 TF=1 maxTF=1 @{0 4334 3}
# andrew -> term3777 Nt=3 TF=3 maxTF=1 @{0 4337 5}
# android -> term321 Nt=12 TF=12 maxTF=1 @{0 4345 5}
# anemia -> term2865 Nt=1 TF=1 maxTF=1 @{0 4372 3}
# anerbc -> term2868 Nt=1 TF=1 maxTF=1 @{0 4375 1}
# aneurysm -> term2458 Nt=1 TF=1 maxTF=1 @{0 4377 7}
# angebot -> term7699 Nt=1 TF=1 maxTF=1 @{0 4380 5}
# angel -> term4043 Nt=1 TF=1 maxTF=1 @{0 4383 7}
# angelegenheiten -> term7061 Nt=2 TF=2 maxTF=1 @{0 4386 7}
# angl -> term6723 Nt=1 TF=1 maxTF=1 @{0 4392 5}
# anglizismen -> term3672 Nt=1 TF=1 maxTF=1 @{0 4395 7}
# ani -> term7987 Nt=1 TF=1 maxTF=1 @{0 4398 7}
# anic -> term3958 Nt=1 TF=1 maxTF=1 @{0 4402 1}
# anim -> term1745 Nt=10 TF=10 maxTF=1 @{0 4405 1}
# ann -> term6003 Nt=1 TF=1 maxTF=1 @{0 4427 7}
# annal -> term3471 Nt=1 TF=1 maxTF=1 @{0 4431 1}
# annif -> term5138 Nt=1 TF=1 maxTF=1 @{0 4434 1}
# annot -> term1673 Nt=53 TF=53 maxTF=1 @{0 4437 1}
# announc -> term5347 Nt=6 TF=6 maxTF=1 @{0 4513 5}
# annual -> term2876 Nt=3 TF=3 maxTF=1 @{0 4527 7}
# ano -> term6812 Nt=1 TF=1 maxTF=1 @{0 4534 7}
# anpassbarkeit -> term8380 Nt=1 TF=1 maxTF=1 @{0 4538 1}
# anrprogramm -> term638 Nt=1 TF=1 maxTF=1 @{0 4541 3}
# answer -> term2561 Nt=12 TF=13 maxTF=2 @{0 4543 5}
# antaeu -> term6530 Nt=1 TF=1 maxTF=1 @{0 4568 0}
# antholog -> term7398 Nt=1 TF=1 maxTF=1 @{0 4571 2}
# anthrobas -> term526 Nt=2 TF=2 maxTF=1 @{0 4574 4}
# anthropolog -> term390 Nt=5 TF=7 maxTF=2 @{0 4578 4}
# anthropologist -> term6613 Nt=1 TF=1 maxTF=1 @{0 4590 4}
# anti -> term1925 Nt=4 TF=4 maxTF=1 @{0 4593 6}
# antibiot -> term2614 Nt=1 TF=1 maxTF=1 @{0 4604 4}
# antibodi -> term6403 Nt=2 TF=2 maxTF=1 @{0 4607 2}
# anticanc -> term2153 Nt=1 TF=1 maxTF=1 @{0 4612 6}
# antigen -> term6400 Nt=1 TF=1 maxTF=1 @{0 4615 4}
# antik -> term4704 Nt=1 TF=1 maxTF=1 @{0 4618 6}
# antikensammlung -> term7098 Nt=1 TF=1 maxTF=1 @{0 4621 6}
# antimicrobi -> term1936 Nt=4 TF=4 maxTF=1 @{0 4625 0}
# antiqu -> term6680 Nt=2 TF=2 maxTF=1 @{0 4634 2}
# anton -> term843 Nt=1 TF=1 maxTF=1 @{0 4640 2}
# anwendungen -> term3099 Nt=3 TF=3 maxTF=1 @{0 4642 4}
# anxieti -> term6649 Nt=1 TF=1 maxTF=1 @{0 4648 6}
# anzeigen -> term3659 Nt=1 TF=2 maxTF=2 @{0 4652 0}
# ao -> term7130 Nt=3 TF=3 maxTF=1 @{0 4655 1}
# aop -> term6364 Nt=1 TF=1 maxTF=1 @{0 4661 7}
# aortic -> term2636 Nt=1 TF=1 maxTF=1 @{0 4665 1}
# ap -> term7763 Nt=1 TF=1 maxTF=1 @{0 4667 7}
# apach -> term312 Nt=8 TF=8 maxTF=1 @{0 4671 1}
# apachebench -> term8325 Nt=2 TF=2 maxTF=1 @{0 4688 3}
# apadb -> term3069 Nt=1 TF=1 maxTF=1 @{0 4693 1}
# apd -> term3189 Nt=1 TF=1 maxTF=1 @{0 4695 7}
# api -> term1001 Nt=22 TF=24 maxTF=2 @{0 4698 5}
# apocrypha -> term5564 Nt=1 TF=1 maxTF=1 @{0 4736 3}
# apokalyptisch -> term3775 Nt=1 TF=1 maxTF=1 @{0 4739 5}
# apollo -> term7806 Nt=1 TF=1 maxTF=1 @{0 4742 5}
# apostolico -> term7787 Nt=1 TF=1 maxTF=1 @{0 4745 7}
# app -> term772 Nt=22 TF=25 maxTF=2 @{0 4749 1}
# appar -> term1060 Nt=1 TF=1 maxTF=1 @{0 4790 6}
# append -> term3820 Nt=2 TF=2 maxTF=1 @{0 4793 2}
# appl -> term511 Nt=1 TF=1 maxTF=1 @{0 4799 4}
# applescript -> term3573 Nt=1 TF=1 maxTF=1 @{0 4801 4}
# appli -> term2909 Nt=9 TF=9 maxTF=1 @{0 4804 4}
# applic -> term322 Nt=85 TF=86 maxTF=2 @{0 4824 0}
# appoint -> term3989 Nt=1 TF=1 maxTF=1 @{0 4948 5}
# apprais -> term2793 Nt=3 TF=3 maxTF=1 @{0 4951 5}
# appreci -> term6031 Nt=1 TF=1 maxTF=1 @{0 4958 3}
# apprentic -> term6499 Nt=1 TF=1 maxTF=1 @{0 4961 5}
# approach -> term1398 Nt=88 TF=88 maxTF=1 @{0 4964 7}
# appropedia -> term7546 Nt=1 TF=1 maxTF=1 @{0 5086 5}
# approv -> term5793 Nt=1 TF=1 maxTF=1 @{0 5089 7}
# approxim -> term5105 Nt=3 TF=3 maxTF=1 @{0 5093 1}
# april -> term1454 Nt=7 TF=7 maxTF=1 @{0 5101 5}
# aptam -> term2008 Nt=1 TF=1 maxTF=1 @{0 5118 5}
# aquabrows -> term5371 Nt=2 TF=2 maxTF=1 @{0 5121 3}
# aquat -> term8295 Nt=1 TF=1 maxTF=1 @{0 5126 7}
# aqueou -> term2055 Nt=1 TF=1 maxTF=1 @{0 5130 1}
# ar -> term8076 Nt=1 TF=1 maxTF=1 @{0 5132 7}
# arab -> term3382 Nt=6 TF=6 maxTF=1 @{0 5136 1}
# arabidopsi -> term1903 Nt=2 TF=2 maxTF=1 @{0 5150 7}
# aral -> term7900 Nt=1 TF=1 maxTF=1 @{0 5155 3}
# arata -> term5332 Nt=1 TF=1 maxTF=1 @{0 5158 5}
# arbeit -> term4539 Nt=2 TF=2 maxTF=1 @{0 5161 7}
# arbeitsgrupp -> term7057 Nt=2 TF=2 maxTF=1 @{0 5167 7}
# arbido -> term7102 Nt=1 TF=1 maxTF=1 @{0 5173 5}
# arbitrari -> term4340 Nt=2 TF=2 maxTF=1 @{0 5176 7}
# arbitrarili -> term4615 Nt=1 TF=1 maxTF=1 @{0 5182 3}
# arbor -> term6002 Nt=1 TF=1 maxTF=1 @{0 5185 3}
# arc -> term4774 Nt=3 TF=3 maxTF=1 @{0 5188 5}
# arcad -> term589 Nt=5 TF=5 maxTF=1 @{0 5195 1}
# arch -> term8164 Nt=1 TF=1 maxTF=1 @{0 5205 3}
# arch2 -> term8398 Nt=1 TF=1 maxTF=1 @{0 5208 5}
# archaeogam -> term8006 Nt=1 TF=1 maxTF=1 @{0 5211 7}
# archaeolog -> term5957 Nt=3 TF=3 maxTF=1 @{0 5215 1}
# archetyp -> term8269 Nt=1 TF=1 maxTF=1 @{0 5223 7}
# archi -> term2941 Nt=1 TF=1 maxTF=1 @{0 5227 1}
# archieven -> term7494 Nt=1 TF=1 maxTF=1 @{0 5229 7}
# archim -> term7115 Nt=1 TF=1 maxTF=1 @{0 5233 1}
# archimed -> term7908 Nt=2 TF=2 maxTF=1 @{0 5236 3}
# architect -> term5396 Nt=1 TF=1 maxTF=1 @{0 5242 1}
# architectour -> term1719 Nt=1 TF=1 maxTF=1 @{0 5245 3}
# architectur -> term849 Nt=37 TF=37 maxTF=1 @{0 5247 7}
# archiv -> term341 Nt=1783 TF=1875 maxTF=4 @{0 5305 7}
# archivag -> term6980 Nt=1 TF=1 maxTF=1 @{0 5858 3}
# archivalia -> term7213 Nt=1 TF=1 maxTF=1 @{0 5861 5}
# archivdienst -> term7965 Nt=1 TF=1 maxTF=1 @{0 5864 7}
# archive1 -> term7111 Nt=1 TF=1 maxTF=1 @{0 5868 1}
# archive20 -> term7533 Nt=1 TF=1 maxTF=1 @{0 5871 3}
# archive2008 -> term7565 Nt=1 TF=1 maxTF=1 @{0 5874 5}
# archivefilm -> term8253 Nt=1 TF=1 maxTF=1 @{0 5877 7}
# archiven -> term7742 Nt=1 TF=1 maxTF=1 @{0 5881 1}
# archivenow -> term7897 Nt=1 TF=1 maxTF=1 @{0 5884 3}
# archives -> term7255 Nt=9 TF=9 maxTF=1 @{0 5887 5}
# archivespark -> term7697 Nt=5 TF=5 maxTF=1 @{0 5900 5}
# archiveweb -> term7706 Nt=9 TF=9 maxTF=1 @{0 5909 3}
# archivierung -> term7089 Nt=1 TF=1 maxTF=1 @{0 5921 7}
# archivio -> term7789 Nt=2 TF=2 maxTF=1 @{0 5925 1}
# archivist -> term7710 Nt=1 TF=1 maxTF=1 @{0 5930 5}
# archivo -> term8059 Nt=3 TF=3 maxTF=1 @{0 5933 7}
# archivportal -> term7698 Nt=1 TF=1 maxTF=1 @{0 5940 1}
# archivschul -> term7962 Nt=1 TF=1 maxTF=1 @{0 5943 3}
# archivwesen -> term7534 Nt=1 TF=1 maxTF=1 @{0 5946 5}
# archnet -> term5623 Nt=1 TF=1 maxTF=1 @{0 5949 7}
# archsearch -> term5956 Nt=1 TF=1 maxTF=1 @{0 5953 1}
# archvi -> term7144 Nt=1 TF=1 maxTF=1 @{0 5956 3}
# arcp -> term8019 Nt=1 TF=1 maxTF=1 @{0 5959 5}
# ard -> term389 Nt=2 TF=2 maxTF=1 @{0 5962 7}
# ardo -> term8287 Nt=2 TF=2 maxTF=1 @{0 5968 1}
# arduino -> term2256 Nt=2 TF=2 maxTF=1 @{0 5971 7}
# area -> term179 Nt=7 TF=7 maxTF=1 @{0 5977 3}
# aren -> term4977 Nt=2 TF=2 maxTF=1 @{0 5995 1}
# argania -> term2233 Nt=1 TF=1 maxTF=1 @{0 6001 1}
# argonaut -> term1829 Nt=2 TF=2 maxTF=1 @{0 6003 7}
# argument -> term3866 Nt=7 TF=8 maxTF=2 @{0 6008 1}
# arhiva -> term7716 Nt=2 TF=2 maxTF=1 @{0 6016 0}
# arhivu -> term8173 Nt=2 TF=2 maxTF=1 @{0 6021 6}
# aristotl -> term6439 Nt=1 TF=1 maxTF=1 @{0 6026 0}
# arithmet -> term4663 Nt=2 TF=2 maxTF=1 @{0 6029 2}
# arizona -> term6338 Nt=1 TF=1 maxTF=1 @{0 6034 6}
# arl -> term4205 Nt=1 TF=1 maxTF=1 @{0 6038 0}
# armadillo -> term5522 Nt=1 TF=1 maxTF=1 @{0 6041 0}
# armenf -> term7814 Nt=1 TF=1 maxTF=1 @{0 6044 2}
# armstrong -> term6351 Nt=1 TF=1 maxTF=1 @{0 6047 4}
# arno -> term4746 Nt=2 TF=2 maxTF=1 @{0 6050 6}
# aromadeg -> term3194 Nt=1 TF=1 maxTF=1 @{0 6056 6}
# aromat -> term3192 Nt=1 TF=1 maxTF=1 @{0 6059 4}
# arrai -> term990 Nt=3 TF=3 maxTF=1 @{0 6062 2}
# arrang -> term5976 Nt=2 TF=2 maxTF=1 @{0 6069 2}
# arrayexpress -> term2967 Nt=1 TF=1 maxTF=1 @{0 6075 0}
# art -> term155 Nt=44 TF=44 maxTF=1 @{0 6077 6}
# artdoc -> term8344 Nt=1 TF=1 maxTF=1 @{0 6153 2}
# artem -> term4107 Nt=1 TF=1 maxTF=1 @{0 6156 4}
# arteri -> term4599 Nt=1 TF=1 maxTF=1 @{0 6159 4}
# articl -> term362 Nt=28 TF=29 maxTF=2 @{0 6162 4}
# artifact -> term7893 Nt=2 TF=2 maxTF=1 @{0 6219 3}
# artifici -> term2887 Nt=10 TF=10 maxTF=1 @{0 6224 3}
# artist -> term5072 Nt=9 TF=9 maxTF=1 @{0 6249 1}
# artpool -> term6967 Nt=1 TF=1 maxTF=1 @{0 6266 3}
# aruba -> term6598 Nt=1 TF=1 maxTF=1 @{0 6269 5}
# arvix -> term7065 Nt=1 TF=1 maxTF=1 @{0 6272 7}
# arxiv -> term6920 Nt=107 TF=108 maxTF=2 @{0 6276 1}
# ascertain -> term2049 Nt=1 TF=1 maxTF=1 @{0 6351 2}
# ascgen -> term4279 Nt=1 TF=1 maxTF=1 @{0 6354 0}
# ascii -> term3372 Nt=11 TF=16 maxTF=6 @{0 6357 0}
# asciiart -> term3437 Nt=1 TF=1 maxTF=1 @{0 6375 7}
# asciiflow -> term4328 Nt=1 TF=1 maxTF=1 @{0 6378 7}
# asciimeo -> term3235 Nt=1 TF=1 maxTF=1 @{0 6381 7}
# asciit -> term3344 Nt=1 TF=1 maxTF=1 @{0 6384 5}
# ascla -> term6465 Nt=1 TF=1 maxTF=1 @{0 6387 5}
# ashra -> term6195 Nt=1 TF=1 maxTF=1 @{0 6390 7}
# asia -> term835 Nt=3 TF=3 maxTF=1 @{0 6394 1}
# asian -> term2956 Nt=2 TF=2 maxTF=1 @{0 6402 1}
# asifa -> term6998 Nt=1 TF=1 maxTF=1 @{0 6407 7}
# ask -> term1494 Nt=6 TF=6 maxTF=1 @{0 6411 1}
# aspect -> term2908 Nt=7 TF=7 maxTF=1 @{0 6425 5}
# aspekt -> term4765 Nt=1 TF=1 maxTF=1 @{0 6441 1}
# assai -> term3135 Nt=1 TF=1 maxTF=1 @{0 6444 1}
# assembl -> term1929 Nt=2 TF=2 maxTF=1 @{0 6446 7}
# assess -> term495 Nt=22 TF=22 maxTF=1 @{0 6452 7}
# asset -> term5285 Nt=2 TF=3 maxTF=2 @{0 6495 7}
# assign -> term5074 Nt=2 TF=2 maxTF=1 @{0 6502 2}
# assimp -> term5286 Nt=1 TF=1 maxTF=1 @{0 6507 6}
# assist -> term3196 Nt=11 TF=12 maxTF=2 @{0 6511 0}
# associ -> term203 Nt=52 TF=52 maxTF=1 @{0 6533 5}
# associati -> term5331 Nt=1 TF=1 maxTF=1 @{0 6613 5}
# assozi -> term4006 Nt=2 TF=2 maxTF=1 @{0 6616 7}
# asssrdb -> term2235 Nt=1 TF=1 maxTF=1 @{0 6621 7}
# assumpt -> term1800 Nt=1 TF=1 maxTF=1 @{0 6624 5}
# assyrian -> term1763 Nt=1 TF=1 maxTF=1 @{0 6627 1}
# astrocyt -> term2979 Nt=1 TF=1 maxTF=1 @{0 6629 5}
# astronom -> term8434 Nt=1 TF=1 maxTF=1 @{0 6632 3}
# astronomi -> term6581 Nt=3 TF=3 maxTF=1 @{0 6635 5}
# astrophys -> term6066 Nt=1 TF=1 maxTF=1 @{0 6644 1}
# atari -> term3826 Nt=1 TF=1 maxTF=1 @{0 6647 3}
# atc -> term2723 Nt=1 TF=1 maxTF=1 @{0 6650 3}
# ateli -> term5230 Nt=1 TF=1 maxTF=1 @{0 6653 1}
# atena -> term8301 Nt=1 TF=1 maxTF=1 @{0 6656 3}
# atext -> term3328 Nt=1 TF=1 maxTF=1 @{0 6659 5}
# athen -> term6391 Nt=7 TF=7 maxTF=1 @{0 6662 5}
# athena -> term2476 Nt=1 TF=1 maxTF=1 @{0 6674 3}
# athenaeum -> term8323 Nt=2 TF=2 maxTF=1 @{0 6677 1}
# atherosclerot -> term2822 Nt=1 TF=1 maxTF=1 @{0 6681 7}
# athisomirdb -> term1904 Nt=1 TF=1 maxTF=1 @{0 6684 5}
# athribonc -> term2063 Nt=1 TF=1 maxTF=1 @{0 6687 3}
# atla -> term957 Nt=6 TF=7 maxTF=2 @{0 6690 1}
# atlant -> term143 Nt=2 TF=2 maxTF=1 @{0 6704 4}
# atm23 -> term7930 Nt=1 TF=1 maxTF=1 @{0 6709 2}
# atmospher -> term6278 Nt=2 TF=2 maxTF=1 @{0 6712 4}
# atn -> term3924 Nt=1 TF=1 maxTF=1 @{0 6718 6}
# atom -> term6932 Nt=2 TF=2 maxTF=1 @{0 6721 6}
# atomiqu -> term7268 Nt=3 TF=3 maxTF=1 @{0 6727 4}
# atomist -> term2343 Nt=1 TF=1 maxTF=1 @{0 6734 2}
# att -> term6137 Nt=2 TF=2 maxTF=1 @{0 6737 0}
# attack -> term2344 Nt=2 TF=2 maxTF=1 @{0 6742 6}
# attend -> term2258 Nt=2 TF=2 maxTF=1 @{0 6748 4}
# attent -> term4348 Nt=5 TF=5 maxTF=1 @{0 6754 2}
# attitud -> term233 Nt=5 TF=5 maxTF=1 @{0 6765 2}
# attribut -> term4424 Nt=3 TF=3 maxTF=1 @{0 6775 4}
# attrit -> term1138 Nt=1 TF=1 maxTF=1 @{0 6782 6}
# au -> term3723 Nt=10 TF=10 maxTF=1 @{0 6785 2}
# auc -> term4722 Nt=1 TF=1 maxTF=1 @{0 6806 0}
# auch -> term4439 Nt=1 TF=1 maxTF=1 @{0 6809 0}
# auctor -> term4018 Nt=1 TF=1 maxTF=1 @{0 6812 0}
# auctoribu -> term7878 Nt=1 TF=1 maxTF=1 @{0 6815 0}
# audio -> term1498 Nt=19 TF=19 maxTF=1 @{0 6818 2}
# audioclip -> term4859 Nt=1 TF=1 maxTF=1 @{0 6859 0}
# audiovisu -> term6684 Nt=5 TF=5 maxTF=1 @{0 6862 0}
# audit -> term1792 Nt=5 TF=5 maxTF=1 @{0 6874 2}
# auf -> term4893 Nt=7 TF=7 maxTF=1 @{0 6886 2}
# aufbruch -> term7026 Nt=1 TF=1 maxTF=1 @{0 6903 6}
# aufgaben -> term7976 Nt=1 TF=1 maxTF=1 @{0 6907 0}
# aug -> term4664 Nt=1 TF=1 maxTF=1 @{0 6910 2}
# augli -> term4216 Nt=1 TF=1 maxTF=1 @{0 6913 2}
# augment -> term2749 Nt=12 TF=12 maxTF=1 @{0 6916 2}
# august -> term5351 Nt=1 TF=1 maxTF=1 @{0 6943 0}
# aurora -> term1446 Nt=1 TF=1 maxTF=1 @{0 6946 2}
# ausgab -> term4585 Nt=2 TF=2 maxTF=1 @{0 6948 6}
# ausgetreten -> term4304 Nt=2 TF=2 maxTF=1 @{0 6954 4}
# ausschreibung -> term3211 Nt=2 TF=2 maxTF=1 @{0 6959 0}
# austgat -> term3784 Nt=1 TF=1 maxTF=1 @{0 6964 2}
# austin -> term6414 Nt=1 TF=1 maxTF=1 @{0 6967 2}
# australia -> term3607 Nt=7 TF=7 maxTF=1 @{0 6970 4}
# australian -> term2269 Nt=4 TF=4 maxTF=1 @{0 6987 4}
# austrian -> term2586 Nt=3 TF=3 maxTF=1 @{0 6998 4}
# aut -> term5175 Nt=2 TF=2 maxTF=1 @{0 7007 2}
# author -> term366 Nt=21 TF=21 maxTF=1 @{0 7012 4}
# authoratori -> term1718 Nt=1 TF=1 maxTF=1 @{0 7055 0}
# authorship -> term4191 Nt=2 TF=2 maxTF=1 @{0 7057 4}
# autism -> term5555 Nt=1 TF=1 maxTF=1 @{0 7063 0}
# auto -> term2166 Nt=3 TF=3 maxTF=1 @{0 7066 2}
# autoconf -> term7517 Nt=2 TF=2 maxTF=1 @{0 7074 6}
# autoimmun -> term2881 Nt=1 TF=1 maxTF=1 @{0 7079 0}
# autoinhibit -> term1870 Nt=1 TF=2 maxTF=2 @{0 7081 6}
# autoinhibitori -> term1867 Nt=1 TF=1 maxTF=1 @{0 7084 5}
# autom -> term587 Nt=67 TF=67 maxTF=1 @{0 7087 3}
# automat -> term1131 Nt=70 TF=70 maxTF=1 @{0 7176 5}
# automatiqu -> term8162 Nt=1 TF=1 maxTF=1 @{0 7276 7}
# automatischen -> term4005 Nt=2 TF=2 maxTF=1 @{0 7280 1}
# automobil -> term7792 Nt=1 TF=1 maxTF=1 @{0 7285 1}
# autonom -> term1818 Nt=5 TF=5 maxTF=1 @{0 7288 3}
# autopatch -> term1612 Nt=1 TF=1 maxTF=1 @{0 7298 1}
# autophagi -> term1888 Nt=1 TF=1 maxTF=1 @{0 7300 5}
# autophagy3d -> term1887 Nt=1 TF=1 maxTF=1 @{0 7303 3}
# autor -> term4707 Nt=1 TF=1 maxTF=1 @{0 7306 1}
# autoregress -> term8457 Nt=1 TF=1 maxTF=1 @{0 7309 1}
# autoren -> term4705 Nt=1 TF=1 maxTF=1 @{0 7312 3}
# autorenhomepag -> term7164 Nt=1 TF=1 maxTF=1 @{0 7315 3}
# autorit -> term4425 Nt=1 TF=1 maxTF=1 @{0 7318 5}
# auvert -> term7513 Nt=1 TF=1 maxTF=1 @{0 7321 5}
# aux -> term7254 Nt=9 TF=9 maxTF=1 @{0 7324 7}
# auxiliari -> term5504 Nt=1 TF=1 maxTF=1 @{0 7337 1}
# avail -> term2334 Nt=6 TF=6 maxTF=1 @{0 7340 3}
# avanju -> term8415 Nt=1 TF=1 maxTF=1 @{0 7350 5}
# avatar -> term3713 Nt=1 TF=1 maxTF=1 @{0 7353 7}
# avenu -> term8338 Nt=1 TF=1 maxTF=1 @{0 7356 7}
# averag -> term157 Nt=2 TF=2 maxTF=1 @{0 7360 1}
# averbi -> term3645 Nt=1 TF=1 maxTF=1 @{0 7364 5}
# avhrr -> term904 Nt=1 TF=1 maxTF=1 @{0 7367 5}
# avi -> term7450 Nt=1 TF=1 maxTF=1 @{0 7369 7}
# aviat -> term1736 Nt=1 TF=1 maxTF=1 @{0 7373 1}
# avidemux -> term7150 Nt=1 TF=1 maxTF=1 @{0 7375 5}
# avoid -> term2241 Nt=2 TF=2 maxTF=1 @{0 7378 7}
# avon -> term5773 Nt=1 TF=1 maxTF=1 @{0 7384 7}
# aw -> term1445 Nt=3 TF=7 maxTF=5 @{0 7388 1}
# awar -> term1843 Nt=10 TF=10 maxTF=1 @{0 7396 7}
# award -> term5428 Nt=9 TF=9 maxTF=1 @{0 7419 5}
# awesom -> term3945 Nt=1 TF=1 maxTF=1 @{0 7436 5}
# awk -> term3284 Nt=1 TF=1 maxTF=1 @{0 7439 5}
# awni -> term4360 Nt=1 TF=1 maxTF=1 @{0 7442 5}
# ax -> term3461 Nt=2 TF=2 maxTF=1 @{0 7445 5}
# azur -> term693 Nt=1 TF=1 maxTF=1 @{0 7450 3}
# ba -> term6141 Nt=2 TF=2 maxTF=1 @{0 7452 5}
# baafila -> term6776 Nt=1 TF=1 maxTF=1 @{0 7458 3}
# babel -> term5398 Nt=4 TF=4 maxTF=1 @{0 7461 5}
# babylonia -> term1253 Nt=1 TF=1 maxTF=1 @{0 7471 5}
# babylonian -> term1761 Nt=1 TF=1 maxTF=1 @{0 7474 1}
# bacillu -> term2357 Nt=2 TF=2 maxTF=1 @{0 7476 5}
# bacillusregnet -> term3014 Nt=1 TF=1 maxTF=1 @{0 7481 7}
# back -> term6090 Nt=4 TF=4 maxTF=1 @{0 7484 5}
# backend -> term2439 Nt=2 TF=2 maxTF=1 @{0 7493 3}
# background -> term3684 Nt=12 TF=12 maxTF=1 @{0 7499 3}
# backup -> term101 Nt=8 TF=8 maxTF=1 @{0 7518 7}
# backward -> term4485 Nt=2 TF=2 maxTF=1 @{0 7536 3}
# bacsoft -> term8077 Nt=1 TF=1 maxTF=1 @{0 7542 3}
# bacteri -> term1881 Nt=5 TF=5 maxTF=1 @{0 7545 5}
# bacteria -> term2161 Nt=3 TF=3 maxTF=1 @{0 7558 1}
# bad -> term487 Nt=1 TF=1 maxTF=1 @{0 7566 3}
# baden -> term7524 Nt=1 TF=1 maxTF=1 @{0 7568 3}
# badg -> term6262 Nt=1 TF=1 maxTF=1 @{0 7571 5}
# baen -> term5176 Nt=5 TF=5 maxTF=1 @{0 7574 7}
# bag -> term4578 Nt=5 TF=5 maxTF=1 @{0 7583 3}
# bahr -> term5443 Nt=1 TF=1 maxTF=1 @{0 7591 7}
# baker -> term5066 Nt=1 TF=1 maxTF=1 @{0 7595 1}
# balanc -> term3429 Nt=3 TF=4 maxTF=2 @{0 7598 1}
# ballard -> term7399 Nt=1 TF=1 maxTF=1 @{0 7607 0}
# bamboo -> term3356 Nt=1 TF=1 maxTF=1 @{0 7610 2}
# ban -> term5366 Nt=1 TF=1 maxTF=1 @{0 7613 2}
# bandoli -> term1503 Nt=1 TF=1 maxTF=1 @{0 7616 4}
# banfield -> term6869 Nt=1 TF=1 maxTF=1 @{0 7619 0}
# bangkok -> term6593 Nt=1 TF=1 maxTF=1 @{0 7622 2}
# bank -> term5378 Nt=5 TF=5 maxTF=1 @{0 7625 4}
# banner -> term4572 Nt=1 TF=1 maxTF=1 @{0 7638 0}
# bar -> term3620 Nt=3 TF=3 maxTF=1 @{0 7641 0}
# barbera -> term3677 Nt=1 TF=1 maxTF=1 @{0 7647 4}
# barcelona -> term6505 Nt=1 TF=1 maxTF=1 @{0 7650 4}
# barclaybarrio -> term7554 Nt=1 TF=1 maxTF=1 @{0 7653 6}
# barcod -> term131 Nt=4 TF=4 maxTF=1 @{0 7657 0}
# barcodepedia -> term129 Nt=2 TF=2 maxTF=1 @{0 7666 4}
# bardic -> term1751 Nt=1 TF=1 maxTF=1 @{0 7670 2}
# bare -> term7307 Nt=1 TF=1 maxTF=1 @{0 7672 6}
# bari -> term448 Nt=1 TF=1 maxTF=1 @{0 7676 0}
# barlei -> term2770 Nt=1 TF=1 maxTF=1 @{0 7678 0}
# barleyvardb -> term2769 Nt=1 TF=1 maxTF=1 @{0 7680 6}
# baron -> term246 Nt=1 TF=1 maxTF=1 @{0 7683 4}
# barrier -> term5819 Nt=3 TF=3 maxTF=1 @{0 7685 2}
# barrierefrei -> term3578 Nt=1 TF=1 maxTF=1 @{0 7694 2}
# bart -> term4458 Nt=1 TF=1 maxTF=1 @{0 7697 2}
# bartolomeo -> term5595 Nt=1 TF=1 maxTF=1 @{0 7700 2}
# base -> term702 Nt=316 TF=320 maxTF=2 @{0 7703 4}
# basel -> term7484 Nt=1 TF=1 maxTF=1 @{0 8008 4}
# baselin -> term4309 Nt=2 TF=2 maxTF=1 @{0 8011 6}
# basement -> term5302 Nt=1 TF=1 maxTF=1 @{0 8016 6}
# basen -> term785 Nt=1 TF=1 maxTF=1 @{0 8020 0}
# basex -> term280 Nt=2 TF=2 maxTF=1 @{0 8022 2}
# bash -> term3821 Nt=2 TF=2 maxTF=1 @{0 8026 0}
# basi -> term4845 Nt=4 TF=4 maxTF=1 @{0 8031 2}
# basic -> term127 Nt=12 TF=12 maxTF=1 @{0 8042 2}
# basicintro -> term1663 Nt=1 TF=1 maxTF=1 @{0 8067 4}
# basiert -> term4843 Nt=1 TF=1 maxTF=1 @{0 8070 0}
# basket -> term2611 Nt=1 TF=1 maxTF=1 @{0 8073 0}
# basqu -> term4179 Nt=2 TF=3 maxTF=2 @{0 8075 6}
# bass -> term5938 Nt=2 TF=2 maxTF=1 @{0 8082 1}
# bassin -> term8037 Nt=1 TF=1 maxTF=1 @{0 8088 1}
# bat -> term4816 Nt=1 TF=1 maxTF=1 @{0 8091 3}
# batch -> term3923 Nt=2 TF=2 maxTF=1 @{0 8094 3}
# batna -> term7433 Nt=1 TF=1 maxTF=1 @{0 8100 5}
# battel -> term1477 Nt=1 TF=1 maxTF=1 @{0 8103 7}
# battl -> term3541 Nt=2 TF=2 maxTF=1 @{0 8106 3}
# baumannii -> term1937 Nt=1 TF=1 maxTF=1 @{0 8112 3}
# bavaria -> term3142 Nt=1 TF=1 maxTF=1 @{0 8115 1}
# bavarian -> term6172 Nt=3 TF=3 maxTF=1 @{0 8117 7}
# bay -> term4775 Nt=5 TF=5 maxTF=1 @{0 8125 7}
# bayerischen -> term8072 Nt=1 TF=1 maxTF=1 @{0 8135 3}
# bayern -> term7478 Nt=2 TF=2 maxTF=1 @{0 8138 5}
# bayesian -> term3880 Nt=5 TF=5 maxTF=1 @{0 8144 1}
# baylor -> term1583 Nt=1 TF=1 maxTF=1 @{0 8157 3}
# bbc -> term5222 Nt=8 TF=8 maxTF=1 @{0 8159 7}
# bc8 -> term2699 Nt=1 TF=1 maxTF=1 @{0 8177 5}
# bcedb -> term2042 Nt=1 TF=1 maxTF=1 @{0 8180 3}
# bcl -> term3121 Nt=1 TF=1 maxTF=1 @{0 8183 1}
# bcl2db -> term3119 Nt=1 TF=1 maxTF=1 @{0 8185 7}
# bd -> term1039 Nt=1 TF=1 maxTF=1 @{0 8188 5}
# be -> term850 Nt=2 TF=2 maxTF=1 @{0 8191 1}
# beacon -> term5170 Nt=2 TF=2 maxTF=1 @{0 8196 1}
# beam -> term7419 Nt=1 TF=1 maxTF=1 @{0 8201 7}
# beamform -> term8429 Nt=1 TF=1 maxTF=1 @{0 8205 1}
# bean -> term5808 Nt=1 TF=1 maxTF=1 @{0 8208 3}
# beanlib -> term5807 Nt=1 TF=1 maxTF=1 @{0 8211 5}
# beast -> term8056 Nt=1 TF=1 maxTF=1 @{0 8214 7}
# beauti -> term4155 Nt=3 TF=3 maxTF=1 @{0 8218 1}
# beautifi -> term3333 Nt=1 TF=1 maxTF=1 @{0 8224 7}
# becken -> term8471 Nt=1 TF=1 maxTF=1 @{0 8227 7}
# bee -> term6236 Nt=3 TF=3 maxTF=1 @{0 8231 1}
# beeindruckend -> term4242 Nt=1 TF=1 maxTF=1 @{0 8239 5}
# beeld -> term7496 Nt=1 TF=1 maxTF=1 @{0 8242 5}
# befremden -> term3475 Nt=1 TF=1 maxTF=1 @{0 8245 7}
# begin -> term1853 Nt=3 TF=3 maxTF=1 @{0 8248 7}
# beginn -> term182 Nt=1 TF=1 maxTF=1 @{0 8257 3}
# behauptet -> term4438 Nt=1 TF=1 maxTF=1 @{0 8258 7}
# behavior -> term4702 Nt=11 TF=11 maxTF=1 @{0 8261 7}
# behaviour -> term6857 Nt=1 TF=1 maxTF=1 @{0 8284 1}
# behren -> term4217 Nt=1 TF=1 maxTF=1 @{0 8287 3}
# bei -> term3534 Nt=4 TF=4 maxTF=1 @{0 8290 3}
# beihilf -> term7660 Nt=1 TF=1 maxTF=1 @{0 8301 1}
# beij -> term3910 Nt=1 TF=1 maxTF=1 @{0 8304 3}
# beitou -> term6285 Nt=1 TF=2 maxTF=2 @{0 8307 3}
# beitrag -> term6753 Nt=1 TF=1 maxTF=1 @{0 8310 6}
# beitragen -> term6686 Nt=1 TF=1 maxTF=1 @{0 8314 0}
# bekr -> term7321 Nt=1 TF=1 maxTF=1 @{0 8317 2}
# bekri -> term7303 Nt=1 TF=1 maxTF=1 @{0 8320 4}
# belang -> term8258 Nt=1 TF=1 maxTF=1 @{0 8323 6}
# belaru -> term6562 Nt=1 TF=1 maxTF=1 @{0 8327 0}
# belarusian -> term4187 Nt=1 TF=2 maxTF=2 @{0 8330 2}
# belbedj -> term7016 Nt=1 TF=1 maxTF=1 @{0 8333 3}
# bele -> term8121 Nt=1 TF=1 maxTF=1 @{0 8336 5}
# belfast -> term6272 Nt=1 TF=1 maxTF=1 @{0 8339 7}
# belkaid -> term7322 Nt=1 TF=1 maxTF=1 @{0 8343 1}
# belong -> term242 Nt=2 TF=2 maxTF=1 @{0 8346 3}
# bemerkungen -> term4949 Nt=1 TF=1 maxTF=1 @{0 8351 3}
# benchmark -> term376 Nt=13 TF=13 maxTF=1 @{0 8354 3}
# benderski -> term4273 Nt=1 TF=1 maxTF=1 @{0 8380 1}
# bengali -> term4180 Nt=1 TF=2 maxTF=2 @{0 8383 1}
# benstopford -> term343 Nt=1 TF=1 maxTF=1 @{0 8386 2}
# bento -> term1096 Nt=1 TF=2 maxTF=2 @{0 8388 0}
# benutz -> term7043 Nt=1 TF=1 maxTF=1 @{0 8390 5}
# benzothiazol -> term1985 Nt=1 TF=1 maxTF=1 @{0 8393 7}
# ber -> term3338 Nt=4 TF=4 maxTF=1 @{0 8396 5}
# berea -> term7434 Nt=1 TF=1 maxTF=1 @{0 8407 1}
# bergewaltig -> term4645 Nt=1 TF=1 maxTF=1 @{0 8410 3}
# berkelei -> term77 Nt=9 TF=9 maxTF=1 @{0 8413 3}
# berlegungen -> term8320 Nt=2 TF=2 maxTF=1 @{0 8431 1}
# berlieferung -> term7967 Nt=2 TF=2 maxTF=1 @{0 8434 5}
# berlin -> term227 Nt=7 TF=7 maxTF=1 @{0 8440 1}
# berlioz -> term4550 Nt=1 TF=1 maxTF=1 @{0 8455 5}
# bern -> term5131 Nt=1 TF=1 maxTF=1 @{0 8458 5}
# bernahm -> term7797 Nt=1 TF=1 maxTF=1 @{0 8461 5}
# berri -> term7396 Nt=1 TF=1 maxTF=1 @{0 8464 7}
# bersicht -> term4159 Nt=1 TF=1 maxTF=1 @{0 8468 1}
# bert -> term2717 Nt=8 TF=8 maxTF=1 @{0 8471 1}
# best -> term594 Nt=26 TF=26 maxTF=1 @{0 8486 3}
# bestand -> term7340 Nt=1 TF=1 maxTF=1 @{0 8537 1}
# bester -> term4500 Nt=1 TF=1 maxTF=1 @{0 8540 3}
# bestimmen -> term3661 Nt=1 TF=1 maxTF=1 @{0 8543 3}
# bestsel -> term4443 Nt=1 TF=1 maxTF=1 @{0 8546 3}
# besucht -> term4647 Nt=1 TF=1 maxTF=1 @{0 8549 3}
# bet -> term3544 Nt=1 TF=1 maxTF=1 @{0 8552 3}
# beta -> term356 Nt=3 TF=4 maxTF=2 @{0 8555 3}
# betjeman -> term7438 Nt=1 TF=1 maxTF=1 @{0 8562 4}
# bew -> term7548 Nt=1 TF=1 maxTF=1 @{0 8565 6}
# bewegung -> term5043 Nt=1 TF=1 maxTF=1 @{0 8569 0}
# bewegungen -> term7961 Nt=1 TF=1 maxTF=1 @{0 8572 0}
# bewertung -> term7794 Nt=1 TF=1 maxTF=1 @{0 8575 2}
# beziehungen -> term4767 Nt=2 TF=2 maxTF=1 @{0 8578 4}
# bfi -> term7073 Nt=1 TF=2 maxTF=2 @{0 8583 4}
# bh3 -> term3118 Nt=1 TF=1 maxTF=1 @{0 8586 7}
# bhaderwah -> term3083 Nt=1 TF=1 maxTF=1 @{0 8589 5}
# bi -> term4588 Nt=3 TF=3 maxTF=1 @{0 8592 3}
# bia -> term3187 Nt=1 TF=1 maxTF=1 @{0 8600 3}
# bias -> term2693 Nt=2 TF=2 maxTF=1 @{0 8603 1}
# bibfram -> term6654 Nt=1 TF=1 maxTF=1 @{0 8609 1}
# bibl -> term3805 Nt=1 TF=2 maxTF=2 @{0 8612 3}
# biblatex -> term4258 Nt=2 TF=2 maxTF=1 @{0 8615 4}
# biblic -> term4682 Nt=2 TF=2 maxTF=1 @{0 8621 6}
# biblio -> term5387 Nt=7 TF=7 maxTF=1 @{0 8626 0}
# bibliograph -> term513 Nt=31 TF=31 maxTF=1 @{0 8638 2}
# bibliographi -> term159 Nt=22 TF=22 maxTF=1 @{0 8689 4}
# bibliographien -> term6257 Nt=1 TF=1 maxTF=1 @{0 8729 4}
# bibliographieren -> term6166 Nt=1 TF=1 maxTF=1 @{0 8732 6}
# bibliometr -> term1950 Nt=13 TF=13 maxTF=1 @{0 8736 0}
# bibliot -> term6143 Nt=3 TF=3 maxTF=1 @{0 8757 4}
# biblioteca -> term6635 Nt=3 TF=5 maxTF=2 @{0 8764 6}
# bibliotech -> term6708 Nt=1 TF=2 maxTF=2 @{0 8771 4}
# bibliotecil -> term6766 Nt=1 TF=1 maxTF=1 @{0 8774 7}
# bibliotek -> term6915 Nt=1 TF=1 maxTF=1 @{0 8778 1}
# biblioteket -> term5810 Nt=1 TF=1 maxTF=1 @{0 8781 3}
# biblioteki -> term6883 Nt=1 TF=1 maxTF=1 @{0 8784 5}
# bibliotekpolitikken -> term6362 Nt=1 TF=1 maxTF=1 @{0 8787 7}
# biblioteksterm -> term5867 Nt=1 TF=1 maxTF=1 @{0 8791 1}
# biblioth -> term6701 Nt=5 TF=5 maxTF=1 @{0 8794 3}
# bibliotheca -> term7831 Nt=1 TF=1 maxTF=1 @{0 8806 1}
# bibliotheek -> term500 Nt=1 TF=1 maxTF=1 @{0 8809 3}
# bibliothek -> term6179 Nt=5 TF=6 maxTF=2 @{0 8811 3}
# bibliothekarin -> term5438 Nt=1 TF=1 maxTF=1 @{0 8823 2}
# bibliothekarisch -> term6162 Nt=1 TF=1 maxTF=1 @{0 8826 4}
# bibliotheken -> term4141 Nt=13 TF=14 maxTF=2 @{0 8829 6}
# bibliothekskatalog -> term5744 Nt=1 TF=1 maxTF=1 @{0 8858 3}
# bibliothequ -> term6085 Nt=1 TF=1 maxTF=1 @{0 8861 5}
# bibsonomi -> term6245 Nt=10 TF=10 maxTF=1 @{0 8864 7}
# bibtex -> term580 Nt=10 TF=10 maxTF=1 @{0 8882 3}
# bidirect -> term2857 Nt=2 TF=2 maxTF=1 @{0 8900 5}
# bidok -> term5709 Nt=1 TF=1 maxTF=1 @{0 8906 1}
# bielefeld -> term3752 Nt=2 TF=3 maxTF=2 @{0 8909 3}
# big -> term344 Nt=27 TF=28 maxTF=2 @{0 8914 6}
# bigg -> term1607 Nt=1 TF=1 maxTF=1 @{0 8963 3}
# bignum -> term5749 Nt=1 TF=1 maxTF=1 @{0 8965 7}
# bike -> term3492 Nt=2 TF=2 maxTF=1 @{0 8969 1}
# bilanz -> term7777 Nt=1 TF=1 maxTF=1 @{0 8975 1}
# bild -> term3339 Nt=9 TF=12 maxTF=3 @{0 8978 3}
# bildagentur -> term3637 Nt=1 TF=1 maxTF=1 @{0 8997 2}
# bilder -> term3316 Nt=1 TF=1 maxTF=1 @{0 9000 2}
# bildtext -> term4953 Nt=1 TF=1 maxTF=1 @{0 9003 2}
# bildung -> term8112 Nt=1 TF=1 maxTF=1 @{0 9006 2}
# bildungsmedien -> term8114 Nt=1 TF=1 maxTF=1 @{0 9009 4}
# bildverarbeitung -> term4350 Nt=1 TF=1 maxTF=1 @{0 9012 6}
# ...
# weak -> term2811 Nt=2 TF=2 maxTF=1 @{0 74876 7}
# weather -> term5407 Nt=1 TF=1 maxTF=1 @{0 74882 3}
# weaver -> term2179 Nt=1 TF=1 maxTF=1 @{0 74885 5}
# web -> term213 Nt=306 TF=320 maxTF=2 @{0 74888 3}
# web2 -> term5733 Nt=1 TF=1 maxTF=1 @{0 75193 1}
# webaim -> term4372 Nt=1 TF=1 maxTF=1 @{0 75196 3}
# webarchivierung -> term7673 Nt=1 TF=1 maxTF=1 @{0 75199 3}
# webcom -> term8032 Nt=1 TF=1 maxTF=1 @{0 75202 5}
# webdesign -> term3580 Nt=2 TF=2 maxTF=1 @{0 75205 7}
# webex -> term1531 Nt=2 TF=2 maxTF=1 @{0 75210 3}
# webhom -> term5766 Nt=1 TF=1 maxTF=1 @{0 75213 5}
# webi -> term7808 Nt=3 TF=3 maxTF=1 @{0 75216 7}
# webinar -> term5662 Nt=1 TF=1 maxTF=1 @{0 75223 7}
# weblog -> term1649 Nt=16 TF=16 maxTF=1 @{0 75227 1}
# weblogg -> term4858 Nt=1 TF=1 maxTF=1 @{0 75257 7}
# weblogstefan -> term3863 Nt=1 TF=1 maxTF=1 @{0 75260 7}
# webmast -> term5986 Nt=1 TF=1 maxTF=1 @{0 75263 7}
# weboffic -> term1532 Nt=2 TF=2 maxTF=1 @{0 75267 1}
# webplatform -> term3430 Nt=1 TF=1 maxTF=1 @{0 75270 3}
# webreport -> term7778 Nt=1 TF=1 maxTF=1 @{0 75273 3}
# webscrap -> term4365 Nt=2 TF=2 maxTF=1 @{0 75276 5}
# webservic -> term3739 Nt=1 TF=1 maxTF=1 @{0 75281 1}
# websit -> term1496 Nt=18 TF=18 maxTF=1 @{0 75284 1}
# websom -> term3857 Nt=1 TF=1 maxTF=1 @{0 75317 1}
# webspac -> term7721 Nt=1 TF=1 maxTF=1 @{0 75320 1}
# webteam -> term7088 Nt=4 TF=4 maxTF=1 @{0 75323 3}
# wechat -> term6336 Nt=1 TF=1 maxTF=1 @{0 75332 3}
# wed -> term4185 Nt=1 TF=1 maxTF=1 @{0 75335 5}
# week -> term1168 Nt=5 TF=5 maxTF=1 @{0 75338 5}
# weekend -> term4522 Nt=1 TF=1 maxTF=1 @{0 75352 3}
# weekli -> term7654 Nt=2 TF=2 maxTF=1 @{0 75355 3}
# weight -> term4329 Nt=7 TF=7 maxTF=1 @{0 75361 1}
# weiter -> term4589 Nt=1 TF=1 maxTF=1 @{0 75375 7}
# weka -> term3495 Nt=1 TF=2 maxTF=2 @{0 75378 7}
# wel -> term7857 Nt=1 TF=1 maxTF=1 @{0 75382 0}
# welcher -> term3318 Nt=1 TF=1 maxTF=1 @{0 75385 2}
# welcom -> term120 Nt=20 TF=20 maxTF=1 @{0 75388 2}
# well -> term3043 Nt=1 TF=1 maxTF=1 @{0 75425 2}
# wellb -> term5965 Nt=1 TF=1 maxTF=1 @{0 75428 0}
# wellcom -> term5877 Nt=1 TF=1 maxTF=1 @{0 75431 2}
# welsh -> term4730 Nt=1 TF=1 maxTF=1 @{0 75434 4}
# welt -> term4039 Nt=5 TF=5 maxTF=1 @{0 75437 4}
# welten -> term4478 Nt=1 TF=1 maxTF=1 @{0 75450 0}
# weltweit -> term6176 Nt=1 TF=1 maxTF=1 @{0 75453 0}
# wenhaus -> term4026 Nt=1 TF=1 maxTF=1 @{0 75456 2}
# wens -> term4646 Nt=1 TF=1 maxTF=1 @{0 75459 2}
# went -> term1205 Nt=2 TF=2 maxTF=1 @{0 75462 2}
# werkgenesen -> term8241 Nt=1 TF=1 maxTF=1 @{0 75468 0}
# werkzeug -> term4452 Nt=1 TF=1 maxTF=1 @{0 75471 2}
# werner -> term7482 Nt=1 TF=1 maxTF=1 @{0 75474 2}
# wess -> term3771 Nt=1 TF=1 maxTF=1 @{0 75477 4}
# west -> term6795 Nt=3 TF=3 maxTF=1 @{0 75480 4}
# western -> term3772 Nt=1 TF=1 maxTF=1 @{0 75488 2}
# westminst -> term7242 Nt=2 TF=2 maxTF=1 @{0 75491 2}
# wetland -> term8389 Nt=1 TF=1 maxTF=1 @{0 75496 4}
# wfirst -> term7678 Nt=1 TF=1 maxTF=1 @{0 75499 6}
# wget -> term6925 Nt=1 TF=1 maxTF=1 @{0 75503 0}
# wgswiki -> term384 Nt=1 TF=1 maxTF=1 @{0 75506 2}
# what -> term7071 Nt=1 TF=1 maxTF=1 @{0 75508 2}
# whatilearnttudai -> term4283 Nt=1 TF=1 maxTF=1 @{0 75511 4}
# whatizit -> term5108 Nt=1 TF=1 maxTF=1 @{0 75514 4}
# wheat -> term2129 Nt=2 TF=2 maxTF=1 @{0 75517 4}
# wheel -> term6803 Nt=2 TF=2 maxTF=1 @{0 75522 4}
# wheeler -> term5558 Nt=1 TF=1 maxTF=1 @{0 75528 2}
# whistl -> term7095 Nt=1 TF=1 maxTF=1 @{0 75531 4}
# white -> term2803 Nt=3 TF=3 maxTF=1 @{0 75534 6}
# whitman -> term7277 Nt=1 TF=1 maxTF=1 @{0 75543 0}
# who -> term6229 Nt=2 TF=2 maxTF=1 @{0 75546 2}
# whole -> term1798 Nt=4 TF=4 maxTF=1 @{0 75552 4}
# wholecellsimdb -> term1797 Nt=1 TF=1 maxTF=1 @{0 75563 2}
# wi -> term6322 Nt=1 TF=1 maxTF=1 @{0 75565 6}
# wick -> term7374 Nt=1 TF=1 maxTF=1 @{0 75569 0}
# wide -> term1262 Nt=14 TF=14 maxTF=1 @{0 75572 2}
# widen -> term6629 Nt=1 TF=1 maxTF=1 @{0 75602 2}
# wider -> term4440 Nt=1 TF=1 maxTF=1 @{0 75605 4}
# widespread -> term6856 Nt=1 TF=1 maxTF=1 @{0 75608 4}
# widget -> term5888 Nt=1 TF=1 maxTF=1 @{0 75611 6}
# wie -> term3703 Nt=4 TF=4 maxTF=1 @{0 75615 0}
# wielkopolska -> term5984 Nt=2 TF=2 maxTF=1 @{0 75626 2}
# wiki -> term425 Nt=14 TF=14 maxTF=1 @{0 75631 0}
# wikibas -> term6396 Nt=1 TF=1 maxTF=1 @{0 75661 4}
# wikidata -> term2088 Nt=4 TF=4 maxTF=1 @{0 75664 6}
# wikidbas -> term424 Nt=1 TF=1 maxTF=1 @{0 75673 4}
# wikify -> term4368 Nt=1 TF=1 maxTF=1 @{0 75675 4}
# wikigenom -> term2089 Nt=1 TF=1 maxTF=1 @{0 75678 4}
# wikihom -> term3979 Nt=1 TF=1 maxTF=1 @{0 75681 2}
# wikileak -> term5184 Nt=6 TF=7 maxTF=2 @{0 75684 2}
# wikimedia -> term1724 Nt=3 TF=3 maxTF=1 @{0 75696 3}
# wikipedia -> term308 Nt=31 TF=33 maxTF=2 @{0 75704 5}
# wikiwiki -> term7625 Nt=1 TF=1 maxTF=1 @{0 75761 3}
# wild -> term4592 Nt=1 TF=1 maxTF=1 @{0 75764 5}
# wildlif -> term2888 Nt=1 TF=1 maxTF=1 @{0 75767 5}
# wildml -> term4049 Nt=1 TF=1 maxTF=1 @{0 75770 3}
# wilei -> term4938 Nt=14 TF=14 maxTF=1 @{0 75773 3}
# will -> term5243 Nt=6 TF=7 maxTF=2 @{0 75794 5}
# willa -> term7204 Nt=1 TF=1 maxTF=1 @{0 75809 2}
# william -> term316 Nt=6 TF=6 maxTF=1 @{0 75812 4}
# willkommen -> term3535 Nt=1 TF=1 maxTF=1 @{0 75825 6}
# wilson -> term7442 Nt=1 TF=1 maxTF=1 @{0 75828 6}
# wiltshir -> term5774 Nt=1 TF=1 maxTF=1 @{0 75832 0}
# wima -> term7483 Nt=1 TF=1 maxTF=1 @{0 75835 2}
# win -> term5427 Nt=2 TF=2 maxTF=1 @{0 75838 4}
# wind -> term8335 Nt=1 TF=1 maxTF=1 @{0 75844 4}
# windev -> term7124 Nt=1 TF=1 maxTF=1 @{0 75847 6}
# window -> term694 Nt=14 TF=14 maxTF=1 @{0 75851 0}
# wine -> term2570 Nt=1 TF=1 maxTF=1 @{0 75880 4}
# winesi -> term2569 Nt=1 TF=1 maxTF=1 @{0 75883 2}
# wingat -> term1581 Nt=1 TF=1 maxTF=1 @{0 75886 0}
# winger -> term5794 Nt=1 TF=1 maxTF=1 @{0 75888 4}
# wink -> term7201 Nt=1 TF=1 maxTF=1 @{0 75891 6}
# winner -> term6268 Nt=1 TF=1 maxTF=1 @{0 75895 0}
# winpcap -> term5919 Nt=1 TF=1 maxTF=1 @{0 75898 2}
# wipo -> term7493 Nt=1 TF=1 maxTF=1 @{0 75901 4}
# wird -> term3349 Nt=4 TF=4 maxTF=1 @{0 75904 6}
# wire -> term4177 Nt=7 TF=7 maxTF=1 @{0 75915 2}
# wireless -> term2257 Nt=4 TF=4 maxTF=1 @{0 75931 2}
# wise -> term2122 Nt=1 TF=1 maxTF=1 @{0 75941 6}
# wissen -> term8113 Nt=1 TF=1 maxTF=1 @{0 75944 4}
# wissenschaft -> term6175 Nt=1 TF=1 maxTF=1 @{0 75947 6}
# wissenschaftl -> term6178 Nt=1 TF=1 maxTF=1 @{0 75951 0}
# wissenschaftlich -> term7956 Nt=1 TF=1 maxTF=1 @{0 75954 2}
# wissensexplor -> term4450 Nt=1 TF=1 maxTF=1 @{0 75957 4}
# wissensgewinnung -> term3718 Nt=2 TF=2 maxTF=1 @{0 75960 4}
# wissensmanag -> term4416 Nt=1 TF=2 maxTF=2 @{0 75964 2}
# wissensrohstoff -> term4581 Nt=4 TF=4 maxTF=1 @{0 75967 3}
# wit -> term4532 Nt=2 TF=2 maxTF=1 @{0 75975 7}
# witchcraft -> term5921 Nt=1 TF=1 maxTF=1 @{0 75982 1}
# witt -> term3719 Nt=2 TF=2 maxTF=1 @{0 75985 3}
# wittelsbach -> term8073 Nt=1 TF=1 maxTF=1 @{0 75989 1}
# wizard -> term3462 Nt=2 TF=3 maxTF=2 @{0 75992 3}
# wizardrss -> term3736 Nt=1 TF=1 maxTF=1 @{0 75998 6}
# wl -> term5846 Nt=1 TF=1 maxTF=1 @{0 76001 6}
# wlan -> term6118 Nt=1 TF=1 maxTF=1 @{0 76005 0}
# wlic -> term6393 Nt=15 TF=15 maxTF=1 @{0 76008 2}
# wmbh -> term6968 Nt=15 TF=15 maxTF=1 @{0 76029 6}
# wo -> term3315 Nt=2 TF=2 maxTF=1 @{0 76041 6}
# woe -> term4261 Nt=1 TF=1 maxTF=1 @{0 76048 0}
# wolfram -> term7504 Nt=1 TF=1 maxTF=1 @{0 76051 0}
# wollen -> term4446 Nt=2 TF=2 maxTF=1 @{0 76054 2}
# women -> term1233 Nt=4 TF=5 maxTF=2 @{0 76060 0}
# won -> term1289 Nt=1 TF=1 maxTF=1 @{0 76070 5}
# wonder -> term306 Nt=2 TF=2 maxTF=1 @{0 76073 1}
# wood -> term552 Nt=3 TF=3 maxTF=1 @{0 76078 1}
# woollei -> term6472 Nt=1 TF=1 maxTF=1 @{0 76084 3}
# word -> term3059 Nt=38 TF=40 maxTF=2 @{0 76087 5}
# word2vec -> term3216 Nt=2 TF=2 maxTF=1 @{0 76147 3}
# word2x -> term3935 Nt=1 TF=1 maxTF=1 @{0 76151 7}
# wordcloud -> term4250 Nt=1 TF=1 maxTF=1 @{0 76154 7}
# wordl -> term4247 Nt=2 TF=2 maxTF=1 @{0 76157 7}
# wordnet -> term452 Nt=28 TF=29 maxTF=2 @{0 76162 7}
# wordpress -> term167 Nt=19 TF=22 maxTF=2 @{0 76205 0}
# wordsift -> term3717 Nt=1 TF=1 maxTF=1 @{0 76239 5}
# wordsworth -> term7243 Nt=2 TF=2 maxTF=1 @{0 76242 5}
# work -> term632 Nt=44 TF=44 maxTF=1 @{0 76247 7}
# workbench -> term912 Nt=2 TF=2 maxTF=1 @{0 76322 3}
# worker -> term6288 Nt=4 TF=4 maxTF=1 @{0 76327 5}
# workflow -> term3137 Nt=3 TF=3 maxTF=1 @{0 76337 5}
# workload -> term981 Nt=5 TF=5 maxTF=1 @{0 76345 7}
# workplac -> term6481 Nt=1 TF=1 maxTF=1 @{0 76357 5}
# workshop -> term1046 Nt=16 TF=16 maxTF=1 @{0 76360 7}
# worksit -> term5289 Nt=1 TF=1 maxTF=1 @{0 76393 3}
# workstat -> term6113 Nt=2 TF=2 maxTF=1 @{0 76396 5}
# world -> term180 Nt=82 TF=82 maxTF=1 @{0 76401 5}
# worldcat -> term5710 Nt=8 TF=9 maxTF=2 @{0 76518 7}
# worldwid -> term2389 Nt=6 TF=6 maxTF=1 @{0 76533 2}
# wors -> term4902 Nt=1 TF=1 maxTF=1 @{0 76549 0}
# worst -> term593 Nt=2 TF=2 maxTF=1 @{0 76552 0}
# wort -> term3665 Nt=2 TF=2 maxTF=1 @{0 76556 4}
# worth -> term6914 Nt=1 TF=1 maxTF=1 @{0 76561 2}
# worthington -> term6021 Nt=1 TF=1 maxTF=1 @{0 76564 4}
# wortliga -> term3539 Nt=1 TF=1 maxTF=1 @{0 76567 6}
# wpdb -> term1479 Nt=1 TF=1 maxTF=1 @{0 76570 6}
# wpf -> term8116 Nt=1 TF=1 maxTF=1 @{0 76573 2}
# wpm -> term3912 Nt=1 TF=1 maxTF=1 @{0 76576 4}
# wrangler -> term5506 Nt=2 TF=2 maxTF=1 @{0 76579 4}
# wrap -> term3879 Nt=5 TF=6 maxTF=2 @{0 76585 6}
# wrapper -> term3426 Nt=1 TF=1 maxTF=1 @{0 76597 1}
# wrcbtv -> term5406 Nt=1 TF=1 maxTF=1 @{0 76600 1}
# wrekin -> term5649 Nt=5 TF=6 maxTF=2 @{0 76603 3}
# write -> term1231 Nt=22 TF=22 maxTF=1 @{0 76613 2}
# writer -> term4494 Nt=4 TF=5 maxTF=2 @{0 76655 4}
# written -> term3961 Nt=7 TF=7 maxTF=1 @{0 76666 7}
# wroc -> term6805 Nt=1 TF=1 maxTF=1 @{0 76683 7}
# wrong -> term5535 Nt=1 TF=1 maxTF=1 @{0 76687 1}
# wrox -> term1854 Nt=1 TF=1 maxTF=1 @{0 76690 3}
# wrt -> term723 Nt=1 TF=2 maxTF=2 @{0 76693 1}
# ws -> term7616 Nt=1 TF=1 maxTF=1 @{0 76695 4}
# wsbase1 -> term7418 Nt=1 TF=1 maxTF=1 @{0 76698 6}
# wsj -> term5233 Nt=2 TF=2 maxTF=1 @{0 76702 0}
# wuerzburg -> term6405 Nt=1 TF=1 maxTF=1 @{0 76707 4}
# wwdb -> term1259 Nt=1 TF=1 maxTF=1 @{0 76710 6}
# wwk -> term543 Nt=2 TF=2 maxTF=1 @{0 76713 2}
# wwpdb -> term7613 Nt=1 TF=1 maxTF=1 @{0 76716 0}
# www -> term340 Nt=29 TF=30 maxTF=2 @{0 76719 2}
# wxhaskel -> term6525 Nt=1 TF=1 maxTF=1 @{0 76770 5}
# wykobi -> term5309 Nt=1 TF=1 maxTF=1 @{0 76773 7}
# wysiwyg -> term4014 Nt=2 TF=2 maxTF=1 @{0 76777 1}
# x11vnc -> term7411 Nt=1 TF=1 maxTF=1 @{0 76781 1}
# x86 -> term169 Nt=2 TF=2 maxTF=1 @{0 76784 3}
# xad -> term8391 Nt=1 TF=1 maxTF=1 @{0 76788 1}
# xapian -> term4390 Nt=1 TF=1 maxTF=1 @{0 76791 3}
# xatafac -> term1505 Nt=1 TF=1 maxTF=1 @{0 76794 3}
# xda -> term7543 Nt=2 TF=2 maxTF=1 @{0 76796 7}
# xdarwin -> term7521 Nt=1 TF=1 maxTF=1 @{0 76801 7}
# xenobiot -> term2238 Nt=1 TF=1 maxTF=1 @{0 76805 1}
# xenograft -> term2754 Nt=1 TF=1 maxTF=1 @{0 76807 7}
# xephir -> term2755 Nt=1 TF=1 maxTF=1 @{0 76810 5}
# xeround -> term692 Nt=1 TF=1 maxTF=1 @{0 76813 3}
# xfree86 -> term7520 Nt=1 TF=1 maxTF=1 @{0 76815 5}
# xiaodong -> term5229 Nt=1 TF=1 maxTF=1 @{0 76818 7}
# xisbn -> term6130 Nt=2 TF=2 maxTF=1 @{0 76822 1}
# xk -> term4418 Nt=1 TF=1 maxTF=1 @{0 76826 5}
# xml -> term281 Nt=42 TF=43 maxTF=2 @{0 76829 5}
# xmobar -> term3621 Nt=1 TF=1 maxTF=1 @{0 76891 0}
# xmpp -> term8090 Nt=3 TF=3 maxTF=1 @{0 76894 0}
# xorg -> term7609 Nt=1 TF=1 maxTF=1 @{0 76900 0}
# xosh -> term3500 Nt=1 TF=1 maxTF=1 @{0 76903 2}
# xp -> term7414 Nt=1 TF=1 maxTF=1 @{0 76906 2}
# xp2 -> term1554 Nt=1 TF=1 maxTF=1 @{0 76909 4}
# xp4 -> term1051 Nt=1 TF=1 maxTF=1 @{0 76912 0}
# xpath -> term4575 Nt=3 TF=3 maxTF=1 @{0 76914 4}
# xplore -> term3951 Nt=1 TF=1 maxTF=1 @{0 76920 0}
# xqueri -> term4574 Nt=3 TF=3 maxTF=1 @{0 76923 0}
# xr -> term6790 Nt=1 TF=1 maxTF=1 @{0 76928 4}
# xrai -> term7540 Nt=1 TF=1 maxTF=1 @{0 76931 6}
# xsb -> term2931 Nt=1 TF=1 maxTF=1 @{0 76935 0}
# xsec -> term5838 Nt=1 TF=1 maxTF=1 @{0 76937 6}
# xslt -> term5052 Nt=1 TF=1 maxTF=1 @{0 76941 0}
# xtf -> term3252 Nt=3 TF=4 maxTF=2 @{0 76944 0}
# xvi -> term6120 Nt=1 TF=1 maxTF=1 @{0 76949 5}
# yago -> term496 Nt=1 TF=1 maxTF=1 @{0 76952 7}
# yahoo -> term980 Nt=8 TF=8 maxTF=1 @{0 76954 7}
# yale -> term7331 Nt=1 TF=1 maxTF=1 @{0 76971 3}
# yat -> term6343 Nt=1 TF=1 maxTF=1 @{0 76974 5}
# year -> term2541 Nt=16 TF=16 maxTF=1 @{0 76977 7}
# yearli -> term7516 Nt=1 TF=1 maxTF=1 @{0 77010 3}
# yeast -> term1784 Nt=2 TF=2 maxTF=1 @{0 77013 5}
# yeastgenom -> term3061 Nt=1 TF=1 maxTF=1 @{0 77018 5}
# yeastract -> term2311 Nt=1 TF=1 maxTF=1 @{0 77021 3}
# yeastss -> term3065 Nt=1 TF=1 maxTF=1 @{0 77024 1}
# yesterdai -> term4058 Nt=1 TF=1 maxTF=1 @{0 77026 7}
# yh -> term2955 Nt=1 TF=1 maxTF=1 @{0 77029 7}
# yield -> term6068 Nt=1 TF=1 maxTF=1 @{0 77032 5}
# york -> term585 Nt=12 TF=12 maxTF=1 @{0 77035 7}
# young -> term4086 Nt=3 TF=3 maxTF=1 @{0 77058 1}
# youth -> term1878 Nt=2 TF=2 maxTF=1 @{0 77066 5}
# youtub -> term1129 Nt=7 TF=7 maxTF=1 @{0 77072 5}
# yread -> term3407 Nt=2 TF=2 maxTF=1 @{0 77087 5}
# yuan -> term8205 Nt=1 TF=1 maxTF=1 @{0 77091 3}
# yui -> term5518 Nt=1 TF=1 maxTF=1 @{0 77094 5}
# yummi -> term5994 Nt=1 TF=1 maxTF=1 @{0 77097 7}
# yuri -> term7491 Nt=1 TF=1 maxTF=1 @{0 77101 1}
# z39 -> term6510 Nt=1 TF=1 maxTF=1 @{0 77104 3}
# zagrabia -> term7879 Nt=1 TF=1 maxTF=1 @{0 77107 5}
# zam -> term5441 Nt=1 TF=1 maxTF=1 @{0 77110 7}
# zambia -> term6576 Nt=1 TF=1 maxTF=1 @{0 77114 1}
# zaria -> term6261 Nt=1 TF=1 maxTF=1 @{0 77117 3}
# zauberhaft -> term5437 Nt=1 TF=1 maxTF=1 @{0 77120 5}
# zbirk -> term7713 Nt=1 TF=1 maxTF=1 @{0 77123 7}
# zdb -> term4546 Nt=1 TF=1 maxTF=1 @{0 77127 1}
# zdnet -> term1712 Nt=1 TF=1 maxTF=1 @{0 77130 1}
# zdravstvenom -> term8416 Nt=1 TF=1 maxTF=1 @{0 77132 5}
# zealand -> term3336 Nt=4 TF=5 maxTF=2 @{0 77135 7}
# zebrafish -> term2753 Nt=2 TF=2 maxTF=1 @{0 77147 0}
# zeichen -> term3664 Nt=1 TF=1 maxTF=1 @{0 77151 6}
# zeit -> term4369 Nt=3 TF=3 maxTF=1 @{0 77154 6}
# zeitschrift -> term4988 Nt=3 TF=3 maxTF=1 @{0 77163 2}
# zeitschriften -> term6184 Nt=1 TF=1 maxTF=1 @{0 77169 6}
# zeitung -> term8324 Nt=2 TF=2 maxTF=1 @{0 77173 0}
# zembl -> term4513 Nt=2 TF=2 maxTF=1 @{0 77177 6}
# zen -> term5656 Nt=1 TF=1 maxTF=1 @{0 77181 0}
# zentral -> term7006 Nt=1 TF=1 maxTF=1 @{0 77184 2}
# zeri -> term8034 Nt=1 TF=1 maxTF=1 @{0 77187 4}
# zero -> term4661 Nt=4 TF=4 maxTF=1 @{0 77190 6}
# zerowasteweek -> term5413 Nt=1 TF=1 maxTF=1 @{0 77201 4}
# zerrouk -> term7304 Nt=1 TF=1 maxTF=1 @{0 77204 6}
# zettel -> term7436 Nt=1 TF=1 maxTF=1 @{0 77208 0}
# zeu -> term5539 Nt=1 TF=1 maxTF=1 @{0 77211 2}
# zflnc -> term3042 Nt=1 TF=1 maxTF=1 @{0 77214 4}
# zhang -> term6870 Nt=1 TF=1 maxTF=1 @{0 77217 2}
# zhiyanov -> term842 Nt=1 TF=1 maxTF=1 @{0 77220 4}
# zhusuan -> term6368 Nt=1 TF=1 maxTF=1 @{0 77222 6}
# zier -> term3515 Nt=1 TF=1 maxTF=1 @{0 77226 0}
# zinc -> term2767 Nt=1 TF=1 maxTF=1 @{0 77229 0}
# zincbind -> term2768 Nt=1 TF=1 maxTF=1 @{0 77231 6}
# zine -> term7448 Nt=1 TF=1 maxTF=1 @{0 77234 4}
# zip -> term4689 Nt=2 TF=3 maxTF=2 @{0 77237 6}
# zipf -> term3488 Nt=1 TF=1 maxTF=1 @{0 77243 7}
# zitationsanalys -> term7841 Nt=1 TF=1 maxTF=1 @{0 77246 7}
# zk -> term7437 Nt=1 TF=1 maxTF=1 @{0 77250 1}
# zn -> term2228 Nt=1 TF=1 maxTF=1 @{0 77253 3}
# zodb -> term1014 Nt=1 TF=1 maxTF=1 @{0 77256 1}
# zoho -> term1528 Nt=1 TF=1 maxTF=1 @{0 77258 5}
# zombi -> term5452 Nt=1 TF=1 maxTF=1 @{0 77261 1}
# zone -> term392 Nt=2 TF=2 maxTF=1 @{0 77264 3}
# zoom -> term4464 Nt=1 TF=1 maxTF=1 @{0 77268 5}
# zope -> term1013 Nt=1 TF=2 maxTF=2 @{0 77271 5}
# zotero -> term5633 Nt=5 TF=5 maxTF=1 @{0 77274 2}
# zte -> term7468 Nt=1 TF=1 maxTF=1 @{0 77287 0}
# zu -> term3351 Nt=10 TF=10 maxTF=1 @{0 77290 2}
# zubud -> term2605 Nt=2 TF=2 maxTF=1 @{0 77312 6}
# zucchini -> term6325 Nt=1 TF=1 maxTF=1 @{0 77317 2}
# zug -> term7104 Nt=2 TF=2 maxTF=1 @{0 77320 4}
# zugang -> term6756 Nt=1 TF=1 maxTF=1 @{0 77326 4}
# zugest -> term5111 Nt=2 TF=2 maxTF=1 @{0 77329 6}
# zugriff -> term6181 Nt=1 TF=1 maxTF=1 @{0 77333 6}
# zugriffskontrol -> term8376 Nt=1 TF=1 maxTF=1 @{0 77337 0}
# zukunft -> term6730 Nt=2 TF=2 maxTF=1 @{0 77340 2}
# zuletzt -> term5128 Nt=1 TF=1 maxTF=1 @{0 77346 2}
# zum -> term3505 Nt=7 TF=7 maxTF=1 @{0 77349 2}
# zur -> term4385 Nt=9 TF=9 maxTF=1 @{0 77365 4}
# zuse -> term7012 Nt=2 TF=2 maxTF=1 @{0 77387 0}
# zwangsarbeit -> term7768 Nt=1 TF=1 maxTF=1 @{0 77393 0}
# zweger -> term7474 Nt=1 TF=1 maxTF=1 @{0 77396 2}
# zwei -> term7649 Nt=1 TF=1 maxTF=1 @{0 77399 4}
# zwischen -> term3474 Nt=2 TF=2 maxTF=1 @{0 77402 6}
# zwischenarchiv -> term7980 Nt=1 TF=1 maxTF=1 @{0 77408 4}
# zwitschernd -> term3483 Nt=1 TF=1 maxTF=1 @{0 77411 6}
# zxing -> term6519 Nt=1 TF=1 maxTF=1 @{0 77414 6}

# %%
term_freq_dict = {}

for kv in index.getLexicon():
    term_freq_dict[kv.getKey()] = kv.getValue().frequency

# %%
term_freq_dict_sorted = sorted(term_freq_dict.items(), key=lambda x: x[1], reverse=True)

# %%
top_k = 30
term_freq_dict_sorted[:top_k]
# Out:
# [('librari', 2267),
#  ('text', 2092),
#  ('archiv', 1875),
#  ('databas', 1837),
#  ('data', 361),
#  ('base', 320),
#  ('web', 320),
#  ('digit', 315),
#  ('system', 314),
#  ('us', 257),
#  ('mine', 243),
#  ('new', 236),
#  ('open', 235),
#  ('internet', 234),
#  ('analysi', 202),
#  ('search', 191),
#  ('research', 185),
#  ('classif', 180),
#  ('model', 175),
#  ('servic', 174),
#  ('onlin', 163),
#  ('manag', 159),
#  ('learn', 158),
#  ('org', 156),
#  ('gener', 153),
#  ('tool', 134),
#  ('semant', 133),
#  ('public', 132),
#  ('scienc', 131),
#  ('free', 130)]

# %%
search_engine = pt.BatchRetrieve(index, wmodel="Tf")
# Out:
# /var/folders/88/9blsh45918g8y3n5vl6vztxr0000gq/T/ipykernel_3547/951663741.py:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   search_engine = pt.BatchRetrieve(index, wmodel="Tf")

# %%
search_engine.search("system")
# Out:
#     qid  docid                                              docno  rank  \
# 0     1    750  https://www.bibsonomy.org/url/be868d201af37d4a...     0
# 1     1   1845  https://www.bibsonomy.org/bibtex/27cebe02af1e4...     1
# 2     1   1861  https://www.bibsonomy.org/bibtex/2e8737a4cce47...     2
# 3     1   1863  https://www.bibsonomy.org/bibtex/2072b030962e3...     3
# 4     1   3853  https://www.bibsonomy.org/bibtex/280f75bb46fcb...     4
# ..   ..    ...                                                ...   ...
# 303   1   7950  https://www.bibsonomy.org/bibtex/2ae6a916923ad...   303
# 304   1   7968  https://www.bibsonomy.org/bibtex/2390b02f23f3d...   304
# 305   1   7973  https://www.bibsonomy.org/bibtex/25d3f12c5e0f6...   305
# 306   1   7974  https://www.bibsonomy.org/bibtex/270a5cfbabcbb...   306
# 307   1   7991  https://www.bibsonomy.org/bibtex/25926f6dbad9b...   307
#
#      score   query
# 0      2.0  system
# 1      2.0  system
# 2      2.0  system
# 3      2.0  system
# 4      2.0  system
# ..     ...     ...
# 303    1.0  system
# 304    1.0  system
# 305    1.0  system
# 306    1.0  system
# 307    1.0  system
#
# [308 rows x 6 columns]

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
stem = stemmer.stem("learning")
stem
# Out:
# 'learn'

# %%
lexicon = index.getLexicon()
lexicon[stem].getDocumentFrequency()
# Out:
# 155

# %%
index.getCollectionStatistics().numberOfDocuments
# Out:
# 8000

# %%
def get_idf_for_term(term, index):
  lex = index.getLexicon()
  stemmed_term = stemmer.stem(term)

  if not stemmed_term in lex:
    return 
    
  lex_entry = lex[stemmed_term]

  df_term = lex_entry.getDocumentFrequency()
  N = index.getCollectionStatistics().numberOfDocuments
  
  #inverse document frequency
  idf = N/df_term

  #apply logarithm(base 10) to idf
  log_idf = np.emath.logn(10, idf)

  return log_idf

# %%
get_idf_for_term("learning", index)
# Out:
# 1.712758288821652

# %%
#define your own tf_idf method here:

def calc_tf_idf(query, docno, index):
    #remember that tfidf is the product of two components
    #hint: the tf model search result contains tf frequencies
    return 0

# %%
search_engine_tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")
# Out:
# /var/folders/88/9blsh45918g8y3n5vl6vztxr0000gq/T/ipykernel_3547/2880449899.py:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   search_engine_tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")

# %%
search_engine_tfidf.search("database")
# Out:
#     qid  docid                                              docno  rank  \
# 0     1    751  https://www.bibsonomy.org/url/a096f0b12753c22e...     0
# 1     1    281  https://www.bibsonomy.org/url/b05f7889d6a0731c...     1
# 2     1    287  https://www.bibsonomy.org/url/b05f7889d6a0731c...     2
# 3     1   1007  https://www.bibsonomy.org/bibtex/2b8151c596a8d...     3
# 4     1   1785  https://www.bibsonomy.org/bibtex/25802e079a691...     4
# ..   ..    ...                                                ...   ...
# 995   1    573  https://www.bibsonomy.org/url/262cdca8951e45ec...   995
# 996   1    579  https://www.bibsonomy.org/url/cd8d11db33dc293f...   996
# 997   1    580  https://www.bibsonomy.org/url/61ccc5248c3559d5...   997
# 998   1    581  https://www.bibsonomy.org/url/17e00df720be1825...   998
# 999   1    586  https://www.bibsonomy.org/url/18670c07c777d29a...   999
#
#         score     query
# 0    2.170079  database
# 1    2.058956  database
# 2    2.058956  database
# 3    2.058956  database
# 4    2.056275  database
# ..        ...       ...
# 995  1.360506  database
# 996  1.360506  database
# 997  1.360506  database
# 998  1.360506  database
# 999  1.360506  database
#
# [1000 rows x 6 columns]

# %%
# Index with multiple fields
df_dict = df_filtered.to_dict(orient='records')

# %%
df_dict
# Out:
# [{'id': 'https://www.bibsonomy.org/url/cc45493bf442b78d923b0b1b9342676b/springnet',
#   'tags': ['web2.0',
#    'database',
#    'desktop',
#    'aggregator',
#    'daily',
#    'incredible',
#    'applications',
#    'bookmarking',
#    'blog'],
#   'label': 'Office 2.0 Database',
#   'description': 'Office 2.0 Database',
#   'date': '2006-04-19 19:49:42',
#   'changeDate': '2008-06-29 17:52:49',
#   'url': 'http://itredux.com/office-20/database/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/cc45493bf442b78d923b0b1b9342676b/springnet',
#   'text': 'Office 2.0 Database'},
#  {'id': 'https://www.bibsonomy.org/url/61474ed79d5c3f63c1d0b6dcd8c653f5/traktools',
#   'tags': ['tool',
#    'database',
#    '3403',
#    'Error',
#    'Fix,',
#    'recovery,',
#    'Database',
#    'Recovery',
#    'SQL'],
#   'label': 'SQL Database 3403 Error Fix',
#   'description': 'SysTools Software releases an effective SQL database recovery software to solve your sql database problems as sql database 3403 error and other problems. SQL database repair software frequently restore stored procedures, tables, views, triggers and other all items from damaged MDF files\r\n',
#   'date': '2009-09-15 19:13:52',
#   'changeDate': '2009-09-15 19:13:52',
#   'url': 'http://www.sqlrecoverytool.com/sql-database-3403-error.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/61474ed79d5c3f63c1d0b6dcd8c653f5/traktools',
#   'text': 'SQL Database 3403 Error Fix'},
#  {'id': 'https://www.bibsonomy.org/url/3cd373dd8ed9c53483d39eaa928686f6/panic',
#   'tags': ['Article(s)', 'Design', 'Database', 'Information'],
#   'label': 'Database Sharding',
#   'description': 'The term "sharding" was coined by Google engineers, and popularized through their publication of the Big Table architecture. However, the concept of "shared-nothing" database partitioning has been around for a decade or more and there have been many implementations over this period, especially high profile in-house built solutions by Internet leaders such as eBay, Amazon, Digg, Flickr, Skype, YouTube, Facebook, Friendster, and Wikipedia.',
#   'date': '2011-10-01 02:24:14',
#   'changeDate': '2011-10-01 02:27:38',
#   'url': 'http://www.codefutures.com/database-sharding/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/3cd373dd8ed9c53483d39eaa928686f6/panic',
#   'text': 'Database Sharding'},
#  {'id': 'https://www.bibsonomy.org/url/cc45493bf442b78d923b0b1b9342676b/akpe',
#   'tags': ['web2.0', '2007', 'database', 'socialsoftware', 'tools', 'list'],
#   'label': 'Office 2.0 Database',
#   'description': 'Overview of roughly 250 Web 2.0 applications, including 29 bookmarking applications, 13 calendar applications, 5 contacts managers, 17 CRM systems, 11 database managers, 17 desktops, 14 development tools, 8 document managers, 11 feed readers, etc',
#   'date': '2007-03-14 20:26:50',
#   'changeDate': '2011-03-14 16:42:58',
#   'url': 'http://itredux.com/office-20/database/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/cc45493bf442b78d923b0b1b9342676b/akpe',
#   'text': 'Office 2.0 Database'},
#  {'id': 'https://www.bibsonomy.org/url/2f5f76391c720a9b688f60ec6f900f1d/ludaesch',
#   'tags': ['databases'],
#   'label': 'Encyclopedia of Database Systems',
#   'description': 'Encyclopedia of Database Systems',
#   'date': '2007-02-08 11:20:08',
#   'changeDate': '2007-09-26 06:23:20',
#   'url': 'http://refworks.springer.com/database-systems/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/2f5f76391c720a9b688f60ec6f900f1d/ludaesch',
#   'text': 'Encyclopedia of Database Systems'},
#  {'id': 'https://www.bibsonomy.org/url/a61cde4a068fbdcd6e62c4aba774e8c0/traktools',
#   'tags': ['Recovery,', 'Database', 'SQL', 'Repair'],
#   'label': 'SQL Database Recovery',
#   'description': 'Are you facing SQL data loss problem due to corruption of MS SQL Server (.MDF) files. Get SysTools SQL Recovery Tool and repair corrupt MDF files. SysTools SQL database recovery software can restore your all SQL Server meta data (tables, views, triggers, stored procedures, default values, user data types, functions etc) from corrupt MDF files.',
#   'date': '2009-06-04 18:44:16',
#   'changeDate': '2009-06-04 18:44:16',
#   'url': 'http://www.nsftopst.com/sql-database-recovery-tool.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/a61cde4a068fbdcd6e62c4aba774e8c0/traktools',
#   'text': 'SQL Database Recovery'},
#  {'id': 'https://www.bibsonomy.org/url/951c278564ddeaf05f3b623107ab2166/lysander07',
#   'tags': ['database', '2012', 'sql', 'nosql'],
#   'label': 'Updated database landscape graphic — Too much information',
#   'description': 'infographic on current database landscape - sql, nosql, relational, graph, etc.',
#   'date': '2012-11-04 10:35:18',
#   'changeDate': '2012-11-04 10:35:18',
#   'url': 'http://blogs.the451group.com/information_management/2012/11/02/updated-database-landscape-graphic/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/951c278564ddeaf05f3b623107ab2166/lysander07',
#   'text': 'Updated database landscape graphic — Too much information'},
#  {'id': 'https://www.bibsonomy.org/url/f24421e7631b58b6a933634efecd96ed/flykeysky',
#   'tags': ['database', 'index', 'article'],
#   'label': 'Database indexes for database speed & optimization',
#   'description': '',
#   'date': '2009-02-06 15:09:32',
#   'changeDate': '2009-02-12 03:07:51',
#   'url': 'http://www.websitedatabases.com/database-index.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/f24421e7631b58b6a933634efecd96ed/flykeysky',
#   'text': 'Database indexes for database speed & optimization'},
#  {'id': 'https://www.bibsonomy.org/url/ea505f12ee46959719250ded1771e349/colindolly',
#   'tags': ['software', 'Database', 'recovery'],
#   'label': 'Database recovery software',
#   'description': 'Database recovery software to repair corrupted access database & SQL Server Database. Repair and Recover corrupt database from Access and SQL. Stellar Phoenix SQL Database Recovery utility is the key tool for repairing the corrupted databases of MS SQL Server. This database repair software can repair all the database objects like triggers, stored procedures, views and lot many. The software creates the script files from which the repaired database can be retrieved. Database recovery software to repair corrupted access database & SQL Server Database. Repair and Recover corrupt database from Access and SQL\r\n\r\n\r\nFor More Details:-  http://www.database-recovery-software.com/\r\n',
#   'date': '2009-07-02 13:36:24',
#   'changeDate': '2009-07-02 13:36:24',
#   'url': 'http://www.database-recovery-software.com/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/ea505f12ee46959719250ded1771e349/colindolly',
#   'text': 'Database recovery software'},
#  {'id': 'https://www.bibsonomy.org/url/6eccf72b8f65d35dd1dc9e2f1dac80e1/mdehghan',
#   'tags': ['database', 'IDS', 'signature', 'cisco'],
#   'label': 'IDS signature database !!! | Other Security Subjects | Cisco Support Community | 5806 | 9451456',
#   'description': 'IDS signature database !!! | Other Security Subjects | Cisco Technical Support Forum | 5806 | 9451456',
#   'date': '2015-06-07 21:27:03',
#   'changeDate': '2015-06-07 21:27:03',
#   'url': 'https://supportforums.cisco.com/discussion/9451456/ids-signature-database',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/6eccf72b8f65d35dd1dc9e2f1dac80e1/mdehghan',
#   'text': 'IDS signature database !!! | Other Security Subjects | Cisco Support Community | 5806 | 9451456'},
#  {'id': 'https://www.bibsonomy.org/url/525e8fe1188cad8723c2d2dbee9e0ba0/springnet',
#   'tags': ['database', 'hierarchical', 'mysql'],
#   'label': 'Storing Hierarchical Data in a Database',
#   'description': 'Whether you want to build your own forum, publish the messages from a mailing list on your Website, or write your own cms [1]: there will be a moment that you’ll want to store hierarchical data in a database. And, unless you’re using a XML [2]-like da',
#   'date': '2006-07-24 03:47:16',
#   'changeDate': '2008-06-29 17:50:38',
#   'url': 'http://www.sitepoint.com/print/hierarchical-data-database',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/525e8fe1188cad8723c2d2dbee9e0ba0/springnet',
#   'text': 'Storing Hierarchical Data in a Database'},
#  {'id': 'https://www.bibsonomy.org/url/52ea707164fbc944952c94a3dd916098/colindolly',
#   'tags': ['repair', 'software', 'Database'],
#   'label': 'Database repair software',
#   'description': 'Stellar Phoenix SQL Database Recovery utility is the key tool for repairing the corrupted databases of MS SQL Server. This database repair software can repair all the database objects like triggers, stored procedures, views and lot many. The software creates the script files from which the repaired database can be retrieved. Database repair software to repair corrupted access database & SQL Server Database. Repair and Recover corrupt database from Access and SQL"\r\n\r\n\r\nFor More Details:-  http://www.database-repair-software.com/\r\n',
#   'date': '2009-07-02 13:37:11',
#   'changeDate': '2009-07-02 13:37:11',
#   'url': 'http://www.database-repair-software.com/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/52ea707164fbc944952c94a3dd916098/colindolly',
#   'text': 'Database repair software'},
#  {'id': 'https://www.bibsonomy.org/url/f5cda44a0641661e095a56acde47e241/lystrata',
#   'tags': ['analytics', 'database', 'visualization', 'data'],
#   'label': 'Database visualization',
#   'description': 'Database Visualization tool',
#   'date': '2007-03-17 01:15:31',
#   'changeDate': '2010-02-20 02:11:50',
#   'url': 'http://www.visokio.com/omniscope/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/f5cda44a0641661e095a56acde47e241/lystrata',
#   'text': 'Database visualization'},
#  {'id': 'https://www.bibsonomy.org/url/e1a0101336c7ffd6b735d893a894a042/gresch',
#   'tags': ['database',
#    'computing',
#    'develop',
#    'refactoring',
#    'tools',
#    'sql',
#    'db'],
#   'label': 'Database Refactoring',
#   'description': 'The Sundog Database Refactoring Tool (SDRT) is an open source (LGPL), DBMS-independent library that eases database development, particularly in an agile environment.',
#   'date': '2007-04-16 13:20:54',
#   'changeDate': '2007-04-16 13:20:54',
#   'url': 'http://www.sundog.net/index.php/databaserefactoring/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/e1a0101336c7ffd6b735d893a894a042/gresch',
#   'text': 'Database Refactoring'},
#  {'id': 'https://www.bibsonomy.org/url/010e73c9e0beea891799e917e76c70e5/iblis',
#   'tags': ['imported',
#    'ecology',
#    'biology',
#    'species',
#    'database',
#    'invasion'],
#   'label': 'Global Invasive Species Database',
#   'description': '',
#   'date': '2006-05-01 11:12:42',
#   'changeDate': '2010-12-19 03:20:50',
#   'url': 'http://www.issg.org/database/welcome/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/010e73c9e0beea891799e917e76c70e5/iblis',
#   'text': 'Global Invasive Species Database'},
#  {'id': 'https://www.bibsonomy.org/url/d9c7e8d4ccd32f1f46e6b628865c340d/traktools',
#   'tags': ['MS', 'Database', 'SQL', 'Repair'],
#   'label': 'SQL Database Repair',
#   'description': 'MS SQL Database Repair Software from SysTools to repair SQL 2008 database, repair SQL 2005 database and repair SQL 2000 database reliably and comfortably. Gets an idea about How to repair corrupt SQL database or how to repair MDF file using this MS SQL repair software.',
#   'date': '2009-12-30 17:10:27',
#   'changeDate': '2009-12-30 17:10:27',
#   'url': 'http://www.sql.databaserepair.net/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/d9c7e8d4ccd32f1f46e6b628865c340d/traktools',
#   'text': 'SQL Database Repair'},
#  {'id': 'https://www.bibsonomy.org/url/5c9906f9bb89d15f1b684c3a65e30f0a/lystrata',
#   'tags': ['hypertable',
#    'database',
#    'mapreduce',
#    'distributed',
#    'bigtable',
#    'hadoop'],
#   'label': '451 CAOS Theory » Introducing Hypertable - a new open source database project',
#   'description': 'Introducing Hypertable - a new open source database project',
#   'date': '2008-02-21 06:07:50',
#   'changeDate': '2010-02-20 02:11:07',
#   'url': 'http://blogs.the451group.com/opensource/2008/02/19/introducing-hypertable-a-new-open-source-database-project/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/5c9906f9bb89d15f1b684c3a65e30f0a/lystrata',
#   'text': '451 CAOS Theory » Introducing Hypertable - a new open source database project'},
#  {'id': 'https://www.bibsonomy.org/url/96589b1b947236e3965a783607d0ba2f/pitman',
#   'tags': ['projects', 'biodiversity', 'database'],
#   'label': 'TDWG: Projects Database',
#   'description': 'Data Standards\r\nAgriculture Network Information Center \tData In',
#   'date': '2008-12-22 21:34:00',
#   'changeDate': '2008-12-22 21:34:00',
#   'url': 'http://www.tdwg.org/biodiv-projects/projects-database/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/96589b1b947236e3965a783607d0ba2f/pitman',
#   'text': 'TDWG: Projects Database'},
#  {'id': 'https://www.bibsonomy.org/url/e8fc97d4e028ac95cae5bc30ca74c91e/nosebrain',
#   'tags': ['database', 'profiler', 'mongodb'],
#   'label': 'Database Profiler - MongoDB',
#   'description': '',
#   'date': '2011-08-11 14:13:51',
#   'changeDate': '2011-08-11 14:13:51',
#   'url': 'http://www.mongodb.org/display/DOCS/Database+Profiler',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/e8fc97d4e028ac95cae5bc30ca74c91e/nosebrain',
#   'text': 'Database Profiler - MongoDB'},
#  {'id': 'https://www.bibsonomy.org/url/5677b0a29fec816a54bcd5acd92b6f77/lystrata',
#   'tags': ['science',
#    'reference',
#    'biology',
#    'database',
#    'nature',
#    'interesting',
#    'animals',
#    'health',
#    'list'],
#   'label': 'Search the AnAge Database',
#   'description': 'Age Database',
#   'date': '2008-06-30 03:33:07',
#   'changeDate': '2010-02-20 02:10:51',
#   'url': 'http://genomics.senescence.info/species/query.php?show=5&sort=4&page=1',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/5677b0a29fec816a54bcd5acd92b6f77/lystrata',
#   'text': 'Search the AnAge Database'},
#  {'id': 'https://www.bibsonomy.org/url/cc45493bf442b78d923b0b1b9342676b/kleverson',
#   'tags': ['collaborative', 'Database', 'office'],
#   'label': 'Itredux.com/office-20/database/',
#   'description': 'interessantíssimo',
#   'date': '2006-04-22 17:24:54',
#   'changeDate': '2006-04-22 17:24:54',
#   'url': 'http://itredux.com/office-20/database/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/cc45493bf442b78d923b0b1b9342676b/kleverson',
#   'text': 'Itredux.com/office-20/database/'},
#  {'id': 'https://www.bibsonomy.org/url/07e7575804a281f1c344da89256ddeee/pitman',
#   'tags': ['database',
#    'bio',
#    'collaborative',
#    'source',
#    'tools',
#    'db',
#    'open'],
#   'label': 'GMOD: Generic Model Organism Database',
#   'description': 'Generic Model Organism Database project, a collection of open source software tools for creating and managing genome-scale biological databases. You can use it to create a small laboratory database of genome annotations, or a large web-accessible community database. GMOD tools are in use at many large and small community databases.',
#   'date': '2008-04-06 18:18:59',
#   'changeDate': '2008-04-06 18:18:59',
#   'url': 'http://www.gmod.org/home',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/07e7575804a281f1c344da89256ddeee/pitman',
#   'text': 'GMOD: Generic Model Organism Database'},
#  {'id': 'https://www.bibsonomy.org/url/a864ce7a699f298b40a176cebc0ca6b6/fisherlibrary',
#   'tags': ['jihadist',
#    'terrorism',
#    'speeches',
#    'extremist',
#    'jihad',
#    'interviews',
#    'terrorist',
#    'statements',
#    'fundamentalistmuslim',
#    'publications'],
#   'label': 'RAND Voices of Jihad Database (Terrorism Database)',
#   'description': 'This online database is a compilation of speeches, interviews, statements, and publications of jihadist leaders, foot soldiers, and sympathizers. Nearly all content is in English translation, and has been collected from publicly-accessible websites. Original links are provided, along with excerpts and full-text content when available.',
#   'date': '2010-06-22 21:44:54',
#   'changeDate': '2010-06-22 21:44:54',
#   'url': 'http://www.rand.org/research_areas/terrorism/database/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/a864ce7a699f298b40a176cebc0ca6b6/fisherlibrary',
#   'text': 'RAND Voices of Jihad Database (Terrorism Database)'},
#  {'id': 'https://www.bibsonomy.org/url/d1c8b0d680c78bf47bdd8c5896e3a7b6/mobileink',
#   'tags': ['bibliography',
#    'library',
#    'web',
#    'mgmt',
#    'database',
#    'doc',
#    'bibtex',
#    'db'],
#   'label': 'Document Database',
#   'description': 'The Document Database was grown out of the need to organize research papers and their BibTex entries.',
#   'date': '2006-06-08 19:12:53',
#   'changeDate': '2006-06-08 19:12:53',
#   'url': 'http://docdb.sourceforge.net/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/d1c8b0d680c78bf47bdd8c5896e3a7b6/mobileink',
#   'text': 'Document Database'},
#  {'id': 'https://www.bibsonomy.org/url/ef82c9d17fa3a21b17c8c8da8b7c5206/polythetic',
#   'tags': ['prosopography',
#    'database',
#    'antiquity',
#    'history',
#    'ancient_near_east'],
#   'label': 'OA Prosopography Database',
#   'description': 'a mySQL backed database of persons occurring in Assyrian texts',
#   'date': '2015-07-18 14:45:16',
#   'changeDate': '2015-07-18 14:45:16',
#   'url': 'http://oatp.net/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/ef82c9d17fa3a21b17c8c8da8b7c5206/polythetic',
#   'text': 'OA Prosopography Database'},
#  {'id': 'https://www.bibsonomy.org/url/8848bfb6ce8a6e6f1c670fc41204b6ba/pitman',
#   'tags': ['science', 'commons', 'database', 'legal', 'protocol', 'creative'],
#   'label': 'Science Commons: Database Protocol',
#   'description': '',
#   'date': '2008-11-02 02:21:57',
#   'changeDate': '2008-11-02 02:21:57',
#   'url': 'http://sciencecommons.org/resources/faq/database-protocol/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/8848bfb6ce8a6e6f1c670fc41204b6ba/pitman',
#   'text': 'Science Commons: Database Protocol'},
#  {'id': 'https://www.bibsonomy.org/url/3279b849950f64742b3be2c1a04832f4/traktools',
#   'tags': ['Database', 'Recovery', 'Open', 'Sql'],
#   'label': 'Open SQL Database',
#   'description': 'An exclusive solution from SysTools Software labs to open SQL server 2005 and 2000 database files even MDF file get damaged or corrupted. SQL database repair software is adept to open damaged or corrupted MDF database files and restore stored procedures, tables, triggers, views and other data.\r\n',
#   'date': '2009-09-08 17:33:31',
#   'changeDate': '2009-09-08 17:33:31',
#   'url': 'http://www.sqlrecoverytool.com/open-sql.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/3279b849950f64742b3be2c1a04832f4/traktools',
#   'text': 'Open SQL Database'},
#  {'id': 'https://www.bibsonomy.org/url/bac57cdd5bbd80c8f1089031726db5b1/drmatusek',
#   'tags': ['database', 'chemistry', 'quantum', 'diatomic'],
#   'label': 'DiRef Reference Database',
#   'description': 'A web-based interface to a literature database on diatomic molecules.',
#   'date': '2012-01-20 04:34:25',
#   'changeDate': '2013-01-03 04:31:44',
#   'url': 'http://diref.uwaterloo.ca',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/bac57cdd5bbd80c8f1089031726db5b1/drmatusek',
#   'text': 'DiRef Reference Database'},
#  {'id': 'https://www.bibsonomy.org/url/bf9f388ef6f8c8f6d552e52b4e3fee91/nroovers',
#   'tags': ['thesis', 'schema', 'database', 'tag'],
#   'label': 'Tags: Database schemas',
#   'description': '',
#   'date': '2007-07-07 14:40:30',
#   'changeDate': '2007-07-14 12:33:31',
#   'url': 'http://www.pui.ch/phred/archives/2005/04/tags-database-schemas.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/bf9f388ef6f8c8f6d552e52b4e3fee91/nroovers',
#   'text': 'Tags: Database schemas'},
#  {'id': 'https://www.bibsonomy.org/url/bf4aa8a53faf5a3e0200d6b4e623ee96/kw',
#   'tags': ['database', 'visualization', 'cooletools', 'mysql'],
#   'label': 'DbVisualizer - The Universal Database Tool',
#   'description': 'The Universal Database Tool',
#   'date': '2011-06-29 10:02:21',
#   'changeDate': '2011-06-29 10:02:21',
#   'url': 'http://www.dbvis.com/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/bf4aa8a53faf5a3e0200d6b4e623ee96/kw',
#   'text': 'DbVisualizer - The Universal Database Tool'},
#  {'id': 'https://www.bibsonomy.org/url/9597b3ae2d84e8130c413609ce01f4c2/dolefulrabbit',
#   'tags': ['java', 'database', 'berkeleydb', 'db'],
#   'label': 'Berkeley DB | Oracle Embedded Database',
#   'description': '',
#   'date': '2009-09-08 17:17:08',
#   'changeDate': '2010-12-17 13:54:07',
#   'url': 'http://www.oracle.com/database/berkeley-db/index.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/9597b3ae2d84e8130c413609ce01f4c2/dolefulrabbit',
#   'text': 'Berkeley DB | Oracle Embedded Database'},
#  {'id': 'https://www.bibsonomy.org/url/9597b3ae2d84e8130c413609ce01f4c2/selm',
#   'tags': ['eL3€7',
#    'database',
#    'Lesezeichen-Symbolleiste',
#    'public',
#    'embedded'],
#   'label': 'Berkeley DB | Oracle Embedded Database',
#   'description': '',
#   'date': '2020-07-25 23:12:12',
#   'changeDate': '2020-07-25 23:49:33',
#   'url': 'http://www.oracle.com/database/berkeley-db/index.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/9597b3ae2d84e8130c413609ce01f4c2/selm',
#   'text': 'Berkeley DB | Oracle Embedded Database'},
#  {'id': 'https://www.bibsonomy.org/url/30e0f888613cc669741cfb913d2e1d9a/lndig',
#   'tags': ['database',
#    'online',
#    'art_history',
#    'iconography',
#    'images',
#    'photography'],
#   'label': 'THE WARBURG INSTITUTE: Iconographic Database',
#   'description': '',
#   'date': '2013-05-25 12:33:36',
#   'changeDate': '2013-11-08 00:05:58',
#   'url': 'http://warburg.sas.ac.uk/photographic-collection/iconographic-database/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/30e0f888613cc669741cfb913d2e1d9a/lndig',
#   'text': 'THE WARBURG INSTITUTE: Iconographic Database'},
#  {'id': 'https://www.bibsonomy.org/url/df6f81b83c656faa7aef78a0a7a26c5a/schmidt2',
#   'tags': ['database', 'free_form', 'definition', 'word'],
#   'label': 'free-form database - Computer Dictionary Definition',
#   'description': '',
#   'date': '2011-08-30 13:47:59',
#   'changeDate': '2011-08-30 13:47:59',
#   'url': 'http://computer.yourdictionary.com/free-form-database',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/df6f81b83c656faa7aef78a0a7a26c5a/schmidt2',
#   'text': 'free-form database - Computer Dictionary Definition'},
#  {'id': 'https://www.bibsonomy.org/url/210e1c25be28a45a928df5b83ead5bb9/sac',
#   'tags': ['system', 'database', 'management', 'probabilistic', 'db'],
#   'label': 'Cornell Database Group - The MayBMS Project',
#   'description': '',
#   'date': '2012-03-08 15:15:26',
#   'changeDate': '2012-03-08 15:15:26',
#   'url': 'http://www.cs.cornell.edu/database-OLD/maybms/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/210e1c25be28a45a928df5b83ead5bb9/sac',
#   'text': 'Cornell Database Group - The MayBMS Project'},
#  {'id': 'https://www.bibsonomy.org/url/f9a4fff160e8332007370add3228d19d/ebo',
#   'tags': ['influenza', 'database', 'molecular'],
#   'label': 'Influenza Research Database - Genome database with visualization and analysis tools',
#   'description': 'Searchable database of influenza genomes with visualization and analysis tools.',
#   'date': '2009-08-07 18:27:32',
#   'changeDate': '2009-08-07 18:27:32',
#   'url': 'http://www.biohealthbase.org/GSearch/home.do?decorator=Influenza',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/f9a4fff160e8332007370add3228d19d/ebo',
#   'text': 'Influenza Research Database - Genome database with visualization and analysis tools'},
#  {'id': 'https://www.bibsonomy.org/url/5c68103f9354f69225dd51dcdbbbd1ce/continued',
#   'tags': ['Wartung',
#    'E-Mail',
#    'Networking',
#    'Network',
#    'IP',
#    'Blocklist',
#    'DNS',
#    'Tools',
#    'Mailserver',
#    'Blacklist',
#    'Internet',
#    'Spam'],
#   'label': 'DNSBL Information - Spam Database Lookup',
#   'description': 'DNS-based block list information/database. Resource to find out information on DNS block lists and check IPs to see if the are block listed in over 100 blacklist in just seconds.',
#   'date': '2016-08-07 21:10:21',
#   'changeDate': '2016-08-07 23:57:21',
#   'url': 'http://www.dnsbl.info/dnsbl-database-check.php',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/5c68103f9354f69225dd51dcdbbbd1ce/continued',
#   'text': 'DNSBL Information - Spam Database Lookup'},
#  {'id': 'https://www.bibsonomy.org/url/3fc4c81480b130151757fcc0a4d420d6/kw',
#   'tags': ['database'],
#   'label': 'Oracle Database 10g Express Edition',
#   'description': '',
#   'date': '2007-11-03 19:58:49',
#   'changeDate': '2007-11-03 19:58:49',
#   'url': 'http://www.oracle.com/technology/products/database/xe/index.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/3fc4c81480b130151757fcc0a4d420d6/kw',
#   'text': 'Oracle Database 10g Express Edition'},
#  {'id': 'https://www.bibsonomy.org/url/525e8fe1188cad8723c2d2dbee9e0ba0/hotho',
#   'tags': ['database', 'hierarchical', 'data', 'storing'],
#   'label': 'Storing Hierarchical Data in a Database',
#   'description': '',
#   'date': '2005-08-12 15:53:07',
#   'changeDate': '2005-08-12 15:53:07',
#   'url': 'http://www.sitepoint.com/print/hierarchical-data-database',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/525e8fe1188cad8723c2d2dbee9e0ba0/hotho',
#   'text': 'Storing Hierarchical Data in a Database'},
#  {'id': 'https://www.bibsonomy.org/url/c3f4f8ef4aae6217297bb90c76292f9d/jepcastel',
#   'tags': ['backup', 'phpmyadmin', 'mysql'],
#   'label': 'How to backup your Mysql database with phpMyAdmin',
#   'description': 'How to backup your Mysql database with phpMyAdmin',
#   'date': '2009-08-17 17:06:57',
#   'changeDate': '2009-08-17 17:06:57',
#   'url': 'http://fragments.turtlemeat.com/mysql-database-backup-restore-phpmyadmin.php',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/c3f4f8ef4aae6217297bb90c76292f9d/jepcastel',
#   'text': 'How to backup your Mysql database with phpMyAdmin'},
#  {'id': 'https://www.bibsonomy.org/url/0163c293056a0ec31fb4718698114868/panic',
#   'tags': ['Java',
#    'C',
#    'Cpp',
#    'Programming',
#    'Database',
#    'Library',
#    'Perl',
#    'Ruby'],
#   'label': 'QDBM: Quick Database Manager',
#   'description': 'a library of routines for managing a database. The database is a simple data file containing records, each is a pair of a key and a value. Every key and value is serial bytes with variable length.',
#   'date': '2011-10-01 02:27:21',
#   'changeDate': '2011-10-01 02:38:09',
#   'url': 'http://qdbm.sourceforge.net/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/0163c293056a0ec31fb4718698114868/panic',
#   'text': 'QDBM: Quick Database Manager'},
#  {'id': 'https://www.bibsonomy.org/url/ead5d25c4fd0907ddefa16e3b01bd769/continued',
#   'tags': ['lang:en',
#    'CJDate',
#    'Logik',
#    'Database',
#    'Datenbank',
#    'Darwen',
#    'Relational_Model',
#    'Relational_Algebra',
#    'Essay',
#    'Logic',
#    'Predicate_Logic'],
#   'label': 'Hugh Darwen, 1997: What a Database Really Is. Predicates and Propositions [PDF, 7 Seiten]',
#   'description': 'Despite the name, a database is best thought of as a repository not just for data, but rather for facts—that is, for true propositions. The article that follows explains this remark in lay terms and begins to explore some of its many implications.',
#   'date': '2017-03-17 22:24:28',
#   'changeDate': '2017-03-18 16:03:58',
#   'url': 'http://web.onetel.com/~hughdarwen/M359/What-a-Database-Really-Is.pdf',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/ead5d25c4fd0907ddefa16e3b01bd769/continued',
#   'text': 'Hugh Darwen, 1997: What a Database Really Is. Predicates and Propositions [PDF, 7 Seiten]'},
#  {'id': 'https://www.bibsonomy.org/url/44431a48670e6eed31411947d7dedd90/florian',
#   'tags': ['SAP', 'installation', '11g', 'Database', 'direct', 'Oracle'],
#   'label': 'SAP on Oracle Database',
#   'description': 'Find official information regarding SAP on Oracle database including articles, blogs, downloads, support and related topics.',
#   'date': '2011-03-10 21:48:35',
#   'changeDate': '2011-03-10 21:48:35',
#   'url': 'http://www.sdn.sap.com/irj/sdn/ora',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/44431a48670e6eed31411947d7dedd90/florian',
#   'text': 'SAP on Oracle Database'},
#  {'id': 'https://www.bibsonomy.org/url/63fc756db7c683ed09749a122d7ba31e/danielle.dennie',
#   'tags': ['genetics', 'biology', 'database', 'bioinformatics', 'nucleotide'],
#   'label': 'EMBL Nucleotide Sequence Database',
#   'description': 'Collection of nucleotide sequences and accompanying annotations produced in collaboration with GenBank DNA Database of Japan (DDBJ).',
#   'date': '2016-05-26 22:28:35',
#   'changeDate': '2016-05-27 17:05:04',
#   'url': 'http://www.ebi.ac.uk/embl/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/63fc756db7c683ed09749a122d7ba31e/danielle.dennie',
#   'text': 'EMBL Nucleotide Sequence Database'},
#  {'id': 'https://www.bibsonomy.org/url/bf4aa8a53faf5a3e0200d6b4e623ee96/sac',
#   'tags': ['database',
#    'fk',
#    'management',
#    'navigation',
#    'visualdb',
#    'tools',
#    'dbvisualizer'],
#   'label': 'Database Management Software Tools - DbVisualizer',
#   'description': 'DbVisualizer is a database management and analysis tool for all major databases (e.g. Oracle, SQL Server, DB2, Sybase, MySQL, SQLite) on Windows, Mac OS X, Linux and Unix platforms with customers in 90 countries.',
#   'date': '2012-10-15 17:21:01',
#   'changeDate': '2012-10-15 17:21:01',
#   'url': 'http://www.dbvis.com/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/bf4aa8a53faf5a3e0200d6b4e623ee96/sac',
#   'text': 'Database Management Software Tools - DbVisualizer'},
#  {'id': 'https://www.bibsonomy.org/url/63043bc840b91a737043021f2e33cd22/karinnadrowski',
#   'tags': ['database', 'databank', 'canopy'],
#   'label': 'Welcome to the Canopy DataBank Database Generator | SciDB - DataBank',
#   'description': '',
#   'date': '2009-01-23 21:12:58',
#   'changeDate': '2009-01-23 21:12:58',
#   'url': 'http://acdrupal.evergreen.edu/databank/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/63043bc840b91a737043021f2e33cd22/karinnadrowski',
#   'text': 'Welcome to the Canopy DataBank Database Generator | SciDB - DataBank'},
#  {'id': 'https://www.bibsonomy.org/url/e222625466630edb7edbb25336f5fae8/timo',
#   'tags': ['server', 'database', 'Linux', 'Windows', 'DBMS', 'SQL', 'Oracle'],
#   'label': 'Oracle Database 10g Express Edition Downloads',
#   'description': '',
#   'date': '2008-08-09 05:42:29',
#   'changeDate': '2008-08-09 05:42:29',
#   'url': 'http://www.oracle.com/technology/software/products/database/xe/index.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/e222625466630edb7edbb25336f5fae8/timo',
#   'text': 'Oracle Database 10g Express Edition Downloads'},
#  {'id': 'https://www.bibsonomy.org/url/86200db600735aa5fcc157ffc7d65f23/chato',
#   'tags': ['database', 'research'],
#   'label': 'CptS 451 Introduction to Database Systems Syllabus',
#   'description': '',
#   'date': '2005-04-22 09:34:51',
#   'changeDate': '2009-08-06 15:21:56',
#   'url': 'http://www.eecs.wsu.edu/~cdyreson/teaching/database/012/syllabus.htm',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/86200db600735aa5fcc157ffc7d65f23/chato',
#   'text': 'CptS 451 Introduction to Database Systems Syllabus'},
#  {'id': 'https://www.bibsonomy.org/url/07ae41123e358ec02f69e40749cff5c8/avivamagnolia',
#   'tags': ['fundamentals',
#    'database',
#    'tutorials',
#    'database+design',
#    'howto',
#    'database+key',
#    'databases',
#    'lessons'],
#   'label': 'Deep Thought |:| Basic Database Design',
#   'description': 'One of the most important things a database needs is a key, or more precisely a Primary Key. This is a unique identifier for a row and is needed to be able to access data in a table. In Core Data this is taken care of automatically, however you will have',
#   'date': '2006-12-25 01:44:50',
#   'changeDate': '2023-07-21 19:56:17',
#   'url': 'http://www.dtgeeks.com/features/tutorialview/basic_database_design/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/07ae41123e358ec02f69e40749cff5c8/avivamagnolia',
#   'text': 'Deep Thought |:| Basic Database Design'},
#  {'id': 'https://www.bibsonomy.org/url/07ae41123e358ec02f69e40749cff5c8/avivagabriel',
#   'tags': ['fundamentals',
#    'database',
#    'tutorials',
#    'database+design',
#    'howto',
#    'database+key',
#    'databases',
#    'lessons'],
#   'label': 'Deep Thought |:| Basic Database Design',
#   'description': 'One of the most important things a database needs is a key, or more precisely a Primary Key. This is a unique identifier for a row and is needed to be able to access data in a table. In Core Data this is taken care of automatically, however you will have',
#   'date': '2006-12-25 01:44:50',
#   'changeDate': '2007-08-08 07:52:21',
#   'url': 'http://www.dtgeeks.com/features/tutorialview/basic_database_design/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/07ae41123e358ec02f69e40749cff5c8/avivagabriel',
#   'text': 'Deep Thought |:| Basic Database Design'},
#  {'id': 'https://www.bibsonomy.org/url/277e5788501313bddd0bdedf6b92d48f/jaeschke',
#   'tags': ['barcode', 'database', 'webcam'],
#   'label': 'Barcodepedia.com - the online barcode database.',
#   'description': 'Barcodepedia is a community based online barcode database. The database is completely free to use, and everyone is welcome to contribute. Although it is possible to create a user on Barcodepedia, you can use the entire homepage without one.',
#   'date': '2009-08-10 13:24:15',
#   'changeDate': '2014-07-28 15:57:31',
#   'url': 'http://en.barcodepedia.com/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/277e5788501313bddd0bdedf6b92d48f/jaeschke',
#   'text': 'Barcodepedia.com - the online barcode database.'},
#  {'id': 'https://www.bibsonomy.org/url/763bfc55ab58a6981581d01e3fae34f3/lystrata',
#   'tags': ['database', 'postgresql', 'MySQL', 'design', 'dia'],
#   'label': 'UML database description tool',
#   'description': "What is tedia2sql? It is a tool that allows you to create a database ERD in Dia (using the UML shape toolset), then to convert that ERD into a SQL DDL script for multiple databases. Traditionally, to be able to do these things, you've needed to have a Wi",
#   'date': '2007-05-19 00:09:33',
#   'changeDate': '2010-02-20 02:11:37',
#   'url': 'http://tedia2sql.tigris.org/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/763bfc55ab58a6981581d01e3fae34f3/lystrata',
#   'text': 'UML database description tool'},
#  {'id': 'https://www.bibsonomy.org/url/ce7cde64ebe359a20f9bd07fa378fa41/shabbychef',
#   'tags': ['R', 'databases'],
#   'label': 'Database interfaces',
#   'description': '',
#   'date': '2015-05-21 15:50:35',
#   'changeDate': '2015-05-21 15:50:35',
#   'url': 'https://ropensci.org/blog/2015/05/20/database-interfaces/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/ce7cde64ebe359a20f9bd07fa378fa41/shabbychef',
#   'text': 'Database interfaces'},
#  {'id': 'https://www.bibsonomy.org/url/01631d558a2802af56234268b5058651/naufraghi',
#   'tags': ['database', 'python', 'persistence'],
#   'label': 'Cog: Simple Python Object Database',
#   'description': 'Cog is the Checkpointed Object Graph object database, providing semi-transparent persistence for large sets of interrelated Python objects.',
#   'date': '2006-06-17 16:32:36',
#   'changeDate': '2007-08-30 17:20:48',
#   'url': 'http://www.itamarst.org/software/cog/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/01631d558a2802af56234268b5058651/naufraghi',
#   'text': 'Cog: Simple Python Object Database'},
#  {'id': 'https://www.bibsonomy.org/url/3adc472c64aef0f93266e304ac75ed26/panic',
#   'tags': ['=O',
#    'WEB',
#    'Security',
#    'OpenSource',
#    'Search',
#    'Programming',
#    'Database'],
#   'label': 'OSVDB: The Open Source Vulnerability Database',
#   'description': 'an independent and open source database created by and for the community.',
#   'date': '2011-10-01 02:27:03',
#   'changeDate': '2019-04-13 14:30:01',
#   'url': 'http://www.osvdb.org/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/3adc472c64aef0f93266e304ac75ed26/panic',
#   'text': 'OSVDB: The Open Source Vulnerability Database'},
#  {'id': 'https://www.bibsonomy.org/url/7efa565900749e864c4ba6b734d937b0/jaj',
#   'tags': ['data', 'history'],
#   'label': 'The Trans-Atlantic Slave Trade SPSS Database (expanded data set)',
#   'description': 'The 2008 version of the Trans-Atlantic Slave Trade Database contains 8,374 voyages added since the CD-Rom was published in 1999 and additional information on 19,320 voyages. The expanded data set has 276 variables, compared with 99 in the Voyages Database available online.',
#   'date': '2012-09-07 04:04:51',
#   'changeDate': '2012-09-07 04:04:51',
#   'url': 'http://www.slavevoyages.org/tast/database/download.faces',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/7efa565900749e864c4ba6b734d937b0/jaj',
#   'text': 'The Trans-Atlantic Slave Trade SPSS Database (expanded data set)'},
#  {'id': 'https://www.bibsonomy.org/url/0dd7c1178d5d556a0f0a8f23c20d73f7/springnet',
#   'tags': ['pear', 'database', 'php', 'tutorial', 'mysql'],
#   'label': "Abstract PHP's database code with PEAR::DB | evolt.org",
#   'description': "Abstract PHP's database code with PEAR::DB",
#   'date': '2006-07-24 03:12:19',
#   'changeDate': '2008-06-29 17:50:42',
#   'url': 'http://www.evolt.org/article/Abstract_PHP_s_database_code_with_PEAR_DB/17/21927/index.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/0dd7c1178d5d556a0f0a8f23c20d73f7/springnet',
#   'text': "Abstract PHP's database code with PEAR::DB | evolt.org"},
#  {'id': 'https://www.bibsonomy.org/url/6194cea32ef9cdd8a356803884a6b9f5/analyst',
#   'tags': ['database', 'article', 'blog', 'programming'],
#   'label': 'The Not-So-Dark Art Of Designing Database Indexes: Reflections From An Average Software Engineer',
#   'description': 'Ben Nadel discusses database index design, including Primary and Secondary indexes, surrogate and natural keys, uniqueness constraints, foreign keys, covering indexes, and even cow-path paving. His hope here is write the article on database index design that he wishes he had had access to way earlier in his web development career.',
#   'date': '2018-07-09 12:15:06',
#   'changeDate': '2018-07-09 12:15:06',
#   'url': 'https://www.bennadel.com/blog/3467-the-not-so-dark-art-of-designing-database-indexes-reflections-from-an-average-software-engineer.htm',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/6194cea32ef9cdd8a356803884a6b9f5/analyst',
#   'text': 'The Not-So-Dark Art Of Designing Database Indexes: Reflections From An Average Software Engineer'},
#  {'id': 'https://www.bibsonomy.org/url/c4c66e2d1e9fe7233258c2e0265b3d49/dbenz',
#   'tags': ['bibliography', 'bst', 'database', 'styles', 'latex'],
#   'label': 'LaTeX Bibliography Styles Database :: Search',
#   'description': 'This database provides style files (bst and sty) for use with LaTeX documents using BibTeX or AMSrefs to manage the bibliography. The styles are referenced by the academic journals to which they apply. Search the database below or read the FAQ for more information. ',
#   'date': '2009-07-23 09:06:07',
#   'changeDate': '2013-07-31 15:39:42',
#   'url': 'http://bst.maururu.net/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/c4c66e2d1e9fe7233258c2e0265b3d49/dbenz',
#   'text': 'LaTeX Bibliography Styles Database :: Search'},
#  {'id': 'https://www.bibsonomy.org/url/ac91b008eabffd7762dd585a2553d45e/akpe',
#   'tags': ['tuning', 'WordPress', 'database', 'plug-in', 'wp'],
#   'label': 'rabich.de » HowTo: WordPress-Plugin “Database Tuning”',
#   'description': 'Viele Anwendungen wie auch WordPress basieren auf einer relationalen Datenbank. Bei WordPress ist dies MySQL. Eine Datenbank benötigt jedoch Pflege. Außerdem besteht hin und wieder der Wunsch, dass die eine oder andere Aktion etwas schneller verlaufen m',
#   'date': '2007-05-09 05:37:33',
#   'changeDate': '2011-03-14 16:42:51',
#   'url': 'http://www.rabich.de/2007/01/05/howto-plugin-database-tuning/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/ac91b008eabffd7762dd585a2553d45e/akpe',
#   'text': 'rabich.de » HowTo: WordPress-Plugin “Database Tuning”'},
#  {'id': 'https://www.bibsonomy.org/url/992fe15c55bdabe7200b8d783f05a21a/jil',
#   'tags': ['image', 'oracle', 'docker', 'volume', 'mount', 'points'],
#   'label': 'Oracle Database Oracle Database Enterprise Edition Installation Guide for Docker Containers, Release 21c For Oracle Linux x86-64',
#   'description': ' -v /opt/oracle/oradata\r\n                         The data volume that you want used for the database. Must be writable by the oracle user (uid: 54321) inside the container\r\n                         If omitted, then the database will not be persisted over container recreation.\r\n -v /opt/oracle/scripts/startup | /docker-entrypoint-initdb.d/startup\r\n                         Optional: A volume with custom scripts to be run after database startup.\r\n                         For further details see the section "Running scripts after setup and on\r\n                         startup" section below.\r\n -v /opt/oracle/scripts/setup | /docker-entrypoint-initdb.d/setup\r\n                         Optional: A volume with custom scripts that you want run after database setup.\r\n                         For further details see the "Running scripts after setup and on startup" section below.',
#   'date': '2024-12-03 17:19:02',
#   'changeDate': '2025-01-17 23:45:32',
#   'url': 'https://docs.oracle.com/en/database/oracle/oracle-database/21/deeck/index.html#GUID-6F97BC9A-15E5-4D59-B293-99D8605D9C85',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/992fe15c55bdabe7200b8d783f05a21a/jil',
#   'text': 'Oracle Database Oracle Database Enterprise Edition Installation Guide for Docker Containers, Release 21c For Oracle Linux x86-64'},
#  {'id': 'https://www.bibsonomy.org/url/d815e3ee7f89ba2a798b4de4d7e0ebd6/saberio',
#   'tags': ['world', 'database', 'protected', 'areas', 'wdpa'],
#   'label': 'World Database on Protected Areas (WDPA)',
#   'description': 'The World Database on Protected Areas (WDPA) provides the most comprehensive dataset on protected areas worldwide',
#   'date': '2013-09-13 12:49:17',
#   'changeDate': '2013-09-13 12:49:17',
#   'url': 'http://www.wdpa.org/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/d815e3ee7f89ba2a798b4de4d7e0ebd6/saberio',
#   'text': 'World Database on Protected Areas (WDPA)'},
#  {'id': 'https://www.bibsonomy.org/url/8826522dcfebe191bcfb7a50350c3b36/cupodmac',
#   'tags': ['database',
#    '.net',
#    'ado.net',
#    'programmieren',
#    'datenbank',
#    'c#',
#    'programming'],
#   'label': 'Using ADO.NET for beginners - The Code Project - C# Database',
#   'description': '',
#   'date': '2007-06-05 19:37:34',
#   'changeDate': '2007-06-05 19:37:34',
#   'url': 'http://www.codeproject.com/cs/database/DatabaseAcessWithAdoNet1.asp',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/8826522dcfebe191bcfb7a50350c3b36/cupodmac',
#   'text': 'Using ADO.NET for beginners - The Code Project - C# Database'},
#  {'id': 'https://www.bibsonomy.org/url/13681510a7e81febbecc547b68f9cc34/jganong',
#   'tags': ['database', 'functional', 'normalization', 'dependence'],
#   'label': 'Concepts of Database Design and Management [Server Side Essentials]',
#   'description': '',
#   'date': '2006-05-22 18:02:58',
#   'changeDate': '2008-09-26 01:23:14',
#   'url': 'http://www.sitepoint.com/article/database-design-management',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/13681510a7e81febbecc547b68f9cc34/jganong',
#   'text': 'Concepts of Database Design and Management [Server Side Essentials]'},
#  {'id': 'https://www.bibsonomy.org/url/839ed8a5467237628ce4efa117eb969e/pitman',
#   'tags': ['computer', 'databases'],
#   'label': 'Computer Database',
#   'description': 'Computer Database\r\n\r\nAvailable 24 hours a day via the Internet, Computer Database provides a combination of indexing, abstracts and full text for leading business and technical publications in the computer, telecommunications and electronic industries.',
#   'date': '2008-01-02 06:49:13',
#   'changeDate': '2008-01-13 02:44:44',
#   'url': 'http://www.galegroup.com/tlist/sb5087.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/839ed8a5467237628ce4efa117eb969e/pitman',
#   'text': 'Computer Database'},
#  {'id': 'https://www.bibsonomy.org/url/b75d3f6e7e2f4e3916bb2299d8508b2f/jaj',
#   'tags': ['news', 'database', 'journalism'],
#   'label': 'Columbia Journalism Review : The News Frontier Database',
# ...
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/6ce2229f94b7e3d92eeda8fbdda48313/brnvrn',
#   'text': 'Animated DataBase Courseware'},
#  {'id': 'https://www.bibsonomy.org/url/7deb33186b49c0af6daeade0b9189940/klagefall',
#   'tags': ['japan', 'archive'],
#   'label': 'Classical Japanese Database',
#   'description': 'Archiv über klassische japanische Texte',
#   'date': '2012-07-01 09:09:57',
#   'changeDate': '2012-07-02 15:21:04',
#   'url': 'http://carlsensei.com/classical/index.php/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/7deb33186b49c0af6daeade0b9189940/klagefall',
#   'text': 'Classical Japanese Database'},
#  {'id': 'https://www.bibsonomy.org/url/320387b2d49c4ee4193e58e7ab903d8b/panic',
#   'tags': ['WEB', 'Chemistry', 'Search', '[US]', 'Information'],
#   'label': 'Household Products Database',
#   'description': 'Health and Safety Information on Household Products',
#   'date': '2011-10-01 02:24:05',
#   'changeDate': '2011-10-01 02:27:38',
#   'url': 'http://hpd.nlm.nih.gov/index.htm',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/320387b2d49c4ee4193e58e7ab903d8b/panic',
#   'text': 'Household Products Database'},
#  {'id': 'https://www.bibsonomy.org/url/9a7050f23977cd8ed0210751c1a3f21d/jemfleming',
#   'tags': ["Diigo_-_Jem_Fleming's_Bookmarks"],
#   'label': 'Patent Searching Database',
#   'description': 'Silk Screen Patents: http://www.freepatentsonline.com/result.html?query_txt=silk+screen&sort=relevance&srch=top&search= :-D great!',
#   'date': '2011-10-08 17:39:37',
#   'changeDate': '2012-10-09 02:53:28',
#   'url': 'http://www.freepatentsonline.com/result.html?query_txt=silk+screen&sort=relevance&srch=top&search=',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/9a7050f23977cd8ed0210751c1a3f21d/jemfleming',
#   'text': 'Patent Searching Database'},
#  {'id': 'https://www.bibsonomy.org/url/364bdad077480f2d01cac974820262b1/braco',
#   'tags': ['natpisi-pretraživi', 'natpisi', 'inscriptions'],
#   'label': 'Epigraphic Database Heidelberg',
#   'description': '',
#   'date': '2012-12-12 15:18:39',
#   'changeDate': '2014-01-03 12:35:57',
#   'url': 'http://edh-www.adw.uni-heidelberg.de/home',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/364bdad077480f2d01cac974820262b1/braco',
#   'text': 'Epigraphic Database Heidelberg'},
#  {'id': 'https://www.bibsonomy.org/url/4d07e903fff49078c1d166a28dd0bd1e/sac',
#   'tags': ['schema', 'music', 'dataset', 'visualdb', 'dump', 'demo', 'sql'],
#   'label': 'Chinook Database - Home',
#   'description': 'The Chinook data model represents a digital media store, including tables for artists, albums, media tracks, invoices and customers. You can see the Chinook data model here. ',
#   'date': '2014-01-09 11:45:45',
#   'changeDate': '2014-01-09 11:45:45',
#   'url': 'http://chinookdatabase.codeplex.com/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/4d07e903fff49078c1d166a28dd0bd1e/sac',
#   'text': 'Chinook Database - Home'},
#  {'id': 'https://www.bibsonomy.org/url/8eb7ae49250bc1a95057163c382ecfb8/merlo',
#   'tags': ['Películas', 'Cine', 'Bases_de_datos'],
#   'label': 'Internet Movie Database',
#   'description': 'Base de datos de películas',
#   'date': '2015-05-04 21:56:37',
#   'changeDate': '2019-11-09 11:13:38',
#   'url': 'http://www.imdb.com/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/8eb7ae49250bc1a95057163c382ecfb8/merlo',
#   'text': 'Internet Movie Database'},
#  {'id': 'https://www.bibsonomy.org/url/b5c9387e49d422091a441a32b5061040/filologanoga',
#   'tags': ['lkkn', 'gaelic'],
#   'label': 'Bardic Poetry Database',
#   'description': '',
#   'date': '2016-01-25 00:25:59',
#   'changeDate': '2016-01-25 00:25:59',
#   'url': 'https://bardic.celt.dias.ie/displayPoem.php?firstLineID=1199',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/b5c9387e49d422091a441a32b5061040/filologanoga',
#   'text': 'Bardic Poetry Database'},
#  {'id': 'https://www.bibsonomy.org/url/e87cf5c48480cfff03747cdcf49928eb/danielle.dennie',
#   'tags': ['biochemistry', 'biology', 'chemistry', 'enzymes'],
#   'label': 'BRENDA: Enzyme Database',
#   'description': 'Free for academic use but registration is required (recognizes users within Concordia IP range). Contains data on the function of 3,500 enzymes with references to the literature',
#   'date': '2016-05-26 22:28:33',
#   'changeDate': '2016-05-27 17:05:04',
#   'url': 'http://www.brenda-enzymes.info/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/e87cf5c48480cfff03747cdcf49928eb/danielle.dennie',
#   'text': 'BRENDA: Enzyme Database'},
#  {'id': 'https://www.bibsonomy.org/url/4a77357ab027a89fdeade6e868ec40cc/robingarcia',
#   'tags': ['Unsortierte_Lesezeichen'],
#   'label': 'FFDN ISP Database',
#   'description': '',
#   'date': '2017-03-17 10:34:40',
#   'changeDate': '2017-04-13 09:58:43',
#   'url': 'https://db.ffdn.org/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/4a77357ab027a89fdeade6e868ec40cc/robingarcia',
#   'text': 'FFDN ISP Database'},
#  {'id': 'https://www.bibsonomy.org/url/1883ae5e6099d7fbcaa639b5805ebcc9/robingarcia',
#   'tags': ['Weitere_Lesezeichen'],
#   'label': 'Cell Cycle Database',
#   'description': '',
#   'date': '2017-03-17 10:35:04',
#   'changeDate': '2017-04-13 10:00:45',
#   'url': 'http://www.itb.cnr.it/cellcycle/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/1883ae5e6099d7fbcaa639b5805ebcc9/robingarcia',
#   'text': 'Cell Cycle Database'},
#  {'id': 'https://www.bibsonomy.org/url/ae2b8e1b002e3493ac038a84dc023ce9/vitelot',
#   'tags': ['Chrome', 'Bookmarks_Bar', 'mygames', 'Chess'],
#   'label': 'lichess.org game database',
#   'description': '',
#   'date': '2017-08-14 13:30:35',
#   'changeDate': '2017-08-14 13:43:37',
#   'url': 'https://database.lichess.org/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/ae2b8e1b002e3493ac038a84dc023ce9/vitelot',
#   'text': 'lichess.org game database'},
#  {'id': 'https://www.bibsonomy.org/url/cbf2f366bca1c195e191a70a4511a035/kclmel',
#   'tags': ['Canada', 'Genetics'],
#   'label': 'HumGen International - Database',
#   'description': 'Humgen, your resource concerning ethical, legal and social issues in human genetics',
#   'date': '2017-08-16 13:17:22',
#   'changeDate': '2017-08-16 13:17:22',
#   'url': 'http://www.humgen.umontreal.ca/int/index.cfm?lang=1',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/cbf2f366bca1c195e191a70a4511a035/kclmel',
#   'text': 'HumGen International - Database'},
#  {'id': 'https://www.bibsonomy.org/url/96caba2922cec93ace17225bfe3cce46/buch_jon',
#   'tags': ['final', 'thema:deepcnn_egg'],
#   'label': 'Sleep-EDF Database',
#   'description': '',
#   'date': '2020-06-08 18:22:28',
#   'changeDate': '2020-06-08 18:22:28',
#   'url': 'https://physionet.org/content/sleep-edf/1.0.0/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/96caba2922cec93ace17225bfe3cce46/buch_jon',
#   'text': 'Sleep-EDF Database'},
#  {'id': 'https://www.bibsonomy.org/url/5369817b790f8febfbda9051cd7cae0b/filologanoga',
#   'tags': ['italia', 'natpisi', 'renaissanceHumanism', 'epigraphica'],
#   'label': 'Epigraphic Database Falsae',
#   'description': 'Krivotvorine antičkih natpisa, zbirka',
#   'date': '2024-01-23 10:09:37',
#   'changeDate': '2024-01-23 10:09:37',
#   'url': 'https://edf.unive.it/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/5369817b790f8febfbda9051cd7cae0b/filologanoga',
#   'text': 'Epigraphic Database Falsae'},
#  {'id': 'https://www.bibsonomy.org/url/1a572d393a9dc6a04f627839a83d6bfe/lystrata',
#   'tags': ['semantic', 'rdf', 'database'],
#   'label': 'D2R Server – Publishing Relational Databases on the Semantic Web',
#   'description': 'Publishing Relational Databases on the Semantic Web',
#   'date': '2007-05-16 23:08:13',
#   'changeDate': '2010-02-20 02:11:37',
#   'url': 'http://sites.wiwiss.fu-berlin.de/suhl/bizer/d2r-server/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/1a572d393a9dc6a04f627839a83d6bfe/lystrata',
#   'text': 'D2R Server – Publishing Relational Databases on the Semantic Web'},
#  {'id': 'https://www.bibsonomy.org/url/6b45cc57da5435ac770a4bfb1a632055/domgabfil',
#   'tags': ['référence',
#    'mésopotamie',
#    'textes_en_ligne',
#    'archéologie',
#    'très_spécialisé',
#    'avant_400',
#    'bases_de_données'],
#   'label': 'The International Database of the Melammu Project - Assyrian and Babylonian Intellectual Heritage Project',
#   'description': 'Continuity of Mesopotamian culture throughout the ancient world from the second millennium BC until Islamic times - an electronic database collecting the relevant textual, art-historical, archaeological, ethnographic and linguistic evidence',
#   'date': '2010-12-17 17:39:57',
#   'changeDate': '2013-01-15 08:22:29',
#   'url': 'http://www.aakkl.helsinki.fi/melammu/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/6b45cc57da5435ac770a4bfb1a632055/domgabfil',
#   'text': 'The International Database of the Melammu Project - Assyrian and Babylonian Intellectual Heritage Project'},
#  {'id': 'https://www.bibsonomy.org/url/3c0ccda69f16e3429209eb23290a4412/danielle.dennie',
#   'tags': ['database', 'chemistry', 'free'],
#   'label': 'Sixty-Four Free Chemistry Databases',
#   'description': '',
#   'date': '2016-05-26 22:28:22',
#   'changeDate': '2016-05-27 17:05:04',
#   'url': 'http://zusammen.metamolecular.com/2009/03/09/sixty-four-free-chemistry-databases-serialized',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/3c0ccda69f16e3429209eb23290a4412/danielle.dennie',
#   'text': 'Sixty-Four Free Chemistry Databases'},
#  {'id': 'https://www.bibsonomy.org/url/9cb334924a33e084108406f50c727ec1/asterix',
#   'tags': ['software', 'fmri', 'research'],
#   'label': 'Nielsen ROI database',
#   'description': '',
#   'date': '2006-05-20 01:29:16',
#   'changeDate': '2006-05-20 01:29:16',
#   'url': 'http://hendrix.imm.dtu.dk/services/jerne/ninf/voi.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/9cb334924a33e084108406f50c727ec1/asterix',
#   'text': 'Nielsen ROI database'},
#  {'id': 'https://www.bibsonomy.org/url/cf8eedf7bda9157a9593027fb75069e9/pietrosperoni',
#   'tags': ['hack', 'wordpress', 'plugin', 'index'],
#   'label': 'WordPress Plugins Database',
#   'description': '',
#   'date': '2005-01-05 16:26:52',
#   'changeDate': '2009-01-07 08:09:00',
#   'url': 'http://www.wp-plugins.net/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/cf8eedf7bda9157a9593027fb75069e9/pietrosperoni',
#   'text': 'WordPress Plugins Database'},
#  {'id': 'https://www.bibsonomy.org/url/3376eb27742b19f9a5fcf995d909fffe/arnerichter',
#   'tags': ['web', 'culture', 'cyberpunk', 'theory'],
#   'label': 'Cyberpunk Information Database',
#   'description': '',
#   'date': '2006-12-05 15:52:24',
#   'changeDate': '2008-04-22 16:07:52',
#   'url': 'http://project.cyberpunk.ru/idb/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/3376eb27742b19f9a5fcf995d909fffe/arnerichter',
#   'text': 'Cyberpunk Information Database'},
#  {'id': 'https://www.bibsonomy.org/url/de97b5311e12dc3e730fb162303fbe1e/neilernst',
#   'tags': ['semantic', 'rdf'],
#   'label': 'Virtuoso Virtual Database',
#   'description': 'open-source db with RDF and SPARQL support',
#   'date': '2006-04-28 17:47:55',
#   'changeDate': '2006-04-28 17:47:55',
#   'url': 'http://virtuoso.openlinksw.com/overview/VOSRelease/index.htm',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/de97b5311e12dc3e730fb162303fbe1e/neilernst',
#   'text': 'Virtuoso Virtual Database'},
#  {'id': 'https://www.bibsonomy.org/url/ec16f754bf877a6c04528412e795d12e/canalsouk',
#   'tags': ['mysql'],
#   'label': 'Database dump progress',
#   'description': '',
#   'date': '2006-07-02 18:20:30',
#   'changeDate': '2006-07-02 18:20:30',
#   'url': 'http://download.wikimedia.org/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/ec16f754bf877a6c04528412e795d12e/canalsouk',
#   'text': 'Database dump progress'},
#  {'id': 'https://www.bibsonomy.org/url/9891210332beeb0306d70924b038d84b/jagbot',
#   'tags': ['plants'],
#   'label': 'Tropical Plant Database',
#   'description': '',
#   'date': '2005-03-01 03:30:05',
#   'changeDate': '2005-03-01 03:30:05',
#   'url': 'http://www.rain-tree.com/plist.htm',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/9891210332beeb0306d70924b038d84b/jagbot',
#   'text': 'Tropical Plant Database'},
#  {'id': 'https://www.bibsonomy.org/url/62ecc0c182d0239f1834362b2c61d96b/jil',
#   'tags': ['unicode', 'value', 'general', 'category'],
#   'label': 'Unicode Character Database',
#   'description': '',
#   'date': '2007-12-04 23:27:52',
#   'changeDate': '2025-01-17 23:45:32',
#   'url': 'http://unicode.org/Public/UNIDATA/UCD.html#General_Category_Values',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/62ecc0c182d0239f1834362b2c61d96b/jil',
#   'text': 'Unicode Character Database'},
#  {'id': 'https://www.bibsonomy.org/url/f5d3aea337e0624dc5ec7a17e6192baf/thomaslevine',
#   'tags': ['hardware', 'Linux'],
#   'label': 'Compatibility Database - Hardware',
#   'description': '',
#   'date': '2006-08-27 08:03:42',
#   'changeDate': '2007-12-22 10:33:27',
#   'url': 'http://www.linuxcompatible.org/compatlist3.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/f5d3aea337e0624dc5ec7a17e6192baf/thomaslevine',
#   'text': 'Compatibility Database - Hardware'},
#  {'id': 'https://www.bibsonomy.org/url/6bde5caa70056f143000e8389fada825/ageissler',
#   'tags': ['Datenbanken'],
#   'label': 'ROBERTIN-database - homepage',
#   'description': '',
#   'date': '2007-04-27 14:17:01',
#   'changeDate': '2008-01-16 12:55:02',
#   'url': 'http://robertin.altertum.uni-halle.de/index.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/6bde5caa70056f143000e8389fada825/ageissler',
#   'text': 'ROBERTIN-database - homepage'},
#  {'id': 'https://www.bibsonomy.org/url/bd5a219fd10a56b5b924653a1cbaed81/flimm',
#   'tags': ['feeds', 'wikipedia'],
#   'label': 'Database dump progress',
#   'description': 'dewiki',
#   'date': '2008-02-14 15:20:33',
#   'changeDate': '2008-02-14 15:20:33',
#   'url': 'http://dumps.wikimedia.org/backup-index.html',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/bd5a219fd10a56b5b924653a1cbaed81/flimm',
#   'text': 'Database dump progress'},
#  {'id': 'https://www.bibsonomy.org/url/e87cf5c48480cfff03747cdcf49928eb/jsicot',
#   'tags': ['ressources_electroniques_web', 'ressources_web'],
#   'label': 'Enzyme Database - BRENDA',
#   'description': 'BRENDA - The Comprehensive Enzyme Information System',
#   'date': '2007-09-03 08:45:33',
#   'changeDate': '2008-05-09 10:54:10',
#   'url': 'http://www.brenda-enzymes.info/',
#   'pub-type': nan,
#   'year': nan,
#   'author': nan,
#   'authors': nan,
#   'docno': 'https://www.bibsonomy.org/url/e87cf5c48480cfff03747cdcf49928eb/jsicot',
#   'text': 'Enzyme Database - BRENDA'},
#  ...]

# %%
index_folder_mult = "./index_mult"

fields=['docno', 'text', 'tags', 'description']

indexer_mult = pt.IterDictIndexer(index_folder_mult, meta={'docno': 200, 'text': 4096}, overwrite=True)
index_ref_mult = indexer_mult.index(df_dict)

print(f"path to our index: {index_ref_mult.toString()}")
# Out:
# 09:18:16.597 [ForkJoinPool-1-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (https://www.bibsonomy.org/url/45d7bb8eace077fe1f46f404529960f4/iblis) - further warnings are suppressed
# 09:18:16.975 [ForkJoinPool-1-worker-1] WARN org.terrier.structures.indexing.Indexer -- Indexed 4 empty documents
# path to our index: ./index_mult/data.properties

# %%
index_mult = pt.IndexFactory.of(index_ref_mult)

# %%
print(index_mult.getCollectionStatistics().toString())
# Out:
# Number of documents: 8000
# Number of terms: 8495
# Number of postings: 46900
# Number of fields: 1
# Number of tokens: 48683
# Field names: [text]
# Positions:   false

# %%
search_engine_mult = pt.terrier.Retriever(index_mult, wmodel="TF_IDF")

# %%
res = search_engine_mult.search("intelligence")
res
# Out:
#    qid  docid                                              docno  rank  \
# 0    1    119  https://www.bibsonomy.org/url/8f1fb00012322e81...     0
# 1    1   3009  https://www.bibsonomy.org/bibtex/21a61a34d4984...     1
# 2    1   3092  https://www.bibsonomy.org/bibtex/21a61a34d4984...     2
# 3    1   3667  https://www.bibsonomy.org/bibtex/2508ce3b4cfd8...     3
# 4    1   6244  https://www.bibsonomy.org/url/7e3b188d3277ff0c...     4
# 5    1   3407  https://www.bibsonomy.org/bibtex/2326beb667d4c...     5
# 6    1   3545  https://www.bibsonomy.org/bibtex/255165fc7f1f9...     6
# 7    1    573  https://www.bibsonomy.org/url/262cdca8951e45ec...     7
# 8    1   2796  https://www.bibsonomy.org/url/e94f2e8c95d6fd01...     8
# 9    1   3205  https://www.bibsonomy.org/bibtex/2934ad4d54596...     9
# 10   1   7461  https://www.bibsonomy.org/bibtex/2e3677666eee2...    10
# 11   1   1560  https://www.bibsonomy.org/bibtex/2a9aeedc023b8...    11
# 12   1   6997  https://www.bibsonomy.org/url/a63d1bffada91ede...    12
# 13   1   7743  https://www.bibsonomy.org/bibtex/20bd599a1d3e4...    13
# 14   1   7873  https://www.bibsonomy.org/bibtex/2eb29bdfaeb62...    14
# 15   1   1319  https://www.bibsonomy.org/bibtex/2e01c06213221...    15
# 16   1   1330  https://www.bibsonomy.org/bibtex/2e01c06213221...    16
# 17   1   3534  https://www.bibsonomy.org/bibtex/2a13a19576a30...    17
# 18   1   7839  https://www.bibsonomy.org/bibtex/28f08bb5a969f...    18
# 19   1   1191  https://www.bibsonomy.org/bibtex/24174ad281bc2...    19
# 20   1   4492  https://www.bibsonomy.org/url/ab0ffbd0949eb1a7...    20
# 21   1   4936  https://www.bibsonomy.org/url/e89e7e0680809e64...    21
# 22   1   7983  https://www.bibsonomy.org/bibtex/217e640a5e9c6...    22
# 23   1   1705  https://www.bibsonomy.org/bibtex/2dada3848a74e...    23
#
#        score         query
# 0   5.319447  intelligence
# 1   5.319447  intelligence
# 2   5.319447  intelligence
# 3   5.319447  intelligence
# 4   5.319447  intelligence
# 5   4.933700  intelligence
# 6   4.933700  intelligence
# 7   4.600116  intelligence
# 8   4.600116  intelligence
# 9   4.600116  intelligence
# 10  4.600116  intelligence
# 11  4.308785  intelligence
# 12  4.308785  intelligence
# 13  4.308785  intelligence
# 14  4.308785  intelligence
# 15  4.052157  intelligence
# 16  4.052157  intelligence
# 17  4.052157  intelligence
# 18  4.052157  intelligence
# 19  3.824379  intelligence
# 20  3.824379  intelligence
# 21  3.824379  intelligence
# 22  3.824379  intelligence
# 23  3.620847  intelligence

# %%
#save our data
pickle.dump(df_filtered, open("index_mult/df_publications.pkl", "wb"))

# %%
#install steamlit
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /opt/anaconda3/lib/python3.12/site-packages (1.37.1)
# Requirement already satisfied: altair<6,>=4.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in /opt/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
