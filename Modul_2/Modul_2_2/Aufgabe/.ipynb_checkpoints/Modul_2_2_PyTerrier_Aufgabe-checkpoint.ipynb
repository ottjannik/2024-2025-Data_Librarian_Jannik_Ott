# %%
import pyterrier as pt
import requests
import pandas as pd
import pickle
import nltk
import numpy as np
import json

# %%
df_filtered = pd.read_json('output.json')
df_filtered
# Out:
#                                                   title  \
# 0     EcoliNet: a database of cofunctional gene netw...
# 1     The drug-minded protein interaction database (...
# 2     PhosphoGRID: a database of experimentally veri...
# 3     GoSynthetic database tool to analyse natural a...
# 4                       Database for Mobile Application
# ...                                                 ...
# 3515  Faculty self-archiving behavior: Factors affec...
# 3516  Sensitivity and Access: Unlocking the Colonial...
# 3517  Online hot topic detection from web news archi...
# 3518  Serge Modular Archive Instrument (SMAI): Bridg...
# 3519  The peer-to-peer trace archive: design and com...
#
#                                                      id         type  \
# 0     https://www.bibsonomy.org/bibtex/2750b8770eec8...  Publication
# 1     https://www.bibsonomy.org/bibtex/2d93ac9b6cfa6...  Publication
# 2     https://www.bibsonomy.org/bibtex/233d3effaf95a...  Publication
# 3     https://www.bibsonomy.org/bibtex/2ca6461cce248...  Publication
# 4     https://www.bibsonomy.org/bibtex/2eb1605409b13...  Publication
# ...                                                 ...          ...
# 3515  https://www.bibsonomy.org/bibtex/2040f345d94cd...  Publication
# 3516  https://www.bibsonomy.org/bibtex/28217f4fe9f6a...  Publication
# 3517  https://www.bibsonomy.org/bibtex/29994ea45725f...  Publication
# 3518  https://www.bibsonomy.org/bibtex/2ee55445bc456...  Publication
# 3519  https://www.bibsonomy.org/bibtex/2dc534ef1b015...  Publication
#
#                                                     url  year  \
# 0             http://dx.doi.org/10.1093/database/bav001  2015
# 1             http://dx.doi.org/10.1093/database/baw041  2016
# 2             http://dx.doi.org/10.1093/database/bap026  2010
# 3             http://dx.doi.org/10.1093/database/bat043  2013
# 4     http://www.ijtsrd.com/computer-science/databas...  2018
# ...                                                 ...   ...
# 3515  http://dblp.uni-trier.de/db/conf/asist/asist20...  2007
# 3516  http://dblp.uni-trier.de/db/journals/dhq/dhq18...  2024
# 3517  http://dblp.uni-trier.de/db/conf/fskd/fskd2014...  2014
# 3518  http://dblp.uni-trier.de/db/conf/nime/nime2023...  2023
# 3519  http://dblp.uni-trier.de/db/conf/conext/sw2010...  2010
#
#                                                 authors  \
# 0     [Hanhae Kim, Jung Eun E. Shim, Junha Shin, Ins...
# 1     [Meik Kunz, Chunguang Liang, Santosh Nilla, Al...
# 2     [Chris Stark, Ting-Cheng C. Su, Ashton Breitkr...
# 3                    [C. Liang, B. Kruger, T. Dandekar]
# 4                      [Jasra Nisar Owais Noor Trumboo]
# ...                                                 ...
# 3515                                       [Jihyun Kim]
# 3516  [Jonathan Dentler, Lise Jaillant, Daniel Folia...
# 3517     [RuiGuo Yu, Mankun Zhao, Peng Chang, MuWen He]
# 3518                          [Ted Moore, Jean Brazeau]
# 3519  [Boxun Zhang, Alexandru Iosup, Johan Pouwelse,...
#
#                           doi     query      editor
# 0     10.1093/database/bav001  database  Jannik Ott
# 1     10.1093/database/baw041  database  Jannik Ott
# 2     10.1093/database/bap026  database  Jannik Ott
# 3     10.1093/database/bat043  database  Jannik Ott
# 4                        None  database  Jannik Ott
# ...                       ...       ...         ...
# 3515                     None   archive  Jannik Ott
# 3516                     None   archive  Jannik Ott
# 3517                     None   archive  Jannik Ott
# 3518                     None   archive  Jannik Ott
# 3519                     None   archive  Jannik Ott
#
# [3520 rows x 9 columns]

# %%
df_filtered.columns
# Out:
# Index(['title', 'id', 'type', 'url', 'year', 'authors', 'doi', 'query',
#        'editor'],
#       dtype='object')

# %%
#pyterrier exspects a docno field
df_filtered['docno'] = df_filtered['id']
df_filtered['text'] = df_filtered['title']

# %%
index_folder = "./df_index"

indexer = pt.DFIndexer(index_folder, overwrite=True)
index_ref = indexer.index(df_filtered['text'], df_filtered['docno'])

print(f"path to our index: {index_ref.toString()}")
# Out:
# /var/folders/88/9blsh45918g8y3n5vl6vztxr0000gq/T/ipykernel_1707/146072258.py:3: DeprecationWarning: Call to deprecated class DFIndexer. (use pt.terrier.IterDictIndexer().index(dataframe.to_dict(orient='records')) instead) -- Deprecated since version 0.11.0.
#   indexer = pt.DFIndexer(index_folder, overwrite=True)
# Java started (triggered by TerrierIndexer.__init__) and loaded: pyterrier.java, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]
# 09:33:52.066 [main] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (https://www.bibsonomy.org/bibtex/2998392ade6025286fed26bb09fc3dfc0/bibgreen) - further warnings are suppressed
# 09:33:52.467 [main] WARN org.terrier.structures.indexing.Indexer -- Indexed 2 empty documents
# path to our index: ./df_index/data.properties

# %%
index = pt.IndexFactory.of(index_ref)

# %%
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 3520
# Number of terms: 5030
# Number of postings: 23455
# Number of fields: 0
# Number of tokens: 24180
# Field names: []
# Positions:   false

# %%
for kv in index.getLexicon():
    print(f"{kv.getKey()} -> {kv.getValue().toString()}")
# Out:
# 0 -> term165 Nt=34 TF=39 maxTF=3 @{0 0 0}
# 000 -> term2348 Nt=2 TF=2 maxTF=1 @{0 49 1}
# 050 -> term1142 Nt=1 TF=1 maxTF=1 @{0 54 5}
# 06 -> term4159 Nt=1 TF=1 maxTF=1 @{0 56 7}
# 1 -> term219 Nt=20 TF=23 maxTF=2 @{0 59 7}
# 10 -> term3466 Nt=2 TF=2 maxTF=1 @{0 94 4}
# 100 -> term2346 Nt=2 TF=2 maxTF=1 @{0 100 0}
# 10g -> term1038 Nt=1 TF=1 maxTF=1 @{0 105 0}
# 11 -> term4230 Nt=2 TF=2 maxTF=1 @{0 107 2}
# 115th -> term1974 Nt=1 TF=1 maxTF=1 @{0 112 4}
# 12 -> term2533 Nt=1 TF=1 maxTF=1 @{0 115 0}
# 14 -> term4158 Nt=1 TF=1 maxTF=1 @{0 117 6}
# 140 -> term3046 Nt=1 TF=1 maxTF=1 @{0 120 6}
# 153 -> term579 Nt=1 TF=1 maxTF=1 @{0 123 4}
# 16 -> term4125 Nt=1 TF=1 maxTF=1 @{0 125 4}
# 16th -> term1602 Nt=1 TF=1 maxTF=1 @{0 128 4}
# 17 -> term4197 Nt=2 TF=2 maxTF=1 @{0 131 0}
# 18 -> term484 Nt=1 TF=1 maxTF=1 @{0 136 0}
# 1869 -> term4280 Nt=1 TF=1 maxTF=1 @{0 138 0}
# 1878 -> term4942 Nt=1 TF=1 maxTF=1 @{0 141 0}
# 19 -> term619 Nt=7 TF=8 maxTF=2 @{0 144 0}
# 1939 -> term4871 Nt=1 TF=1 maxTF=1 @{0 158 3}
# 1941 -> term4939 Nt=1 TF=1 maxTF=1 @{0 161 3}
# 1945 -> term4870 Nt=1 TF=1 maxTF=1 @{0 164 3}
# 1950 -> term2998 Nt=1 TF=1 maxTF=1 @{0 167 3}
# 1959 -> term3129 Nt=2 TF=2 maxTF=1 @{0 170 1}
# 1960 -> term4928 Nt=1 TF=1 maxTF=1 @{0 174 7}
# 1960er -> term4544 Nt=1 TF=1 maxTF=1 @{0 177 7}
# 1965 -> term3915 Nt=1 TF=1 maxTF=1 @{0 180 7}
# 1967 -> term3682 Nt=1 TF=1 maxTF=1 @{0 183 7}
# 1970 -> term2978 Nt=2 TF=2 maxTF=1 @{0 186 7}
# 1976 -> term3042 Nt=1 TF=1 maxTF=1 @{0 191 7}
# 1980er -> term4547 Nt=1 TF=1 maxTF=1 @{0 194 5}
# 1984 -> term3131 Nt=1 TF=1 maxTF=1 @{0 197 5}
# 1986 -> term4247 Nt=1 TF=1 maxTF=1 @{0 200 3}
# 1990 -> term2979 Nt=1 TF=1 maxTF=1 @{0 203 3}
# 1994 -> term2126 Nt=1 TF=1 maxTF=1 @{0 206 1}
# 1997 -> term1181 Nt=1 TF=1 maxTF=1 @{0 208 7}
# 1999 -> term3190 Nt=1 TF=1 maxTF=1 @{0 211 1}
# 1d -> term3488 Nt=1 TF=1 maxTF=1 @{0 213 7}
# 1st -> term3288 Nt=1 TF=1 maxTF=1 @{0 216 7}
# 2 -> term164 Nt=39 TF=40 maxTF=2 @{0 219 5}
# 20 -> term3744 Nt=2 TF=2 maxTF=1 @{0 277 0}
# 2000 -> term1076 Nt=7 TF=7 maxTF=1 @{0 282 2}
# 2001 -> term1221 Nt=2 TF=2 maxTF=1 @{0 297 6}
# 2002 -> term1492 Nt=1 TF=1 maxTF=1 @{0 303 0}
# 2003 -> term1635 Nt=1 TF=1 maxTF=1 @{0 305 4}
# 2004 -> term252 Nt=1 TF=1 maxTF=1 @{0 308 0}
# 2005 -> term256 Nt=2 TF=2 maxTF=1 @{0 309 6}
# 2006 -> term87 Nt=2 TF=2 maxTF=1 @{0 314 4}
# 2007 -> term3811 Nt=2 TF=2 maxTF=1 @{0 317 4}
# 2009 -> term181 Nt=3 TF=3 maxTF=1 @{0 322 2}
# 2010 -> term3361 Nt=2 TF=2 maxTF=1 @{0 328 6}
# 2011 -> term677 Nt=3 TF=3 maxTF=1 @{0 332 4}
# 2012 -> term2012 Nt=2 TF=2 maxTF=1 @{0 339 4}
# 2014 -> term3254 Nt=2 TF=2 maxTF=1 @{0 344 4}
# 2015 -> term1187 Nt=6 TF=6 maxTF=1 @{0 349 0}
# 2016 -> term1835 Nt=6 TF=6 maxTF=1 @{0 361 6}
# 2017 -> term1975 Nt=3 TF=5 maxTF=2 @{0 374 2}
# 2018 -> term816 Nt=6 TF=6 maxTF=1 @{0 382 2}
# 2019 -> term3308 Nt=8 TF=9 maxTF=2 @{0 396 0}
# 2020 -> term2808 Nt=2 TF=2 maxTF=1 @{0 408 5}
# 2021 -> term2784 Nt=4 TF=4 maxTF=1 @{0 414 1}
# 2022 -> term2807 Nt=2 TF=2 maxTF=1 @{0 423 3}
# 2030 -> term3082 Nt=9 TF=9 maxTF=1 @{0 427 5}
# 21 -> term4420 Nt=1 TF=1 maxTF=1 @{0 440 1}
# 21st -> term1760 Nt=7 TF=7 maxTF=1 @{0 443 1}
# 22 -> term2903 Nt=2 TF=2 maxTF=1 @{0 457 7}
# 24 -> term2902 Nt=1 TF=1 maxTF=1 @{0 463 3}
# 25 -> term3179 Nt=1 TF=1 maxTF=1 @{0 466 1}
# 256 -> term2465 Nt=1 TF=1 maxTF=1 @{0 468 7}
# 25th -> term1186 Nt=1 TF=1 maxTF=1 @{0 471 5}
# 28 -> term2120 Nt=1 TF=1 maxTF=1 @{0 473 7}
# 29 -> term3123 Nt=1 TF=1 maxTF=1 @{0 476 5}
# 2bibliometr -> term2822 Nt=1 TF=1 maxTF=1 @{0 479 3}
# 2d -> term1795 Nt=3 TF=3 maxTF=1 @{0 482 1}
# 2nd -> term1106 Nt=2 TF=2 maxTF=1 @{0 489 5}
# 3 -> term1147 Nt=5 TF=5 maxTF=1 @{0 494 5}
# 30 -> term3976 Nt=2 TF=2 maxTF=1 @{0 505 5}
# 33 -> term3920 Nt=1 TF=1 maxTF=1 @{0 510 7}
# 3cdb -> term1815 Nt=1 TF=1 maxTF=1 @{0 513 7}
# 3d -> term1177 Nt=18 TF=18 maxTF=1 @{0 516 3}
# 3rd -> term3420 Nt=1 TF=1 maxTF=1 @{0 549 1}
# 4 -> term1423 Nt=9 TF=9 maxTF=1 @{0 552 1}
# 40 -> term4378 Nt=1 TF=1 maxTF=1 @{0 569 5}
# 4586 -> term1973 Nt=1 TF=1 maxTF=1 @{0 572 5}
# 478 -> term3922 Nt=1 TF=1 maxTF=1 @{0 575 1}
# 484 -> term3921 Nt=1 TF=1 maxTF=1 @{0 578 1}
# 5 -> term1329 Nt=2 TF=2 maxTF=1 @{0 581 1}
# 50 -> term2758 Nt=3 TF=3 maxTF=1 @{0 586 3}
# 5th -> term596 Nt=1 TF=1 maxTF=1 @{0 594 1}
# 6 -> term1645 Nt=2 TF=2 maxTF=1 @{0 596 1}
# 7 -> term1644 Nt=3 TF=3 maxTF=1 @{0 601 5}
# 71 -> term3684 Nt=1 TF=1 maxTF=1 @{0 609 5}
# 76th -> term3540 Nt=1 TF=1 maxTF=1 @{0 612 5}
# 8 -> term2976 Nt=3 TF=3 maxTF=1 @{0 615 5}
# 82nd -> term3150 Nt=1 TF=1 maxTF=1 @{0 623 3}
# 8th -> term170 Nt=2 TF=2 maxTF=1 @{0 626 1}
# 9 -> term4641 Nt=1 TF=1 maxTF=1 @{0 630 3}
# a3 -> term2322 Nt=1 TF=1 maxTF=1 @{0 633 3}
# a4 -> term3971 Nt=1 TF=1 maxTF=1 @{0 636 1}
# aa2 -> term3326 Nt=1 TF=1 maxTF=1 @{0 639 1}
# aaai -> term4195 Nt=1 TF=1 maxTF=1 @{0 642 1}
# aagingbas -> term276 Nt=1 TF=1 maxTF=1 @{0 645 1}
# aatss -> term2096 Nt=1 TF=1 maxTF=1 @{0 646 7}
# ab52 -> term3328 Nt=1 TF=1 maxTF=1 @{0 649 3}
# abampdb -> term291 Nt=1 TF=1 maxTF=1 @{0 652 3}
# abbrevi -> term1159 Nt=1 TF=1 maxTF=1 @{0 654 1}
# abcdef -> term4630 Nt=1 TF=1 maxTF=1 @{0 656 3}
# abella -> term4688 Nt=1 TF=1 maxTF=1 @{0 659 3}
# abiot -> term1336 Nt=1 TF=1 maxTF=1 @{0 662 3}
# abschi -> term2548 Nt=1 TF=1 maxTF=1 @{0 664 7}
# abschluss -> term4395 Nt=1 TF=1 maxTF=1 @{0 667 5}
# absorpt -> term4121 Nt=1 TF=1 maxTF=1 @{0 670 5}
# abstract -> term1130 Nt=12 TF=12 maxTF=1 @{0 673 5}
# academ -> term732 Nt=58 TF=60 maxTF=3 @{0 695 5}
# academi -> term3192 Nt=1 TF=1 maxTF=1 @{0 760 1}
# academician -> term4327 Nt=1 TF=1 maxTF=1 @{0 762 7}
# acc -> term3705 Nt=1 TF=1 maxTF=1 @{0 765 7}
# acceler -> term434 Nt=4 TF=4 maxTF=1 @{0 768 7}
# accent -> term4927 Nt=1 TF=1 maxTF=1 @{0 776 7}
# access -> term104 Nt=60 TF=60 maxTF=1 @{0 779 7}
# accid -> term901 Nt=1 TF=1 maxTF=1 @{0 862 3}
# accident -> term2896 Nt=1 TF=1 maxTF=1 @{0 864 5}
# accord -> term3460 Nt=2 TF=2 maxTF=1 @{0 867 3}
# account -> term1397 Nt=1 TF=1 maxTF=1 @{0 872 5}
# accur -> term2720 Nt=1 TF=1 maxTF=1 @{0 875 1}
# accuraci -> term1937 Nt=3 TF=3 maxTF=1 @{0 877 7}
# acetobas -> term1908 Nt=1 TF=1 maxTF=1 @{0 885 1}
# achiev -> term3312 Nt=3 TF=3 maxTF=1 @{0 887 5}
# acid -> term610 Nt=5 TF=5 maxTF=1 @{0 895 3}
# acinetobact -> term295 Nt=2 TF=2 maxTF=1 @{0 906 3}
# acinetobas -> term325 Nt=1 TF=1 maxTF=1 @{0 909 1}
# acoust -> term331 Nt=2 TF=2 maxTF=1 @{0 910 7}
# acquir -> term2445 Nt=3 TF=3 maxTF=1 @{0 915 5}
# acquisit -> term2020 Nt=7 TF=7 maxTF=1 @{0 921 5}
# across -> term1566 Nt=5 TF=5 maxTF=1 @{0 936 7}
# act -> term1977 Nt=7 TF=7 maxTF=1 @{0 947 1}
# action -> term270 Nt=8 TF=8 maxTF=1 @{0 961 3}
# activ -> term542 Nt=23 TF=24 maxTF=2 @{0 976 1}
# acubert -> term1520 Nt=1 TF=1 maxTF=1 @{0 1015 0}
# acupunctur -> term1522 Nt=1 TF=1 maxTF=1 @{0 1017 4}
# ad -> term1581 Nt=3 TF=4 maxTF=2 @{0 1020 0}
# ada -> term4798 Nt=1 TF=1 maxTF=1 @{0 1027 1}
# adam -> term1160 Nt=1 TF=1 maxTF=1 @{0 1030 1}
# adapt -> term768 Nt=20 TF=20 maxTF=1 @{0 1032 3}
# add -> term3598 Nt=1 TF=1 maxTF=1 @{0 1068 5}
# addit -> term2645 Nt=1 TF=1 maxTF=1 @{0 1071 5}
# address -> term924 Nt=6 TF=6 maxTF=1 @{0 1074 3}
# addresse -> term2567 Nt=1 TF=1 maxTF=1 @{0 1088 1}
# adhyayana -> term2282 Nt=1 TF=1 maxTF=1 @{0 1090 7}
# aditi -> term1705 Nt=1 TF=1 maxTF=1 @{0 1093 5}
# administr -> term846 Nt=6 TF=6 maxTF=1 @{0 1096 1}
# ado -> term3933 Nt=1 TF=1 maxTF=1 @{0 1109 1}
# adolesc -> term2082 Nt=1 TF=1 maxTF=1 @{0 1112 1}
# adopt -> term377 Nt=3 TF=3 maxTF=1 @{0 1114 5}
# advanc -> term206 Nt=16 TF=16 maxTF=1 @{0 1121 5}
# advantag -> term2981 Nt=1 TF=1 maxTF=1 @{0 1150 5}
# adventur -> term2434 Nt=2 TF=2 maxTF=1 @{0 1153 3}
# advers -> term1518 Nt=1 TF=1 maxTF=1 @{0 1157 7}
# adversari -> term2057 Nt=5 TF=5 maxTF=1 @{0 1160 3}
# advertis -> term1988 Nt=3 TF=3 maxTF=1 @{0 1168 7}
# advic -> term2940 Nt=1 TF=1 maxTF=1 @{0 1176 3}
# advisori -> term2904 Nt=3 TF=3 maxTF=1 @{0 1179 1}
# advocaci -> term3408 Nt=1 TF=1 maxTF=1 @{0 1186 1}
# aerial -> term1592 Nt=1 TF=1 maxTF=1 @{0 1189 1}
# aerob -> term1951 Nt=1 TF=1 maxTF=1 @{0 1191 5}
# aesthet -> term3319 Nt=1 TF=1 maxTF=1 @{0 1194 1}
# affect -> term1756 Nt=3 TF=3 maxTF=1 @{0 1197 1}
# affili -> term3645 Nt=1 TF=1 maxTF=1 @{0 1205 1}
# afford -> term3378 Nt=1 TF=1 maxTF=1 @{0 1208 1}
# affymetrix -> term855 Nt=1 TF=1 maxTF=1 @{0 1211 1}
# afghan -> term4508 Nt=1 TF=1 maxTF=1 @{0 1213 3}
# africa -> term3356 Nt=3 TF=3 maxTF=1 @{0 1216 3}
# african -> term1316 Nt=2 TF=2 maxTF=1 @{0 1223 3}
# aftm -> term507 Nt=1 TF=1 maxTF=1 @{0 1228 7}
# ag -> term277 Nt=10 TF=11 maxTF=2 @{0 1230 7}
# agata -> term3531 Nt=1 TF=1 maxTF=1 @{0 1250 2}
# agbas -> term1890 Nt=1 TF=1 maxTF=1 @{0 1253 2}
# agbay -> term3870 Nt=1 TF=1 maxTF=1 @{0 1255 6}
# agbiodata -> term1018 Nt=1 TF=1 maxTF=1 @{0 1258 6}
# agd -> term1065 Nt=1 TF=1 maxTF=1 @{0 1261 0}
# ageid -> term1232 Nt=1 TF=1 maxTF=1 @{0 1263 2}
# agenc -> term1515 Nt=1 TF=1 maxTF=1 @{0 1265 4}
# agend -> term3774 Nt=1 TF=1 maxTF=1 @{0 1268 0}
# agenda -> term2537 Nt=5 TF=5 maxTF=1 @{0 1271 0}
# agendi -> term3940 Nt=1 TF=1 maxTF=1 @{0 1281 0}
# agent -> term1828 Nt=6 TF=6 maxTF=1 @{0 1284 0}
# ager -> term3435 Nt=1 TF=1 maxTF=1 @{0 1297 4}
# aggreg -> term1360 Nt=9 TF=9 maxTF=1 @{0 1300 4}
# agil -> term3491 Nt=2 TF=2 maxTF=1 @{0 1319 4}
# agodb -> term327 Nt=1 TF=1 maxTF=1 @{0 1323 0}
# agonist -> term2874 Nt=1 TF=1 maxTF=1 @{0 1324 6}
# agreement -> term3201 Nt=1 TF=1 maxTF=1 @{0 1327 4}
# agricultur -> term418 Nt=4 TF=4 maxTF=1 @{0 1330 2}
# agrosi -> term1262 Nt=1 TF=1 maxTF=1 @{0 1338 6}
# ahp -> term461 Nt=2 TF=2 maxTF=1 @{0 1341 0}
# ai -> term2847 Nt=3 TF=3 maxTF=1 @{0 1345 6}
# aid -> term1615 Nt=2 TF=2 maxTF=1 @{0 1353 2}
# aimedgraph -> term1424 Nt=1 TF=1 maxTF=1 @{0 1358 6}
# air -> term5009 Nt=1 TF=1 maxTF=1 @{0 1361 2}
# airborn -> term4839 Nt=1 TF=1 maxTF=1 @{0 1364 2}
# aircraft -> term3761 Nt=1 TF=1 maxTF=1 @{0 1367 2}
# ajax -> term3533 Nt=2 TF=2 maxTF=1 @{0 1370 2}
# akwukwo -> term3853 Nt=1 TF=1 maxTF=1 @{0 1376 0}
# al -> term703 Nt=4 TF=5 maxTF=2 @{0 1379 0}
# ala -> term3081 Nt=5 TF=5 maxTF=1 @{0 1387 3}
# alamo -> term1737 Nt=1 TF=1 maxTF=1 @{0 1398 3}
# alert -> term618 Nt=1 TF=1 maxTF=1 @{0 1400 7}
# alexandria -> term3640 Nt=2 TF=2 maxTF=1 @{0 1402 7}
# alexandrian -> term3692 Nt=1 TF=1 maxTF=1 @{0 1408 5}
# alexandrina -> term4223 Nt=1 TF=1 maxTF=1 @{0 1411 5}
# alexandrinu -> term4772 Nt=1 TF=1 maxTF=1 @{0 1414 5}
# algal -> term1719 Nt=1 TF=1 maxTF=1 @{0 1417 5}
# algebra -> term1698 Nt=1 TF=1 maxTF=1 @{0 1420 1}
# algorithm -> term41 Nt=72 TF=73 maxTF=2 @{0 1422 5}
# algorithmen -> term2006 Nt=3 TF=3 maxTF=1 @{0 1505 4}
# algoritm -> term4998 Nt=1 TF=1 maxTF=1 @{0 1512 0}
# alic -> term3177 Nt=1 TF=1 maxTF=1 @{0 1515 0}
# align -> term370 Nt=9 TF=9 maxTF=1 @{0 1517 6}
# all -> term3787 Nt=1 TF=1 maxTF=1 @{0 1536 0}
# alla -> term3726 Nt=2 TF=2 maxTF=1 @{0 1539 0}
# allama -> term3659 Nt=1 TF=1 maxTF=1 @{0 1544 4}
# allgemein -> term4826 Nt=2 TF=2 maxTF=1 @{0 1547 4}
# allianc -> term4073 Nt=1 TF=1 maxTF=1 @{0 1552 0}
# alloc -> term3764 Nt=1 TF=1 maxTF=1 @{0 1555 0}
# allow -> term977 Nt=2 TF=2 maxTF=1 @{0 1558 0}
# alltheweb -> term4306 Nt=1 TF=1 maxTF=1 @{0 1563 0}
# alon -> term1313 Nt=2 TF=2 maxTF=1 @{0 1566 0}
# alpha -> term728 Nt=1 TF=1 maxTF=1 @{0 1571 2}
# alphab -> term4768 Nt=1 TF=1 maxTF=1 @{0 1573 2}
# alphafold -> term509 Nt=1 TF=1 maxTF=1 @{0 1576 2}
# alphamissens -> term1452 Nt=1 TF=1 maxTF=1 @{0 1578 2}
# alten -> term4921 Nt=1 TF=1 maxTF=1 @{0 1580 6}
# altern -> term1008 Nt=6 TF=6 maxTF=1 @{0 1583 6}
# altmann -> term2531 Nt=1 TF=1 maxTF=1 @{0 1597 0}
# altregistratur -> term4405 Nt=1 TF=1 maxTF=1 @{0 1599 6}
# altsiedellandschaft -> term5021 Nt=1 TF=1 maxTF=1 @{0 1602 6}
# alzheim -> term1580 Nt=1 TF=1 maxTF=1 @{0 1605 6}
# am -> term4359 Nt=2 TF=2 maxTF=1 @{0 1608 2}
# amass -> term4528 Nt=2 TF=2 maxTF=1 @{0 1613 6}
# amaz -> term3015 Nt=1 TF=1 maxTF=1 @{0 1618 2}
# ambigu -> term1596 Nt=1 TF=1 maxTF=1 @{0 1621 0}
# america -> term3114 Nt=2 TF=2 maxTF=1 @{0 1623 4}
# american -> term2830 Nt=9 TF=9 maxTF=1 @{0 1628 6}
# amg -> term3712 Nt=1 TF=1 maxTF=1 @{0 1646 4}
# amga -> term5003 Nt=1 TF=1 maxTF=1 @{0 1649 4}
# amgcl -> term3710 Nt=1 TF=1 maxTF=1 @{0 1652 4}
# amh -> term4543 Nt=1 TF=1 maxTF=1 @{0 1655 4}
# amino -> term1332 Nt=1 TF=1 maxTF=1 @{0 1658 4}
# aminobutyr -> term1477 Nt=1 TF=1 maxTF=1 @{0 1661 0}
# amr -> term2328 Nt=1 TF=1 maxTF=1 @{0 1663 4}
# amsterdam -> term3107 Nt=1 TF=1 maxTF=1 @{0 1666 2}
# analog -> term3887 Nt=2 TF=2 maxTF=1 @{0 1669 0}
# analys -> term32 Nt=6 TF=6 maxTF=1 @{0 1674 4}
# analysi -> term13 Nt=139 TF=141 maxTF=2 @{0 1685 6}
# analysieren -> term2676 Nt=1 TF=1 maxTF=1 @{0 1841 0}
# analyst -> term2028 Nt=1 TF=1 maxTF=1 @{0 1843 6}
# analyt -> term1059 Nt=15 TF=15 maxTF=1 @{0 1846 2}
# analyz -> term1334 Nt=12 TF=12 maxTF=1 @{0 1873 4}
# anambra -> term930 Nt=1 TF=1 maxTF=1 @{0 1896 2}
# anaphora -> term1922 Nt=1 TF=1 maxTF=1 @{0 1898 4}
# anatomi -> term2236 Nt=1 TF=1 maxTF=1 @{0 1901 0}
# ancestri -> term1612 Nt=1 TF=1 maxTF=1 @{0 1903 6}
# anchor -> term2106 Nt=5 TF=5 maxTF=1 @{0 1906 2}
# ancient -> term1561 Nt=2 TF=2 maxTF=1 @{0 1915 6}
# anderen -> term4021 Nt=1 TF=1 maxTF=1 @{0 1921 2}
# andexperiment -> term3514 Nt=1 TF=1 maxTF=1 @{0 1924 2}
# andrei -> term4326 Nt=1 TF=1 maxTF=1 @{0 1927 2}
# android -> term2275 Nt=3 TF=3 maxTF=1 @{0 1930 2}
# anemia -> term1613 Nt=1 TF=1 maxTF=1 @{0 1938 2}
# anerbc -> term1616 Nt=1 TF=1 maxTF=1 @{0 1940 6}
# aneurysm -> term1066 Nt=1 TF=1 maxTF=1 @{0 1943 2}
# angebot -> term4058 Nt=1 TF=1 maxTF=1 @{0 1945 4}
# angl -> term3740 Nt=1 TF=1 maxTF=1 @{0 1948 4}
# ani -> term4413 Nt=1 TF=1 maxTF=1 @{0 1951 4}
# anim -> term756 Nt=6 TF=6 maxTF=1 @{0 1954 4}
# annif -> term2747 Nt=1 TF=1 maxTF=1 @{0 1967 2}
# annot -> term69 Nt=45 TF=45 maxTF=1 @{0 1970 0}
# annual -> term1601 Nt=3 TF=3 maxTF=1 @{0 2030 4}
# ano -> term3849 Nt=1 TF=1 maxTF=1 @{0 2037 0}
# anpassbarkeit -> term4904 Nt=1 TF=1 maxTF=1 @{0 2040 0}
# answer -> term1216 Nt=9 TF=10 maxTF=2 @{0 2043 0}
# antaeu -> term3507 Nt=1 TF=1 maxTF=1 @{0 2060 3}
# anthropolog -> term5007 Nt=1 TF=1 maxTF=1 @{0 2063 3}
# anthropologist -> term3609 Nt=1 TF=1 maxTF=1 @{0 2066 3}
# anti -> term278 Nt=3 TF=3 maxTF=1 @{0 2069 3}
# antibiot -> term1331 Nt=1 TF=1 maxTF=1 @{0 2076 3}
# antibodi -> term3325 Nt=2 TF=2 maxTF=1 @{0 2078 7}
# anticanc -> term602 Nt=1 TF=1 maxTF=1 @{0 2084 1}
# antigen -> term3322 Nt=1 TF=1 maxTF=1 @{0 2086 1}
# antik -> term2190 Nt=1 TF=1 maxTF=1 @{0 2089 1}
# antimicrobi -> term292 Nt=4 TF=4 maxTF=1 @{0 2091 7}
# antiqu -> term3689 Nt=2 TF=2 maxTF=1 @{0 2099 5}
# anwendungen -> term1848 Nt=1 TF=1 maxTF=1 @{0 2105 1}
# anxieti -> term3658 Nt=1 TF=1 maxTF=1 @{0 2107 5}
# aop -> term3273 Nt=1 TF=1 maxTF=1 @{0 2110 5}
# aortic -> term1307 Nt=1 TF=1 maxTF=1 @{0 2113 3}
# ap -> term4139 Nt=1 TF=1 maxTF=1 @{0 2115 5}
# apach -> term1053 Nt=1 TF=1 maxTF=1 @{0 2118 5}
# apachebench -> term4830 Nt=2 TF=2 maxTF=1 @{0 2120 7}
# apadb -> term1809 Nt=1 TF=1 maxTF=1 @{0 2125 3}
# apd -> term1948 Nt=1 TF=1 maxTF=1 @{0 2127 7}
# api -> term1490 Nt=4 TF=5 maxTF=2 @{0 2130 3}
# apollo -> term4194 Nt=1 TF=1 maxTF=1 @{0 2138 6}
# apostolico -> term4168 Nt=1 TF=1 maxTF=1 @{0 2141 6}
# app -> term1800 Nt=5 TF=6 maxTF=2 @{0 2144 6}
# append -> term4962 Nt=1 TF=1 maxTF=1 @{0 2156 3}
# appli -> term1629 Nt=6 TF=6 maxTF=1 @{0 2159 3}
# applic -> term33 Nt=61 TF=61 maxTF=1 @{0 2171 1}
# apprais -> term1488 Nt=3 TF=3 maxTF=1 @{0 2250 7}
# appreci -> term2781 Nt=1 TF=1 maxTF=1 @{0 2257 1}
# apprentic -> term3457 Nt=1 TF=1 maxTF=1 @{0 2259 7}
# approach -> term656 Nt=78 TF=78 maxTF=1 @{0 2262 7}
# approxim -> term2699 Nt=3 TF=3 maxTF=1 @{0 2363 5}
# april -> term2905 Nt=1 TF=1 maxTF=1 @{0 2371 3}
# aptam -> term386 Nt=1 TF=1 maxTF=1 @{0 2374 1}
# aquat -> term4791 Nt=1 TF=1 maxTF=1 @{0 2375 7}
# aqueou -> term460 Nt=1 TF=1 maxTF=1 @{0 2378 7}
# ar -> term4520 Nt=1 TF=1 maxTF=1 @{0 2380 7}
# arab -> term2095 Nt=4 TF=4 maxTF=1 @{0 2383 7}
# arabidopsi -> term246 Nt=2 TF=2 maxTF=1 @{0 2392 7}
# aral -> term4310 Nt=1 TF=1 maxTF=1 @{0 2396 3}
# arbitrari -> term2588 Nt=1 TF=1 maxTF=1 @{0 2399 3}
# arbitrarili -> term2050 Nt=1 TF=1 maxTF=1 @{0 2402 1}
# arc -> term2285 Nt=2 TF=2 maxTF=1 @{0 2404 5}
# arch -> term4629 Nt=1 TF=1 maxTF=1 @{0 2410 3}
# arch2 -> term4924 Nt=1 TF=1 maxTF=1 @{0 2413 3}
# archaeogam -> term4435 Nt=1 TF=1 maxTF=1 @{0 2416 3}
# archaeolog -> term4007 Nt=2 TF=2 maxTF=1 @{0 2419 3}
# archetyp -> term4763 Nt=1 TF=1 maxTF=1 @{0 2424 7}
# archi -> term1662 Nt=1 TF=1 maxTF=1 @{0 2427 7}
# archimed -> term4319 Nt=2 TF=2 maxTF=1 @{0 2430 3}
# architectur -> term1101 Nt=28 TF=28 maxTF=1 @{0 2435 7}
# archiv -> term777 Nt=857 TF=893 maxTF=4 @{0 2479 7}
# archivdienst -> term4388 Nt=1 TF=1 maxTF=1 @{0 2733 5}
# archivefilm -> term4741 Nt=1 TF=1 maxTF=1 @{0 2736 5}
# archiven -> term4112 Nt=1 TF=1 maxTF=1 @{0 2739 5}
# archivenow -> term4305 Nt=1 TF=1 maxTF=1 @{0 2742 5}
# archivespark -> term4055 Nt=3 TF=3 maxTF=1 @{0 2745 5}
# archiveweb -> term4068 Nt=5 TF=5 maxTF=1 @{0 2752 1}
# archivio -> term4172 Nt=2 TF=2 maxTF=1 @{0 2760 3}
# archivist -> term4075 Nt=1 TF=1 maxTF=1 @{0 2765 5}
# archivo -> term4498 Nt=2 TF=2 maxTF=1 @{0 2768 5}
# archivportal -> term4056 Nt=1 TF=1 maxTF=1 @{0 2773 7}
# archivschul -> term4385 Nt=1 TF=1 maxTF=1 @{0 2776 7}
# arcp -> term4449 Nt=1 TF=1 maxTF=1 @{0 2779 7}
# ardo -> term4781 Nt=2 TF=2 maxTF=1 @{0 2782 7}
# arduino -> term736 Nt=2 TF=2 maxTF=1 @{0 2786 3}
# area -> term1259 Nt=4 TF=4 maxTF=1 @{0 2790 7}
# aren -> term2532 Nt=2 TF=2 maxTF=1 @{0 2801 1}
# argania -> term709 Nt=1 TF=1 maxTF=1 @{0 2806 5}
# argonaut -> term130 Nt=2 TF=2 maxTF=1 @{0 2808 5}
# arhiva -> term4082 Nt=2 TF=2 maxTF=1 @{0 2811 5}
# arhivu -> term4638 Nt=2 TF=2 maxTF=1 @{0 2817 1}
# aristotl -> term3368 Nt=1 TF=1 maxTF=1 @{0 2821 1}
# arithmet -> term2129 Nt=1 TF=1 maxTF=1 @{0 2824 1}
# arizona -> term3237 Nt=1 TF=1 maxTF=1 @{0 2826 7}
# armstrong -> term3252 Nt=1 TF=1 maxTF=1 @{0 2829 5}
# arno -> term2246 Nt=1 TF=1 maxTF=1 @{0 2832 3}
# aromadeg -> term1954 Nt=1 TF=1 maxTF=1 @{0 2835 1}
# aromat -> term1952 Nt=1 TF=1 maxTF=1 @{0 2837 5}
# arrai -> term1500 Nt=2 TF=2 maxTF=1 @{0 2840 1}
# arrang -> term3914 Nt=1 TF=1 maxTF=1 @{0 2844 5}
# arrayexpress -> term1692 Nt=1 TF=1 maxTF=1 @{0 2847 5}
# art -> term2182 Nt=16 TF=16 maxTF=1 @{0 2850 1}
# artdoc -> term4851 Nt=1 TF=1 maxTF=1 @{0 2879 7}
# arteri -> term2030 Nt=1 TF=1 maxTF=1 @{0 2882 7}
# articl -> term1539 Nt=13 TF=14 maxTF=2 @{0 2885 3}
# artifact -> term4296 Nt=2 TF=2 maxTF=1 @{0 2911 6}
# artifici -> term1589 Nt=6 TF=6 maxTF=1 @{0 2916 4}
# artist -> term2661 Nt=8 TF=8 maxTF=1 @{0 2930 6}
# aruba -> term3590 Nt=1 TF=1 maxTF=1 @{0 2945 2}
# ascertain -> term443 Nt=1 TF=1 maxTF=1 @{0 2948 2}
# ascii -> term2452 Nt=1 TF=1 maxTF=1 @{0 2950 0}
# ascla -> term3409 Nt=1 TF=1 maxTF=1 @{0 2952 6}
# ashra -> term3049 Nt=1 TF=1 maxTF=1 @{0 2955 6}
# asia -> term4333 Nt=1 TF=1 maxTF=1 @{0 2958 4}
# asian -> term1680 Nt=2 TF=2 maxTF=1 @{0 2961 4}
# ask -> term2038 Nt=1 TF=1 maxTF=1 @{0 2966 6}
# aspect -> term1628 Nt=5 TF=5 maxTF=1 @{0 2969 2}
# aspekt -> term2270 Nt=1 TF=1 maxTF=1 @{0 2981 2}
# assai -> term1889 Nt=1 TF=1 maxTF=1 @{0 2984 0}
# assembl -> term283 Nt=2 TF=2 maxTF=1 @{0 2986 4}
# assess -> term1236 Nt=17 TF=17 maxTF=1 @{0 2991 2}
# assign -> term2664 Nt=1 TF=1 maxTF=1 @{0 3022 0}
# assist -> term1956 Nt=9 TF=10 maxTF=2 @{0 3024 6}
# associ -> term139 Nt=33 TF=33 maxTF=1 @{0 3042 7}
# asssrdb -> term711 Nt=1 TF=1 maxTF=1 @{0 3090 1}
# assumpt -> term58 Nt=1 TF=1 maxTF=1 @{0 3092 1}
# astrocyt -> term1708 Nt=1 TF=1 maxTF=1 @{0 3093 1}
# astronom -> term4966 Nt=1 TF=1 maxTF=1 @{0 3095 5}
# astronomi -> term3568 Nt=2 TF=2 maxTF=1 @{0 3098 5}
# astrophys -> term2843 Nt=1 TF=1 maxTF=1 @{0 3104 1}
# atc -> term1404 Nt=1 TF=1 maxTF=1 @{0 3106 7}
# atena -> term4794 Nt=1 TF=1 maxTF=1 @{0 3109 3}
# athen -> term3311 Nt=7 TF=7 maxTF=1 @{0 3112 3}
# athena -> term1102 Nt=1 TF=1 maxTF=1 @{0 3123 7}
# athenaeum -> term4827 Nt=2 TF=2 maxTF=1 @{0 3126 1}
# atherosclerot -> term1552 Nt=1 TF=1 maxTF=1 @{0 3130 5}
# athisomirdb -> term247 Nt=1 TF=1 maxTF=1 @{0 3133 1}
# athribonc -> term473 Nt=1 TF=1 maxTF=1 @{0 3134 7}
# atla -> term287 Nt=5 TF=5 maxTF=1 @{0 3136 7}
# atm23 -> term4348 Nt=1 TF=1 maxTF=1 @{0 3147 3}
# atmospher -> term3147 Nt=2 TF=2 maxTF=1 @{0 3150 3}
# atomist -> term882 Nt=1 TF=1 maxTF=1 @{0 3155 7}
# att -> term2963 Nt=2 TF=2 maxTF=1 @{0 3158 1}
# attack -> term884 Nt=2 TF=2 maxTF=1 @{0 3163 3}
# attend -> term739 Nt=2 TF=2 maxTF=1 @{0 3168 3}
# attent -> term2493 Nt=3 TF=3 maxTF=1 @{0 3173 1}
# attitud -> term3271 Nt=3 TF=3 maxTF=1 @{0 3179 5}
# attribut -> term2539 Nt=2 TF=2 maxTF=1 @{0 3185 5}
# au -> term3911 Nt=3 TF=3 maxTF=1 @{0 3189 7}
# auc -> term2214 Nt=1 TF=1 maxTF=1 @{0 3197 1}
# auctoribu -> term4282 Nt=1 TF=1 maxTF=1 @{0 3199 7}
# audio -> term2053 Nt=10 TF=10 maxTF=1 @{0 3202 7}
# audioclip -> term2398 Nt=1 TF=1 maxTF=1 @{0 3223 1}
# audiovisu -> term3698 Nt=5 TF=5 maxTF=1 @{0 3225 7}
# audit -> term38 Nt=4 TF=4 maxTF=1 @{0 3237 1}
# auf -> term2435 Nt=6 TF=6 maxTF=1 @{0 3244 5}
# aufgaben -> term4400 Nt=1 TF=1 maxTF=1 @{0 3258 5}
# aug -> term2118 Nt=1 TF=1 maxTF=1 @{0 3261 5}
# augment -> term1434 Nt=9 TF=9 maxTF=1 @{0 3264 3}
# ausgab -> term2009 Nt=1 TF=1 maxTF=1 @{0 3283 3}
# austin -> term3338 Nt=1 TF=1 maxTF=1 @{0 3285 7}
# australia -> term4517 Nt=1 TF=1 maxTF=1 @{0 3288 7}
# australian -> term761 Nt=4 TF=4 maxTF=1 @{0 3291 7}
# austrian -> term1251 Nt=2 TF=2 maxTF=1 @{0 3301 3}
# author -> term1021 Nt=12 TF=12 maxTF=1 @{0 3306 5}
# authorship -> term2225 Nt=1 TF=1 maxTF=1 @{0 3331 1}
# auto -> term621 Nt=1 TF=1 maxTF=1 @{0 3333 7}
# autoimmun -> term1606 Nt=1 TF=1 maxTF=1 @{0 3335 7}
# autoinhibit -> term194 Nt=1 TF=2 maxTF=2 @{0 3338 3}
# autoinhibitori -> term191 Nt=1 TF=1 maxTF=1 @{0 3340 0}
# autom -> term517 Nt=41 TF=41 maxTF=1 @{0 3341 4}
# automat -> term313 Nt=56 TF=56 maxTF=1 @{0 3397 2}
# automatiqu -> term4626 Nt=1 TF=1 maxTF=1 @{0 3471 0}
# automobil -> term4176 Nt=1 TF=1 maxTF=1 @{0 3474 0}
# autonom -> term90 Nt=3 TF=3 maxTF=1 @{0 3477 0}
# autophagi -> term225 Nt=1 TF=1 maxTF=1 @{0 3483 2}
# autophagy3d -> term224 Nt=1 TF=1 maxTF=1 @{0 3484 6}
# autor -> term2193 Nt=1 TF=1 maxTF=1 @{0 3486 2}
# autoregress -> term4996 Nt=1 TF=1 maxTF=1 @{0 3489 0}
# autoren -> term2191 Nt=1 TF=1 maxTF=1 @{0 3492 0}
# avail -> term866 Nt=3 TF=3 maxTF=1 @{0 3494 6}
# avanju -> term4944 Nt=1 TF=1 maxTF=1 @{0 3501 4}
# avenu -> term4844 Nt=1 TF=1 maxTF=1 @{0 3504 4}
# averag -> term2232 Nt=1 TF=1 maxTF=1 @{0 3507 4}
# avoid -> term718 Nt=2 TF=2 maxTF=1 @{0 3510 2}
# aw -> term3842 Nt=1 TF=1 maxTF=1 @{0 3515 0}
# awar -> term156 Nt=8 TF=8 maxTF=1 @{0 3518 0}
# award -> term2960 Nt=7 TF=7 maxTF=1 @{0 3533 6}
# ba -> term2969 Nt=2 TF=2 maxTF=1 @{0 3545 6}
# baafila -> term3800 Nt=1 TF=1 maxTF=1 @{0 3551 0}
# babel -> term3478 Nt=2 TF=2 maxTF=1 @{0 3554 0}
# bacillu -> term908 Nt=2 TF=2 maxTF=1 @{0 3559 0}
# bacillusregnet -> term1746 Nt=1 TF=1 maxTF=1 @{0 3563 4}
# back -> term2887 Nt=4 TF=4 maxTF=1 @{0 3566 0}
# backend -> term1034 Nt=1 TF=1 maxTF=1 @{0 3573 6}
# background -> term2222 Nt=4 TF=4 maxTF=1 @{0 3576 0}
# backup -> term55 Nt=4 TF=4 maxTF=1 @{0 3584 2}
# backward -> term3132 Nt=1 TF=1 maxTF=1 @{0 3592 0}
# bacsoft -> term4521 Nt=1 TF=1 maxTF=1 @{0 3594 6}
# bacteri -> term215 Nt=5 TF=5 maxTF=1 @{0 3597 6}
# bacteria -> term613 Nt=3 TF=3 maxTF=1 @{0 3608 6}
# badg -> term3128 Nt=1 TF=1 maxTF=1 @{0 3616 0}
# bag -> term1998 Nt=2 TF=2 maxTF=1 @{0 3618 6}
# baker -> term2654 Nt=1 TF=1 maxTF=1 @{0 3623 2}
# balanc -> term3983 Nt=2 TF=2 maxTF=1 @{0 3626 0}
# banfield -> term3923 Nt=1 TF=1 maxTF=1 @{0 3631 4}
# bangkok -> term3585 Nt=1 TF=1 maxTF=1 @{0 3634 4}
# bank -> term4052 Nt=3 TF=3 maxTF=1 @{0 3637 4}
# banner -> term1989 Nt=1 TF=1 maxTF=1 @{0 3645 0}
# barcelona -> term3463 Nt=1 TF=1 maxTF=1 @{0 3647 4}
# barcod -> term488 Nt=2 TF=2 maxTF=1 @{0 3650 4}
# barlei -> term1465 Nt=1 TF=1 maxTF=1 @{0 3655 4}
# barleyvardb -> term1464 Nt=1 TF=1 maxTF=1 @{0 3658 0}
# barrier -> term3760 Nt=2 TF=2 maxTF=1 @{0 3660 4}
# base -> term202 Nt=231 TF=234 maxTF=2 @{0 3666 0}
# basi -> term2384 Nt=3 TF=3 maxTF=1 @{0 3879 5}
# basic -> term203 Nt=6 TF=6 maxTF=1 @{0 3887 3}
# basiert -> term2380 Nt=1 TF=1 maxTF=1 @{0 3900 3}
# basket -> term1283 Nt=1 TF=1 maxTF=1 @{0 3903 1}
# basqu -> term4895 Nt=1 TF=1 maxTF=1 @{0 3905 3}
# bassin -> term4472 Nt=1 TF=1 maxTF=1 @{0 3908 3}
# bat -> term2344 Nt=1 TF=1 maxTF=1 @{0 3911 3}
# batch -> term4556 Nt=1 TF=1 maxTF=1 @{0 3914 1}
# baumannii -> term293 Nt=1 TF=1 maxTF=1 @{0 3917 1}
# bavaria -> term1896 Nt=1 TF=1 maxTF=1 @{0 3918 7}
# bavarian -> term3019 Nt=3 TF=3 maxTF=1 @{0 3921 3}
# bay -> term2287 Nt=4 TF=4 maxTF=1 @{0 3928 5}
# bayerischen -> term4514 Nt=1 TF=1 maxTF=1 @{0 3936 1}
# bayesian -> term2459 Nt=3 TF=3 maxTF=1 @{0 3939 1}
# bbc -> term4126 Nt=4 TF=4 maxTF=1 @{0 3946 7}
# bc8 -> term1389 Nt=1 TF=1 maxTF=1 @{0 3955 1}
# bcedb -> term427 Nt=1 TF=1 maxTF=1 @{0 3957 5}
# bcl -> term1872 Nt=1 TF=1 maxTF=1 @{0 3959 3}
# bcl2db -> term1870 Nt=1 TF=1 maxTF=1 @{0 3961 7}
# be -> term1675 Nt=1 TF=1 maxTF=1 @{0 3964 3}
# beacon -> term2980 Nt=1 TF=1 maxTF=1 @{0 3966 7}
# beamform -> term4960 Nt=1 TF=1 maxTF=1 @{0 3969 5}
# beast -> term4494 Nt=1 TF=1 maxTF=1 @{0 3972 5}
# becken -> term5016 Nt=1 TF=1 maxTF=1 @{0 3975 5}
# bee -> term3095 Nt=3 TF=3 maxTF=1 @{0 3978 5}
# begin -> term172 Nt=2 TF=2 maxTF=1 @{0 3986 3}
# behavior -> term2187 Nt=11 TF=11 maxTF=1 @{0 3990 5}
# behaviour -> term3903 Nt=1 TF=1 maxTF=1 @{0 4011 3}
# bei -> term2244 Nt=2 TF=2 maxTF=1 @{0 4014 3}
# beihilf -> term4010 Nt=1 TF=1 maxTF=1 @{0 4019 7}
# beitou -> term3159 Nt=1 TF=2 maxTF=2 @{0 4022 7}
# beitrag -> term3780 Nt=1 TF=1 maxTF=1 @{0 4025 6}
# beitragen -> term3700 Nt=1 TF=1 maxTF=1 @{0 4028 6}
# belang -> term4747 Nt=1 TF=1 maxTF=1 @{0 4031 6}
# belaru -> term3550 Nt=1 TF=1 maxTF=1 @{0 4034 6}
# bele -> term4572 Nt=1 TF=1 maxTF=1 @{0 4037 6}
# belfast -> term3141 Nt=1 TF=1 maxTF=1 @{0 4040 6}
# benchmark -> term968 Nt=8 TF=8 maxTF=1 @{0 4043 4}
# benzothiazol -> term359 Nt=1 TF=1 maxTF=1 @{0 4060 6}
# berkelei -> term3826 Nt=1 TF=1 maxTF=1 @{0 4062 4}
# berlegungen -> term4821 Nt=1 TF=1 maxTF=1 @{0 4065 4}
# berlieferung -> term4390 Nt=2 TF=2 maxTF=1 @{0 4068 4}
# berlin -> term2010 Nt=4 TF=4 maxTF=1 @{0 4073 6}
# bern -> term2734 Nt=1 TF=1 maxTF=1 @{0 4081 4}
# bernahm -> term4184 Nt=1 TF=1 maxTF=1 @{0 4084 2}
# bert -> term1403 Nt=6 TF=6 maxTF=1 @{0 4087 2}
# best -> term442 Nt=10 TF=10 maxTF=1 @{0 4098 0}
# bewegung -> term2620 Nt=1 TF=1 maxTF=1 @{0 4118 2}
# bewegungen -> term4384 Nt=1 TF=1 maxTF=1 @{0 4121 0}
# bewertung -> term4181 Nt=1 TF=1 maxTF=1 @{0 4124 0}
# beziehungen -> term2273 Nt=2 TF=2 maxTF=1 @{0 4127 0}
# bh3 -> term1869 Nt=1 TF=1 maxTF=1 @{0 4131 6}
# bhaderwah -> term1831 Nt=1 TF=1 maxTF=1 @{0 4134 2}
# bi -> term2014 Nt=3 TF=3 maxTF=1 @{0 4136 6}
# bia -> term1946 Nt=1 TF=1 maxTF=1 @{0 4143 6}
# bias -> term1373 Nt=2 TF=2 maxTF=1 @{0 4146 2}
# bibfram -> term3663 Nt=1 TF=1 maxTF=1 @{0 4151 6}
# biblic -> term2148 Nt=2 TF=2 maxTF=1 @{0 4154 6}
# bibliograph -> term459 Nt=11 TF=11 maxTF=1 @{0 4158 4}
# bibliographi -> term1172 Nt=5 TF=5 maxTF=1 @{0 4178 6}
# bibliographien -> term3122 Nt=1 TF=1 maxTF=1 @{0 4190 4}
# bibliographieren -> term3010 Nt=1 TF=1 maxTF=1 @{0 4193 2}
# bibliometr -> term307 Nt=6 TF=6 maxTF=1 @{0 4196 0}
# bibliot -> term2971 Nt=3 TF=3 maxTF=1 @{0 4208 2}
# biblioteca -> term3633 Nt=3 TF=5 maxTF=2 @{0 4215 0}
# bibliotech -> term3723 Nt=1 TF=2 maxTF=2 @{0 4221 4}
# bibliotecil -> term3777 Nt=1 TF=1 maxTF=1 @{0 4224 5}
# bibliotek -> term3979 Nt=1 TF=1 maxTF=1 @{0 4227 5}
# biblioteki -> term3941 Nt=1 TF=1 maxTF=1 @{0 4230 5}
# bibliotekpolitikken -> term3267 Nt=1 TF=1 maxTF=1 @{0 4233 5}
# biblioth -> term3716 Nt=4 TF=4 maxTF=1 @{0 4236 3}
# bibliotheca -> term4224 Nt=1 TF=1 maxTF=1 @{0 4245 1}
# bibliothek -> term3030 Nt=4 TF=5 maxTF=2 @{0 4248 1}
# bibliothekarisch -> term3006 Nt=1 TF=1 maxTF=1 @{0 4257 6}
# bibliotheken -> term2324 Nt=7 TF=8 maxTF=2 @{0 4260 4}
# bibliothequ -> term2881 Nt=1 TF=1 maxTF=1 @{0 4276 1}
# bibsonomi -> term3108 Nt=1 TF=1 maxTF=1 @{0 4278 7}
# bibtex -> term4493 Nt=1 TF=1 maxTF=1 @{0 4281 5}
# bidirect -> term1562 Nt=2 TF=2 maxTF=1 @{0 4284 5}
# big -> term740 Nt=22 TF=22 maxTF=1 @{0 4289 3}
# bike -> term3621 Nt=1 TF=1 maxTF=1 @{0 4325 3}
# bilanz -> term4153 Nt=1 TF=1 maxTF=1 @{0 4328 3}
# bild -> term2271 Nt=3 TF=5 maxTF=3 @{0 4331 3}
# bilingu -> term2946 Nt=5 TF=5 maxTF=1 @{0 4338 3}
# bill -> term827 Nt=3 TF=3 maxTF=1 @{0 4349 3}
# billion -> term3982 Nt=2 TF=2 maxTF=1 @{0 4356 7}
# bim -> term1533 Nt=2 TF=2 maxTF=1 @{0 4362 1}
# binar -> term4704 Nt=1 TF=1 maxTF=1 @{0 4367 5}
# binari -> term2185 Nt=2 TF=2 maxTF=1 @{0 4370 5}
# bind -> term354 Nt=6 TF=6 maxTF=1 @{0 4376 1}
# bio -> term2428 Nt=3 TF=3 maxTF=1 @{0 4385 1}
# bioacoust -> term4490 Nt=1 TF=1 maxTF=1 @{0 4391 7}
# bioactiv -> term1474 Nt=1 TF=1 maxTF=1 @{0 4394 7}
# biobank -> term1427 Nt=2 TF=2 maxTF=1 @{0 4397 3}
# biochem -> term176 Nt=5 TF=5 maxTF=1 @{0 4402 3}
# biochem4j -> term1728 Nt=1 TF=1 maxTF=1 @{0 4411 5}
# bioclips -> term2173 Nt=1 TF=2 maxTF=2 @{0 4414 1}
# biocr -> term1369 Nt=5 TF=5 maxTF=1 @{0 4417 0}
# biocur -> term1603 Nt=4 TF=4 maxTF=1 @{0 4424 0}
# biocyc -> term695 Nt=1 TF=1 maxTF=1 @{0 4431 6}
# biodataom -> term314 Nt=1 TF=1 maxTF=1 @{0 4433 6}
# biodegrad -> term400 Nt=1 TF=1 maxTF=1 @{0 4435 4}
# biodeterior -> term4583 Nt=1 TF=1 maxTF=1 @{0 4437 2}
# biodivers -> term967 Nt=3 TF=3 maxTF=1 @{0 4440 2}
# biogerontologist -> term1472 Nt=1 TF=1 maxTF=1 @{0 4447 2}
# biogrid -> term1625 Nt=1 TF=1 maxTF=1 @{0 4449 6}
# bioinformat -> term162 Nt=7 TF=7 maxTF=1 @{0 4452 2}
# biolog -> term147 Nt=10 TF=10 maxTF=1 @{0 4464 4}
# biologi -> term110 Nt=15 TF=15 maxTF=1 @{0 4483 2}
# biomark -> term281 Nt=5 TF=5 maxTF=1 @{0 4506 4}
# biomart -> term46 Nt=1 TF=1 maxTF=1 @{0 4513 4}
# biomed -> term1286 Nt=25 TF=25 maxTF=1 @{0 4514 4}
# biomedicin -> term180 Nt=2 TF=2 maxTF=1 @{0 4545 6}
# biometr -> term737 Nt=1 TF=1 maxTF=1 @{0 4550 0}
# biomodel -> term764 Nt=1 TF=1 maxTF=1 @{0 4552 0}
# biomolecular -> term572 Nt=1 TF=1 maxTF=1 @{0 4554 0}
# bionumb -> term109 Nt=1 TF=1 maxTF=1 @{0 4556 0}
# bior -> term1445 Nt=2 TF=2 maxTF=1 @{0 4557 2}
# bioreact -> term770 Nt=1 TF=1 maxTF=1 @{0 4561 4}
# biosecur -> term758 Nt=1 TF=1 maxTF=1 @{0 4563 4}
# biosystem -> term1837 Nt=1 TF=1 maxTF=1 @{0 4565 4}
# biotechnolog -> term655 Nt=3 TF=3 maxTF=1 @{0 4568 0}
# biotransform -> term715 Nt=1 TF=1 maxTF=1 @{0 4572 4}
# biowarehous -> term957 Nt=1 TF=1 maxTF=1 @{0 4574 4}
# bird -> term4376 Nt=1 TF=1 maxTF=1 @{0 4576 6}
# birth -> term1201 Nt=1 TF=1 maxTF=1 @{0 4579 6}
# bisaba -> term3795 Nt=1 TF=1 maxTF=1 @{0 4582 0}
# biskupij -> term4646 Nt=1 TF=1 maxTF=1 @{0 4585 0}
# bit -> term4366 Nt=1 TF=1 maxTF=1 @{0 4588 0}
# bite -> term3817 Nt=1 TF=1 maxTF=1 @{0 4591 0}
# bizkaifon -> term4897 Nt=1 TF=1 maxTF=1 @{0 4594 0}
# bjelovar -> term3484 Nt=1 TF=1 maxTF=1 @{0 4597 0}
# bkm -> term290 Nt=1 TF=1 maxTF=1 @{0 4600 0}
# bl -> term4719 Nt=1 TF=1 maxTF=1 @{0 4601 6}
# blab2cancerkd -> term612 Nt=1 TF=1 maxTF=1 @{0 4604 6}
# black -> term2791 Nt=2 TF=2 maxTF=1 @{0 4606 6}
# blackboard -> term3917 Nt=1 TF=1 maxTF=1 @{0 4612 2}
# blacklight -> term3093 Nt=1 TF=1 maxTF=1 @{0 4615 2}
# blacksburg -> term4339 Nt=1 TF=1 maxTF=1 @{0 4618 0}
# bladzijd -> term4484 Nt=1 TF=1 maxTF=1 @{0 4621 0}
# blind -> term1987 Nt=3 TF=4 maxTF=2 @{0 4624 0}
# blindensturz -> term2562 Nt=1 TF=1 maxTF=1 @{0 4631 7}
# block -> term1913 Nt=3 TF=3 maxTF=1 @{0 4634 5}
# blockchain -> term1779 Nt=3 TF=3 maxTF=1 @{0 4642 1}
# blog -> term2365 Nt=3 TF=3 maxTF=1 @{0 4649 7}
# blogpost -> term3991 Nt=1 TF=1 maxTF=1 @{0 4656 7}
# blood -> term682 Nt=2 TF=2 maxTF=1 @{0 4659 7}
# bloomington -> term4260 Nt=1 TF=1 maxTF=1 @{0 4664 1}
# blotch -> term4537 Nt=2 TF=2 maxTF=1 @{0 4667 1}
# blue -> term3215 Nt=2 TF=2 maxTF=1 @{0 4672 3}
# bluetooth -> term2277 Nt=1 TF=1 maxTF=1 @{0 4677 5}
# bmtedb -> term1905 Nt=1 TF=1 maxTF=1 @{0 4680 3}
# bne -> term3617 Nt=1 TF=1 maxTF=1 @{0 4682 7}
# board -> term3693 Nt=1 TF=1 maxTF=1 @{0 4685 7}
# bobet -> term3172 Nt=1 TF=1 maxTF=1 @{0 4688 7}
# bodi -> term2868 Nt=2 TF=2 maxTF=1 @{0 4691 5}
# bogot -> term3422 Nt=1 TF=1 maxTF=1 @{0 4696 7}
# boilerpl -> term2627 Nt=1 TF=1 maxTF=1 @{0 4699 7}
# bomb -> term4432 Nt=1 TF=1 maxTF=1 @{0 4702 5}
# bombardieren -> term2655 Nt=1 TF=1 maxTF=1 @{0 4705 5}
# book -> term2862 Nt=14 TF=14 maxTF=1 @{0 4708 3}
# bookstor -> term3602 Nt=1 TF=1 maxTF=1 @{0 4731 1}
# boost -> term2386 Nt=11 TF=11 maxTF=1 @{0 4734 1}
# boostext -> term2608 Nt=1 TF=1 maxTF=1 @{0 4753 3}
# bootstrap -> term2561 Nt=2 TF=2 maxTF=1 @{0 4756 1}
# borg -> term3480 Nt=1 TF=1 maxTF=1 @{0 4761 5}
# born -> term3953 Nt=3 TF=3 maxTF=1 @{0 4764 5}
# borrow -> term3089 Nt=1 TF=2 maxTF=2 @{0 4772 1}
# bosn -> term4949 Nt=1 TF=1 maxTF=1 @{0 4775 0}
# bosni -> term4940 Nt=1 TF=1 maxTF=1 @{0 4778 0}
# bostick -> term3657 Nt=1 TF=1 maxTF=1 @{0 4781 0}
# boston -> term4430 Nt=1 TF=1 maxTF=1 @{0 4784 0}
# bot -> term4672 Nt=1 TF=1 maxTF=1 @{0 4787 0}
# botryosphaerial -> term1399 Nt=1 TF=2 maxTF=2 @{0 4790 0}
# bottleneck -> term1618 Nt=3 TF=3 maxTF=1 @{0 4792 5}
# bottom -> term3390 Nt=3 TF=3 maxTF=1 @{0 4799 1}
# bound -> term2231 Nt=2 TF=2 maxTF=1 @{0 4806 3}
# boundari -> term1667 Nt=3 TF=3 maxTF=1 @{0 4811 7}
# bow -> term4806 Nt=1 TF=1 maxTF=1 @{0 4819 3}
# bowel -> term1555 Nt=1 TF=1 maxTF=1 @{0 4822 3}
# bowstrok -> term4807 Nt=1 TF=1 maxTF=1 @{0 4824 7}
# box -> term1123 Nt=5 TF=5 maxTF=1 @{0 4827 7}
# br -> term4730 Nt=1 TF=1 maxTF=1 @{0 4838 5}
# brain -> term1710 Nt=5 TF=5 maxTF=1 @{0 4841 5}
# branch -> term2351 Nt=3 TF=3 maxTF=1 @{0 4852 5}
# brand -> term2292 Nt=2 TF=2 maxTF=1 @{0 4860 1}
# brandenburg -> term2013 Nt=1 TF=1 maxTF=1 @{0 4863 1}
# breach -> term1934 Nt=1 TF=1 maxTF=1 @{0 4865 5}
# breed -> term734 Nt=3 TF=4 maxTF=2 @{0 4868 1}
# brenda -> term1190 Nt=2 TF=2 maxTF=1 @{0 4874 4}
# brentwood -> term2926 Nt=1 TF=1 maxTF=1 @{0 4879 0}
# brexit -> term4577 Nt=1 TF=1 maxTF=1 @{0 4881 6}
# brianc -> term2022 Nt=1 TF=1 maxTF=1 @{0 4884 6}
# brick -> term3756 Nt=1 TF=1 maxTF=1 @{0 4887 2}
# bridg -> term782 Nt=6 TF=6 maxTF=1 @{0 4890 2}
# brief -> term972 Nt=5 TF=5 maxTF=1 @{0 4904 0}
# brighton -> term2921 Nt=1 TF=1 maxTF=1 @{0 4914 2}
# british -> term2086 Nt=6 TF=6 maxTF=1 @{0 4917 0}
# brittl -> term2203 Nt=2 TF=2 maxTF=1 @{0 4929 6}
# broadband -> term4958 Nt=1 TF=1 maxTF=1 @{0 4934 2}
# broadcast -> term1205 Nt=3 TF=3 maxTF=1 @{0 4937 2}
# broader -> term4031 Nt=1 TF=1 maxTF=1 @{0 4943 4}
# broccoli -> term2688 Nt=1 TF=1 maxTF=1 @{0 4946 4}
# brodman -> term3069 Nt=1 TF=1 maxTF=1 @{0 4949 2}
# brows -> term1416 Nt=5 TF=5 maxTF=1 @{0 4952 0}
# browser -> term1357 Nt=7 TF=7 maxTF=1 @{0 4964 0}
# bsp -> term4869 Nt=1 TF=1 maxTF=1 @{0 4978 6}
# bu -> term1258 Nt=2 TF=2 maxTF=1 @{0 4981 6}
# buchdeckel -> term2723 Nt=1 TF=1 maxTF=1 @{0 4986 6}
# buchreihen -> term3031 Nt=1 TF=1 maxTF=1 @{0 4989 4}
# bud -> term21 Nt=1 TF=1 maxTF=1 @{0 4992 2}
# buddhist -> term4426 Nt=2 TF=2 maxTF=1 @{0 4992 6}
# budo -> term3877 Nt=1 TF=1 maxTF=1 @{0 4998 0}
# buea -> term2777 Nt=1 TF=1 maxTF=1 @{0 5001 0}
# build -> term1274 Nt=56 TF=58 maxTF=2 @{0 5003 6}
# builder -> term5013 Nt=1 TF=1 maxTF=1 @{0 5078 0}
# built -> term3519 Nt=1 TF=1 maxTF=1 @{0 5081 0}
# bulacan -> term2809 Nt=1 TF=1 maxTF=1 @{0 5084 0}
# bulgarian -> term4587 Nt=1 TF=1 maxTF=1 @{0 5086 6}
# bulletin -> term4876 Nt=1 TF=1 maxTF=1 @{0 5089 6}
# bundl -> term2062 Nt=1 TF=1 maxTF=1 @{0 5092 6}
# burgher -> term4522 Nt=1 TF=1 maxTF=1 @{0 5095 2}
# burn -> term4783 Nt=1 TF=1 maxTF=1 @{0 5098 2}
# bursti -> term2019 Nt=1 TF=1 maxTF=1 @{0 5101 2}
# busi -> term2305 Nt=6 TF=6 maxTF=1 @{0 5103 6}
# butler -> term4862 Nt=1 TF=1 maxTF=1 @{0 5117 2}
# butterfli -> term3052 Nt=1 TF=1 maxTF=1 @{0 5120 2}
# cach -> term4661 Nt=3 TF=3 maxTF=1 @{0 5123 0}
# cad -> term1069 Nt=2 TF=2 maxTF=1 @{0 5129 4}
# cadastr -> term897 Nt=1 TF=1 maxTF=1 @{0 5134 0}
# cadet -> term3893 Nt=1 TF=1 maxTF=1 @{0 5136 2}
# cadrul -> term3775 Nt=1 TF=1 maxTF=1 @{0 5139 2}
# caesar -> term2468 Nt=1 TF=1 maxTF=1 @{0 5142 2}
# caf -> term2773 Nt=1 TF=1 maxTF=1 @{0 5145 0}
# cafeteriasa -> term1565 Nt=1 TF=1 maxTF=1 @{0 5147 6}
# calai -> term4523 Nt=1 TF=1 maxTF=1 @{0 5150 2}
# calasantio -> term4295 Nt=1 TF=1 maxTF=1 @{0 5153 2}
# calgari -> term3955 Nt=1 TF=1 maxTF=1 @{0 5156 2}
# calicut -> term3239 Nt=1 TF=1 maxTF=1 @{0 5159 2}
# california -> term1936 Nt=1 TF=1 maxTF=1 @{0 5162 0}
# californian -> term4451 Nt=1 TF=1 maxTF=1 @{0 5164 4}
# call -> term2707 Nt=7 TF=8 maxTF=2 @{0 5167 4}
# cam -> term1620 Nt=1 TF=1 maxTF=1 @{0 5180 3}
# cambridg -> term1494 Nt=1 TF=1 maxTF=1 @{0 5182 7}
# camera -> term662 Nt=2 TF=2 maxTF=1 @{0 5185 3}
# campaign -> term2798 Nt=1 TF=1 maxTF=1 @{0 5190 3}
# campu -> term3471 Nt=4 TF=4 maxTF=1 @{0 5193 1}
# can -> term2175 Nt=10 TF=11 maxTF=2 @{0 5201 3}
# canada -> term2824 Nt=3 TF=3 maxTF=1 @{0 5220 6}
# canadian -> term3742 Nt=4 TF=4 maxTF=1 @{0 5228 4}
# canberra -> term3818 Nt=1 TF=1 maxTF=1 @{0 5237 6}
# cancer -> term323 Nt=24 TF=25 maxTF=2 @{0 5240 6}
# candid -> term449 Nt=1 TF=1 maxTF=1 @{0 5271 3}
# cape -> term3526 Nt=2 TF=2 maxTF=1 @{0 5273 1}
# capitalist -> term4695 Nt=1 TF=1 maxTF=1 @{0 5278 1}
# captcha -> term2704 Nt=1 TF=1 maxTF=1 @{0 5281 1}
# caption -> term2750 Nt=1 TF=1 maxTF=1 @{0 5283 7}
# captum -> term3202 Nt=1 TF=1 maxTF=1 @{0 5286 5}
# captur -> term807 Nt=8 TF=8 maxTF=1 @{0 5289 3}
# caract -> term4476 Nt=1 TF=1 maxTF=1 @{0 5305 7}
# caracterizaci -> term4104 Nt=1 TF=1 maxTF=1 @{0 5308 7}
# carbohydr -> term960 Nt=2 TF=3 maxTF=2 @{0 5311 7}
# carbon -> term1343 Nt=6 TF=6 maxTF=1 @{0 5316 4}
# card -> term896 Nt=5 TF=5 maxTF=1 @{0 5329 2}
# cardiac -> term1306 Nt=2 TF=2 maxTF=1 @{0 5341 4}
# cardio -> term558 Nt=1 TF=1 maxTF=1 @{0 5346 2}
# cardiolog -> term557 Nt=1 TF=1 maxTF=1 @{0 5348 2}
# care -> term4887 Nt=2 TF=2 maxTF=1 @{0 5350 2}
# caribbean -> term4670 Nt=1 TF=1 maxTF=1 @{0 5354 2}
# carnot -> term920 Nt=1 TF=1 maxTF=1 @{0 5357 2}
# carp -> term1344 Nt=1 TF=1 maxTF=1 @{0 5359 4}
# carpentri -> term3341 Nt=2 TF=2 maxTF=1 @{0 5362 0}
# carstream -> term1271 Nt=1 TF=1 maxTF=1 @{0 5367 2}
# carter -> term3545 Nt=1 TF=1 maxTF=1 @{0 5369 4}
# cascad -> term2370 Nt=1 TF=1 maxTF=1 @{0 5372 4}
# case -> term454 Nt=54 TF=54 maxTF=1 @{0 5375 2}
# cassandra -> term95 Nt=1 TF=1 maxTF=1 @{0 5449 2}
# catalog -> term522 Nt=22 TF=25 maxTF=3 @{0 5450 4}
# catalogu -> term1220 Nt=9 TF=10 maxTF=2 @{0 5483 3}
# catchment -> term4499 Nt=1 TF=1 maxTF=1 @{0 5501 0}
# categor -> term1279 Nt=59 TF=59 maxTF=1 @{0 5504 0}
# categori -> term689 Nt=2 TF=2 maxTF=1 @{0 5565 4}
# categoris -> term2573 Nt=1 TF=1 maxTF=1 @{0 5570 2}
# caucasian -> term1840 Nt=4 TF=4 maxTF=1 @{0 5573 0}
# caucasu -> term1843 Nt=4 TF=5 maxTF=2 @{0 5578 6}
# caus -> term702 Nt=1 TF=1 maxTF=1 @{0 5584 5}
# causal -> term1650 Nt=2 TF=2 maxTF=1 @{0 5586 5}
# cave -> term4142 Nt=1 TF=1 maxTF=1 @{0 5591 5}
# cazym -> term305 Nt=1 TF=1 maxTF=1 @{0 5594 5}
# cbd -> term1475 Nt=1 TF=1 maxTF=1 @{0 5596 3}
# cbgda -> term1394 Nt=1 TF=1 maxTF=1 @{0 5598 7}
# cbpddb -> term360 Nt=1 TF=1 maxTF=1 @{0 5601 3}
# ccidb -> term435 Nt=1 TF=1 maxTF=1 @{0 5603 1}
# ccienc -> term3437 Nt=1 TF=1 maxTF=1 @{0 5604 7}
# cd -> term3017 Nt=1 TF=1 maxTF=1 @{0 5607 7}
# cdi -> term4102 Nt=1 TF=1 maxTF=1 @{0 5610 5}
# cdl -> term4005 Nt=1 TF=1 maxTF=1 @{0 5613 5}
# cdx -> term4324 Nt=1 TF=1 maxTF=1 @{0 5616 5}
# ceg -> term1787 Nt=1 TF=1 maxTF=1 @{0 5619 5}
# cell -> term53 Nt=15 TF=19 maxTF=3 @{0 5622 1}
# cellular -> term448 Nt=3 TF=3 maxTF=1 @{0 5641 7}
# cenhanc -> term482 Nt=1 TF=1 maxTF=1 @{0 5646 5}
# censu -> term4122 Nt=3 TF=4 maxTF=2 @{0 5648 5}
# center -> term653 Nt=20 TF=21 maxTF=2 @{0 5656 0}
# centr -> term3483 Nt=3 TF=4 maxTF=2 @{0 5691 1}
# central -> term452 Nt=15 TF=15 maxTF=1 @{0 5698 2}
# centric -> term806 Nt=8 TF=8 maxTF=1 @{0 5724 2}
# centroid -> term4069 Nt=1 TF=1 maxTF=1 @{0 5740 6}
# centuri -> term1761 Nt=11 TF=11 maxTF=1 @{0 5743 6}
# cerebrovascular -> term1550 Nt=1 TF=1 maxTF=1 @{0 5764 2}
# ceremoni -> term4881 Nt=1 TF=1 maxTF=1 @{0 5766 6}
# cerevisia -> term18 Nt=2 TF=2 maxTF=1 @{0 5769 6}
# cerif -> term4557 Nt=1 TF=1 maxTF=1 @{0 5772 2}
# certif -> term3080 Nt=4 TF=4 maxTF=1 @{0 5775 2}
# certifi -> term2927 Nt=3 TF=3 maxTF=1 @{0 5784 4}
# cervic -> term1124 Nt=1 TF=1 maxTF=1 @{0 5791 6}
# cevada -> term4318 Nt=1 TF=1 maxTF=1 @{0 5794 0}
# cg -> term1176 Nt=1 TF=1 maxTF=1 @{0 5797 0}
# chain -> term1318 Nt=4 TF=4 maxTF=1 @{0 5799 2}
# chainercv -> term2833 Nt=1 TF=1 maxTF=1 @{0 5808 2}
# challeng -> term1420 Nt=20 TF=20 maxTF=1 @{0 5811 0}
# chanc -> term3936 Nt=2 TF=2 maxTF=1 @{0 5845 4}
# chancen -> term3781 Nt=1 TF=1 maxTF=1 @{0 5849 6}
# chang -> term986 Nt=23 TF=25 maxTF=3 @{0 5852 6}
# channel -> term4573 Nt=2 TF=2 maxTF=1 @{0 5892 4}
# chapel -> term3421 Nt=1 TF=1 maxTF=1 @{0 5897 4}
# chaperonin -> term1732 Nt=1 TF=1 maxTF=1 @{0 5900 4}
# chapter -> term3071 Nt=3 TF=3 maxTF=1 @{0 5903 0}
# charact -> term1970 Nt=10 TF=10 maxTF=1 @{0 5908 6}
# character -> term1157 Nt=4 TF=4 maxTF=1 @{0 5927 0}
# characterist -> term263 Nt=5 TF=5 maxTF=1 @{0 5936 6}
# charit -> term2765 Nt=1 TF=1 maxTF=1 @{0 5948 2}
# chast -> term3344 Nt=1 TF=1 maxTF=1 @{0 5951 0}
# chat -> term1967 Nt=2 TF=2 maxTF=1 @{0 5954 0}
# chatbot -> term2560 Nt=3 TF=3 maxTF=1 @{0 5959 0}
# chatgpt -> term2846 Nt=2 TF=2 maxTF=1 @{0 5966 4}
# chebi -> term146 Nt=3 TF=3 maxTF=1 @{0 5972 0}
# check -> term4864 Nt=1 TF=1 maxTF=1 @{0 5978 0}
# checklist -> term2977 Nt=3 TF=3 maxTF=1 @{0 5981 0}
# chembioport -> term1567 Nt=1 TF=1 maxTF=1 @{0 5987 2}
# chemic -> term145 Nt=11 TF=11 maxTF=1 @{0 5989 6}
# chemistri -> term1239 Nt=3 TF=3 maxTF=1 @{0 6006 0}
# chemoresist -> term496 Nt=1 TF=1 maxTF=1 @{0 6013 6}
# cher -> term2724 Nt=2 TF=2 maxTF=1 @{0 6015 6}
# chiefli -> term3748 Nt=1 TF=1 maxTF=1 @{0 6020 4}
# child -> term3564 Nt=1 TF=1 maxTF=1 @{0 6023 4}
# childhood -> term4097 Nt=1 TF=1 maxTF=1 @{0 6026 4}
# children -> term2366 Nt=4 TF=4 maxTF=1 @{0 6029 4}
# china -> term466 Nt=4 TF=4 maxTF=1 @{0 6038 0}
# chinchilla -> term1884 Nt=1 TF=1 maxTF=1 @{0 6045 6}
# chines -> term2109 Nt=7 TF=7 maxTF=1 @{0 6048 2}
# chm13 -> term1449 Nt=1 TF=1 maxTF=1 @{0 6064 0}
# choic -> term965 Nt=3 TF=3 maxTF=1 @{0 6066 4}
# chromosom -> term1374 Nt=2 TF=2 maxTF=1 @{0 6074 0}
# chronicl -> term4215 Nt=1 TF=1 maxTF=1 @{0 6078 6}
# chronolog -> term3591 Nt=1 TF=1 maxTF=1 @{0 6081 6}
# chunk -> term2498 Nt=2 TF=2 maxTF=1 @{0 6084 6}
# ciliamin -> term312 Nt=1 TF=1 maxTF=1 @{0 6089 0}
# ciliopathi -> term311 Nt=1 TF=2 maxTF=2 @{0 6090 6}
# cilipsgogreen -> term2760 Nt=1 TF=1 maxTF=1 @{0 6092 5}
# cine -> term2263 Nt=1 TF=1 maxTF=1 @{0 6095 3}
# cipher -> term2464 Nt=1 TF=1 maxTF=1 @{0 6098 1}
# cipic -> term1487 Nt=1 TF=1 maxTF=1 @{0 6100 7}
# circfunbas -> term1485 Nt=1 TF=1 maxTF=1 @{0 6103 3}
# circr2canc -> term1907 Nt=1 TF=1 maxTF=1 @{0 6105 7}
# circrna -> term1807 Nt=2 TF=2 maxTF=1 @{0 6108 3}
# circul -> term1075 Nt=2 TF=2 maxTF=1 @{0 6112 5}
# circular -> term1484 Nt=1 TF=1 maxTF=1 @{0 6117 7}
# citat -> term1011 Nt=9 TF=9 maxTF=1 @{0 6120 3}
# cite -> term3106 Nt=1 TF=1 maxTF=1 @{0 6138 3}
# citeseerx -> term3077 Nt=1 TF=1 maxTF=1 @{0 6141 1}
# citi -> term2838 Nt=4 TF=4 maxTF=1 @{0 6143 7}
# citizen -> term799 Nt=3 TF=3 maxTF=1 @{0 6152 7}
# cityli -> term3229 Nt=1 TF=1 maxTF=1 @{0 6158 3}
# civic -> term2817 Nt=1 TF=1 maxTF=1 @{0 6161 1}
# ckan -> term3369 Nt=1 TF=1 maxTF=1 @{0 6163 7}
# cklich -> term2725 Nt=1 TF=1 maxTF=1 @{0 6166 7}
# claremont -> term128 Nt=1 TF=1 maxTF=1 @{0 6169 5}
# clarifi -> term3837 Nt=1 TF=1 maxTF=1 @{0 6171 1}
# clarkson -> term3708 Nt=1 TF=1 maxTF=1 @{0 6174 1}
# class -> term693 Nt=12 TF=12 maxTF=1 @{0 6177 1}
# classic -> term2280 Nt=3 TF=3 maxTF=1 @{0 6200 1}
# classif -> term633 Nt=120 TF=122 maxTF=3 @{0 6207 3}
# classifi -> term1109 Nt=7 TF=7 maxTF=1 @{0 6318 7}
# classroom -> term3528 Nt=1 TF=1 maxTF=1 @{0 6332 5}
# cleans -> term1685 Nt=1 TF=1 maxTF=1 @{0 6335 5}
# clearanc -> term1290 Nt=1 TF=1 maxTF=1 @{0 6338 1}
# clearer -> term1553 Nt=1 TF=1 maxTF=1 @{0 6340 3}
# clef -> term2252 Nt=2 TF=2 maxTF=1 @{0 6342 7}
# clemen -> term4773 Nt=1 TF=1 maxTF=1 @{0 6346 5}
# cleric -> term2180 Nt=1 TF=1 maxTF=1 @{0 6349 5}
# cleveland -> term917 Nt=1 TF=1 maxTF=1 @{0 6352 3}
# click -> term4179 Nt=2 TF=2 maxTF=1 @{0 6354 5}
# climat -> term1339 Nt=11 TF=11 maxTF=1 @{0 6360 1}
# clinic -> term578 Nt=10 TF=10 maxTF=1 @{0 6380 3}
# clinton -> term4077 Nt=1 TF=1 maxTF=1 @{0 6399 1}
# clip -> term2356 Nt=3 TF=3 maxTF=1 @{0 6402 1}
# clonal -> term3014 Nt=1 TF=1 maxTF=1 @{0 6409 1}
# clone -> term4705 Nt=1 TF=1 maxTF=1 @{0 6411 7}
# close -> term1978 Nt=1 TF=1 maxTF=1 @{0 6414 7}
# cloud -> term852 Nt=13 TF=13 maxTF=1 @{0 6417 3}
# cloudi -> term3962 Nt=1 TF=1 maxTF=1 @{0 6443 5}
# cluster -> term367 Nt=46 TF=47 maxTF=2 @{0 6446 5}
# cm54 -> term1941 Nt=1 TF=1 maxTF=1 @{0 6501 6}
# cmbd -> term321 Nt=1 TF=1 maxTF=1 @{0 6504 2}
# cmip5 -> term4551 Nt=1 TF=1 maxTF=1 @{0 6506 0}
# cmregnet -> term840 Nt=1 TF=1 maxTF=1 @{0 6509 0}
# cmsaf -> term1947 Nt=1 TF=1 maxTF=1 @{0 6511 2}
# cnvintegr -> term550 Nt=1 TF=1 maxTF=1 @{0 6513 6}
# coala -> term3697 Nt=1 TF=1 maxTF=1 @{0 6515 6}
# coast -> term4245 Nt=1 TF=1 maxTF=1 @{0 6518 6}
# coastlin -> term4244 Nt=1 TF=1 maxTF=1 @{0 6521 6}
# cobb -> term2788 Nt=1 TF=1 maxTF=1 @{0 6524 6}
# cobweb -> term4199 Nt=2 TF=2 maxTF=1 @{0 6527 4}
# cod -> term1167 Nt=1 TF=1 maxTF=1 @{0 6530 6}
# code -> term472 Nt=18 TF=18 maxTF=1 @{0 6533 0}
# codrop -> term2081 Nt=1 TF=1 maxTF=1 @{0 6566 0}
# coel -> term779 Nt=1 TF=1 maxTF=1 @{0 6568 4}
# coevolut -> term4219 Nt=6 TF=6 maxTF=1 @{0 6570 4}
# coevolutionari -> term4202 Nt=4 TF=4 maxTF=1 @{0 6581 0}
# coexpress -> term823 Nt=1 TF=1 maxTF=1 @{0 6589 0}
# cofunct -> term6 Nt=1 TF=1 maxTF=1 @{0 6591 0}
# cognit -> term1757 Nt=1 TF=1 maxTF=1 @{0 6591 2}
# coher -> term2447 Nt=1 TF=1 maxTF=1 @{0 6593 6}
# cohes -> term1983 Nt=4 TF=4 maxTF=1 @{0 6596 4}
# coi -> term487 Nt=2 TF=2 maxTF=1 @{0 6605 0}
# coil -> term3745 Nt=1 TF=1 maxTF=1 @{0 6608 2}
# coin -> term582 Nt=1 TF=1 maxTF=1 @{0 6611 2}
# coir -> term3958 Nt=1 TF=1 maxTF=1 @{0 6613 2}
# coli -> term1 Nt=2 TF=2 maxTF=1 @{0 6616 2}
# collabor -> term848 Nt=29 TF=29 maxTF=1 @{0 6619 4}
# collect -> term251 Nt=64 TF=68 maxTF=2 @{0 6662 4}
# collectnet -> term1605 Nt=1 TF=1 maxTF=1 @{0 6751 4}
# colleg -> term2801 Nt=7 TF=7 maxTF=1 @{0 6754 0}
# collid -> term2361 Nt=1 TF=1 maxTF=1 @{0 6767 0}
# cologn -> term4006 Nt=1 TF=1 maxTF=1 @{0 6769 6}
# colombia -> term3424 Nt=1 TF=1 maxTF=1 @{0 6772 6}
# colon -> term1902 Nt=1 TF=1 maxTF=1 @{0 6775 6}
# coloni -> term4532 Nt=3 TF=3 maxTF=1 @{0 6778 2}
# color -> term2164 Nt=1 TF=1 maxTF=1 @{0 6785 4}
# colorado -> term3304 Nt=2 TF=2 maxTF=1 @{0 6788 2}
# colorect -> term1476 Nt=1 TF=1 maxTF=1 @{0 6792 2}
# colour -> term4161 Nt=3 TF=3 maxTF=1 @{0 6794 6}
# colouris -> term4845 Nt=1 TF=1 maxTF=1 @{0 6801 0}
# columbia -> term3746 Nt=1 TF=1 maxTF=1 @{0 6804 0}
# columbu -> term3151 Nt=3 TF=3 maxTF=1 @{0 6807 0}
# column -> term197 Nt=3 TF=3 maxTF=1 @{0 6814 0}
# coluntur -> term4274 Nt=1 TF=1 maxTF=1 @{0 6820 0}
# com -> term395 Nt=2 TF=2 maxTF=1 @{0 6823 0}
# combat -> term3133 Nt=1 TF=1 maxTF=1 @{0 6827 6}
# combin -> term2364 Nt=4 TF=4 maxTF=1 @{0 6830 4}
# combinatori -> term3884 Nt=1 TF=1 maxTF=1 @{0 6839 6}
# come -> term3596 Nt=3 TF=3 maxTF=1 @{0 6842 6}
# comedi -> term2684 Nt=1 TF=1 maxTF=1 @{0 6848 0}
# comfort -> term3549 Nt=1 TF=1 maxTF=1 @{0 6850 6}
# comic -> term4466 Nt=1 TF=1 maxTF=1 @{0 6853 6}
# commemor -> term4664 Nt=1 TF=1 maxTF=1 @{0 6856 6}
# commentari -> term2145 Nt=2 TF=2 maxTF=1 @{0 6859 6}
# commerc -> term835 Nt=1 TF=1 maxTF=1 @{0 6863 4}
# commerci -> term733 Nt=4 TF=4 maxTF=1 @{0 6865 4}
# commiss -> term3734 Nt=1 TF=1 maxTF=1 @{0 6875 0}
# commit -> term3916 Nt=1 TF=1 maxTF=1 @{0 6878 0}
# committe -> term783 Nt=2 TF=2 maxTF=1 @{0 6881 0}
# common -> term341 Nt=10 TF=10 maxTF=1 @{0 6885 6}
# commonkad -> term3532 Nt=1 TF=1 maxTF=1 @{0 6906 2}
# commonsens -> term2242 Nt=1 TF=1 maxTF=1 @{0 6909 2}
# commun -> term329 Nt=57 TF=65 maxTF=4 @{0 6912 0}
# como -> term3674 Nt=1 TF=1 maxTF=1 @{0 6994 4}
# compani -> term211 Nt=1 TF=1 maxTF=1 @{0 6997 4}
# companion -> term2525 Nt=1 TF=1 maxTF=1 @{0 6999 0}
# compar -> term121 Nt=23 TF=23 maxTF=1 @{0 7001 6}
# comparison -> term123 Nt=22 TF=22 maxTF=1 @{0 7041 2}
# compart -> term648 Nt=1 TF=1 maxTF=1 @{0 7078 4}
# compat -> term2519 Nt=3 TF=3 maxTF=1 @{0 7080 4}
# compcon -> term1627 Nt=1 TF=1 maxTF=1 @{0 7087 4}
# compendia -> term857 Nt=1 TF=1 maxTF=1 @{0 7090 0}
# compens -> term3429 Nt=1 TF=1 maxTF=1 @{0 7092 2}
# compet -> term929 Nt=4 TF=4 maxTF=1 @{0 7095 2}
# competit -> term1582 Nt=2 TF=2 maxTF=1 @{0 7105 0}
# compil -> term993 Nt=3 TF=3 maxTF=1 @{0 7110 2}
# complet -> term1363 Nt=4 TF=4 maxTF=1 @{0 7116 6}
# complex -> term748 Nt=9 TF=9 maxTF=1 @{0 7126 2}
# complianc -> term4607 Nt=1 TF=1 maxTF=1 @{0 7144 0}
# compliant -> term2657 Nt=3 TF=3 maxTF=1 @{0 7147 0}
# complic -> term1327 Nt=2 TF=2 maxTF=1 @{0 7153 2}
# compon -> term1080 Nt=11 TF=11 maxTF=1 @{0 7158 4}
# composit -> term1961 Nt=4 TF=4 maxTF=1 @{0 7179 4}
# compound -> term358 Nt=1 TF=1 maxTF=1 @{0 7188 2}
# comprehens -> term223 Nt=37 TF=37 maxTF=1 @{0 7190 0}
# compress -> term195 Nt=9 TF=9 maxTF=1 @{0 7232 2}
# comput -> term643 Nt=42 TF=43 maxTF=2 @{0 7249 2}
# computer -> term2888 Nt=3 TF=3 maxTF=1 @{0 7316 3}
# computeris -> term2335 Nt=1 TF=1 maxTF=1 @{0 7323 5}
# concept -> term919 Nt=39 TF=39 maxTF=1 @{0 7326 3}
# conceptospher -> term2660 Nt=1 TF=1 maxTF=1 @{0 7386 7}
# conceptu -> term498 Nt=9 TF=9 maxTF=1 @{0 7389 5}
# concern -> term3539 Nt=1 TF=1 maxTF=1 @{0 7406 1}
# ...
# unrestrict -> term2480 Nt=1 TF=1 maxTF=1 @{0 35723 6}
# unsteadi -> term4441 Nt=1 TF=1 maxTF=1 @{0 35726 4}
# unstructur -> term1963 Nt=4 TF=4 maxTF=1 @{0 35729 4}
# unsupervis -> term2068 Nt=5 TF=5 maxTF=1 @{0 35736 2}
# untag -> term2414 Nt=1 TF=1 maxTF=1 @{0 35746 2}
# untangl -> term2497 Nt=1 TF=1 maxTF=1 @{0 35749 0}
# unten -> term4381 Nt=1 TF=1 maxTF=1 @{0 35751 6}
# unterlagen -> term4186 Nt=1 TF=1 maxTF=1 @{0 35754 6}
# unterschiedlich -> term4401 Nt=1 TF=1 maxTF=1 @{0 35757 6}
# untersuchung -> term2318 Nt=1 TF=1 maxTF=1 @{0 35760 6}
# unveil -> term4615 Nt=1 TF=1 maxTF=1 @{0 35763 4}
# updat -> term68 Nt=33 TF=33 maxTF=1 @{0 35766 4}
# upload -> term4548 Nt=1 TF=1 maxTF=1 @{0 35811 2}
# upstream -> term914 Nt=1 TF=1 maxTF=1 @{0 35814 2}
# ur -> term1702 Nt=1 TF=1 maxTF=1 @{0 35816 4}
# urban -> term3415 Nt=2 TF=2 maxTF=1 @{0 35819 0}
# uri -> term2092 Nt=2 TF=2 maxTF=1 @{0 35824 4}
# url -> term4242 Nt=1 TF=1 maxTF=1 @{0 35829 6}
# urteil -> term2195 Nt=1 TF=1 maxTF=1 @{0 35832 6}
# us -> term97 Nt=170 TF=171 maxTF=2 @{0 35835 4}
# usa -> term3152 Nt=2 TF=2 maxTF=1 @{0 36007 7}
# usabl -> term1994 Nt=10 TF=10 maxTF=1 @{0 36012 7}
# usag -> term1212 Nt=10 TF=10 maxTF=1 @{0 36033 5}
# useabl -> term4934 Nt=2 TF=2 maxTF=1 @{0 36054 7}
# user -> term409 Nt=60 TF=63 maxTF=4 @{0 36059 3}
# usiu -> term3318 Nt=1 TF=1 maxTF=1 @{0 36140 0}
# util -> term505 Nt=9 TF=9 maxTF=1 @{0 36143 0}
# utopi -> term2243 Nt=1 TF=1 maxTF=1 @{0 36162 6}
# uvani -> term4649 Nt=1 TF=1 maxTF=1 @{0 36165 4}
# v2 -> term541 Nt=1 TF=1 maxTF=1 @{0 36168 4}
# v3 -> term1261 Nt=1 TF=1 maxTF=1 @{0 36170 4}
# v4 -> term1453 Nt=1 TF=1 maxTF=1 @{0 36172 6}
# v9 -> term1198 Nt=1 TF=1 maxTF=1 @{0 36175 2}
# va -> term1100 Nt=1 TF=1 maxTF=1 @{0 36177 4}
# vaccin -> term1744 Nt=1 TF=1 maxTF=1 @{0 36179 6}
# vadr -> term1310 Nt=1 TF=1 maxTF=1 @{0 36182 2}
# vae -> term2451 Nt=1 TF=1 maxTF=1 @{0 36184 4}
# valid -> term814 Nt=9 TF=9 maxTF=1 @{0 36187 2}
# vallei -> term3236 Nt=1 TF=1 maxTF=1 @{0 36204 4}
# vallila -> term3401 Nt=1 TF=1 maxTF=1 @{0 36207 2}
# valu -> term1085 Nt=10 TF=10 maxTF=1 @{0 36210 2}
# valuat -> term4474 Nt=1 TF=1 maxTF=1 @{0 36231 0}
# van -> term4748 Nt=1 TF=1 maxTF=1 @{0 36234 0}
# vancouv -> term2879 Nt=2 TF=2 maxTF=1 @{0 36237 0}
# var -> term3846 Nt=1 TF=1 maxTF=1 @{0 36242 2}
# vari -> term2267 Nt=1 TF=1 maxTF=1 @{0 36245 2}
# variabl -> term1868 Nt=1 TF=1 maxTF=1 @{0 36248 0}
# variant -> term380 Nt=6 TF=7 maxTF=2 @{0 36250 4}
# variat -> term554 Nt=6 TF=6 maxTF=1 @{0 36262 3}
# varieti -> term2061 Nt=3 TF=3 maxTF=1 @{0 36272 7}
# vascular -> term4275 Nt=1 TF=1 maxTF=1 @{0 36280 5}
# vaticano -> term4173 Nt=1 TF=1 maxTF=1 @{0 36283 5}
# vatikanskom -> term4645 Nt=1 TF=1 maxTF=1 @{0 36286 5}
# vdn -> term1725 Nt=1 TF=1 maxTF=1 @{0 36289 5}
# vector -> term2094 Nt=5 TF=5 maxTF=1 @{0 36292 1}
# vehicl -> term1270 Nt=1 TF=1 maxTF=1 @{0 36301 5}
# veidosana -> term2970 Nt=1 TF=1 maxTF=1 @{0 36303 7}
# veidot -> term3057 Nt=1 TF=1 maxTF=1 @{0 36306 5}
# veil -> term2453 Nt=1 TF=1 maxTF=1 @{0 36309 3}
# veloc -> term4787 Nt=1 TF=1 maxTF=1 @{0 36312 1}
# velopp -> term3719 Nt=1 TF=1 maxTF=1 @{0 36315 1}
# velux -> term2217 Nt=1 TF=1 maxTF=1 @{0 36318 1}
# vendor -> term2778 Nt=2 TF=2 maxTF=1 @{0 36320 7}
# venetian -> term4965 Nt=1 TF=1 maxTF=1 @{0 36326 1}
# ventur -> term3425 Nt=1 TF=1 maxTF=1 @{0 36329 1}
# verb -> term1777 Nt=1 TF=1 maxTF=1 @{0 36332 1}
# vereinten -> term3785 Nt=1 TF=1 maxTF=1 @{0 36334 5}
# verf -> term2194 Nt=1 TF=1 maxTF=1 @{0 36337 5}
# verfahren -> term4267 Nt=1 TF=1 maxTF=1 @{0 36340 3}
# verif -> term437 Nt=5 TF=5 maxTF=1 @{0 36343 3}
# verifi -> term16 Nt=2 TF=2 maxTF=1 @{0 36354 1}
# verletzungen -> term4011 Nt=1 TF=1 maxTF=1 @{0 36357 5}
# vers -> term4973 Nt=1 TF=1 maxTF=1 @{0 36360 5}
# versatil -> term3261 Nt=1 TF=1 maxTF=1 @{0 36363 5}
# version -> term684 Nt=12 TF=12 maxTF=1 @{0 36366 3}
# verstehen -> term2677 Nt=1 TF=1 maxTF=1 @{0 36386 5}
# versuch -> term4726 Nt=1 TF=1 maxTF=1 @{0 36389 3}
# vertebr -> term4790 Nt=1 TF=1 maxTF=1 @{0 36392 3}
# vertic -> term44 Nt=1 TF=1 maxTF=1 @{0 36395 3}
# verzeichnungsgrund -> term4046 Nt=1 TF=1 maxTF=1 @{0 36396 3}
# vessel -> term4782 Nt=1 TF=1 maxTF=1 @{0 36399 3}
# veterinari -> term2353 Nt=1 TF=1 maxTF=1 @{0 36402 3}
# vfdb -> term216 Nt=1 TF=1 maxTF=1 @{0 36405 1}
# vi -> term3335 Nt=3 TF=3 maxTF=1 @{0 36406 5}
# vibrat -> term4463 Nt=1 TF=1 maxTF=1 @{0 36414 3}
# victim -> term3428 Nt=1 TF=1 maxTF=1 @{0 36417 3}
# victoria -> term2756 Nt=1 TF=1 maxTF=1 @{0 36420 3}
# video -> term1900 Nt=37 TF=38 maxTF=2 @{0 36423 1}
# videoconfer -> term4460 Nt=1 TF=1 maxTF=1 @{0 36472 0}
# videogam -> term4091 Nt=1 TF=2 maxTF=2 @{0 36475 0}
# videotap -> term4554 Nt=1 TF=1 maxTF=1 @{0 36478 1}
# vienna -> term4127 Nt=1 TF=1 maxTF=1 @{0 36481 1}
# vietnames -> term2558 Nt=3 TF=3 maxTF=1 @{0 36484 1}
# view -> term688 Nt=10 TF=10 maxTF=1 @{0 36492 1}
# viewer -> term5025 Nt=1 TF=1 maxTF=1 @{0 36510 3}
# vii -> term1367 Nt=3 TF=3 maxTF=1 @{0 36513 3}
# viii -> term1446 Nt=3 TF=3 maxTF=1 @{0 36518 7}
# violin -> term4805 Nt=1 TF=1 maxTF=1 @{0 36525 7}
# viral -> term502 Nt=3 TF=3 maxTF=1 @{0 36528 7}
# virtu -> term2813 Nt=1 TF=1 maxTF=1 @{0 36536 1}
# virtual -> term1637 Nt=25 TF=25 maxTF=1 @{0 36538 7}
# virtuellen -> term4903 Nt=1 TF=1 maxTF=1 @{0 36578 3}
# viru -> term218 Nt=2 TF=2 maxTF=1 @{0 36581 3}
# virul -> term214 Nt=2 TF=2 maxTF=1 @{0 36585 3}
# virusurf -> term501 Nt=1 TF=1 maxTF=1 @{0 36589 1}
# visibl -> term3396 Nt=1 TF=1 maxTF=1 @{0 36591 1}
# vision -> term2200 Nt=6 TF=6 maxTF=1 @{0 36594 1}
# visionless -> term2075 Nt=1 TF=1 maxTF=1 @{0 36608 1}
# visit -> term3203 Nt=3 TF=3 maxTF=1 @{0 36610 5}
# visual -> term334 Nt=49 TF=49 maxTF=1 @{0 36616 1}
# visualis -> term1055 Nt=5 TF=5 maxTF=1 @{0 36688 7}
# vitripenni -> term1716 Nt=1 TF=1 maxTF=1 @{0 36699 3}
# vitro -> term1291 Nt=1 TF=1 maxTF=1 @{0 36701 7}
# vivo -> term19 Nt=1 TF=1 maxTF=1 @{0 36704 1}
# vlasti -> term4936 Nt=1 TF=1 maxTF=1 @{0 36704 5}
# vlsi -> term1957 Nt=2 TF=2 maxTF=1 @{0 36707 5}
# vo -> term4249 Nt=2 TF=2 maxTF=1 @{0 36712 7}
# vocabulari -> term2153 Nt=3 TF=3 maxTF=1 @{0 36717 7}
# vocal -> term5006 Nt=1 TF=1 maxTF=1 @{0 36725 5}
# vocat -> term3143 Nt=1 TF=1 maxTF=1 @{0 36728 5}
# vodic -> term4081 Nt=1 TF=1 maxTF=1 @{0 36731 3}
# voic -> term2213 Nt=4 TF=4 maxTF=1 @{0 36734 3}
# volken -> term3394 Nt=1 TF=1 maxTF=1 @{0 36743 3}
# volum -> term2528 Nt=1 TF=1 maxTF=1 @{0 36746 3}
# vom -> term2623 Nt=1 TF=1 maxTF=1 @{0 36749 1}
# von -> term2169 Nt=9 TF=10 maxTF=2 @{0 36751 7}
# vorbild -> term3699 Nt=1 TF=1 maxTF=1 @{0 36770 4}
# voronoi -> term4070 Nt=2 TF=2 maxTF=1 @{0 36773 4}
# vorschl -> term4232 Nt=1 TF=1 maxTF=1 @{0 36778 6}
# vroom -> term3511 Nt=1 TF=1 maxTF=1 @{0 36781 6}
# vsim -> term4908 Nt=1 TF=1 maxTF=1 @{0 36784 6}
# vu -> term1695 Nt=1 TF=1 maxTF=1 @{0 36787 6}
# vukotinov -> term4269 Nt=1 TF=1 maxTF=1 @{0 36790 2}
# w3c -> term3178 Nt=1 TF=1 maxTF=1 @{0 36793 2}
# w4 -> term4225 Nt=1 TF=1 maxTF=1 @{0 36796 0}
# wage -> term2401 Nt=1 TF=1 maxTF=1 @{0 36799 0}
# wahn -> term2612 Nt=1 TF=1 maxTF=1 @{0 36801 6}
# wai -> term2152 Nt=10 TF=10 maxTF=1 @{0 36804 4}
# walk -> term1769 Nt=4 TF=4 maxTF=1 @{0 36824 4}
# wall -> term3665 Nt=3 TF=3 maxTF=1 @{0 36834 4}
# wander -> term4214 Nt=1 TF=1 maxTF=1 @{0 36841 4}
# want -> term4779 Nt=1 TF=1 maxTF=1 @{0 36844 4}
# war -> term4824 Nt=1 TF=1 maxTF=1 @{0 36847 4}
# warc -> term4757 Nt=1 TF=1 maxTF=1 @{0 36850 4}
# warcbas -> term4526 Nt=1 TF=1 maxTF=1 @{0 36853 4}
# warclight -> term4611 Nt=1 TF=1 maxTF=1 @{0 36856 4}
# warehous -> term946 Nt=3 TF=3 maxTF=1 @{0 36859 4}
# wartim -> term4570 Nt=1 TF=1 maxTF=1 @{0 36863 6}
# warum -> term2618 Nt=2 TF=2 maxTF=1 @{0 36866 6}
# wash -> term952 Nt=1 TF=1 maxTF=1 @{0 36872 2}
# washington -> term4148 Nt=1 TF=1 maxTF=1 @{0 36874 4}
# wasp -> term1376 Nt=1 TF=1 maxTF=1 @{0 36877 4}
# waspatla -> term1718 Nt=1 TF=1 maxTF=1 @{0 36880 0}
# wast -> term2046 Nt=1 TF=1 maxTF=1 @{0 36882 4}
# watch -> term5024 Nt=1 TF=1 maxTF=1 @{0 36885 0}
# watcher -> term2045 Nt=1 TF=1 maxTF=1 @{0 36888 0}
# watermark -> term873 Nt=1 TF=1 maxTF=1 @{0 36890 4}
# watson -> term3919 Nt=1 TF=1 maxTF=1 @{0 36892 6}
# wavelet -> term2379 Nt=2 TF=2 maxTF=1 @{0 36895 6}
# wayback -> term4302 Nt=1 TF=1 maxTF=1 @{0 36900 4}
# weak -> term1511 Nt=1 TF=1 maxTF=1 @{0 36903 4}
# weaver -> term642 Nt=1 TF=1 maxTF=1 @{0 36906 0}
# web -> term118 Nt=190 TF=200 maxTF=2 @{0 36908 0}
# webarchivierung -> term4026 Nt=1 TF=1 maxTF=1 @{0 37081 6}
# webcom -> term4465 Nt=1 TF=1 maxTF=1 @{0 37084 6}
# webi -> term4198 Nt=3 TF=3 maxTF=1 @{0 37087 6}
# weblog -> term2787 Nt=1 TF=1 maxTF=1 @{0 37094 2}
# weblogg -> term2397 Nt=1 TF=1 maxTF=1 @{0 37097 0}
# webreport -> term4154 Nt=1 TF=1 maxTF=1 @{0 37099 6}
# websit -> term1218 Nt=4 TF=4 maxTF=1 @{0 37102 6}
# webspac -> term4088 Nt=1 TF=1 maxTF=1 @{0 37111 2}
# wechat -> term3233 Nt=1 TF=1 maxTF=1 @{0 37114 2}
# weekli -> term4001 Nt=2 TF=2 maxTF=1 @{0 37117 0}
# weight -> term2058 Nt=5 TF=5 maxTF=1 @{0 37122 4}
# weiter -> term2015 Nt=1 TF=1 maxTF=1 @{0 37132 4}
# wel -> term4261 Nt=1 TF=1 maxTF=1 @{0 37135 0}
# welcom -> term3458 Nt=2 TF=2 maxTF=1 @{0 37138 0}
# well -> term1786 Nt=1 TF=1 maxTF=1 @{0 37143 4}
# welt -> term4059 Nt=1 TF=1 maxTF=1 @{0 37146 0}
# weltweit -> term3027 Nt=1 TF=1 maxTF=1 @{0 37149 0}
# went -> term3294 Nt=1 TF=1 maxTF=1 @{0 37151 6}
# werkgenesen -> term4725 Nt=1 TF=1 maxTF=1 @{0 37154 6}
# west -> term3825 Nt=3 TF=3 maxTF=1 @{0 37157 6}
# wetland -> term4915 Nt=1 TF=1 maxTF=1 @{0 37164 4}
# wfirst -> term4032 Nt=1 TF=1 maxTF=1 @{0 37167 4}
# whatizit -> term2706 Nt=1 TF=1 maxTF=1 @{0 37170 4}
# wheat -> term569 Nt=2 TF=2 maxTF=1 @{0 37173 2}
# wheel -> term3836 Nt=1 TF=1 maxTF=1 @{0 37177 4}
# white -> term1502 Nt=2 TF=2 maxTF=1 @{0 37180 4}
# who -> term3087 Nt=2 TF=2 maxTF=1 @{0 37185 2}
# whole -> term49 Nt=3 TF=3 maxTF=1 @{0 37190 6}
# wholecellsimdb -> term47 Nt=1 TF=1 maxTF=1 @{0 37197 0}
# wi -> term3214 Nt=1 TF=1 maxTF=1 @{0 37198 0}
# wide -> term72 Nt=12 TF=12 maxTF=1 @{0 37200 6}
# widen -> term3626 Nt=1 TF=1 maxTF=1 @{0 37223 0}
# widespread -> term3900 Nt=1 TF=1 maxTF=1 @{0 37226 0}
# wie -> term2008 Nt=2 TF=2 maxTF=1 @{0 37229 0}
# wiki -> term1027 Nt=2 TF=2 maxTF=1 @{0 37234 2}
# wikibas -> term3316 Nt=1 TF=1 maxTF=1 @{0 37237 6}
# wikidata -> term512 Nt=4 TF=4 maxTF=1 @{0 37240 6}
# wikigenom -> term513 Nt=1 TF=1 maxTF=1 @{0 37248 0}
# wikipedia -> term2162 Nt=11 TF=12 maxTF=2 @{0 37250 0}
# wild -> term2018 Nt=1 TF=1 maxTF=1 @{0 37271 5}
# wildlif -> term1591 Nt=1 TF=1 maxTF=1 @{0 37274 1}
# wilei -> term2482 Nt=1 TF=1 maxTF=1 @{0 37276 5}
# will -> term3495 Nt=4 TF=5 maxTF=2 @{0 37279 3}
# win -> term3905 Nt=1 TF=1 maxTF=1 @{0 37288 6}
# wind -> term4840 Nt=1 TF=1 maxTF=1 @{0 37291 6}
# window -> term1672 Nt=1 TF=1 maxTF=1 @{0 37294 6}
# wine -> term1229 Nt=1 TF=1 maxTF=1 @{0 37297 2}
# winesi -> term1228 Nt=1 TF=1 maxTF=1 @{0 37299 4}
# winner -> term3136 Nt=1 TF=1 maxTF=1 @{0 37301 6}
# wire -> term4157 Nt=1 TF=1 maxTF=1 @{0 37304 4}
# wireless -> term738 Nt=3 TF=3 maxTF=1 @{0 37307 4}
# wise -> term562 Nt=1 TF=1 maxTF=1 @{0 37314 4}
# wissenschaft -> term3026 Nt=1 TF=1 maxTF=1 @{0 37316 4}
# wissenschaftl -> term3029 Nt=1 TF=1 maxTF=1 @{0 37319 2}
# wissenschaftlich -> term4379 Nt=1 TF=1 maxTF=1 @{0 37322 0}
# wissensrohstoff -> term2004 Nt=4 TF=4 maxTF=1 @{0 37325 0}
# wit -> term4591 Nt=1 TF=1 maxTF=1 @{0 37333 0}
# wittelsbach -> term4515 Nt=1 TF=1 maxTF=1 @{0 37336 0}
# wlan -> term2932 Nt=1 TF=1 maxTF=1 @{0 37339 0}
# wlic -> term3313 Nt=15 TF=15 maxTF=1 @{0 37341 6}
# wollen -> term2735 Nt=1 TF=1 maxTF=1 @{0 37362 6}
# women -> term1417 Nt=2 TF=3 maxTF=2 @{0 37365 4}
# wonder -> term3173 Nt=1 TF=1 maxTF=1 @{0 37371 1}
# wood -> term1594 Nt=1 TF=1 maxTF=1 @{0 37373 7}
# woollei -> term3419 Nt=1 TF=1 maxTF=1 @{0 37376 3}
# word -> term1812 Nt=21 TF=22 maxTF=2 @{0 37379 3}
# wordnet -> term639 Nt=10 TF=11 maxTF=2 @{0 37410 6}
# work -> term1184 Nt=18 TF=18 maxTF=1 @{0 37428 7}
# workbench -> term2692 Nt=1 TF=1 maxTF=1 @{0 37461 7}
# worker -> term3162 Nt=3 TF=3 maxTF=1 @{0 37464 5}
# workflow -> term1891 Nt=2 TF=2 maxTF=1 @{0 37471 3}
# workload -> term1158 Nt=4 TF=4 maxTF=1 @{0 37476 5}
# workplac -> term3430 Nt=1 TF=1 maxTF=1 @{0 37485 5}
# workshop -> term1587 Nt=4 TF=4 maxTF=1 @{0 37488 5}
# workstat -> term2925 Nt=2 TF=2 maxTF=1 @{0 37497 1}
# world -> term1089 Nt=29 TF=29 maxTF=1 @{0 37501 5}
# worldcat -> term2949 Nt=3 TF=4 maxTF=2 @{0 37546 5}
# worldwid -> term958 Nt=3 TF=3 maxTF=1 @{0 37553 2}
# worth -> term3978 Nt=1 TF=1 maxTF=1 @{0 37560 4}
# worthington -> term2767 Nt=1 TF=1 maxTF=1 @{0 37563 4}
# wpf -> term4566 Nt=1 TF=1 maxTF=1 @{0 37566 2}
# wrangler -> term4674 Nt=1 TF=1 maxTF=1 @{0 37569 2}
# wrap -> term3937 Nt=1 TF=1 maxTF=1 @{0 37572 2}
# write -> term1984 Nt=5 TF=5 maxTF=1 @{0 37575 2}
# writer -> term3286 Nt=2 TF=3 maxTF=2 @{0 37586 6}
# written -> term2177 Nt=2 TF=2 maxTF=1 @{0 37592 1}
# wroc -> term3840 Nt=1 TF=1 maxTF=1 @{0 37597 5}
# wrox -> term173 Nt=1 TF=1 maxTF=1 @{0 37600 5}
# wuerzburg -> term3327 Nt=1 TF=1 maxTF=1 @{0 37602 1}
# www -> term392 Nt=3 TF=3 maxTF=1 @{0 37605 1}
# wxhaskel -> term3504 Nt=1 TF=1 maxTF=1 @{0 37611 5}
# xad -> term4917 Nt=1 TF=1 maxTF=1 @{0 37614 5}
# xenobiot -> term714 Nt=1 TF=1 maxTF=1 @{0 37617 5}
# xenograft -> term1439 Nt=1 TF=1 maxTF=1 @{0 37619 5}
# xephir -> term1440 Nt=1 TF=1 maxTF=1 @{0 37622 1}
# xisbn -> term2950 Nt=2 TF=2 maxTF=1 @{0 37624 5}
# xml -> term124 Nt=16 TF=16 maxTF=1 @{0 37628 5}
# xmpp -> term4539 Nt=2 TF=2 maxTF=1 @{0 37652 5}
# xpath -> term1992 Nt=3 TF=3 maxTF=1 @{0 37656 7}
# xqueri -> term1991 Nt=3 TF=3 maxTF=1 @{0 37661 7}
# xr -> term3822 Nt=1 TF=1 maxTF=1 @{0 37666 7}
# xsb -> term1658 Nt=1 TF=1 maxTF=1 @{0 37669 7}
# xslt -> term2633 Nt=1 TF=1 maxTF=1 @{0 37672 3}
# xvi -> term2934 Nt=1 TF=1 maxTF=1 @{0 37675 1}
# yat -> term3243 Nt=1 TF=1 maxTF=1 @{0 37677 7}
# year -> term1191 Nt=12 TF=12 maxTF=1 @{0 37680 5}
# yeast -> term20 Nt=2 TF=2 maxTF=1 @{0 37704 1}
# yeastgenom -> term1799 Nt=1 TF=1 maxTF=1 @{0 37707 1}
# yeastract -> term831 Nt=1 TF=1 maxTF=1 @{0 37709 5}
# yeastss -> term1805 Nt=1 TF=1 maxTF=1 @{0 37711 5}
# yh -> term1679 Nt=1 TF=1 maxTF=1 @{0 37714 1}
# yield -> term2848 Nt=1 TF=1 maxTF=1 @{0 37716 5}
# york -> term3155 Nt=2 TF=2 maxTF=1 @{0 37719 3}
# young -> term2521 Nt=2 TF=2 maxTF=1 @{0 37723 3}
# youth -> term210 Nt=2 TF=2 maxTF=1 @{0 37728 5}
# yuan -> term4683 Nt=1 TF=1 maxTF=1 @{0 37733 1}
# z39 -> term3469 Nt=1 TF=1 maxTF=1 @{0 37736 1}
# zagrabia -> term4283 Nt=1 TF=1 maxTF=1 @{0 37739 1}
# zambia -> term3566 Nt=1 TF=1 maxTF=1 @{0 37742 1}
# zaria -> term3127 Nt=1 TF=1 maxTF=1 @{0 37745 1}
# zbirk -> term4079 Nt=1 TF=1 maxTF=1 @{0 37747 7}
# zdravstvenom -> term4945 Nt=1 TF=1 maxTF=1 @{0 37750 7}
# zealand -> term2943 Nt=1 TF=1 maxTF=1 @{0 37753 7}
# zebrafish -> term1438 Nt=2 TF=2 maxTF=1 @{0 37756 5}
# zeit -> term2564 Nt=1 TF=1 maxTF=1 @{0 37761 1}
# zeitschrift -> term2547 Nt=2 TF=2 maxTF=1 @{0 37763 7}
# zeitschriften -> term3036 Nt=1 TF=1 maxTF=1 @{0 37769 3}
# zeitung -> term4828 Nt=2 TF=2 maxTF=1 @{0 37772 1}
# zeri -> term4469 Nt=1 TF=1 maxTF=1 @{0 37776 5}
# zero -> term2117 Nt=4 TF=4 maxTF=1 @{0 37779 5}
# zflnc -> term1785 Nt=1 TF=1 maxTF=1 @{0 37789 1}
# zhang -> term3924 Nt=1 TF=1 maxTF=1 @{0 37791 5}
# zhusuan -> term3280 Nt=1 TF=1 maxTF=1 @{0 37794 5}
# zinc -> term1462 Nt=1 TF=1 maxTF=1 @{0 37797 3}
# zincbind -> term1463 Nt=1 TF=1 maxTF=1 @{0 37799 7}
# zip -> term2161 Nt=1 TF=1 maxTF=1 @{0 37802 3}
# zitationsanalys -> term4238 Nt=1 TF=1 maxTF=1 @{0 37805 1}
# zn -> term704 Nt=1 TF=1 maxTF=1 @{0 37808 1}
# zotero -> term3476 Nt=2 TF=2 maxTF=1 @{0 37810 1}
# zu -> term2274 Nt=3 TF=3 maxTF=1 @{0 37815 1}
# zubud -> term1275 Nt=1 TF=1 maxTF=1 @{0 37822 5}
# zug -> term4502 Nt=1 TF=1 maxTF=1 @{0 37824 7}
# zugang -> term3783 Nt=1 TF=1 maxTF=1 @{0 37827 7}
# zugest -> term2710 Nt=1 TF=1 maxTF=1 @{0 37830 7}
# zugriff -> term3033 Nt=1 TF=1 maxTF=1 @{0 37833 5}
# zugriffskontrol -> term4900 Nt=1 TF=1 maxTF=1 @{0 37836 3}
# zukunft -> term3749 Nt=2 TF=2 maxTF=1 @{0 37839 3}
# zuletzt -> term2729 Nt=1 TF=1 maxTF=1 @{0 37844 3}
# zum -> term2648 Nt=3 TF=3 maxTF=1 @{0 37847 1}
# zur -> term2316 Nt=6 TF=6 maxTF=1 @{0 37854 7}
# zuse -> term4301 Nt=1 TF=1 maxTF=1 @{0 37868 3}
# zwangsarbeit -> term4143 Nt=1 TF=1 maxTF=1 @{0 37871 3}
# zwei -> term3992 Nt=1 TF=1 maxTF=1 @{0 37874 3}
# zwischen -> term2730 Nt=1 TF=1 maxTF=1 @{0 37877 3}
# zwischenarchiv -> term4404 Nt=1 TF=1 maxTF=1 @{0 37880 1}
# zxing -> term3489 Nt=1 TF=1 maxTF=1 @{0 37883 1}

# %%
term_freq_dict = {}

for kv in index.getLexicon():
    term_freq_dict[kv.getKey()] = kv.getValue().frequency

# %%
term_freq_dict_sorted = sorted(term_freq_dict.items(), key=lambda x: x[1], reverse=True)

# %%
top_k = 30
term_freq_dict_sorted[:top_k]
# Out:
# [('librari', 981),
#  ('archiv', 893),
#  ('databas', 824),
#  ('text', 824),
#  ('data', 252),
#  ('system', 239),
#  ('base', 234),
#  ('web', 200),
#  ('digit', 179),
#  ('us', 171),
#  ('analysi', 141),
#  ('model', 141),
#  ('mine', 130),
#  ('classif', 122),
#  ('research', 115),
#  ('servic', 111),
#  ('manag', 109),
#  ('green', 100),
#  ('new', 99),
#  ('sustain', 99),
#  ('learn', 92),
#  ('semant', 85),
#  ('studi', 85),
#  ('design', 84),
#  ('network', 80),
#  ('approach', 78),
#  ('integr', 77),
#  ('resourc', 76),
#  ('search', 76),
#  ('gener', 75)]

# %%
search_engine = pt.BatchRetrieve(index, wmodel="Tf")
# Out:
# /var/folders/88/9blsh45918g8y3n5vl6vztxr0000gq/T/ipykernel_1707/951663741.py:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   search_engine = pt.BatchRetrieve(index, wmodel="Tf")

# %%
search_engine.search("system")
# Out:
#     qid  docid                                              docno  rank  \
# 0     1    775  https://www.bibsonomy.org/bibtex/27cebe02af1e4...     0
# 1     1    791  https://www.bibsonomy.org/bibtex/2e8737a4cce47...     1
# 2     1    794  https://www.bibsonomy.org/bibtex/2072b030962e3...     2
# 3     1   1568  https://www.bibsonomy.org/bibtex/280f75bb46fcb...     3
# 4     1     17  https://www.bibsonomy.org/bibtex/28af31bbdb0bd...     4
# ..   ..    ...                                                ...   ...
# 230   1   3472  https://www.bibsonomy.org/bibtex/2ae6a916923ad...   230
# 231   1   3489  https://www.bibsonomy.org/bibtex/2390b02f23f3d...   231
# 232   1   3494  https://www.bibsonomy.org/bibtex/25d3f12c5e0f6...   232
# 233   1   3495  https://www.bibsonomy.org/bibtex/270a5cfbabcbb...   233
# 234   1   3511  https://www.bibsonomy.org/bibtex/25926f6dbad9b...   234
#
#      score   query
# 0      2.0  system
# 1      2.0  system
# 2      2.0  system
# 3      2.0  system
# 4      1.0  system
# ..     ...     ...
# 230    1.0  system
# 231    1.0  system
# 232    1.0  system
# 233    1.0  system
# 234    1.0  system
#
# [235 rows x 6 columns]

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
stem = stemmer.stem("learning")
stem
# Out:
# 'learn'

# %%
lexicon = index.getLexicon()
lexicon[stem].getDocumentFrequency()
# Out:
# 90

# %%
index.getCollectionStatistics().numberOfDocuments
# Out:
# 3520

# %%
def get_idf_for_term(term, index):
  lex = index.getLexicon()
  stemmed_term = stemmer.stem(term)

  if not stemmed_term in lex:
    return 
    
  lex_entry = lex[stemmed_term]

  df_term = lex_entry.getDocumentFrequency()
  N = index.getCollectionStatistics().numberOfDocuments
  
  #inverse document frequency
  idf = N/df_term

  #apply logarithm(base 10) to idf
  log_idf = np.emath.logn(10, idf)

  return log_idf

# %%
get_idf_for_term("learning", index)
# Out:
# 1.592300154038806

# %%
#define your own tf_idf method here:

def calc_tf_idf(query, docno, index):
    #remember that tfidf is the product of two components
    #hint: the tf model search result contains tf frequencies
    return 0

# %%
search_engine_tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")
# Out:
# /var/folders/88/9blsh45918g8y3n5vl6vztxr0000gq/T/ipykernel_1707/2880449899.py:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   search_engine_tfidf = pt.BatchRetrieve(index, wmodel="TF_IDF")

# %%
search_engine_tfidf.search("database")
# Out:
#     qid  docid                                              docno  rank  \
# 0     1      7  https://www.bibsonomy.org/bibtex/2b8151c596a8d...     0
# 1     1    716  https://www.bibsonomy.org/bibtex/25802e079a691...     1
# 2     1     29  https://www.bibsonomy.org/bibtex/292e537486422...     2
# 3     1    237  https://www.bibsonomy.org/bibtex/2949b00f83f34...     3
# 4     1    353  https://www.bibsonomy.org/bibtex/2baef7a8d376b...     4
# ..   ..    ...                                                ...   ...
# 779   1    907  https://www.bibsonomy.org/bibtex/2f43d9d72eae5...   779
# 780   1    297  https://www.bibsonomy.org/bibtex/2170909f0b219...   780
# 781   1    420  https://www.bibsonomy.org/bibtex/25fbb861f86f5...   781
# 782   1    214  https://www.bibsonomy.org/bibtex/2251c59300d5d...   782
# 783   1   2307  https://www.bibsonomy.org/bibtex/28edcbb8e3073...   783
#
#         score     query
# 0    2.087840  database
# 1    2.060145  database
# 2    1.995273  database
# 3    1.995273  database
# 4    1.995273  database
# ..        ...       ...
# 779  0.902869  database
# 780  0.868039  database
# 781  0.868039  database
# 782  0.835797  database
# 783  0.835797  database
#
# [784 rows x 6 columns]

# %%
# Index with multiple fields
df_dict = df_filtered.to_dict(orient='records')

# %%
df_dict
# Out:
# [{'title': 'EcoliNet: a database of cofunctional gene network for Escherichia coli.',
#   'id': 'https://www.bibsonomy.org/bibtex/2750b8770eec83ca7d18107df3d520113/karthikraman',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1093/database/bav001',
#   'year': 2015,
#   'authors': ['Hanhae Kim', 'Jung Eun E. Shim', 'Junha Shin', 'Insuk Lee'],
#   'doi': '10.1093/database/bav001',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2750b8770eec83ca7d18107df3d520113/karthikraman',
#   'text': 'EcoliNet: a database of cofunctional gene network for Escherichia coli.'},
#  {'title': 'The drug-minded protein interaction database (DrumPID) for efficient target analysis and drug development.',
#   'id': 'https://www.bibsonomy.org/bibtex/2d93ac9b6cfa60505ee7b3d7ffefca15f/karthikraman',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1093/database/baw041',
#   'year': 2016,
#   'authors': ['Meik Kunz',
#    'Chunguang Liang',
#    'Santosh Nilla',
#    'Alexander Cecil',
#    'Thomas Dandekar'],
#   'doi': '10.1093/database/baw041',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2d93ac9b6cfa60505ee7b3d7ffefca15f/karthikraman',
#   'text': 'The drug-minded protein interaction database (DrumPID) for efficient target analysis and drug development.'},
#  {'title': 'PhosphoGRID: a database of experimentally verified in vivo protein phosphorylation sites from the budding yeast Saccharomyces cerevisiae.',
#   'id': 'https://www.bibsonomy.org/bibtex/233d3effaf95a6d714a6fb06099bdf647/karthikraman',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1093/database/bap026',
#   'year': 2010,
#   'authors': ['Chris Stark',
#    'Ting-Cheng C. Su',
#    'Ashton Breitkreutz',
#    'Pedro Lourenco',
#    'Matthew Dahabieh',
#    'Bobby-Joe J. Breitkreutz',
#    'Mike Tyers',
#    'Ivan Sadowski'],
#   'doi': '10.1093/database/bap026',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/233d3effaf95a6d714a6fb06099bdf647/karthikraman',
#   'text': 'PhosphoGRID: a database of experimentally verified in vivo protein phosphorylation sites from the budding yeast Saccharomyces cerevisiae.'},
#  {'title': 'GoSynthetic database tool to analyse natural and engineered molecular processes',
#   'id': 'https://www.bibsonomy.org/bibtex/2ca6461cce248858567237c85cca8f378/evp66rk',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1093/database/bat043',
#   'year': 2013,
#   'authors': ['C. Liang', 'B. Kruger', 'T. Dandekar'],
#   'doi': '10.1093/database/bat043',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2ca6461cce248858567237c85cca8f378/evp66rk',
#   'text': 'GoSynthetic database tool to analyse natural and engineered molecular processes'},
#  {'title': 'Database for Mobile Application',
#   'id': 'https://www.bibsonomy.org/bibtex/2eb1605409b134cc14adb1c45bc1bd3b0/ijtsrd',
#   'type': 'Publication',
#   'url': 'http://www.ijtsrd.com/computer-science/database/11215/database-for-mobile-application/jasra-nisar',
#   'year': 2018,
#   'authors': ['Jasra Nisar Owais Noor Trumboo'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2eb1605409b134cc14adb1c45bc1bd3b0/ijtsrd',
#   'text': 'Database for Mobile Application'},
#  {'title': 'An international otology database',
#   'id': 'https://www.bibsonomy.org/bibtex/25f85238089c4a2ec183b243bf83fa523/stevenarild',
#   'type': 'Publication',
#   'url': 'http://www.ncbi.nlm.nih.gov.ep.fjernadgang.kb.dk/pubmed/?term=yung+gjuric+haeusler',
#   'year': 2005,
#   'authors': ['M Yung',
#    'M Gjuric',
#    'R Haeusler',
#    'P H Van de Heyning',
#    'C Martin',
#    'I R Swan',
#    'R A Tange',
#    'P T Huy',
#    ' European Otology Database Project Group'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/25f85238089c4a2ec183b243bf83fa523/stevenarild',
#   'text': 'An international otology database'},
#  {'title': 'Enable Auditing in Oracle database',
#   'id': 'https://www.bibsonomy.org/bibtex/27757584ce817952545d28d956896ba6a/ijtsrd',
#   'type': 'Publication',
#   'url': 'https://www.ijtsrd.com/computer-science/database/29881/enable-auditing-in-oracle-database/amrish-srivastava',
#   'year': 2019,
#   'authors': ['Amrish Srivastava'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/27757584ce817952545d28d956896ba6a/ijtsrd',
#   'text': 'Enable Auditing in Oracle database'},
#  {'title': 'Database and database application security',
#   'id': 'https://www.bibsonomy.org/bibtex/2b8151c596a8d3eb7e7233f1a47d53b08/malte.wunsch',
#   'type': 'Publication',
#   'url': 'http://portal.acm.org/citation.cfm?id=1562877.1562909',
#   'year': 2009,
#   'authors': ['Huwida E. Said',
#    'Mario A. Guimaraes',
#    'Zakaria Maamar',
#    'Leon Jololian'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2b8151c596a8d3eb7e7233f1a47d53b08/malte.wunsch',
#   'text': 'Database and database application security'},
#  {'title': 'Vertical partitioning algorithms for database design',
#   'id': 'https://www.bibsonomy.org/bibtex/281eb5e7b67cc969365c65a67721cb495/joergh',
#   'type': 'Publication',
#   'url': 'http://portal.acm.org/citation.cfm?id=1994.2209',
#   'year': 1984,
#   'authors': ['Shamkant Navathe',
#    'Stefano Ceri',
#    'Gio Wiederhold',
#    'Jinglie Dou'],
#   'doi': 'http://doi.acm.org/10.1145/1994.2209',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/281eb5e7b67cc969365c65a67721cb495/joergh',
#   'text': 'Vertical partitioning algorithms for database design'},
#  {'title': 'The Reactome BioMart.',
#   'id': 'https://www.bibsonomy.org/bibtex/206ba5aaa99967712038c684d1864c421/karthikraman',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1093/database/bar031',
#   'year': 2011,
#   'authors': ['Robin A. Haw',
#    'David Croft',
#    'Christina K. Yung',
#    'Nelson Ndegwa',
#    "Peter D'Eustachio",
#    'Henning Hermjakob',
#    'Lincoln D. Stein'],
#   'doi': '10.1093/database/bar031',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/206ba5aaa99967712038c684d1864c421/karthikraman',
#   'text': 'The Reactome BioMart.'},
#  {'title': 'WholeCellSimDB: a hybrid relational/HDF database for whole-cell model predictions.',
#   'id': 'https://www.bibsonomy.org/bibtex/235a7f0439923ab61281f80bb4fbe77c9/karthikraman',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1093/database/bau095',
#   'year': 2014,
#   'authors': ['Jonathan R. Karr', 'Nolan C. Phillips', 'Markus W. Covert'],
#   'doi': '10.1093/database/bau095',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/235a7f0439923ab61281f80bb4fbe77c9/karthikraman',
#   'text': 'WholeCellSimDB: a hybrid relational/HDF database for whole-cell model predictions.'},
#  {'title': 'Oracle Database Backup Testing',
#   'id': 'https://www.bibsonomy.org/bibtex/23300b9d02e6150493d24278d652fd980/ijtsrd',
#   'type': 'Publication',
#   'url': 'http://www.ijtsrd.com/computer-science/database/11572/oracle-database-backup-testing/vijay-kumar-tiwari',
#   'year': 2018,
#   'authors': ['Vijay Kumar Tiwari'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/23300b9d02e6150493d24278d652fd980/ijtsrd',
#   'text': 'Oracle Database Backup Testing'},
#  {'title': 'Implications of certain assumptions in database performance evauation',
#   'id': 'https://www.bibsonomy.org/bibtex/2a8e950024e05fb6206578bb5a3c4d44a/jhammerb',
#   'type': 'Publication',
#   'url': 'http://portal.acm.org/citation.cfm?doid=329.318578',
#   'year': 1984,
#   'authors': ['S. Christodoulakis'],
#   'doi': 'http://doi.acm.org/10.1145/329.318578',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2a8e950024e05fb6206578bb5a3c4d44a/jhammerb',
#   'text': 'Implications of certain assumptions in database performance evauation'},
#  {'title': 'A standardized database management of middle ear surgery in Korea',
#   'id': 'https://www.bibsonomy.org/bibtex/24d001da0c68be5efe71702f9ecc2e4f2/stevenarild',
#   'type': 'Publication',
#   'url': 'http://www.ncbi.nlm.nih.gov.ep.fjernadgang.kb.dk/pubmed/?term=kim+hj+a+standardized+database+management',
#   'year': 2007,
#   'authors': ['H J Kim'],
#   'doi': '10.1080/03655230701624871',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/24d001da0c68be5efe71702f9ecc2e4f2/stevenarild',
#   'text': 'A standardized database management of middle ear surgery in Korea'},
#  {'title': 'SwissRegulon, a database of genome-wide annotations of regulatory sites: recent updates',
#   'id': 'https://www.bibsonomy.org/bibtex/2e15360b1fc6345c1913a65b3112680fd/karthikraman',
#   'type': 'Publication',
#   'url': 'https://www.ncbi.nlm.nih.gov/pubmed/?term=SwissRegulon%2C+a+database+of+genome-wide+annotations+of+regulatory+sites%3A+recent+updates',
#   'year': 2013,
#   'authors': ['M Pachkov',
#    'P J Balwierz',
#    'P Arnold',
#    'E Ozonov',
#    'E van Nimwegen'],
#   'doi': '10.1093/nar/gks1145',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2e15360b1fc6345c1913a65b3112680fd/karthikraman',
#   'text': 'SwissRegulon, a database of genome-wide annotations of regulatory sites: recent updates'},
#  {'title': 'ConsensusPathDB--a database for integrating human functional interaction networks',
#   'id': 'https://www.bibsonomy.org/bibtex/22b7406cd1753f56e5a06ae8b48b24cdf/wnpxrz',
#   'type': 'Publication',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18940869',
#   'year': 2009,
#   'authors': ['A Kamburov', 'C Wierling', 'H Lehrach', 'R Herwig'],
#   'doi': '10.1093/nar/gkn698',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/22b7406cd1753f56e5a06ae8b48b24cdf/wnpxrz',
#   'text': 'ConsensusPathDB--a database for integrating human functional interaction networks'},
#  {'title': 'PID: the Pathway Interaction Database',
#   'id': 'https://www.bibsonomy.org/bibtex/250055d426be1ad08439d9523ae3c83d1/wnpxrz',
#   'type': 'Publication',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/18832364',
#   'year': 2009,
#   'authors': ['C F Schaefer',
#    'K Anthony',
#    'S Krupa',
#    'J Buchoff',
#    'M Day',
#    'T Hannay',
#    'K H Buetow'],
#   'doi': '10.1093/nar/gkn653',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/250055d426be1ad08439d9523ae3c83d1/wnpxrz',
#   'text': 'PID: the Pathway Interaction Database'},
#  {'title': 'Parallel database systems: the future of database processing or a passing fad?',
#   'id': 'https://www.bibsonomy.org/bibtex/28af31bbdb0bde12ef6965492973f4831/jhammerb',
#   'type': 'Publication',
#   'url': 'http://portal.acm.org/citation.cfm?id=122058.122071',
#   'year': 1990,
#   'authors': ['David J. DeWitt', 'Jim Gray'],
#   'doi': 'http://doi.acm.org/10.1145/122058.122071',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/28af31bbdb0bde12ef6965492973f4831/jhammerb',
#   'text': 'Parallel database systems: the future of database processing or a passing fad?'},
#  {'title': 'The HUGO Gene Nomenclature Database, 2006 updates',
#   'id': 'https://www.bibsonomy.org/bibtex/29b3aa72d312bf8a3e038ca92b6612fcd/sbsad',
#   'type': 'Publication',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/16381876',
#   'year': 2006,
#   'authors': ['T A Eyre',
#    'F Ducluzeau',
#    'T P Sneddon',
#    'S Povey',
#    'E A Bruford',
#    'M J Lush'],
#   'doi': '10.1093/nar/gkj147',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/29b3aa72d312bf8a3e038ca92b6612fcd/sbsad',
#   'text': 'The HUGO Gene Nomenclature Database, 2006 updates'},
#  {'title': 'Traditional Databases vs NOSQL',
#   'id': 'https://www.bibsonomy.org/bibtex/2a25665734dddc3bd249a981cd424fc74/ijtsrd',
#   'type': 'Publication',
#   'url': 'http://www.ijtsrd.com/computer-science/database/12961/traditional-databases-vs-nosql/owais-noor-trumboo',
#   'year': 2018,
#   'authors': ['Owais Noor Trumboo Jasra Nisar'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2a25665734dddc3bd249a981cd424fc74/ijtsrd',
#   'text': 'Traditional Databases vs NOSQL'},
#  {'title': 'Federated database systems for managing distributed, heterogeneous, and autonomous databases',
#   'id': 'https://www.bibsonomy.org/bibtex/2d8ab08ff39573bd64e7dc080adb2230b/buehner',
#   'type': 'Publication',
#   'url': 'http://delivery.acm.org/10.1145/100000/96604/p183-sheth.pdf?key1=96604&key2=8693487821&coll=GUIDE&dl=ACM&CFID=107002774&CFTOKEN=13258373',
#   'year': 1990,
#   'authors': ['Amit P. Sheth', 'James A. Larson'],
#   'doi': '10.1145/96602.96604',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2d8ab08ff39573bd64e7dc080adb2230b/buehner',
#   'text': 'Federated database systems for managing distributed, heterogeneous, and autonomous databases'},
#  {'title': 'Migration from relational database like MySQL to nosql database like Cassandra is necessary and how to migrate it using spark',
#   'id': 'https://www.bibsonomy.org/bibtex/2c47aa8b0c0695dbf04c04e34bb3a9101/ijtsrd',
#   'type': 'Publication',
#   'url': 'http://www.ijtsrd.com/engineering/computer-engineering/57/migration-from-relational-database-like-mysql-to-nosql-database-like-cassandra-is-necessary-and-how-to-migrate-it-using-spark/dr-kishor-atkotiya',
#   'year': 2016,
#   'authors': ['Dr. Kishor Atkotiya | Parag Shukla'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2c47aa8b0c0695dbf04c04e34bb3a9101/ijtsrd',
#   'text': 'Migration from relational database like MySQL to nosql database like Cassandra is necessary and how to migrate it using spark'},
#  {'title': 'Database Security Model using Access Control Mechanism in Student Data Management',
#   'id': 'https://www.bibsonomy.org/bibtex/2f21be0dc285cb90890e1d9ce3146a63a/ijtsrd',
#   'type': 'Publication',
#   'url': 'https://www.ijtsrd.com/computer-science/database/22820/database-security-model-using-access-control-mechanism-in-student-data-management/aye-mon-win',
#   'year': 2019,
#   'authors': ['Aye Mon Win | Khin Lay Myint'],
#   'doi': 'https://doi.org/10.31142/ijtsrd22820',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2f21be0dc285cb90890e1d9ce3146a63a/ijtsrd',
#   'text': 'Database Security Model using Access Control Mechanism in Student Data Management'},
#  {'title': 'Survival of an Intrusion Tolerance Database System',
#   'id': 'https://www.bibsonomy.org/bibtex/24f8b60cb12c7f1d1b31465d7e7b2f44b/ijtsrd',
#   'type': 'Publication',
#   'url': 'https://www.ijtsrd.com/computer-science/computer-security/26748/survival-of-an-intrusion-tolerance-database-system/su-thawda-win',
#   'year': 2019,
#   'authors': ['Su Thawda Win'],
#   'doi': 'https://doi.org/10.31142/ijtsrd26748',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/24f8b60cb12c7f1d1b31465d7e7b2f44b/ijtsrd',
#   'text': 'Survival of an Intrusion Tolerance Database System'},
#  {'title': 'BioNumbers--the database of key numbers in molecular and cell biology',
#   'id': 'https://www.bibsonomy.org/bibtex/2c35febbc664422e27257b6f2f27b40f4/karthikraman',
#   'type': 'Publication',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2808940/',
#   'year': 2010,
#   'authors': ['R Milo', 'P Jorgensen', 'U Moran', 'G Weber', 'M Springer'],
#   'doi': '10.1093/nar/gkp889',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2c35febbc664422e27257b6f2f27b40f4/karthikraman',
#   'text': 'BioNumbers--the database of key numbers in molecular and cell biology'},
#  {'title': 'Janaushadhi Database Management System',
#   'id': 'https://www.bibsonomy.org/bibtex/20900193932683227409336a3befeac54/ijtsrd',
#   'type': 'Publication',
#   'url': 'https://www.ijtsrd.com/computer-science/database/26403/janaushadhi-database-management-system/naimisha-u',
#   'year': 2019,
#   'authors': ['Naimisha U | Ashritha A'],
#   'doi': 'https://doi.org/10.31142/ijtsrd26403',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/20900193932683227409336a3befeac54/ijtsrd',
#   'text': 'Janaushadhi Database Management System'},
#  {'title': 'GAMMA\\—a high performance dataflow database machine',
#   'id': 'https://www.bibsonomy.org/bibtex/2a295018d8ecc0212aca487ae1b0c753e/jhammerb',
#   'type': 'Publication',
#   'url': 'http://portal.acm.org/citation.cfm?id=48751.48773',
#   'year': 1988,
#   'authors': ['David J. DeWitt',
#    'Goetz Graefe',
#    'Krishna B. Kumar',
#    'Robert H. Gerber',
#    'Michael L. Heytens',
#    'M. Muralikrishna'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2a295018d8ecc0212aca487ae1b0c753e/jhammerb',
#   'text': 'GAMMA\\—a high performance dataflow database machine'},
#  {'title': 'Performance Driven Database Design for Scalable Web Applications',
#   'id': 'https://www.bibsonomy.org/bibtex/2c753bff717eb9632d39e3679f7c269ef/mbruschi',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1007/978-3-642-03973-7_5',
#   'year': 2009,
#   'authors': ['Jozsef Patvarczki', 'Murali Mani', 'Neil Heffernan'],
#   'doi': '10.1007/978-3-642-03973-7_5',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2c753bff717eb9632d39e3679f7c269ef/mbruschi',
#   'text': 'Performance Driven Database Design for Scalable Web Applications'},
#  {'title': 'A comparative analysis of methodologies for database schema integration',
#   'id': 'https://www.bibsonomy.org/bibtex/22636802d129dbf10d3dc35bdfdc6efb6/gravity',
#   'type': 'Publication',
#   'url': 'http://portal.acm.org/citation.cfm?doid=27633.27634',
#   'year': 1986,
#   'authors': ['C. Batini', 'M. Lenzerini', 'S. B. Navathe'],
#   'doi': 'http://doi.acm.org/10.1145/27633.27634',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/22636802d129dbf10d3dc35bdfdc6efb6/gravity',
#   'text': 'A comparative analysis of methodologies for database schema integration'},
#  {'title': 'A Comparison between Relational Databases and NoSQL Databases',
#   'id': 'https://www.bibsonomy.org/bibtex/292e537486422445d574ddbbef9a49300/ijtsrd',
#   'type': 'Publication',
#   'url': 'http://www.ijtsrd.com/computer-science/database/11214/a-comparison-between-relational-databases-and-nosql-databases/behjat-u-nisa',
#   'year': 2018,
#   'authors': ['Behjat U Nisa'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/292e537486422445d574ddbbef9a49300/ijtsrd',
#   'text': 'A Comparison between Relational Databases and NoSQL Databases'},
#  {'title': 'XML and relational database management systems: the inside story',
#   'id': 'https://www.bibsonomy.org/bibtex/26d3b73cfb1b666af1155c893cd37f5d5/malte.wunsch',
#   'type': 'Publication',
#   'url': 'http://portal.acm.org/citation.cfm?id=1066157.1066298',
#   'year': 2005,
#   'authors': ['Michael Rys', 'Don Chamberlin', 'Daniela Florescu'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/26d3b73cfb1b666af1155c893cd37f5d5/malte.wunsch',
#   'text': 'XML and relational database management systems: the inside story'},
#  {'title': 'The Claremont report on database research',
#   'id': 'https://www.bibsonomy.org/bibtex/2c23ca6a7338e9687327054b7d62596bf/sb3000',
#   'type': 'Publication',
#   'url': 'http://doi.acm.org/10.1145/1516046.1516062',
#   'year': 2009,
#   'authors': ['Rakesh Agrawal',
#    'Anastasia Ailamaki',
#    'Philip A. Bernstein',
#    'Eric A. Brewer',
#    'Michael J. Carey',
#    'Surajit Chaudhuri',
#    'Anhai Doan',
#    'Daniela Florescu',
#    'Michael J. Franklin',
#    'Hector Garcia-Molina',
#    'Johannes Gehrke',
#    'Le Gruenwald',
#    'Laura M. Haas',
#    'Alon Y. Halevy',
#    'Joseph M. Hellerstein',
#    'Yannis E. Ioannidis',
#    'Hank F. Korth',
#    'Donald Kossmann',
#    'Samuel Madden',
#    'Roger Magoulas',
#    'Beng Chin Ooi',
#    "Tim O'Reilly",
#    'Raghu Ramakrishnan',
#    'Sunita Sarawagi',
#    'Michael Stonebraker',
#    'Alexander S. Szalay',
#    'Gerhard Weikum'],
#   'doi': '10.1145/1516046.1516062',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2c23ca6a7338e9687327054b7d62596bf/sb3000',
#   'text': 'The Claremont report on database research'},
#  {'title': 'Argonaute--a database for gene regulation by mammalian microRNAs.',
#   'id': 'https://www.bibsonomy.org/bibtex/2ebee7ffeb63027567b55bf06c3d56e87/bbrors',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1093/nar/gkj093',
#   'year': 2006,
#   'authors': ['Priyanka Shahi',
#    'Serguei Loukianiouk',
#    'Andreas Bohne-Lang',
#    'Marc Kenzelmann',
#    'Stefan Küffer',
#    'Sabine Maertens',
#    'Roland Eils',
#    'Herrmann-Josef Gröne',
#    'Norbert Gretz',
#    'Benedikt Brors'],
#   'doi': '10.1093/nar/gkj093',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2ebee7ffeb63027567b55bf06c3d56e87/bbrors',
#   'text': 'Argonaute--a database for gene regulation by mammalian microRNAs.'},
#  {'title': 'Meta-Modeling to design the Structured Database Schema',
#   'id': 'https://www.bibsonomy.org/bibtex/21ff8657202cd17730f4dfb25f867073d/dm.kovalev',
#   'type': 'Publication',
#   'url': '',
#   'year': 2006,
#   'authors': ['Elvira Locuratolo'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/21ff8657202cd17730f4dfb25f867073d/dm.kovalev',
#   'text': 'Meta-Modeling to design the Structured Database Schema'},
#  {'title': 'SMPDB: The Small Molecule Pathway Database.',
#   'id': 'https://www.bibsonomy.org/bibtex/28679729b73db4e8c758f177ed6c1b7bb/karthikraman',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1093/nar/gkp1002',
#   'year': 2010,
#   'authors': ['Alex Frolkis',
#    'Craig Knox',
#    'Emilia Lim',
#    'Timothy Jewison',
#    'Vivian Law',
#    'David D. Hau',
#    'Phillip Liu',
#    'Bijaya Gautam',
#    'Son Ly',
#    'An Chi C. Guo',
#    'Jianguo Xia',
#    'Yongjie Liang',
#    'Savita Shrivastava',
#    'David S. Wishart'],
#   'doi': '10.1093/nar/gkp1002',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/28679729b73db4e8c758f177ed6c1b7bb/karthikraman',
#   'text': 'SMPDB: The Small Molecule Pathway Database.'},
#  {'title': 'RAIN: RNA-protein Association and Interaction Networks.',
#   'id': 'https://www.bibsonomy.org/bibtex/2d13ac84ab45538ea9d0463e006d70ffa/karthikraman',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1093/database/baw167',
#   'year': 2017,
#   'authors': ['Alexander Junge',
#    'Jan C. Refsgaard',
#    'Christian Garde',
#    'Xiaoyong Pan',
#    'Alberto Santos',
#    'Ferhat Alkan',
#    'Christian Anthon',
#    'Christian von Mering',
#    'Christopher T. Workman',
#    'Lars Juhl J. Jensen',
#    'Jan Gorodkin'],
#   'doi': '10.1093/database/baw167',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2d13ac84ab45538ea9d0463e006d70ffa/karthikraman',
#   'text': 'RAIN: RNA-protein Association and Interaction Networks.'},
#  {'title': 'LIGAND: chemical database of enzyme reactions',
#   'id': 'https://www.bibsonomy.org/bibtex/263a5437227eab1cc867c5cf5e310779e/artheibault',
#   'type': 'Publication',
#   'url': 'http://dblp.uni-trier.de/db/journals/nar/nar28.html#GotoNK00',
#   'year': 2000,
#   'authors': ['Susumu Goto', 'Takaaki Nishioka', 'Minoru Kanehisa'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/263a5437227eab1cc867c5cf5e310779e/artheibault',
#   'text': 'LIGAND: chemical database of enzyme reactions'},
#  {'title': 'ChEBI - Chemical Entities of Biological Interest',
#   'id': 'https://www.bibsonomy.org/bibtex/232c444add4e2b89c8e61b6406211eb0f/fairybasslet',
#   'type': 'Publication',
#   'url': 'http://www.oxfordjournals.org/nar/database/summary/646',
#   'year': 2006,
#   'authors': ['P. de Matos',
#    'M. Ennis',
#    'M. Zbinden',
#    'A. McNaught',
#    'R. Alcántara',
#    'M. Darsow',
#    'M. Guedj',
#    'M. Ashburner',
#    'K. Degtyarenko'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/232c444add4e2b89c8e61b6406211eb0f/fairybasslet',
#   'text': 'ChEBI - Chemical Entities of Biological Interest'},
#  {'title': 'On replacing standard system error messages for relational database constraints with context aware natural language ones',
#   'id': 'https://www.bibsonomy.org/bibtex/28295d89e9077528ec2e8075a7e3450c0/gjetajournal',
#   'type': 'Publication',
#   'url': 'https://gjeta.com/content/replacing-standard-system-error-messages-relational-database-constraints-context-aware',
#   'year': 2023,
#   'authors': ['Diana Christina Mancas'],
#   'doi': '10.30574/gjeta.2023.14.3.0062',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/28295d89e9077528ec2e8075a7e3450c0/gjetajournal',
#   'text': 'On replacing standard system error messages for relational database constraints with context aware natural language ones'},
#  {'title': 'PolyQ Database - an integrated database on polyglutamine diseases.',
#   'id': 'https://www.bibsonomy.org/bibtex/2fa048127b5236c08aad055f921f0f172/dblp',
#   'type': 'Publication',
#   'url': 'http://dblp.uni-trier.de/db/journals/biodb/biodb2023.html#EstevamMN23',
#   'year': 2023,
#   'authors': ['Bernardo Estevam', 'Carlos A. Matos', 'Clévio Nóbrega'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2fa048127b5236c08aad055f921f0f172/dblp',
#   'text': 'PolyQ Database - an integrated database on polyglutamine diseases.'},
#  {'title': 'MEMOSys 2.0: an update of the bioinformatics database for genome-scale models and genomic data.',
#   'id': 'https://www.bibsonomy.org/bibtex/23798a8113a8f076a1b188ca98eb5a9d5/karthikraman',
#   'type': 'Publication',
#   'url': 'http://view.ncbi.nlm.nih.gov/pubmed/24532766',
#   'year': 2014,
#   'authors': ['Stephan Pabinger',
#    'Rene Snajder',
#    'Timo Hardiman',
#    'Michaela Willi',
#    'Andreas Dander',
#    'Zlatko Trajanoski'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/23798a8113a8f076a1b188ca98eb5a9d5/karthikraman',
#   'text': 'MEMOSys 2.0: an update of the bioinformatics database for genome-scale models and genomic data.'},
#  {'title': 'An introduction to database systems',
#   'id': 'https://www.bibsonomy.org/bibtex/27f49dd238fa7ce88cbd91004b080ef64/vivion',
#   'type': 'Publication',
#   'url': 'http://www.amazon.com/Introduction-Database-Systems-8th/dp/0321197844',
#   'year': 2004,
#   'authors': ['C. J Date'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/27f49dd238fa7ce88cbd91004b080ef64/vivion',
#   'text': 'An introduction to database systems'},
#  {'title': 'DBGET/LinkDB: an integrated database retrieval system',
#   'id': 'https://www.bibsonomy.org/bibtex/2a7c165d1f79c89f55ff28d2cb9d0019c/artheibault',
#   'type': 'Publication',
#   'url': 'http://psb.stanford.edu/psb-online/proceedings/psb98/abstracts/p683.html',
#   'year': 1998,
#   'authors': ['W. Fujibuchi',
#    'S. Goto',
#    'H. Migimatsu',
#    'I. Uchiyama',
#    'A. Ogiwara',
#    'Y. Akiyama',
#    'M. Kanehisa'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2a7c165d1f79c89f55ff28d2cb9d0019c/artheibault',
#   'text': 'DBGET/LinkDB: an integrated database retrieval system'},
#  {'title': 'Introduction to Database Systems, An (8th Edition)',
#   'id': 'https://www.bibsonomy.org/bibtex/265848417b2c10b9e8241cce148763e63/mksivana',
#   'type': 'Publication',
#   'url': 'http://www.amazon.com/Introduction-Database-Systems-C-J-Date/dp/0321197844%3FSubscriptionId%3D192BW6DQ43CK9FN0ZGG2%26tag%3Dws%26linkCode%3Dxm2%26camp%3D2025%26creative%3D165953%26creativeASIN%3D0321197844',
#   'year': 2003,
#   'authors': ['C.J. Date'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/265848417b2c10b9e8241cce148763e63/mksivana',
#   'text': 'Introduction to Database Systems, An (8th Edition)'},
#  {'title': 'Beginning Database Design Solutions (Wrox Programmer to Programmer)',
#   'id': 'https://www.bibsonomy.org/bibtex/2b1532af1f47c7afdb576b95a0a9c5517/mksivana',
#   'type': 'Publication',
#   'url': 'http://www.amazon.com/Beginning-Database-Design-Solutions-Programmer/dp/0470385499%3FSubscriptionId%3D192BW6DQ43CK9FN0ZGG2%26tag%3Dws%26linkCode%3Dxm2%26camp%3D2025%26creative%3D165953%26creativeASIN%3D0470385499',
#   'year': 2008,
#   'authors': ['Rod Stephens'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2b1532af1f47c7afdb576b95a0a9c5517/mksivana',
#   'text': 'Beginning Database Design Solutions (Wrox Programmer to Programmer)'},
#  {'title': 'SABIO-RK--database for biochemical reaction kinetics.',
#   'id': 'https://www.bibsonomy.org/bibtex/2c054e549e878e3d9404cbecdbeaad576/karthikraman',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1093/nar/gkr1046',
#   'year': 2012,
#   'authors': ['Ulrike Wittig',
#    'Renate Kania',
#    'Martin Golebiewski',
#    'Maja Rey',
#    'Lei Shi',
#    'Lenneke Jong',
#    'Enkhjargal Algaa',
#    'Andreas Weidemann',
#    'Heidrun Sauer-Danzwith',
#    'Saqib Mir',
#    'Olga Krebs',
#    'Meik Bittkowski',
#    'Elina Wetsch',
#    'Isabel Rojas',
#    'Wolfgang Müller'],
#   'doi': '10.1093/nar/gkr1046',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2c054e549e878e3d9404cbecdbeaad576/karthikraman',
#   'text': 'SABIO-RK--database for biochemical reaction kinetics.'},
#  {'title': 'Heterogeneous database integration in biomedicine.',
#   'id': 'https://www.bibsonomy.org/bibtex/2710d023013e81830ace8a7920b7a8ac1/neilernst',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1006/jbin.2001.1024',
#   'year': 2001,
#   'authors': ['W. Sujansky'],
#   'doi': '10.1006/jbin.2001.1024',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2710d023013e81830ace8a7920b7a8ac1/neilernst',
#   'text': 'Heterogeneous database integration in biomedicine.'},
#  {'title': 'Human Protein Reference Database--2009 update.',
#   'id': 'https://www.bibsonomy.org/bibtex/260921811a03b42c976a31094c5877e08/karthikraman',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1093/nar/gkn892',
#   'year': 2009,
#   'authors': ['T. S. K. Prasad',
#    'Renu Goel',
#    'Kumaran Kandasamy',
#    'Shivakumar Keerthikumar',
#    'Sameer Kumar',
#    'Suresh Mathivanan',
#    'Deepthi Telikicherla',
#    'Rajesh Raju',
#    'Beema Shafreen',
#    'Abhilash Venugopal',
#    'Lavanya Balakrishnan',
#    'Arivusudar Marimuthu',
#    'Sutopa Banerjee',
#    'Devi S. Somanathan',
#    'Aimy Sebastian',
#    'Sandhya Rani',
#    'Somak Ray',
#    'C. J. Harrys Kishore',
#    'Sashi Kanth',
#    'Mukhtar Ahmed',
#    'Manoj K. Kashyap',
#    'Riaz Mohmood',
#    'Y. L. Ramachandra',
#    'V. Krishna',
#    'Abdul A. Rahiman',
#    'Sujatha Mohan',
#    'Prathibha Ranganathan',
#    'Subhashri Ramabadran',
#    'Raghothama Chaerkady',
#    'Akhilesh Pandey'],
#   'doi': '10.1093/nar/gkn892',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/260921811a03b42c976a31094c5877e08/karthikraman',
#   'text': 'Human Protein Reference Database--2009 update.'},
#  {'title': 'Coronavirus Immunotherapeutic Consortium Database.',
#   'id': 'https://www.bibsonomy.org/bibtex/2414a4dabcdd032b866640600b45ffde4/dblp',
#   'type': 'Publication',
#   'url': 'http://dblp.uni-trier.de/db/journals/biodb/biodb2023.html#MahitaHGSLHDLKPBMOAOVGMKHKAGBTGBG23',
#   'year': 2023,
#   'authors': ['Jarjapu Mahita',
#    'Brendan Ha',
#    'Anais Gambiez',
#    'Sharon L. Schendel',
#    'Haoyang Li',
#    'Kathryn M. Hastie',
#    'S. Moses Dennison',
#    'Kan Li',
#    'Natalia Kuzmina',
#    'Sivakumar Periasamy',
#    'Alexander Bukreyev',
#    'Jennifer E. Munt',
#    'Mary Osei-Twum',
#    'Caroline Atyeo',
#    'James A. Overton',
#    'Randi Vita',
#    'Hector Guzman-Orozco',
#    'Marcus Mendes',
#    'Mari Kojima',
#    'Peter J. Halfmann',
#    'Yoshihiro Kawaoka',
#    'Galit Alter',
#    'Luc Gagnon',
#    'Ralph S. Baric',
#    'Georgia D. Tomaras',
#    'Tim Germann',
#    'Daniel Bedinger',
#    'Jason A. Greenbaum',
#    'Erica Ollmann Saphire',
#    'Bjoern Peters'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2414a4dabcdd032b866640600b45ffde4/dblp',
#   'text': 'Coronavirus Immunotherapeutic Consortium Database.'},
#  {'title': 'Properties of geothermal fluids in Switzerland: A new interactive database',
#   'id': 'https://www.bibsonomy.org/bibtex/27ef9235f5377a8f379f36449b52798ee/thorade',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1016/j.geothermics.2008.07.001',
#   'year': 2008,
#   'authors': ['Romain Sonney', 'François-D. Vuataz'],
#   'doi': '10.1016/j.geothermics.2008.07.001',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/27ef9235f5377a8f379f36449b52798ee/thorade',
#   'text': 'Properties of geothermal fluids in Switzerland: A new interactive database'},
#  {'title': 'Autoinhibited Protein Database: a curated database of autoinhibitory domains and their autoinhibition mechanisms.',
#   'id': 'https://www.bibsonomy.org/bibtex/244e9d39cefe1ca2efc46b43bf4bf0515/dblp',
#   'type': 'Publication',
#   'url': 'http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#ChoLKSHLPTKVBPLGKN24',
#   'year': 2024,
#   'authors': ['Daeahn Cho',
#    'Hyang-Mi Lee',
#    'Ji Ah Kim',
#    'Jae Gwang Song',
#    'Su hee Hwang',
#    'Bomi Lee',
#    'Jinsil Park',
#    'Kha Mong Tran',
#    'Jiwon Kim',
#    'Phuong Ngoc Lam Vo',
#    'Jooeun Bae',
#    'Teerapat Pimt',
#    'Kangseok Lee',
#    'Jörg Gsponer',
#    'Hyung Wook Kim',
#    'Dokyun Na'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/244e9d39cefe1ca2efc46b43bf4bf0515/dblp',
#   'text': 'Autoinhibited Protein Database: a curated database of autoinhibitory domains and their autoinhibition mechanisms.'},
#  {'title': 'Integrating compression and execution in column-oriented database systems',
#   'id': 'https://www.bibsonomy.org/bibtex/299c75c63dbe821e399a559d5859e5790/jhammerb',
#   'type': 'Publication',
#   'url': 'http://portal.acm.org/citation.cfm?id=1142473.1142548',
#   'year': 2006,
#   'authors': ['Daniel Abadi', 'Samuel Madden', 'Miguel Ferreira'],
#   'doi': 'http://doi.acm.org/10.1145/1142473.1142548',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/299c75c63dbe821e399a559d5859e5790/jhammerb',
#   'text': 'Integrating compression and execution in column-oriented database systems'},
#  {'title': 'Update of TTD: Therapeutic Target Database.',
#   'id': 'https://www.bibsonomy.org/bibtex/25b096e8ed6040b5c5136e9177854aff3/karthikraman',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1093/nar/gkp1014',
#   'year': 2010,
#   'authors': ['Feng Zhu',
#    'BuCong Han',
#    'Pankaj Kumar',
#    'XiangHui Liu',
#    'XiaoHua Ma',
#    'Xiaona Wei',
#    'Lu Huang',
#    'YangFan Guo',
#    'LianYi Han',
#    'ChanJuan Zheng',
#    'YuZong Chen'],
#   'doi': '10.1093/nar/gkp1014',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/25b096e8ed6040b5c5136e9177854aff3/karthikraman',
#   'text': 'Update of TTD: Therapeutic Target Database.'},
#  {'title': 'A Analysis of Different Type of Advance database System For Data Mining Based on Basic Factor',
#   'id': 'https://www.bibsonomy.org/bibtex/28cf327f27489aae5ae55bb5625868945/ijritcc',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.17762/ijritcc2321-8169.150206',
#   'year': 2015,
#   'authors': ['Kamlesh Kumar Pandey',
#    'Rajat Kumar Yadu',
#    'Anshu Dwivedi',
#    'Pradeep Kumar Shukla'],
#   'doi': '10.17762/ijritcc2321-8169.150206',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/28cf327f27489aae5ae55bb5625868945/ijritcc',
#   'text': 'A Analysis of Different Type of Advance database System For Data Mining Based on Basic Factor'},
#  {'title': 'Strategic Database Security Management and Cybercrime Reduction among Youths in Information Technology Companies in Nigeria',
#   'id': 'https://www.bibsonomy.org/bibtex/27bb034bc5ccc279720df2d0a1f53bcba/ijtsrd',
#   'type': 'Publication',
#   'url': 'https://www.ijtsrd.com/management/strategic-management/47643/strategic-database-security-management-and-cybercrime-reduction-among-youths-in-information-technology-companies-in-nigeria/agbeche-aaron',
#   'year': 2021,
#   'authors': ['Agbeche Aaron | Elechi Bobby Chime | Okechukwu Prince Jumbo'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/27bb034bc5ccc279720df2d0a1f53bcba/ijtsrd',
#   'text': 'Strategic Database Security Management and Cybercrime Reduction among Youths in Information Technology Companies in Nigeria'},
#  {'title': 'VFDB: a reference database for bacterial virulence factors.',
#   'id': 'https://www.bibsonomy.org/bibtex/2a823bcdc4890fc93dfff20ec10d5810b/karthikraman',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1093/nar/gki008',
#   'year': 2005,
#   'authors': ['Lihong Chen',
#    'Jian Yang',
#    'Jun Yu',
#    'Zhijian Yao',
#    'Lilian Sun',
#    'Yan Shen',
#    'Qi Jin'],
#   'doi': '10.1093/nar/gki008',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2a823bcdc4890fc93dfff20ec10d5810b/karthikraman',
#   'text': 'VFDB: a reference database for bacterial virulence factors.'},
#  {'title': 'Human immunodeficiency virus type 1, human protein interaction database at NCBI',
#   'id': 'https://www.bibsonomy.org/bibtex/225f0ed2bbba34e4efc60c35caff70351/wnpxrz',
#   'type': 'Publication',
#   'url': 'http://nar.oxfordjournals.org/cgi/content/abstract/37/suppl_1/D417',
#   'year': 2009,
#   'authors': ['William Fu',
#    'Brigitte E. Sanders-Beer',
#    'Kenneth S. Katz',
#    'Donna R. Maglott',
#    'Kim D. Pruitt',
#    'Roger G. Ptak'],
#   'doi': '10.1093/nar/gkn708',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/225f0ed2bbba34e4efc60c35caff70351/wnpxrz',
#   'text': 'Human immunodeficiency virus type 1, human protein interaction database at NCBI'},
#  {'title': 'A prospective multicentre otology database',
#   'id': 'https://www.bibsonomy.org/bibtex/25f551a2372225fbca2bae05c30bb2e20/stevenarild',
#   'type': 'Publication',
#   'url': 'http://www.ncbi.nlm.nih.gov.ep.fjernadgang.kb.dk/pubmed/17245068',
#   'year': 2007,
#   'authors': ['M Yung', 'P v Heyning'],
#   'doi': '10.1159/000098856',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/25f551a2372225fbca2bae05c30bb2e20/stevenarild',
#   'text': 'A prospective multicentre otology database'},
#  {'title': 'Autophagy3D: a comprehensive autophagy structure database.',
#   'id': 'https://www.bibsonomy.org/bibtex/2e555ce98e627ba663ccf8ced1e24ee23/dblp',
#   'type': 'Publication',
#   'url': 'http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#NehaCFGAT24',
#   'year': 2024,
#   'authors': [' Neha',
#    'Jesu Castin',
#    'Saman Fatihi',
#    'Deepanshi Gahlot',
#    'Akanksha Arun',
#    'Lipi Thukral'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2e555ce98e627ba663ccf8ced1e24ee23/dblp',
#   'text': 'Autophagy3D: a comprehensive autophagy structure database.'},
#  {'title': 'HOFE: an interactive forensic entomological database.',
#   'id': 'https://www.bibsonomy.org/bibtex/214b0484f7ece5d86b1ef302a79eaf2a4/dblp',
#   'type': 'Publication',
#   'url': 'http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#LiuQLJMLHCM24',
#   'year': 2024,
#   'authors': ['Mandie Liu',
#    'Yihong Qu',
#    'Yifei Luo',
#    'Binta J. J. Jallow',
#    'Yuting Ma',
#    'Afito Luciano',
#    'Jingjing Huang',
#    'Jifeng Cai',
#    'Fanming Meng'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/214b0484f7ece5d86b1ef302a79eaf2a4/dblp',
#   'text': 'HOFE: an interactive forensic entomological database.'},
#  {'title': 'SEPDB: a database of secreted proteins.',
#   'id': 'https://www.bibsonomy.org/bibtex/29775f21b89228d7b629530b347af0ef8/dblp',
#   'type': 'Publication',
#   'url': 'http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#WangRGLBZZCZ24',
#   'year': 2024,
#   'authors': ['Ruiqing Wang',
#    'Chao Ren',
#    'Tian Gao',
#    'Hao Li',
#    'Xiaochen Bo',
#    'Dahai Zhu',
#    'Dan Zhang',
#    'Hebing Chen',
#    'Yong Zhang'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/29775f21b89228d7b629530b347af0ef8/dblp',
#   'text': 'SEPDB: a database of secreted proteins.'},
#  {'title': 'GMMID: genetically modified mice information database.',
#   'id': 'https://www.bibsonomy.org/bibtex/22f200183a4d3e5f59ccc836adfa8ac49/dblp',
#   'type': 'Publication',
#   'url': 'http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#XuFCXXCZWZCZDJLCZLGHLYJ24',
#   'year': 2024,
#   'authors': ['Menglin Xu',
#    'Minghui Fang',
#    'Qiyang Chen',
#    'Wenjun Xiao',
#    'Zhixuan Xu',
#    'Bao Cai',
#    'Zhenyang Zhao',
#    'Tao Wang',
#    'Zhu Zhu',
#    'Yingshan Chen',
#    'Yue Zhu',
#    'Mingzhou Dai',
#    'Tiancheng Jiang',
#    'Xinyi Li',
#    'Siuwing Chun',
#    'Runhua Zhou',
#    'Yafei Li',
#    'Yueyue Gou',
#    'Jingjing He',
#    'Lin Luo',
#    'Linlin You',
#    'Xuan Jiang'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/22f200183a4d3e5f59ccc836adfa8ac49/dblp',
#   'text': 'GMMID: genetically modified mice information database.'},
#  {'title': 'TRY – a global database of plant traits',
#   'id': 'https://www.bibsonomy.org/bibtex/26ca2603105742c082347f1136dc8133f/schmidt2',
#   'type': 'Publication',
#   'url': 'http://dx.doi.org/10.1111/j.1365-2486.2011.02451.x',
#   'year': 2011,
#   'authors': ['J. KATTGE',
#    'S. DÍAZ',
#    'S. LAVOREL',
#    'I. C. PRENTICE',
#    'P. LEADLEY',
#    'G. BÖNISCH',
#    'E. GARNIER',
#    'M. WESTOBY',
#    'P. B. REICH',
#    'I. J. WRIGHT',
#    'J. H. C. CORNELISSEN',
#    'C. VIOLLE',
#    'S. P. HARRISON',
#    'P. M. Van BODEGOM',
#    'M. REICHSTEIN',
#    'B. J. ENQUIST',
#    'N. A. SOUDZILOVSKAIA',
#    'D. D. ACKERLY',
#    'M. ANAND',
#    'O. ATKIN',
#    'M. BAHN',
#    'T. R. BAKER',
#    'D. BALDOCCHI',
#    'R. BEKKER',
#    'C. C. BLANCO',
#    'B. BLONDER',
#    'W. J. BOND',
#    'R. BRADSTOCK',
#    'D. E. BUNKER',
#    'F. CASANOVES',
#    'J. CAVENDER-BARES',
#    'J. Q. CHAMBERS',
#    'F. S. CHAPIN III',
#    'J. CHAVE',
#    'D. COOMES',
#    'W. K. CORNWELL',
#    'J. M. CRAINE',
#    'B. H. DOBRIN',
#    'L. DUARTE',
#    'W. DURKA',
#    'J. ELSER',
#    'G. ESSER',
#    'M. ESTIARTE',
#    'W. F. FAGAN',
#    'J. FANG',
#    'F. FERNÁNDEZ-MÉNDEZ',
#    'A. FIDELIS',
#    'B. FINEGAN',
#    'O. FLORES',
#    'H. FORD',
#    'D. FRANK',
#    'G. T. FRESCHET',
#    'N. M. FYLLAS',
#    'R. V. GALLAGHER',
#    'W. A. GREEN',
#    'A. G. GUTIERREZ',
#    'T. HICKLER',
#    'S. I. HIGGINS',
#    'J. G. HODGSON',
#    'A. JALILI',
#    'S. JANSEN',
#    'C. A. JOLY',
#    'A. J. KERKHOFF',
#    'D. KIRKUP',
#    'K. KITAJIMA',
#    'M. KLEYER',
#    'S. KLOTZ',
#    'J. M. H. KNOPS',
#    'K. KRAMER',
#    'I. KÜHN',
#    'H. KUROKAWA',
#    'D. LAUGHLIN',
#    'T. D. LEE',
#    'M. LEISHMAN',
#    'F. LENS',
#    'T. LENZ',
#    'S. L. LEWIS',
#    'J. LLOYD',
#    'J. LLUSIÀ',
#    'F. LOUAULT',
#    'S. MA',
#    'M. D. MAHECHA',
#    'P. MANNING',
#    'T. MASSAD',
#    'B. E. MEDLYN',
#    'J. MESSIER',
#    'A. T. MOLES',
#    'S. C. MÜLLER',
#    'K. NADROWSKI',
#    'S. NAEEM',
#    'Ü. NIINEMETS',
#    'S. NÖLLERT',
#    'A. NÜSKE',
#    'R. OGAYA',
#    'J. OLEKSYN',
#    'V. G. ONIPCHENKO',
#    'Y. ONODA',
#    'J. ORDOÑEZ',
#    'G. OVERBECK',
#    'W. A. OZINGA',
#    'S. PATIÑO',
#    'S. PAULA',
#    'J. G. PAUSAS',
#    'J. PEÑUELAS',
#    'O. L. PHILLIPS',
#    'V. PILLAR',
#    'H. POORTER',
#    'L. POORTER',
#    'P. POSCHLOD',
#    'A. PRINZING',
#    'R. PROULX',
#    'A. RAMMIG',
#    'S. REINSCH',
#    'B. REU',
#    'L. SACK',
#    'B. SALGADO-NEGRET',
#    'J. SARDANS',
#    'S. SHIODERA',
#    'B. SHIPLEY',
#    'A. SIEFERT',
#    'E. SOSINSKI',
#    'J.-F. SOUSSANA',
#    'E. SWAINE',
#    'N. SWENSON',
#    'K. THOMPSON',
#    'P. THORNTON',
#    'M. WALDRAM',
#    'E. WEIHER',
#    'M. WHITE',
#    'S. WHITE',
#    'S. J. WRIGHT',
#    'B. YGUEL',
#    'S. ZAEHLE',
#    'A. E. ZANNE',
#    'C. WIRTH'],
#   'doi': '10.1111/j.1365-2486.2011.02451.x',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/26ca2603105742c082347f1136dc8133f/schmidt2',
#   'text': 'TRY – a global database of plant traits'},
#  {'title': "GabiPD: the GABI primary database--a plant integrative 'omics' database",
#   'id': 'https://www.bibsonomy.org/bibtex/228d1d6bf10bf9535cf975fa605d7fd04/schmidt2',
#   'type': 'Publication',
#   'url': 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2686513/?report=abstract',
#   'year': 2009,
#   'authors': ['D M Riaño-Pachón',
#    'A Nagel',
#    'J Neigenfind',
#    'R Wagner',
#    'R Basekow',
#    'E Weber',
#    'B Mueller-Roeber',
#    'S Diehl',
#    'B Kersten'],
#   'doi': '10.1093/nar/gkn611',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/228d1d6bf10bf9535cf975fa605d7fd04/schmidt2',
#   'text': "GabiPD: the GABI primary database--a plant integrative 'omics' database"},
#  {'title': 'An introduction to multilevel secure relational database management systems',
#   'id': 'https://www.bibsonomy.org/bibtex/251d33c392d126d4380d8366f09151b49/malte.wunsch',
#   'type': 'Publication',
#   'url': 'http://portal.acm.org/citation.cfm?id=1034932',
#   'year': 2004,
#   'authors': ['Walid Rjaibi'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/251d33c392d126d4380d8366f09151b49/malte.wunsch',
#   'text': 'An introduction to multilevel secure relational database management systems'},
#  {'title': 'The European ribosomal RNA database',
#   'id': 'https://www.bibsonomy.org/bibtex/212c5e8b4f2b0d1b934308106aab0d832/lutzm',
#   'type': 'Publication',
#   'url': 'http://www.ncbi.nlm.nih.gov/pubmed/14681368?dopt=Abstract',
#   'year': 2004,
#   'authors': ['J Wuyts', 'G Perrière', 'Y Van De Peer'],
#   'doi': '10.1093/nar/gkh065',
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/212c5e8b4f2b0d1b934308106aab0d832/lutzm',
#   'text': 'The European ribosomal RNA database'},
#  {'title': 'athisomiRDB: A comprehensive database of Arabidopsis isomiRs.',
#   'id': 'https://www.bibsonomy.org/bibtex/2a3fe70219a05115fa5a2a967fb1b01d7/dblp',
#   'type': 'Publication',
#   'url': 'http://dblp.uni-trier.de/db/journals/biodb/biodb2024.html#VivekASK24',
#   'year': 2024,
#   'authors': ['A. T. Vivek',
#    'Ajay Arya',
#    'Supriya P. Swain',
#    'Shailesh Kumar'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2a3fe70219a05115fa5a2a967fb1b01d7/dblp',
#   'text': 'athisomiRDB: A comprehensive database of Arabidopsis isomiRs.'},
#  {'title': 'PSINDB: the postsynaptic protein-protein interaction database.',
#   'id': 'https://www.bibsonomy.org/bibtex/23a7cfafb2923ceae382162beaba4bc73/dblp',
#   'type': 'Publication',
#   'url': 'http://dblp.uni-trier.de/db/journals/biodb/biodb2022.html#KalmanDMGD22',
#   'year': 2022,
#   'authors': ['Zsofia E. Kalman',
#    'Dániel Dudola',
#    'Bálint Mészáros',
#    'Zoltán Gáspári',
#    'Laszlo Dobson'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/23a7cfafb2923ceae382162beaba4bc73/dblp',
#   'text': 'PSINDB: the postsynaptic protein-protein interaction database.'},
#  {'title': 'The molecular biology database collection: 2004 update',
#   'id': 'https://www.bibsonomy.org/bibtex/264b95239e9a6bcc0b07b8af1b0c57f5c/tkirsten',
#   'type': 'Publication',
#   'url': 'http://www.pubmedcentral.nih.gov/articlerender.fcgi?artid=308877',
#   'year': 2004,
#   'authors': ['Michael Y. Galperin'],
#   'doi': None,
#   'query': 'database',
#   'editor': 'Jannik Ott',
# ...
#   'text': 'Graph-based text classification: learn from your neighbors'},
#  {'title': 'Text Classification Algorithms: A Survey',
#   'id': 'https://www.bibsonomy.org/bibtex/29dbc379143bea3265f667755071b9e0a/kk7nc',
#   'type': 'Publication',
#   'url': 'http://arxiv.org/abs/1904.08067',
#   'year': 2019,
#   'authors': ['Kamran Kowsari',
#    'Kiana Jafari Meimandi',
#    'Mojtaba Heidarysafa',
#    'Sanjana Mendu',
#    'Laura E. Barnes',
#    'Donald E. Brown'],
#   'doi': '10.3390/info10040150',
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/29dbc379143bea3265f667755071b9e0a/kk7nc',
#   'text': 'Text Classification Algorithms: A Survey'},
#  {'title': 'AN ELABORATION OF TEXT CATEGORIZATION AND AUTOMATIC TEXT CLASSIFICATION THROUGH MATHEMATICAL AND GRAPHICAL MODELLING',
#   'id': 'https://www.bibsonomy.org/bibtex/2dfc6b1e636dd7ba05a6efe9503cd8f58/micaela',
#   'type': 'Publication',
#   'url': '',
#   'year': 2015,
#   'authors': ['Ahmed Faraz'],
#   'doi': '10.5121/cseij.2015.5301',
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2dfc6b1e636dd7ba05a6efe9503cd8f58/micaela',
#   'text': 'AN ELABORATION OF TEXT CATEGORIZATION AND AUTOMATIC TEXT CLASSIFICATION THROUGH MATHEMATICAL AND GRAPHICAL MODELLING'},
#  {'title': 'Text stream processing: Tutorial',
#   'id': 'https://www.bibsonomy.org/bibtex/2b29f663d44e5176fc8cdd9c5cbc9aa78/render-project',
#   'type': 'Publication',
#   'url': 'http://www.slideshare.net/renderproject/text-stream-processing-tutorial-wims-2012',
#   'year': 2012,
#   'authors': ['Dunja Mladenic',
#    'Marko Grobelnik',
#    'Blaz Fortuna',
#    'Delia Rusu'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2b29f663d44e5176fc8cdd9c5cbc9aa78/render-project',
#   'text': 'Text stream processing: Tutorial'},
#  {'title': 'Flexible Ontology Population from Text: The OwlExporter',
#   'id': 'https://www.bibsonomy.org/bibtex/2a2ad0e5e4d42b1fff5b1bc874403c08e/renew',
#   'type': 'Publication',
#   'url': 'http://rene-witte.net/ontology-population-from-text-owlexporter-lrec2010',
#   'year': 2010,
#   'authors': ['René Witte', 'Ninus Khamis', 'Juergen Rilling'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2a2ad0e5e4d42b1fff5b1bc874403c08e/renew',
#   'text': 'Flexible Ontology Population from Text: The OwlExporter'},
#  {'title': 'Character Region Awareness for Text Detection',
#   'id': 'https://www.bibsonomy.org/bibtex/27c5e9992708ce31241ede32c9a875cf1/nmatsuk',
#   'type': 'Publication',
#   'url': 'http://arxiv.org/abs/1904.01941',
#   'year': 2019,
#   'authors': ['Youngmin Baek',
#    'Bado Lee',
#    'Dongyoon Han',
#    'Sangdoo Yun',
#    'Hwalsuk Lee'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/27c5e9992708ce31241ede32c9a875cf1/nmatsuk',
#   'text': 'Character Region Awareness for Text Detection'},
#  {'title': 'test',
#   'id': 'https://www.bibsonomy.org/bibtex/23e9cf0c8f2df790d6ea1f66cf5779561/dddddd',
#   'type': 'Publication',
#   'url': '',
#   'year': 1970,
#   'authors': [' test'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/23e9cf0c8f2df790d6ea1f66cf5779561/dddddd',
#   'text': 'test'},
#  {'title': 'Release on Waste Watchers: paperwork and storage and microfilm',
#   'id': 'https://www.bibsonomy.org/bibtex/22794c4f2b47fdbe6e09b7669fdc90237/cirrus',
#   'type': 'Publication',
#   'url': 'http://digital.library.pitt.edu/cgi-bin/t/text/text-idx?idno=AIS9830.09.02.0118;view=toc;c=thornnewsreleases',
#   'year': 1978,
#   'authors': [' ?'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/22794c4f2b47fdbe6e09b7669fdc90237/cirrus',
#   'text': 'Release on Waste Watchers: paperwork and storage and microfilm'},
#  {'title': 'Use of ontology-to-text relation for creating semantic annotation',
#   'id': 'https://www.bibsonomy.org/bibtex/2ec39da3084cf338e83b92563bcb18bb6/martin-zenker',
#   'type': 'Publication',
#   'url': 'http://doi.acm.org/10.1145/2383276.2383288',
#   'year': 2012,
#   'authors': ['Kamenka Staykova', 'Gennady Agre'],
#   'doi': '10.1145/2383276.2383288',
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2ec39da3084cf338e83b92563bcb18bb6/martin-zenker',
#   'text': 'Use of ontology-to-text relation for creating semantic annotation'},
#  {'title': 'XQuery 1.0 and XPath 2.0 Full-Text 1.0 Use Cases',
#   'id': 'https://www.bibsonomy.org/bibtex/22e7e1a5c005c4c8dd24cada364cfdc97/dret',
#   'type': 'Publication',
#   'url': '',
#   'year': 2008,
#   'authors': ['Sihem Amer-Yahia', 'Pat Case'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/22e7e1a5c005c4c8dd24cada364cfdc97/dret',
#   'text': 'XQuery 1.0 and XPath 2.0 Full-Text 1.0 Use Cases'},
#  {'title': 'Arbitrarily Oriented Scene Text Detection using SMSER and Connected component analysis',
#   'id': '5464',
#   'type': 'Publication',
#   'url': 'http://www.imperialjournals.com/index.php/IJIR/article/view/5464',
#   'year': 2017,
#   'authors': ['Parveen Sharma', 'Er. Anupam Garg'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': '5464',
#   'text': 'Arbitrarily Oriented Scene Text Detection using SMSER and Connected component analysis'},
#  {'title': 'Lexical cohesion computed by thesaural relations as an indicator of the structure of text',
#   'id': 'https://www.bibsonomy.org/bibtex/2f903aaf4d45f5f33c4e4709c208d9734/jil',
#   'type': 'Publication',
#   'url': 'http://portal.acm.org/citation.cfm?id=971740&dl=GUIDE&coll=GUIDE&CFID=78733227&CFTOKEN=35066520',
#   'year': 1991,
#   'authors': ['Jane Morris', 'Graeme Hirst'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2f903aaf4d45f5f33c4e4709c208d9734/jil',
#   'text': 'Lexical cohesion computed by thesaural relations as an indicator of the structure of text'},
#  {'title': 'Universal Language Model Fine-tuning for Text Classification',
#   'id': 'https://www.bibsonomy.org/bibtex/20281c13bb77e3d2588bd676d2c8ccaa9/schwemmlein',
#   'type': 'Publication',
#   'url': 'http://arxiv.org/abs/1801.06146',
#   'year': 2018,
#   'authors': ['Jeremy Howard', 'Sebastian Ruder'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/20281c13bb77e3d2588bd676d2c8ccaa9/schwemmlein',
#   'text': 'Universal Language Model Fine-tuning for Text Classification'},
#  {'title': 'An Efficient Method For Text And File Encryption For Secure Data Transmission Through Audio Steganography',
#   'id': 'https://www.bibsonomy.org/bibtex/29d39ebc47712b1d9ecdd9c8d069a9f52/ijtsrd',
#   'type': 'Publication',
#   'url': 'http://www.ijtsrd.com/engineering/computer-engineering/14562/an-efficient-method-for-text-and-file-encryption-for-secure-data-transmission-through-audio-steganography/dr-s-hemalatha',
#   'year': 2018,
#   'authors': ['Dr S Hemalatha | Androse | E Sharmili'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/29d39ebc47712b1d9ecdd9c8d069a9f52/ijtsrd',
#   'text': 'An Efficient Method For Text And File Encryption For Secure Data Transmission Through Audio Steganography'},
#  {'title': 'Sentiment-based text segmentation',
#   'id': 'https://www.bibsonomy.org/bibtex/25b6b703543d0b43785f0a6fe44824551/asmelash',
#   'type': 'Publication',
#   'url': 'http://ieeexplore.ieee.org/xpls/abs_all.jsp?arnumber=6632053&tag=1',
#   'year': 2013,
#   'authors': ['Costin-Gabriel Chiru', 'Asmelash Teka Hadgu'],
#   'doi': '10.1109/IcConSCS.2013.6632053',
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/25b6b703543d0b43785f0a6fe44824551/asmelash',
#   'text': 'Sentiment-based text segmentation'},
#  {'title': 'Adversarial Training Methods for Semi-Supervised Text Classification',
#   'id': 'https://www.bibsonomy.org/bibtex/249a3bda7edf1c04d4b39d5b77b96e306/daschloer',
#   'type': 'Publication',
#   'url': 'http://arxiv.org/abs/1605.07725',
#   'year': 2016,
#   'authors': ['Takeru Miyato', 'Andrew M. Dai', 'Ian Goodfellow'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/249a3bda7edf1c04d4b39d5b77b96e306/daschloer',
#   'text': 'Adversarial Training Methods for Semi-Supervised Text Classification'},
#  {'title': 'An extension of topic models for text classification: A term weighting approach',
#   'id': 'https://www.bibsonomy.org/bibtex/276d7846c4c6c2d0e7e70de0e30b470d2/schwemmlein',
#   'type': 'Publication',
#   'url': 'http://ieeexplore.ieee.org/xpl/articleDetails.jsp?arnumber=7072834&abstractAccess=no&userType=inst',
#   'year': 2015,
#   'authors': ['Seonggyu Lee', 'Jinho Kim', 'Sung-Hyon Myaeng'],
#   'doi': '10.1109/35021BIGCOMP.2015.7072834',
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/276d7846c4c6c2d0e7e70de0e30b470d2/schwemmlein',
#   'text': 'An extension of topic models for text classification: A term weighting approach'},
#  {'title': 'Evaluating text categorization',
#   'id': 'https://www.bibsonomy.org/bibtex/22e8f19bde0a73d96d16c071b2016073f/jaeschke',
#   'type': 'Publication',
#   'url': 'http://citeseerx.ist.psu.edu/viewdoc/download;jsessionid=FB1ECC14412DFFF631E7C0725D4DB3CC?doi=10.1.1.56.9675&rep=rep1&type=pdf',
#   'year': 1991,
#   'authors': ['David D. Lewis'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/22e8f19bde0a73d96d16c071b2016073f/jaeschke',
#   'text': 'Evaluating text categorization'},
#  {'title': 'Multi-class text categorization based on ŁDA\\ and \\SVM\\',
#   'id': 'https://www.bibsonomy.org/bibtex/2c723825cbb815b0ffc93bb408e96ee42/schwemmlein',
#   'type': 'Publication',
#   'url': 'http://www.sciencedirect.com/science/article/pii/S1877705811018674',
#   'year': 2011,
#   'authors': ['Kunlun Li', 'Jing Xie', 'Xue Sun', 'Yinghui Ma', 'Hui Bai'],
#   'doi': 'http://dx.doi.org/10.1016/j.proeng.2011.08.366',
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2c723825cbb815b0ffc93bb408e96ee42/schwemmlein',
#   'text': 'Multi-class text categorization based on ŁDA\\ and \\SVM\\'},
#  {'title': 'Model Higgs bundles in exceptional components of the\r\n  $Sp(4,R)$-character variety',
#   'id': 'https://www.bibsonomy.org/bibtex/25d5aeca2cd4773fc5948bb8cb392a5fb/simonechiarello',
#   'type': 'Publication',
#   'url': 'http://arxiv.org/abs/1805.10497',
#   'year': 2018,
#   'authors': ['Georgios Kydonakis'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/25d5aeca2cd4773fc5948bb8cb392a5fb/simonechiarello',
#   'text': 'Model Higgs bundles in exceptional components of the\r\n  $Sp(4,R)$-character variety'},
#  {'title': 'MusicLM: Generating Music From Text',
#   'id': 'https://www.bibsonomy.org/bibtex/2c64dac21a1a5d2459ca37f4b9d7efa60/annakrause',
#   'type': 'Publication',
#   'url': 'http://arxiv.org/abs/2301.11325',
#   'year': 2023,
#   'authors': ['Andrea Agostinelli',
#    'Timo I. Denk',
#    'Zalán Borsos',
#    'Jesse Engel',
#    'Mauro Verzetti',
#    'Antoine Caillon',
#    'Qingqing Huang',
#    'Aren Jansen',
#    'Adam Roberts',
#    'Marco Tagliasacchi',
#    'Matt Sharifi',
#    'Neil Zeghidour',
#    'Christian Frank'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2c64dac21a1a5d2459ca37f4b9d7efa60/annakrause',
#   'text': 'MusicLM: Generating Music From Text'},
#  {'title': 'An unsupervised model for text message normalization',
#   'id': 'https://www.bibsonomy.org/bibtex/25ffcde106e83f8a0ea825661c75864b8/zhenzhenx',
#   'type': 'Publication',
#   'url': 'http://portal.acm.org/citation.cfm?id=1642021&dl=#',
#   'year': 2009,
#   'authors': ['Paul Cook', 'Suzanne Stevenson'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/25ffcde106e83f8a0ea825661c75864b8/zhenzhenx',
#   'text': 'An unsupervised model for text message normalization'},
#  {'title': 'A robust algorithm for text string separation from mixed text/graphics\n\timages',
#   'id': 'https://www.bibsonomy.org/bibtex/20baf98dc4f9cbff3a9f331ec76899d80/cocus',
#   'type': 'Publication',
#   'url': '',
#   'year': 1988,
#   'authors': ['L.A. Fletcher', 'R. Kasturi'],
#   'doi': '10.1109/34.9112',
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/20baf98dc4f9cbff3a9f331ec76899d80/cocus',
#   'text': 'A robust algorithm for text string separation from mixed text/graphics\n\timages'},
#  {'title': 'Synchronic Diachronic Aspect of Lexic Semantic and Functional Features of Scientific Pedagogical Text of English',
#   'id': 'https://www.bibsonomy.org/bibtex/20c50fef0db4980b6df4c5efe8e95befc/ijtsrd',
#   'type': 'Publication',
#   'url': 'https://www.ijtsrd.com/humanities-and-the-arts/english/39851/synchronicdiachronic-aspect-of-lexicsemantic-and-functional-features-of-scientificpedagogical-text-of-english/sharipova-mekhriniso-shavkatovna',
#   'year': 2021,
#   'authors': ['Sharipova Mekhriniso Shavkatovna'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/20c50fef0db4980b6df4c5efe8e95befc/ijtsrd',
#   'text': 'Synchronic Diachronic Aspect of Lexic Semantic and Functional Features of Scientific Pedagogical Text of English'},
#  {'title': 'Recognizing of Text and Product Label from Hand Held Entity Intended for Visionless Persons',
#   'id': 'https://www.bibsonomy.org/bibtex/267e50cfcf39ec992fdedda85a4f7e68d/ijtsrd',
#   'type': 'Publication',
#   'url': 'https://www.ijtsrd.com/engineering/electronics-and-communication-engineering/39808/recognizing-of-text-and-product-label-from-hand-held-entity-intended-for-visionless-persons/arunkumar-v',
#   'year': 2021,
#   'authors': ['Arunkumar. V | Aswin M. D | Bhavan. S | Gopinath. V | Dr. Kishorekumar. A'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/267e50cfcf39ec992fdedda85a4f7e68d/ijtsrd',
#   'text': 'Recognizing of Text and Product Label from Hand Held Entity Intended for Visionless Persons'},
#  {'title': 'Discovering evolutionary theme patterns from text: an exploration of temporal text mining',
#   'id': 'https://www.bibsonomy.org/bibtex/223cafcbc0f4a06fe7071f8be01ccbdee/lillejul',
#   'type': 'Publication',
#   'url': 'http://portal.acm.org/citation.cfm?id=1081895',
#   'year': 2005,
#   'authors': ['Qiaozhu Mei', 'ChengXiang Zhai'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/223cafcbc0f4a06fe7071f8be01ccbdee/lillejul',
#   'text': 'Discovering evolutionary theme patterns from text: an exploration of temporal text mining'},
#  {'title': 'Exploring the Limits of Transfer Learning with a Unified Text-to-Text\r\n  Transformer',
#   'id': 'https://www.bibsonomy.org/bibtex/2701ad0bb796e58c22d41791ea1979f57/stdiff',
#   'type': 'Publication',
#   'url': 'http://arxiv.org/abs/1910.10683',
#   'year': 2019,
#   'authors': ['Colin Raffel',
#    'Noam Shazeer',
#    'Adam Roberts',
#    'Katherine Lee',
#    'Sharan Narang',
#    'Michael Matena',
#    'Yanqi Zhou',
#    'Wei Li',
#    'Peter J. Liu'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2701ad0bb796e58c22d41791ea1979f57/stdiff',
#   'text': 'Exploring the Limits of Transfer Learning with a Unified Text-to-Text\r\n  Transformer'},
#  {'title': 'Text-to-text semantic similarity for automatic short answer grading',
#   'id': 'https://www.bibsonomy.org/bibtex/2c94c49b17c57d5f485233e9d2b33cf22/jennymac',
#   'type': 'Publication',
#   'url': 'http://portal.acm.org/citation.cfm?id=1609067.1609130',
#   'year': 2009,
#   'authors': ['Michael Mohler', 'Rada Mihalcea'],
#   'doi': None,
#   'query': 'text',
#   'editor': 'Jannik Ott',
#   'docno': 'https://www.bibsonomy.org/bibtex/2c94c49b17c57d5f485233e9d2b33cf22/jennymac',
#   'text': 'Text-to-text semantic similarity for automatic short answer grading'},
#  ...]

# %%
index_folder_mult = "./index_mult"

fields=['docno', 'text', 'tags', 'description']

indexer_mult = pt.IterDictIndexer(index_folder_mult, meta={'docno': 200, 'text': 4096}, overwrite=True)
index_ref_mult = indexer_mult.index(df_dict)

print(f"path to our index: {index_ref_mult.toString()}")
# Out:
# 09:34:49.464 [ForkJoinPool-1-worker-1] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (https://www.bibsonomy.org/bibtex/2998392ade6025286fed26bb09fc3dfc0/bibgreen) - further warnings are suppressed
# 09:34:49.671 [ForkJoinPool-1-worker-1] WARN org.terrier.structures.indexing.Indexer -- Indexed 2 empty documents
# path to our index: ./index_mult/data.properties

# %%
index_mult = pt.IndexFactory.of(index_ref_mult)

# %%
print(index_mult.getCollectionStatistics().toString())
# Out:
# Number of documents: 3520
# Number of terms: 5033
# Number of postings: 23460
# Number of fields: 1
# Number of tokens: 24185
# Field names: [text]
# Positions:   false

# %%
search_engine_mult = pt.terrier.Retriever(index_mult, wmodel="TF_IDF")

# %%
res = search_engine_mult.search("intelligence")
res
# Out:
#    qid  docid                                              docno  rank  \
# 0    1    925  https://www.bibsonomy.org/bibtex/21a61a34d4984...     0
# 1    1   1447  https://www.bibsonomy.org/bibtex/2508ce3b4cfd8...     1
# 2    1   1234  https://www.bibsonomy.org/bibtex/2326beb667d4c...     2
# 3    1   1351  https://www.bibsonomy.org/bibtex/255165fc7f1f9...     3
# 4    1   1074  https://www.bibsonomy.org/bibtex/2934ad4d54596...     4
# 5    1   3011  https://www.bibsonomy.org/bibtex/2e3677666eee2...     5
# 6    1    502  https://www.bibsonomy.org/bibtex/2a9aeedc023b8...     6
# 7    1   3274  https://www.bibsonomy.org/bibtex/20bd599a1d3e4...     7
# 8    1   3396  https://www.bibsonomy.org/bibtex/2eb29bdfaeb62...     8
# 9    1    298  https://www.bibsonomy.org/bibtex/2e01c06213221...     9
# 10   1   1344  https://www.bibsonomy.org/bibtex/2a13a19576a30...    10
# 11   1   3364  https://www.bibsonomy.org/bibtex/28f08bb5a969f...    11
# 12   1    183  https://www.bibsonomy.org/bibtex/24174ad281bc2...    12
# 13   1   3504  https://www.bibsonomy.org/bibtex/217e640a5e9c6...    13
# 14   1    638  https://www.bibsonomy.org/bibtex/2dada3848a74e...    14
#
#        score         query
# 0   5.184718  intelligence
# 1   5.184718  intelligence
# 2   4.837320  intelligence
# 3   4.837320  intelligence
# 4   4.533552  intelligence
# 5   4.533552  intelligence
# 6   4.265681  intelligence
# 7   4.265681  intelligence
# 8   4.265681  intelligence
# 9   4.027699  intelligence
# 10  4.027699  intelligence
# 11  4.027699  intelligence
# 12  3.814868  intelligence
# 13  3.814868  intelligence
# 14  3.623401  intelligence

# %%
#save our data
pickle.dump(df_filtered, open("index_mult/df_publications.pkl", "wb"))

# %%
#install steamlit
# %pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /opt/anaconda3/lib/python3.12/site-packages (1.37.1)
# Requirement already satisfied: altair<6,>=4.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (8.2.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in /opt/anaconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
