# %%
import pandas as pd

# %%
df = pd.read_csv("data/Library_Usage.csv",low_memory=False, na_values="Null")

# %%
df
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                      Senior                5               0
# 1                       Adult                0               0
# 2                       Adult                0               0
# 3                     Welcome                1               1
# 4                      Senior                0               0
# ...                       ...              ...             ...
# 450354    Digital Access Card                0               0
# 450355    Digital Access Card                0               0
# 450356    Digital Access Card                0               0
# 450357    Digital Access Card                0               0
# 450358    Digital Access Card                0               0
#
#                 Age Range Home Library Definition Circulation Active Month  \
# 0       75 years and over                    Main                      Nov
# ...

# %%
len(df)
# Out:
# 450359

# %%
df.columns
# Out:
# Index(['Patron Type Definition', 'Total Checkouts', 'Total Renewals',
#        'Age Range', 'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Definition',
#        'Provided Email Address', 'Year Patron Registered',
#        'Within San Francisco County'],
#       dtype='object')

# %% [markdown]
# ## 2.1 Grundbegriffe (60 Min)
# Beantworte und diskutiere die folgenden Fragen konkret für den in Einheit 1 heruntergeladenen San Francisco Library Usage Datensatz. Notiere Deine Ergebnisse in Stichpunkte.

# %%
# Wie viele Merkmale besitzt der Datensatz?
df.shape
# Der Datensatz enthält 11 Merkmale.
# Out:
# (450359, 11)

# %%
# Wie groß ist die Stichprobengröße des Datensatzes?
len(df)
# Die Stichprobengröße des Datensatzes beträgt 450359.
# Out:
# 450359

# %%
# Wer oder was sind die Merkmalsträger?
# Bibliothekskunden der SF Public Library

# %%
# Von wann bis wann wurden die Daten erhoben?
df["Year Patron Registered"].describe()
# df["Year Patron Registered"].agg(['min', 'max'])
# Erster Datensatz 2003 erhoben, letzter 2023.
# Out:
# count    450359.000000
# mean       2016.094902
# std           6.278639
# min        2003.000000
# 25%        2012.000000
# 50%        2018.000000
# 75%        2021.000000
# max        2023.000000
# Name: Year Patron Registered, dtype: float64

# %%
# Wie lässt sich die Grundgesamtheit beschreiben? Handelt es sich um eine Vollerhebung?

# %%
# Welche Merkmale sind stetig? Welche diskret?

# %%
# Welchem Skalenniveau entsprechen die einzelnen Merkmale (Nominal-, Ordinal- oder Metrische Skala)?

# %%
# Enthält der Datensatz fehlende Werte?
df.isna().sum()
# Out:
# Patron Type Definition              0
# Total Checkouts                     0
# Total Renewals                      0
# Age Range                         510
# Home Library Definition            30
# Circulation Active Month        40317
# Circulation Active Year         40317
# Notice Preference Definition     3315
# Provided Email Address              0
# Year Patron Registered              0
# Within San Francisco County       221
# dtype: int64

# %%
# Handelt es sich um Querschnitts-, Längsschnitss- oder Paneldaten?
# Querschnittsdaten
