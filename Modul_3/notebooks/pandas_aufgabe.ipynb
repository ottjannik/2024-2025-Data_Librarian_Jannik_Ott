# %%
# import the library and give it a shorter name 'pd'
import pandas as pd

# create a dataframe by hand with two columns and three rows
df = pd.DataFrame({
        'month': [1, 2, 3, 4, 5, 6],
        'temperatur': [-12, 3, 9, 30, -2, 32]
})

# have a look at df
df

# print out some descriptive statistics
df.describe()
# Out:
#           month  temperatur
# count  6.000000    6.000000
# mean   3.500000   10.000000
# std    1.870829   17.674841
# min    1.000000  -12.000000
# 25%    2.250000   -0.750000
# 50%    3.500000    6.000000
# 75%    4.750000   24.750000
# max    6.000000   32.000000
