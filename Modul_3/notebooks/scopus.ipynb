# %%
import pandas as pd

# %%
df = pd.read_csv('../data/scopus_Export.csv')

# %%
df.head()
# Out:
#                                              Authors  \
# 0  Placke T.; Heckmann A.; Schmuch R.; Meister P....
# 1  Wagner J.N.; Häußler W.; Holderer O.; Bauer A....
# 2  Xiang G.; Tang Y.; Liu Z.; Zhu W.; Liu H.; Wan...
# 3  Rüßmann P.; Mahatha S.K.; Sessi P.; Valbuena M...
# 4  Clemente de Lima R.; Merdzhanova T.; Turan B.;...
#
#                                    Author full names  \
# 0  Placke, Tobias (54388181100); Heckmann, Andrea...
# 1  Wagner, Julia N. (57212430022); Häußler, Wolfg...
# 2  Xiang, Guolei (26668166200); Tang, Yan (572111...
# 3  Rüßmann, Philipp (57191038324); Mahatha, Sanjo...
# 4  Clemente de Lima, R. (57203851345); Merdzhanov...
#
#                                         Author(s) ID  \
# 0  54388181100; 57091473700; 55510092400; 5588837...
# 1  57212430022; 6602550047; 16064134400; 56673539...
# 2  26668166200; 57211191268; 55869701500; 5703459...
# 3  57191038324; 6508281646; 21740350400; 12785881...
# ...

# %%
df.columns
# Out:
# Index(['Authors', 'Author full names', 'Author(s) ID', 'Title', 'Year',
#        'Source title', 'Volume', 'Issue', 'Art. No.', 'Page start', 'Page end',
#        'Page count', 'Cited by', 'DOI', 'Link', 'Affiliations',
#        'Authors with affiliations', 'Abstract', 'Author Keywords',
#        'Index Keywords', 'Molecular Sequence Numbers', 'Chemicals/CAS',
#        'Tradenames', 'Manufacturers', 'Funding Details', 'Funding Texts',
#        'References', 'Correspondence Address', 'Editors', 'Publisher',
#        'Sponsors', 'Conference name', 'Conference date', 'Conference location',
#        'Conference code', 'ISSN', 'ISBN', 'CODEN', 'PubMed ID',
#        'Language of Original Document', 'Abbreviated Source Title',
#        'Document Type', 'Publication Stage', 'Open Access', 'Source', 'EID'],
#       dtype='object')

# %%
df['Document Type'].value_counts()
# Out:
# Document Type
# Article             2072
# Conference paper     321
# Review               120
# Book chapter          44
# Erratum               25
# Note                  15
# Letter                 8
# Editorial              7
# Short survey           5
# Data paper             1
# Book                   1
# Name: count, dtype: int64

# %%
len(df)
# Out:
# 2619

# %%
df['Cited by'].max()
# Out:
# 6221

# %%
df_subset = df[['Title', 'Authors', 'Source title', 'Cited by', 'Document Type']]

# %%
df_subset
# Out:
#                                                   Title  \
# 0     Perspective on Performance, Cost, and Technica...
# 1     Influence of concentration fluctuations on rel...
# 2                              Probing Ligand-Induce...
# 3     Towards microscopic control of the magnetic ex...
# 4     Voltage-matched thin film solar cells in 3-ter...
# ...                                                 ...
# 2614  Inhibitory interneurons and their circuit moti...
# 2615  Reconstruction of Three-Dimensional Aquifer He...
# 2616  Offsetting global warming-induced elevated gre...
# 2617                Colloidal dispersions in shear flow
# 2618  Expression, purification, and preliminary char...
#
#                                                 Authors  \
# 0     Placke T.; Heckmann A.; Schmuch R.; Meister P....
# 1     Wagner J.N.; Häußler W.; Holderer O.; Bauer A....
# 2     Xiang G.; Tang Y.; Liu Z.; Zhu W.; Liu H.; Wan...
# 3     Rüßmann P.; Mahatha S.K.; Sessi P.; Valbuena M...
# ...

# %%
df_subset['Source title'].value_counts()
# Out:
# Source title
# Physical Review B                               69
# Proceedings of Science                          44
# Atmospheric Chemistry and Physics               41
# Scientific Reports                              40
# Physical Review Letters                         37
#                                                 ..
# BMC Bioinformatics                               1
# Journal of Neurophysiology                       1
# Environmental Science and Pollution Research     1
# British Journal of Pharmacology                  1
# Process Biochemistry                             1
# Name: count, Length: 869, dtype: int64

# %%
df_subset.groupby('Source title')['Cited by'].sum()
# Out:
# Source title
# 10th International Workshop on the CKM Unitarity Triangle, CKM 2018                                                      0
# 2017 IEEE Nuclear Science Symposium and Medical Imaging Conference, NSS/MIC 2017 - Conference Proceedings                5
# 2018 14th IEEE International Conference on Solid-State and Integrated Circuit Technology, ICSICT 2018 - Proceedings      1
# 2018 17th International Conference on Ground Penetrating Radar, GPR 2018                                                17
# 2018 18th International Workshop on Junction Technology, IWJT 2018                                                       2
#                                                                                                                       ...
# mBio                                                                                                                    26
# ...

# %%
df_subset['Authors'].str.split(';').str[0]
# Out:
# 0                 Placke T.
# 1               Wagner J.N.
# 2                  Xiang G.
# 3                Rüßmann P.
# 4       Clemente de Lima R.
#                ...
# 2614           Feldmeyer D.
# 2615             Gueting N.
# 2616           Bamminger C.
# 2617          Lettinga M.P.
# 2618                Yang G.
# Name: Authors, Length: 2619, dtype: object

# %%
df['Page count'].mean()
# Out:
# 10.776687116564418

# %%
import seaborn as sns
sns.set_theme()

# %%
fg = sns.countplot(data=df, x='Language of Original Document', stat='percent')
fg.bar_label(fg.containers[0])
# Out:
# [Text(0, 0, '99.2745'), Text(0, 0, '0.725468')]
