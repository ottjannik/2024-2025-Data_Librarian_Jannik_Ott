# %%
import pandas as pd

# %%
df = pd.read_csv(./data/Library_Usage.csv)
# Out:
#   Cell In[9], line 1
#     df = pd.read_csv(./data/Library_Usage.csv)
#                      ^
# SyntaxError: invalid syntax
